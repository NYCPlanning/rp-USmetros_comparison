# %% [markdown]
# Author: Dana Chermesh, Regional Planning intern; NYC DCP
# Summer 2018
#
# ### _NYC DCP Regional Planning Division_
#
#
# # US Metros comparison
# ## _comparison of Population, Economics and Housing dynamics of the major 15 regions (CSA's) in the country, by the county level_
#
# ### _Notebook no.0: Geographies aggregations and geo-coding >> for later use in all the analysis aspects_
# All data were download from the [Tiger Line](https://www.census.gov/geo/maps-data/data/tiger-line.html) and the [American Fact Finder](https://factfinder.census.gov/faces/nav/jsf/pages/searchresults.xhtml?refresh=t)
#
# ----

# %% [markdown]
# # 0 - Imports

# %%
# from census import Census
# from us import states

import requests
import pandas as pd
import numpy as np

from __future__ import print_function, division
import matplotlib.pylab as pl
from pandas.tools.plotting import scatter_matrix
import seaborn as sns
sns.set_style('whitegrid')
import json
import geopandas as gpd
import fiona
import shapely

import statsmodels.formula.api as smf
import statsmodels.api as sm

# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %% [markdown]
# # 1 - Spatial Data acquisition -- shapefiles

# %% [markdown]
# ## 1.1 US 15 Major Metros .shp
# - downloaded from **[American Fact Finder](https://factfinder.census.gov/faces/nav/jsf/pages/searchresults.xhtml?refresh=t)**, saved search for counties within the 15 highest GDP share from US GDP Metros

# %%
pd.read_excel('../DCP internship/data/County_CSA_geo code list.xlsx')
# Out:
#       STCO  ST   CO  CSA
# 0     6001   6    1  488
# 1     6013   6   13  488
# 2     6037   6   37  348
# 3     6041   6   41  488
# 4     6055   6   55  488
# 5     6059   6   59  348
# 6     6065   6   65  348
# 7     6069   6   69  488
# 8     6071   6   71  348
# 9     6075   6   75  488
# 10    6077   6   77  488
# 11    6081   6   81  488
# 12    6085   6   85  488
# 13    6087   6   87  488
# 14    6095   6   95  488
# 15    6097   6   97  488
# 16    6111   6  111  348
# 17    8001   8    1  216
# 18    8005   8    5  216
# 19    8013   8   13  216
# 20    8014   8   14  216
# 21    8019   8   19  216
# 22    8031   8   31  216
# 23    8035   8   35  216
# 24    8039   8   39  216
# 25    8047   8   47  216
# 26    8059   8   59  216
# 27    8093   8   93  216
# 28    8123   8  123  216
# 29    9015   9   15  148
# ..     ...  ..  ...  ...
# 245   9009   9    9  408
# 246  34003  34    3  408
# 247  34013  34   13  408
# 248  34017  34   17  408
# 249  34019  34   19  408
# 250  34021  34   21  408
# 251  34023  34   23  408
# 252  34025  34   25  408
# 253  34027  34   27  408
# 254  34029  34   29  408
# 255  34031  34   31  408
# 256  34035  34   35  408
# 257  34037  34   37  408
# 258  34039  34   39  408
# 259  34041  34   41  408
# 260  36005  36    5  408
# 261  36027  36   27  408
# 262  36047  36   47  408
# 263  36059  36   59  408
# 264  36061  36   61  408
# 265  36071  36   71  408
# 266  36079  36   79  408
# 267  36081  36   81  408
# 268  36085  36   85  408
# 269  36087  36   87  408
# 270  36103  36  103  408
# 271  36105  36  105  408
# 272  36111  36  111  408
# 273  36119  36  119  408
# 274  40013  40   13  206
#
# [275 rows x 4 columns]

# %%
USmetros = gpd.GeoDataFrame.from_file('../DCP internship/05000.shp')
print(USmetros.shape)
USmetros.head()
# Out:
# (277, 9)
#            GEO_ID STATE COUNTY          NAME    LSAD    SHAPE_AREA  \
# 0  0500000US04013    04    013      Maricopa  County  3.432456e+10
# 1  0500000US04021    04    021         Pinal  County  1.980515e+10
# 2  0500000US06001    06    001       Alameda  County  3.124167e+09
# 3  0500000US06013    06    013  Contra Costa  County  3.158013e+09
# 4  0500000US06037    06    037   Los Angeles  County  1.561232e+10
#
#        SHAPE_LEN  STCO                                           geometry
# 0  951872.150986     0  POLYGON ((-12616263.466 4016946.415700004, -12...
# 1  696888.142939     0  POLYGON ((-12490462.7566 3887572.943000004, -1...
# 2  305860.973251     0  POLYGON ((-13618345.0421 4551161.905000001, -1...
# 3  300016.092481     0  POLYGON ((-13628818.5334 4574539.895900004, -1...
# 4  781150.181506     0  (POLYGON ((-13240429.4019 4038872.710100003, -...

# %%
USmetros.crs
# Out:
# {'init': 'epsg:3857'}

# %% [markdown]
# ## _Sullivan County in New-York Region (36105) is missing in this dataset!!_
#  ** Due to projection differences when combining Sullivan county to the US metros dataset, for the first phase of this analysis mapping NYC metro will show the 34 counties without Sullivan.

# %%
# USmetros['STCOzip']=list(zip(USmetros.STATE, USmetros.COUNTY))
USmetros['STCO'] = USmetros['GEO_ID'].map(lambda x: x[-5:])
USmetros = USmetros.drop(['STATE', 'COUNTY', 'GEO_ID', 'LSAD'], axis=1)

print(USmetros.shape)
USmetros.head()
# Out:
# (277, 5)
#            NAME    SHAPE_AREA      SHAPE_LEN   STCO  \
# 0      Maricopa  3.432456e+10  951872.150986  04013
# 1         Pinal  1.980515e+10  696888.142939  04021
# 2       Alameda  3.124167e+09  305860.973251  06001
# 3  Contra Costa  3.158013e+09  300016.092481  06013
# 4   Los Angeles  1.561232e+10  781150.181506  06037
#
#                                             geometry
# 0  POLYGON ((-12616263.466 4016946.415700004, -12...
# 1  POLYGON ((-12490462.7566 3887572.943000004, -1...
# 2  POLYGON ((-13618345.0421 4551161.905000001, -1...
# 3  POLYGON ((-13628818.5334 4574539.895900004, -1...
# 4  (POLYGON ((-13240429.4019 4038872.710100003, -...

# %%
USmetros.columns
# Out:
# Index(['NAME', 'SHAPE_AREA', 'SHAPE_LEN', 'STCO', 'geometry'], dtype='object')

# %%
fig = pl.figure(figsize=(20,10))
ax = fig.add_subplot(111)
USmetros.plot(ax=ax, color='#EDFF78', edgecolor='k', linewidth=.2, alpha=0.8)
tmp = ax.axis('off')

# %% [markdown]
# ## 1.2 US CSAs

# %%
allCSA = gpd.GeoDataFrame.from_file('../DCP internship/cb_2017_us_csa_500k/cb_2017_us_csa_500k.shp')
print(allCSA.shape)
allCSA.head()
# Out:
# (174, 8)
#   CSAFP      AFFGEOID GEOID                                            NAME  \
# 0   450  330M300US450   450                  Raleigh-Durham-Chapel Hill, NC
# 1   544  330M300US544   544                        Victoria-Port Lavaca, TX
# 2   324  330M300US324   324                       Lake Charles-Jennings, LA
# 3   548  330M300US548   548  Washington-Baltimore-Arlington, DC-MD-VA-WV-PA
# 4   268  330M300US268   268       Greensboro--Winston-Salem--High Point, NC
#
#   LSAD        ALAND      AWATER  \
# 0   M0  14270829773   301833048
# 1   M0   5804050524  1398360729
# 2   M0   7771400431  1784449473
# 3   M0  32712037570  5208979324
# 4   M0  12845012068   188816451
#
#                                             geometry
# 0  POLYGON ((-79.554816 35.547456, -79.5540379999...
# 1  (POLYGON ((-96.77208399999999 28.421988, -96.7...
# 2  POLYGON ((-93.929208 29.802952, -93.9279919999...
# 3  (POLYGON ((-76.065444 38.129795, -76.064612999...
# 4  POLYGON ((-80.973643 36.453474, -80.968289 36....

# %%
fig = pl.figure(figsize=(20,10))
ax = fig.add_subplot(111)
allCSA.plot(ax=ax, color='grey', edgecolor='k',linewidth=.6, alpha=0.08)

ax.axis('off')

allCSA = allCSA.drop(['geometry'], axis=1)
print(allCSA.shape)
allCSA.head()
# Out:
# (174, 7)
#   CSAFP      AFFGEOID GEOID                                            NAME  \
# 0   450  330M300US450   450                  Raleigh-Durham-Chapel Hill, NC
# 1   544  330M300US544   544                        Victoria-Port Lavaca, TX
# 2   324  330M300US324   324                       Lake Charles-Jennings, LA
# 3   548  330M300US548   548  Washington-Baltimore-Arlington, DC-MD-VA-WV-PA
# 4   268  330M300US268   268       Greensboro--Winston-Salem--High Point, NC
#
#   LSAD        ALAND      AWATER
# 0   M0  14270829773   301833048
# 1   M0   5804050524  1398360729
# 2   M0   7771400431  1784449473
# 3   M0  32712037570  5208979324
# 4   M0  12845012068   188816451

# %% [markdown]
# ## 1.3 All US Counties .shp for assigning Counties to CSAs

# %%
AllCounties = gpd.GeoDataFrame.from_file('../DCP internship/tl_2017_us_county/tl_2017_us_county.shp')
AllCounties = AllCounties[['GEOID', 'NAME', 'MTFCC', 'CSAFP', 'geometry']]

print(type(AllCounties))
print(AllCounties.shape)
AllCounties.head()
# Out:
# <class 'geopandas.geodataframe.GeoDataFrame'>
# (3233, 5)
#    GEOID       NAME  MTFCC CSAFP  \
# 0  31039     Cuming  G4020
# 1  53069  Wahkiakum  G4020
# 2  35011    De Baca  G4020
# 3  31109  Lancaster  G4020   339
# 4  31129   Nuckolls  G4020
#
#                                             geometry
# 0  POLYGON ((-97.019516 42.004097, -97.019519 42....
# 1  POLYGON ((-123.436394 46.238197, -123.447592 4...
# 2  POLYGON ((-104.567387 33.997566, -104.567717 3...
# 3  POLYGON ((-96.91059899999999 40.958407, -96.91...
# 4  POLYGON ((-98.27366699999999 40.089399, -98.27...

# %%
AllCounties.crs
# Out:
# {'init': 'epsg:4269'}

# %%
AllCounties.crs = {'init' :'epsg:3857'}
AllCounties.crs
# Out:
# {'init': 'epsg:3857'}

# %%
AllCounties['CSAFP'].dtypes
# Out:
# dtype('O')

# %%
AllCounties['CSAFP'][AllCounties['GEOID'] == '36105'] = '408'

AllCounties[AllCounties['GEOID'] == '36105']
# Out:
#       GEOID      NAME  MTFCC CSAFP  \
# 1760  36105  Sullivan  G4020   408
#
#                                                geometry
# 1760  POLYGON ((-75.054131 41.73010499999999, -75.05...

# %%
AllCounties.shape
# Out:
# (3233, 5)

# %% [markdown]
# ### Merge with Major US counties .shp

# %%
print(type(USmetros))
# Out:
# <class 'geopandas.geodataframe.GeoDataFrame'>

# %%
type(USmetros.merge(AllCounties.iloc[:,:-1], on = 'NAME'))
# Out:
# geopandas.geodataframe.GeoDataFrame

# %%
USmetros = USmetros.merge(AllCounties.iloc[:,:-1], left_on = 'STCO', right_on = 'GEOID')
USmetros = USmetros.drop(['NAME_x', 'GEOID', 'MTFCC'], axis=1)
USmetros.columns = ['SHAPE_AREA', 'SHAPE_LEN', 'STCO', 'geometry', 'NAME', 'CSAFP']

print(type(USmetros))
print(USmetros.shape)
USmetros.head()
# Out:
# <class 'geopandas.geodataframe.GeoDataFrame'>
# (277, 6)
#      SHAPE_AREA      SHAPE_LEN   STCO  \
# 0  3.432456e+10  951872.150986  04013
# 1  1.980515e+10  696888.142939  04021
# 2  3.124167e+09  305860.973251  06001
# 3  3.158013e+09  300016.092481  06013
# 4  1.561232e+10  781150.181506  06037
#
#                                             geometry          NAME CSAFP
# 0  POLYGON ((-12616263.466 4016946.415700004, -12...      Maricopa
# 1  POLYGON ((-12490462.7566 3887572.943000004, -1...         Pinal
# 2  POLYGON ((-13618345.0421 4551161.905000001, -1...       Alameda   488
# 3  POLYGON ((-13628818.5334 4574539.895900004, -1...  Contra Costa   488
# 4  (POLYGON ((-13240429.4019 4038872.710100003, -...   Los Angeles   348

# %% [markdown]
# ### Merge with CSA .shp

# %%
CSAwCounties = USmetros.merge(allCSA, on = 'CSAFP')
CSAwCounties = CSAwCounties.drop(['SHAPE_LEN', 'AFFGEOID', 'GEOID', 'LSAD', 'ALAND', 'AWATER'], axis=1)
CSAwCounties.columns = ['SHAPE_AREA', 'STCO', 'geometry', 'County_name', 'CSA', 'CSA_name']

print(type(CSAwCounties))
print(CSAwCounties.shape)
print(CSAwCounties.geometry.name)
CSAwCounties.head()
# Out:
# <class 'geopandas.geodataframe.GeoDataFrame'>
# (274, 6)
# geometry
#      SHAPE_AREA   STCO                                           geometry  \
# 0  3.124167e+09  06001  POLYGON ((-13618345.0421 4551161.905000001, -1...
# 1  3.158013e+09  06013  POLYGON ((-13628818.5334 4574539.895900004, -1...
# 2  2.298070e+09  06041  (POLYGON ((-13694586.3189 4579361.395599999, -...
# 3  3.344885e+09  06055  POLYGON ((-13652937.1333 4664335.483199999, -1...
# 4  5.596080e+09  06069  POLYGON ((-13541348.2494 4424341.478500001, -1...
#
#     County_name  CSA                            CSA_name
# 0       Alameda  488  San Jose-San Francisco-Oakland, CA
# 1  Contra Costa  488  San Jose-San Francisco-Oakland, CA
# 2         Marin  488  San Jose-San Francisco-Oakland, CA
# 3          Napa  488  San Jose-San Francisco-Oakland, CA
# 4    San Benito  488  San Jose-San Francisco-Oakland, CA

# %%
AllCounties = AllCounties.drop(['MTFCC'], axis=1)
AllCounties.columns = ['STCO', 'County_name', 'CSA', 'geometry']

print(AllCounties.shape)
AllCounties.head()
# Out:
# (3233, 4)
#     STCO County_name  CSA                                           geometry
# 0  31039      Cuming       POLYGON ((-97.019516 42.004097, -97.019519 42....
# 1  53069   Wahkiakum       POLYGON ((-123.436394 46.238197, -123.447592 4...
# 2  35011     De Baca       POLYGON ((-104.567387 33.997566, -104.567717 3...
# 3  31109   Lancaster  339  POLYGON ((-96.91059899999999 40.958407, -96.91...
# 4  31129    Nuckolls       POLYGON ((-98.27366699999999 40.089399, -98.27...

# %% [markdown]
# ----
# # **Don't run these cells -- projection incompability!
# ### Adding miising county of NY region - county _Sullivan_

# %%
# Adding missing county of NY region - county Sullivan
CSAwCounties = pd.concat([CSAwCounties,AllCounties[AllCounties['STCO'] == '36105']], axis=0, ignore_index=True)

print(CSAwCounties.shape)
CSAwCounties.head()
# Out:
# (275, 7)
# /anaconda3/lib/python3.5/site-packages/ipykernel_launcher.py:2: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.
#    CSA                            CSA_name   County_name    SHAPE_AREA   STCO  \
# 0  488  San Jose-San Francisco-Oakland, CA       Alameda  3.124167e+09  06001
# 1  488  San Jose-San Francisco-Oakland, CA  Contra Costa  3.158013e+09  06013
# 2  488  San Jose-San Francisco-Oakland, CA         Marin  2.298070e+09  06041
# 3  488  San Jose-San Francisco-Oakland, CA          Napa  3.344885e+09  06055
# 4  488  San Jose-San Francisco-Oakland, CA    San Benito  5.596080e+09  06069
#
#      STCOzip                                           geometry
# 0  (06, 001)  POLYGON ((-13618345.0421 4551161.905000001, -1...
# 1  (06, 013)  POLYGON ((-13628818.5334 4574539.895900004, -1...
# 2  (06, 041)  (POLYGON ((-13694586.3189 4579361.395599999, -...
# 3  (06, 055)  POLYGON ((-13652937.1333 4664335.483199999, -1...
# 4  (06, 069)  POLYGON ((-13541348.2494 4424341.478500001, -1...

# %%
CSAwCounties[CSAwCounties['STCO'] == '36105']
# Out:
#      CSA CSA_name County_name  SHAPE_AREA   STCO STCOzip  \
# 274  408      NaN    Sullivan         NaN  36105     NaN
#
#                                               geometry
# 274  POLYGON ((-75.054131 41.73010499999999, -75.05...

# %%
CSAwCounties['geometry'][CSAwCounties['STCO'] == '36105'].area
# Out:
# 274    0.279299
# dtype: float64

# %%
# assigning values to NaNs

CSAwCounties['CSA_name'][CSAwCounties['STCO'] == '36105'] = 'New York-Newark, NY-NJ-CT-PA'
CSAwCounties['SHAPE_AREA'][CSAwCounties['STCO'] == '36105'] = CSAwCounties['geometry'][CSAwCounties['STCO'] == '36105'].area
CSAwCounties['STCOzip'][CSAwCounties['STCO'] == '36105'] = '(36, 105)'

CSAwCounties[CSAwCounties['STCO'] == '36105']
# Out:
# /anaconda3/lib/python3.5/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# /anaconda3/lib/python3.5/site-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   after removing the cwd from sys.path.
# /anaconda3/lib/python3.5/site-packages/ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """
#      CSA                      CSA_name County_name  SHAPE_AREA   STCO  \
# 274  408  New York-Newark, NY-NJ-CT-PA    Sullivan    0.279299  36105
#
#        STCOzip                                           geometry
# 274  (36, 105)  POLYGON ((-75.054131 41.73010499999999, -75.05...

# %% [markdown]
# ----
#
# # **RUN FROM HERE
#
# ### List of CSA's

# %%
print(len(CSAwCounties['CSA'].unique()))
print(CSAwCounties['CSA'].unique())
# Out:
# 15
# ['488' '348' '216' '408' '148' '428' '548' '370' '122' '176' '220' '378'
#  '206' '288' '500']

# %% [markdown]
# ### Reduce NY regionfrom 35 to 31 counties

# %%
NYreg = pd.read_excel('../DCP internship/31CR-CountyCodes.xlsx')
NYreg
# Out:
#     StCo_Str  StCo_Num   Co  Subreg1   Subreg2  \
# 0       9001      9001    1       CT        CT
# 1       9005      9005    5       CT        CT
# 2       9009      9009    9       CT        CT
# 3      34003     34003    3    NJ In  North NJ
# 4      34013     34013   13    NJ In  North NJ
# 5      34017     34017   17    NJ In  North NJ
# 6      34019     34019   19   NJ Out  North NJ
# 7      34021     34021   21   NJ Out  North NJ
# 8      34023     34023   23    NJ In  North NJ
# 9      34025     34025   25   NJ Out  North NJ
# 10     34027     34027   27    NJ In  North NJ
# 11     34029     34029   29   NJ Out  North NJ
# 12     34031     34031   31    NJ In  North NJ
# 13     34035     34035   35    NJ In  North NJ
# 14     34037     34037   37   NJ Out  North NJ
# 15     34039     34039   39    NJ In  North NJ
# 16     34041     34041   41   NJ Out  North NJ
# 17     36005     36005    5      NYC       NYC
# 18     36027     36027   27  Mid Hud        HV
# 19     36047     36047   47      NYC       NYC
# 20     36059     36059   59       LI        LI
# 21     36061     36061   61      NYC       NYC
# 22     36071     36071   71  Mid Hud        HV
# 23     36079     36079   79  Low Hud        HV
# 24     36081     36081   81      NYC       NYC
# 25     36085     36085   85      NYC       NYC
# 26     36087     36087   87  Low Hud        HV
# 27     36103     36103  103       LI        LI
# 28     36105     36105  105  Mid Hud        HV
# 29     36111     36111  111  Mid Hud        HV
# 30     36119     36119  119  Low Hud        HV
#
#                           StCo_Lbl         Co_lbl
# 0    Fairfield County, Connecticut      Fairfield
# 1   Litchfield County, Connecticut     Litchfield
# 2    New Haven County, Connecticut      New Haven
# 3        Bergen County, New Jersey         Bergen
# 4         Essex County, New Jersey          Essex
# 5        Hudson County, New Jersey         Hudson
# 6     Hunterdon County, New Jersey      Hunterdon
# 7        Mercer County, New Jersey         Mercer
# 8     Middlesex County, New Jersey      Middlesex
# 9      Monmouth County, New Jersey       Monmouth
# 10       Morris County, New Jersey         Morris
# 11        Ocean County, New Jersey          Ocean
# 12      Passaic County, New Jersey        Passaic
# 13     Somerset County, New Jersey       Somerset
# 14       Sussex County, New Jersey         Sussex
# 15        Union County, New Jersey          Union
# 16       Warren County, New Jersey         Warren
# 17          Bronx County, New York          Bronx
# 18       Dutchess County, New York       Dutchess
# 19          Kings County, New York       Brooklyn
# 20         Nassau County, New York         Nassau
# 21       New York County, New York      Manhattan
# 22         Orange County, New York         Orange
# 23         Putnam County, New York         Putnam
# 24         Queens County, New York         Queens
# 25       Richmond County, New York  Staten Island
# 26       Rockland County, New York       Rockland
# 27        Suffolk County, New York        Suffolk
# 28       Sullivan County, New York       Sullivan
# 29         Ulster County, New York         Ulster
# 30    Westchester County, New York    Westchester

# %% [markdown]
# #### _NY CSA counties that are not contained in NY Region:_

# %% [raw]
# 56         Carbon
# 57         Lehigh
# 58         Monroe
# 59    Northampton
# 60           Pike

# %% [markdown]
# #### _removing the 5 counties that are not contained in NY Region:_

# %%
CSAwCounties[56:61]
# Out:
#       SHAPE_AREA   STCO                                           geometry  \
# 56  1.755351e+09  42025  POLYGON ((-8459986.081 4999515.4309, -8458722....
# 57  1.560527e+09  42077  POLYGON ((-8438884.469599999 4969292.068400003...
# 58  2.825647e+09  42089  POLYGON ((-8419647.2371 5030529.472099997, -84...
# 59  1.694765e+09  42095  POLYGON ((-8416753.7096 4981031.695, -8413247....
# 60  2.605426e+09  42103  POLYGON ((-8386209.645099999 5052207.073399998...
#
#     County_name  CSA                      CSA_name
# 56       Carbon  408  New York-Newark, NY-NJ-CT-PA
# 57       Lehigh  408  New York-Newark, NY-NJ-CT-PA
# 58       Monroe  408  New York-Newark, NY-NJ-CT-PA
# 59  Northampton  408  New York-Newark, NY-NJ-CT-PA
# 60         Pike  408  New York-Newark, NY-NJ-CT-PA

# %%
CSAwCounties = CSAwCounties.drop(CSAwCounties.index[56:61])

print(CSAwCounties.shape)
# Out:
# (269, 6)

# %%
CSAwCounties[CSAwCounties['CSA'] == '408'].shape
# Out:
# (30, 6)

# %% [markdown]
# -----

# %%
print(len(CSAwCounties.CSA_name.unique()))
CSAwCounties.CSA_name.unique()
# Out:
# 15
# array(['San Jose-San Francisco-Oakland, CA', 'Los Angeles-Long Beach, CA',
#        'Denver-Aurora, CO', 'New York-Newark, NY-NJ-CT-PA',
#        'Boston-Worcester-Providence, MA-RI-NH-CT',
#        'Philadelphia-Reading-Camden, PA-NJ-DE-MD',
#        'Washington-Baltimore-Arlington, DC-MD-VA-WV-PA',
#        'Miami-Fort Lauderdale-Port St. Lucie, FL',
#        'Atlanta--Athens-Clarke County--Sandy Springs, GA',
#        'Chicago-Naperville, IL-IN-WI', 'Detroit-Warren-Ann Arbor, MI',
#        'Minneapolis-St. Paul, MN-WI', 'Dallas-Fort Worth, TX-OK',
#        'Houston-The Woodlands, TX', 'Seattle-Tacoma, WA'], dtype=object)

# %%
CSAs = CSAwCounties.groupby(['CSA', 'CSA_name']).count().reset_index().set_index('CSA')
CSAs = CSAs.iloc[:,:2]
CSAs.columns = ['CSA_name', 'numberCounties']

print(CSAs.index)
print(CSAs.shape)
CSAs
# Out:
# Index(['122', '148', '176', '206', '216', '220', '288', '348', '370', '378',
#        '408', '428', '488', '500', '548'],
#       dtype='object', name='CSA')
# (15, 2)
#                                              CSA_name  numberCounties
# CSA
# 122  Atlanta--Athens-Clarke County--Sandy Springs, GA              39
# 148          Boston-Worcester-Providence, MA-RI-NH-CT              19
# 176                      Chicago-Naperville, IL-IN-WI              18
# 206                          Dallas-Fort Worth, TX-OK              20
# 216                                 Denver-Aurora, CO              12
# 220                      Detroit-Warren-Ann Arbor, MI              10
# 288                         Houston-The Woodlands, TX              14
# 348                        Los Angeles-Long Beach, CA               2
# 370          Miami-Fort Lauderdale-Port St. Lucie, FL               7
# 378                       Minneapolis-St. Paul, MN-WI              21
# 408                      New York-Newark, NY-NJ-CT-PA              30
# 428          Philadelphia-Reading-Camden, PA-NJ-DE-MD              16
# 488                San Jose-San Francisco-Oakland, CA              12
# 500                                Seattle-Tacoma, WA               9
# 548    Washington-Baltimore-Arlington, DC-MD-VA-WV-PA              40

# %%
CSAs['CSA_short'] = CSAs['CSA_name'].str.split('-').str[0]
CSAs['CSA_short'] = CSAs['CSA_short'].replace(['San Jose'], ['San Francisco']) 

CSAs
# Out:
#                                              CSA_name  numberCounties  \
# CSA
# 122  Atlanta--Athens-Clarke County--Sandy Springs, GA              39
# 148          Boston-Worcester-Providence, MA-RI-NH-CT              19
# 176                      Chicago-Naperville, IL-IN-WI              18
# 206                          Dallas-Fort Worth, TX-OK              20
# 216                                 Denver-Aurora, CO              12
# 220                      Detroit-Warren-Ann Arbor, MI              10
# 288                         Houston-The Woodlands, TX              14
# 348                        Los Angeles-Long Beach, CA               2
# 370          Miami-Fort Lauderdale-Port St. Lucie, FL               7
# 378                       Minneapolis-St. Paul, MN-WI              21
# 408                      New York-Newark, NY-NJ-CT-PA              30
# 428          Philadelphia-Reading-Camden, PA-NJ-DE-MD              16
# 488                San Jose-San Francisco-Oakland, CA              12
# 500                                Seattle-Tacoma, WA               9
# 548    Washington-Baltimore-Arlington, DC-MD-VA-WV-PA              40
#
#          CSA_short
# CSA
# 122        Atlanta
# 148         Boston
# 176        Chicago
# 206         Dallas
# 216         Denver
# 220        Detroit
# 288        Houston
# 348    Los Angeles
# 370          Miami
# 378    Minneapolis
# 408       New York
# 428   Philadelphia
# 488  San Francisco
# 500        Seattle
# 548     Washington

# %%
fig = pl.figure(figsize=(20,10))
ax = fig.add_subplot(111)

CSAwCounties.plot(ax=ax, color='#EDFF78', edgecolor='k',linewidth=.2, alpha=0.8);

ax.axis('off')
# print(CSAwCounties['NAME'][CSAwCounties['CSAFP'] == '348'])
# Out:
# (-14050055.802375002,
#  -7486012.8163250005,
#  2730485.8160950006,
#  6382973.441805003)

# %%
CSAs['CSA_name'][CSAs.index[0]]
# Out:
# 'Atlanta--Athens-Clarke County--Sandy Springs, GA'

# %%
CSAs_sorted = ['500','216', '220','378','148',
               '488','176',  '122','548','408',
               '348', '206', '288', '428', '370']

# %%
from matplotlib.colorbar import ColorbarBase

fig = pl.figure(figsize=(40,24))
sns.set_style("whitegrid")
vmin, vmax = 0, 4000

# cax = fig.add_axes([0.1, 0.92, .85, 0.015])
# sm = plt.cm.ScalarMappable(cmap='gist_heat_r', norm=plt.Normalize(vmin=vmin, vmax=vmax))
# sm._A = []
# fig.colorbar(sm, cax=cax, orientation='horizontal')

# 15 choroplets of 15 major metros
for k in range(len(CSAs_sorted)):
    ax = fig.add_subplot(3,5,k+1)
    CSAwCounties[CSAwCounties['CSA'] == CSAs_sorted[k]].plot(ax=ax, color='lightgrey', edgecolor='k',linewidth=.6, alpha=0.6);
    ax.set_title('{} Region'.format(CSAs['CSA_short'][CSAs_sorted[k]]), fontsize=36, y=1.015)
    ax.grid(linewidth=0.25)
    ax.axis('off')

# %%
# exporting the above as .csv for later plotting; 
# NYC Metro: no Sullivan County, extra 5 counties 
CSAwCounties.to_file("exports/USmetros_rawNYC.shp")
# CSAwCounties.to_csv('USmetros_rawNYC.csv')

# %% [markdown]
# ----
#
# ## ** _EXTRA_ US border plot

# %%
# US map
allUSshp = gpd.GeoDataFrame.from_file('cb_2017_us_state_500k/cb_2017_us_state_500k.shp')
allUSshp.crs = {'init' :'epsg:2263'}
allUSshp.head()
# Out:
#   STATEFP   STATENS     AFFGEOID GEOID STUSPS           NAME LSAD  \
# 0      54  01779805  0400000US54    54     WV  West Virginia   00
# 1      17  01779784  0400000US17    17     IL       Illinois   00
# 2      24  01714934  0400000US24    24     MD       Maryland   00
# 3      16  01779783  0400000US16    16     ID          Idaho   00
# 4      50  01779802  0400000US50    50     VT        Vermont   00
#
#           ALAND      AWATER                                           geometry
# 0   62265662566   489840834  POLYGON ((-82.6431981036679 38.1690897960737, ...
# 1  143784114293  6211277447  POLYGON ((-91.512974 40.181062, -91.511073 40....
# 2   25150696145  6980371026  (POLYGON ((-76.05015299999999 37.986905, -76.0...
# 3  214048160737  2393355752  POLYGON ((-117.242675 44.396548, -117.234835 4...
# 4   23873457570  1031134839  POLYGON ((-73.43773999999999 44.045006, -73.43...

# %%
allUSshp.plot(color='grey', edgecolor='k',linewidth=.6, alpha=0.08)

# %% [markdown]
# -----
#
# # EXPORTING .shp of 15 Major Metros of the analysis

# %%
CSAwCounties
# Out:
#        SHAPE_AREA   STCO                                           geometry  \
# 0    3.124167e+09  06001  POLYGON ((-13618345.0421 4551161.905000001, -1...
# 1    3.158013e+09  06013  POLYGON ((-13628818.5334 4574539.895900004, -1...
# 2    2.298070e+09  06041  (POLYGON ((-13694586.3189 4579361.395599999, -...
# 3    3.344885e+09  06055  POLYGON ((-13652937.1333 4664335.483199999, -1...
# 4    5.596080e+09  06069  POLYGON ((-13541348.2494 4424341.478500001, -1...
# 5    2.003099e+08  06075  (POLYGON ((-13638249.8624 4548510.4001, -13637...
# 6    5.943382e+09  06077  POLYGON ((-13534468.9275 4589096.202299997, -1...
# 7    1.899909e+09  06081  POLYGON ((-13638807.6722 4514280.979199998, -1...
# 8    5.334077e+09  06085  POLYGON ((-13603537.1055 4489832.2557, -136034...
# 9    1.821667e+09  06087  POLYGON ((-13616342.0753 4465196.642399997, -1...
# 10   3.741256e+09  06095  POLYGON ((-13626261.0872 4601434.7839, -136134...
# 11   6.721220e+09  06097  POLYGON ((-13751690.2121 4688552.089100003, -1...
# 12   1.561232e+10  06037  (POLYGON ((-13240429.4019 4038872.710100003, -...
# 13   2.996405e+09  06059  POLYGON ((-13148691.2333 3994418.744099997, -1...
# 14   5.203980e+09  08001  POLYGON ((-11694456.5964 4849296.484700002, -1...
# 15   3.516331e+09  08005  (POLYGON ((-11694576.0422 4804037.795599997, -...
# 16   3.268782e+09  08013  (POLYGON ((-11714964.7635 4904073.452299997, -...
# 17   1.524998e+08  08014  (POLYGON ((-11687165.5037 4864062.342699997, -...
# 18   1.725381e+09  08019  POLYGON ((-11791474.5382 4822293.653800003, -1...
# 19   7.083773e+08  08031  POLYGON ((-11700803.4771 4811937.373099998, -1...
# 20   3.649798e+09  08035  POLYGON ((-11723451.5389 4744489.987899996, -1...
# 21   8.010603e+09  08039  POLYGON ((-11651053.9062 4773666.191399999, -1...
# 22   6.674539e+08  08047  POLYGON ((-11766438.8961 4850187.714199997, -1...
# 23   3.375813e+09  08059  (POLYGON ((-11732935.1802 4810212.248499997, -...
# 24   9.524860e+09  08093  POLYGON ((-11823262.3754 4736567.884499997, -1...
# 25   1.804343e+10  08123  POLYGON ((-11694860.5748 4916829.419299997, -1...
# 26   2.990685e+09  09001  POLYGON ((-8207338.370300001 5027205.665700004...
# 27   4.399278e+09  09005  POLYGON ((-8183851.071 5114294.871299997, -818...
# 28   2.847877e+09  09009  POLYGON ((-8161821.389 5087144.936499998, -815...
# 29   1.119370e+09  34003  POLYGON ((-8267756.5787 5015606.5295, -8265538...
# ..            ...    ...                                                ...
# 244  3.926475e+09  48349  POLYGON ((-10783969.2492 3774462.471699998, -1...
# 245  3.618414e+09  48363  POLYGON ((-10973444.7073 3838693.9573, -109734...
# 246  3.346281e+09  48367  POLYGON ((-10916612.0997 3841671.926899999, -1...
# 247  5.487019e+08  48397  POLYGON ((-10744488.2333 3888924.283100002, -1...
# 248  6.962647e+08  48425  POLYGON ((-10903257.1004 3793996.097499996, -1...
# 249  3.312052e+09  48439  POLYGON ((-10859275.1036 3837365.533600003, -1...
# 250  3.422578e+09  48497  POLYGON ((-10900505.06 3902593.555100001, -109...
# 251  2.265430e+09  48015  POLYGON ((-10755909.613 3509243.281199999, -10...
# 252  4.998272e+09  48039  POLYGON ((-10672647.9773 3404914.564099997, -1...
# 253  2.185764e+09  48071  POLYGON ((-10513261.5096 3489358.870999999, -1...
# 254  3.037522e+09  48157  POLYGON ((-10696568.7547 3452448.772600003, -1...
# 255  1.483051e+09  48167  (POLYGON ((-10601155.8173 3435936.938299999, -...
# 256  6.122347e+09  48201  POLYGON ((-10631188.814 3522079.212800004, -10...
# 257  4.093763e+09  48291  POLYGON ((-10593819.1949 3547970.8134, -105876...
# 258  4.110377e+09  48321  POLYGON ((-10729179.9872 3298648.0244, -107283...
# 259  3.762393e+09  48339  POLYGON ((-10667773.5194 3584826.992899999, -1...
# 260  2.528297e+09  48455  POLYGON ((-10623751.2249 3640296.575400002, -1...
# 261  2.814815e+09  48471  POLYGON ((-10670135.9416 3615532.415399998, -1...
# 262  1.790499e+09  48473  POLYGON ((-10708020.1907 3521354.881399997, -1...
# 263  2.159304e+09  48477  POLYGON ((-10772104.1499 3526629.659500003, -1...
# 264  3.741773e+09  48481  POLYGON ((-10757950.6559 3407223.897299998, -1...
# 265  1.274238e+09  53029  (POLYGON ((-13666687.0942 6144794.5471, -13665...
# 266  1.242801e+10  53033  (POLYGON ((-13628827.558 6050297.534100004, -1...
# 267  2.490244e+09  53035  POLYGON ((-13688655.4875 6038202.301700003, -1...
# 268  1.335155e+10  53041  POLYGON ((-13733571.8518 5908262.023400001, -1...
# 269  5.742154e+09  53045  POLYGON ((-13748627.9242 5998412.405199997, -1...
# 270  9.582264e+09  53053  (POLYGON ((-13659349.6926 5953814.456799999, -...
# 271  1.038155e+10  53057  (POLYGON ((-13660346.5586 6186881.295999996, -...
# 272  1.223292e+10  53061  (POLYGON ((-13624985.5884 6149748.7399, -13624...
# 273  4.228986e+09  53067  POLYGON ((-13714791.2518 5955942.122900002, -1...
#
#        County_name  CSA                            CSA_name
# 0          Alameda  488  San Jose-San Francisco-Oakland, CA
# 1     Contra Costa  488  San Jose-San Francisco-Oakland, CA
# 2            Marin  488  San Jose-San Francisco-Oakland, CA
# 3             Napa  488  San Jose-San Francisco-Oakland, CA
# 4       San Benito  488  San Jose-San Francisco-Oakland, CA
# 5    San Francisco  488  San Jose-San Francisco-Oakland, CA
# 6      San Joaquin  488  San Jose-San Francisco-Oakland, CA
# 7        San Mateo  488  San Jose-San Francisco-Oakland, CA
# 8      Santa Clara  488  San Jose-San Francisco-Oakland, CA
# 9       Santa Cruz  488  San Jose-San Francisco-Oakland, CA
# 10          Solano  488  San Jose-San Francisco-Oakland, CA
# 11          Sonoma  488  San Jose-San Francisco-Oakland, CA
# 12     Los Angeles  348          Los Angeles-Long Beach, CA
# 13          Orange  348          Los Angeles-Long Beach, CA
# 14           Adams  216                   Denver-Aurora, CO
# 15        Arapahoe  216                   Denver-Aurora, CO
# 16         Boulder  216                   Denver-Aurora, CO
# 17      Broomfield  216                   Denver-Aurora, CO
# 18     Clear Creek  216                   Denver-Aurora, CO
# 19          Denver  216                   Denver-Aurora, CO
# 20         Douglas  216                   Denver-Aurora, CO
# 21          Elbert  216                   Denver-Aurora, CO
# 22          Gilpin  216                   Denver-Aurora, CO
# 23       Jefferson  216                   Denver-Aurora, CO
# 24            Park  216                   Denver-Aurora, CO
# 25            Weld  216                   Denver-Aurora, CO
# 26       Fairfield  408        New York-Newark, NY-NJ-CT-PA
# 27      Litchfield  408        New York-Newark, NY-NJ-CT-PA
# 28       New Haven  408        New York-Newark, NY-NJ-CT-PA
# 29          Bergen  408        New York-Newark, NY-NJ-CT-PA
# ..             ...  ...                                 ...
# 244        Navarro  206            Dallas-Fort Worth, TX-OK
# 245     Palo Pinto  206            Dallas-Fort Worth, TX-OK
# 246         Parker  206            Dallas-Fort Worth, TX-OK
# 247       Rockwall  206            Dallas-Fort Worth, TX-OK
# 248      Somervell  206            Dallas-Fort Worth, TX-OK
# 249        Tarrant  206            Dallas-Fort Worth, TX-OK
# 250           Wise  206            Dallas-Fort Worth, TX-OK
# 251         Austin  288           Houston-The Woodlands, TX
# 252       Brazoria  288           Houston-The Woodlands, TX
# 253       Chambers  288           Houston-The Woodlands, TX
# 254      Fort Bend  288           Houston-The Woodlands, TX
# 255      Galveston  288           Houston-The Woodlands, TX
# 256         Harris  288           Houston-The Woodlands, TX
# 257        Liberty  288           Houston-The Woodlands, TX
# 258      Matagorda  288           Houston-The Woodlands, TX
# 259     Montgomery  288           Houston-The Woodlands, TX
# 260        Trinity  288           Houston-The Woodlands, TX
# 261         Walker  288           Houston-The Woodlands, TX
# 262         Waller  288           Houston-The Woodlands, TX
# 263     Washington  288           Houston-The Woodlands, TX
# 264        Wharton  288           Houston-The Woodlands, TX
# 265         Island  500                  Seattle-Tacoma, WA
# 266           King  500                  Seattle-Tacoma, WA
# 267         Kitsap  500                  Seattle-Tacoma, WA
# 268          Lewis  500                  Seattle-Tacoma, WA
# 269          Mason  500                  Seattle-Tacoma, WA
# 270         Pierce  500                  Seattle-Tacoma, WA
# 271         Skagit  500                  Seattle-Tacoma, WA
# 272      Snohomish  500                  Seattle-Tacoma, WA
# 273       Thurston  500                  Seattle-Tacoma, WA
#
# [274 rows x 6 columns]

# %%
# 1. with Sullivan County
CSAwCounties.to_csv('USmetros_full.csv')

# 2. WO Sullivan County
CSAwCounties[:-1].to_csv('USmetros_notfull.csv')

# %% [markdown]
# -----

# %% [markdown]
# # Assigning census tracts to Counties-CSAs

# %%
tractsGeo = pd.read_excel('../DCP internship/data/ALL Tract Geo Codes.xlsx')
tractsGeo['ST'] = tractsGeo['ST'].apply(lambda x: '{0:0>2}'.format(x))

print(tractsGeo.shape)
tractsGeo.head(10)
# Out:
# (28066, 5)
#          TRACT  CSA   STCO  ST  CO
# 0  10001041600  428  10001  10   1
# 1  10003001300  428  10003  10   3
# 2  10003011100  428  10003  10   3
# 3  10003011600  428  10003  10   3
# 4  10003013200  428  10003  10   3
# 5  10003014200  428  10003  10   3
# 6  10003015400  428  10003  10   3
# 7  10003016301  428  10003  10   3
# 8  10003980100  428  10003  10   3
# 9  10001040700  428  10001  10   1

# %%
Alltracts = gpd.GeoDataFrame.from_file("data/MM_Tracts_CSA-NYMetro/MM_Tracts_CSA-NYMetro.shp")

print(Alltracts.shape)
Alltracts.head()
# Out:
# (28058, 12)
#   STATEFP COUNTYFP TRACTCE              AFFGEOID        GEOID NAME LSAD  \
# 0      10      001  041600  1400000US10001041600  10001041600  416   CT
# 1      10      003  001300  1400000US10003001300  10003001300   13   CT
# 2      10      003  011100  1400000US10003011100  10003011100  111   CT
# 3      10      003  011600  1400000US10003011600  10003011600  116   CT
# 4      10      003  013200  1400000US10003013200  10003013200  132   CT
#
#      ALAND  AWATER  CSA  ALAND_mi  \
# 0  2917742  115233  428   1.12655
# 1  2283096    1623  428   0.88151
# 2  3057015       0  428   1.18032
# 3  1892942       0  428   0.73087
# 4  1501029       0  428   0.57955
#
#                                             geometry
# 0  POLYGON ((-75.53657299999999 39.115211, -75.53...
# 1  POLYGON ((-75.579956 39.763371, -75.577848 39....
# 2  POLYGON ((-75.505088 39.802164, -75.497941 39....
# 3  POLYGON ((-75.547082 39.79482, -75.545728 39.7...
# 4  POLYGON ((-75.655851 39.73490899999999, -75.65...

# %%
Alltracts.GEOID.dtypes
# Out:
# dtype('O')

# %%
states = list(tractsGeo.ST.unique())
print(len(states))
states
# Out:
# 24
# ['10',
#  '44',
#  '25',
#  '09',
#  '33',
#  '34',
#  '42',
#  '08',
#  '11',
#  '12',
#  '13',
#  '17',
#  '18',
#  '24',
#  '26',
#  '27',
#  '48',
#  '51',
#  '53',
#  '54',
#  '55',
#  '06',
#  '36',
#  '40']

# %%
CSAs = list(tractsGeo.CSA.unique())
CSAs
# Out:
# [428, 148, 548, 216, 370, 122, 176, 220, 378, 288, 206, 500, 488, 348, 408]

# %%
len(tractsGeo.CSA.unique())
# Out:
# 15

# %%
# population 2017
# total POP for all census tracts in the US
POP17tracts = []

for i in states:
    df = pd.read_json('https://api.census.gov/data/2016/acs/acs5?get=NAME,B01001_001E&for=tract:*&in=state:'+str(i))
    df.columns = df.iloc[0]
    df = df[1:]
    POP17tracts.append(df)
    
POP17tracts = pd.concat(POP17tracts)

POP17tracts['state'] = POP17tracts['state'].apply(lambda x: '{0:0>2}'.format(x))
POP17tracts['county'] = POP17tracts['county'].apply(lambda x: '{0:0>3}'.format(x))
POP17tracts['GEOID'] = POP17tracts[['state', 'county', 'tract']].apply(lambda x: ''.join(x), axis=1)

POP17tracts = POP17tracts.rename(columns={'B01001_001E':'pop17'})

print(POP17tracts.shape)
POP17tracts.head()
# Out:
# (50673, 6)
# 0                                        NAME  pop17 state county   tract  \
# 1     Census Tract 401, Kent County, Delaware   6498    10    001  040100
# 2  Census Tract 402.01, Kent County, Delaware   5143    10    001  040201
# 3  Census Tract 402.02, Kent County, Delaware  14552    10    001  040202
# 4  Census Tract 402.03, Kent County, Delaware   6019    10    001  040203
# 5  Census Tract 405.01, Kent County, Delaware   4424    10    001  040501
#
# 0        GEOID
# 1  10001040100
# 2  10001040201
# 3  10001040202
# 4  10001040203
# 5  10001040501

# %%
POP17tracts.GEOID.dtypes
# Out:
# dtype('O')

# %% [markdown]
# ### Merge to reduce to tracts within the 15 CSA's boundaries and calculate pop density to each tract

# %%
CSAtracts = POP17tracts.merge(Alltracts, on='GEOID')
CSAtracts = CSAtracts.drop(['STATEFP', 'COUNTYFP', 'TRACTCE', 'AFFGEOID', 'LSAD'], axis=1)
CSAtracts = CSAtracts.rename(columns={'NAME_x':'NAME'})
CSAtracts = CSAtracts.set_index('NAME')
CSAtracts['pop17'] = CSAtracts['pop17'].astype(int)

CSAtracts['pop_density'] = CSAtracts['pop17'] / CSAtracts['ALAND_mi']
CSAtracts = CSAtracts.drop(['NAME_y'], axis=1)

print(CSAtracts.shape)
print(CSAtracts.dtypes)
CSAtracts.head()
# Out:
# (28058, 11)
# pop17            int64
# state           object
# county          object
# tract           object
# GEOID           object
# ALAND            int64
# AWATER           int64
# CSA             object
# ALAND_mi       float64
# geometry        object
# pop_density    float64
# dtype: object
#                                             pop17 state county   tract  \
# NAME
# Census Tract 401, Kent County, Delaware      6498    10    001  040100
# Census Tract 402.01, Kent County, Delaware   5143    10    001  040201
# Census Tract 402.02, Kent County, Delaware  14552    10    001  040202
# Census Tract 402.03, Kent County, Delaware   6019    10    001  040203
# Census Tract 405.01, Kent County, Delaware   4424    10    001  040501
#
#                                                   GEOID      ALAND   AWATER  \
# NAME
# Census Tract 401, Kent County, Delaware     10001040100  124745851        0
# Census Tract 402.01, Kent County, Delaware  10001040201    9730121    37235
# Census Tract 402.02, Kent County, Delaware  10001040202   31959485   669328
# Census Tract 402.03, Kent County, Delaware  10001040203   59368816  1534599
# Census Tract 405.01, Kent County, Delaware  10001040501   10394105        0
#
#                                             CSA  ALAND_mi  \
# NAME
# Census Tract 401, Kent County, Delaware     428  48.16462
# Census Tract 402.01, Kent County, Delaware  428   3.75682
# Census Tract 402.02, Kent County, Delaware  428  12.33962
# Census Tract 402.03, Kent County, Delaware  428  22.92242
# Census Tract 405.01, Kent County, Delaware  428   4.01318
#
#                                                                                      geometry  \
# NAME
# Census Tract 401, Kent County, Delaware     POLYGON ((-75.76010435237289 39.2968165224723,...
# Census Tract 402.01, Kent County, Delaware  POLYGON ((-75.66581099999999 39.290567, -75.66...
# Census Tract 402.02, Kent County, Delaware  POLYGON ((-75.64978599999999 39.272225, -75.64...
# Census Tract 402.03, Kent County, Delaware  POLYGON ((-75.60659799999999 39.30809, -75.603...
# Census Tract 405.01, Kent County, Delaware  POLYGON ((-75.58473499999999 39.242025, -75.58...
#
#                                             pop_density
# NAME
# Census Tract 401, Kent County, Delaware      134.912307
# Census Tract 402.01, Kent County, Delaware  1368.976954
# Census Tract 402.02, Kent County, Delaware  1179.290772
# Census Tract 402.03, Kent County, Delaware   262.581350
# Census Tract 405.01, Kent County, Delaware  1102.367698

# %%
CSAtracts[(CSAtracts['CSA'] == '408') & (CSAtracts['pop_density'] > 50000) & 
          (CSAtracts['state'] == '36')][600:610]
# Out:
#                                                pop17 state county   tract  \
# NAME
# Census Tract 81, New York County, New York      8170    36    061  008100
# Census Tract 83, New York County, New York      3994    36    061  008300
# Census Tract 86.01, New York County, New York   2828    36    061  008601
# Census Tract 86.03, New York County, New York   4062    36    061  008603
# Census Tract 87, New York County, New York      7008    36    061  008700
# Census Tract 88, New York County, New York      6840    36    061  008800
# Census Tract 89, New York County, New York      5368    36    061  008900
# Census Tract 90, New York County, New York      7760    36    061  009000
# Census Tract 91, New York County, New York      6402    36    061  009100
# Census Tract 93, New York County, New York     10012    36    061  009300
#
#                                                      GEOID   ALAND  AWATER  \
# NAME
# Census Tract 81, New York County, New York     36061008100  174287       0
# Census Tract 83, New York County, New York     36061008300  174158       0
# Census Tract 86.01, New York County, New York  36061008601  125340  499842
# Census Tract 86.03, New York County, New York  36061008603  116670  153941
# Census Tract 87, New York County, New York     36061008700  165443       0
# Census Tract 88, New York County, New York     36061008800  179256       0
# Census Tract 89, New York County, New York     36061008900  165578       0
# Census Tract 90, New York County, New York     36061009000  174692       0
# Census Tract 91, New York County, New York     36061009100  179099       0
# Census Tract 93, New York County, New York     36061009300  179101       0
#
#                                                CSA  ALAND_mi  \
# NAME
# Census Tract 81, New York County, New York     408   0.06729
# Census Tract 83, New York County, New York     408   0.06724
# Census Tract 86.01, New York County, New York  408   0.04839
# Census Tract 86.03, New York County, New York  408   0.04505
# Census Tract 87, New York County, New York     408   0.06388
# Census Tract 88, New York County, New York     408   0.06921
# Census Tract 89, New York County, New York     408   0.06393
# Census Tract 90, New York County, New York     408   0.06745
# Census Tract 91, New York County, New York     408   0.06915
# Census Tract 93, New York County, New York     408   0.06915
#
#                                                                                         geometry  \
# NAME
# Census Tract 81, New York County, New York     POLYGON ((-74.00201899999999 40.740444, -74.00...
# Census Tract 83, New York County, New York     POLYGON ((-74.007238 40.74346999999999, -74.00...
# Census Tract 86.01, New York County, New York  POLYGON ((-73.972576 40.745068, -73.9721299999...
# Census Tract 86.03, New York County, New York  POLYGON ((-73.966616 40.753244, -73.966157 40....
# Census Tract 87, New York County, New York     POLYGON ((-74.000275 40.742839, -73.999848 40....
# Census Tract 88, New York County, New York     POLYGON ((-73.975835 40.748863, -73.9744489999...
# Census Tract 89, New York County, New York     POLYGON ((-74.00553499999999 40.745816, -74.00...
# Census Tract 90, New York County, New York     POLYGON ((-73.973045 40.752692, -73.972588 40....
# Census Tract 91, New York County, New York     POLYGON ((-73.998486 40.745294, -73.998009 40....
# Census Tract 93, New York County, New York     POLYGON ((-74.00416799999999 40.74769, -74.003...
#
#                                                  pop_density
# NAME
# Census Tract 81, New York County, New York     121414.771883
# Census Tract 83, New York County, New York      59399.167162
# Census Tract 86.01, New York County, New York   58441.826824
# Census Tract 86.03, New York County, New York   90166.481687
# Census Tract 87, New York County, New York     109705.698184
# Census Tract 88, New York County, New York      98829.648895
# Census Tract 89, New York County, New York      83966.838730
# Census Tract 90, New York County, New York     115048.183840
# Census Tract 91, New York County, New York      92581.344902
# Census Tract 93, New York County, New York     144786.695589

# %%
fig = pl.figure(figsize=(40,24))
sns.set_style("whitegrid")
vmin, vmax = 0, 4000

# 15 choroplets of 15 major metros
for k in range(len(CSAs_sorted)):
    ax = fig.add_subplot(3,5,k+1)
    CSAs[CSAs.index == CSAs_sorted[k]].plot(ax=ax, color='w', edgecolor='k',linewidth=4, alpha=0.6);
    Counties[Counties['CSA'] == CSAs_sorted[k]].plot(ax=ax, color='lightgrey', edgecolor='k',linewidth=.6, alpha=0.6);
    Places[Places['CSA'] == CSAs_sorted[k]].plot(ax=ax, color='#EDFF78', edgecolor='k',linewidth=3, alpha=0.8);

    ax.set_title('{} Region'.format(CSAs['CSA_short'][CSAs_sorted[k]]), fontsize=32, y=1.015)
    ax.grid(linewidth=0.25)
    ax.axis('off')
    
plt.savefig("geographies.pdf", transparent=True)

# %%
# download and clean census tract shp
# or from dara -- cleaned ArcMap exports

# %% [markdown]
# -----
#
# # 2 - Census Data acquisition

# %%
#reading in my api key saved in censusAPI.py as
#myAPI = 'XXXXXXXXXXXXXXX'
from censusAPI import myAPI

# %%
import json
import requests 
import urllib

#read in in the variables available. the info you need is in the 1year ACS data
url = "https://api.census.gov/data/2017/pep/population/variables.json"
resp = requests.request('GET', url)
aff1y = json.loads(resp.text)

# %%
#turning things into arrays to enable broadcasting
#Python3
affkeys = np.array(list(aff1y['variables'].keys()))

# %%
affkeys
# Out:
# array(['CONCIT', 'for', 'COUSUB', 'DIVISION', 'POP', 'in', 'DENSITY',
#        'GEONAME', 'PLACE', 'COUNTY', 'LASTUPDATE', 'DATE_DESC',
#        'UNIVERSE', 'PRIMGEOFLAG', 'SUMLEV', 'MDIV', 'DATE', 'FUNCSTAT',
#        'CBSA', 'NATION', 'REGION', 'STATE', 'CSA'], dtype='<U11')

# %%
# keyword for POP estimates
POP = 'POP'

aff1y['variables'][POP]
# Out:
# {'concept': 'Estimates',
#  'group': 'N/A',
#  'label': 'Population',
#  'limit': 0,
#  'predicateType': 'int'}

# %% [markdown]
# ## POPULATION 2017

# %%
# total POP for all counties in the US
POP17 = pd.read_json('https://api.census.gov/data/2017/pep/population?get=POP,GEONAME&for=county:*')
POP17.columns = POP17.iloc[0]
POP17 = POP17[1:]

POP17['state'] = POP17['state'].apply(lambda x: '{0:0>2}'.format(x))
POP17['county'] = POP17['county'].apply(lambda x: '{0:0>3}'.format(x))
POP17['STCO'] = POP17[['state', 'county']].apply(lambda x: ''.join(x), axis=1)

print(POP17.shape)
POP17.head()
# Out:
# (3220, 5)
# 0     POP                  GEONAME state county   STCO
# 1   55504  Autauga County, Alabama    01    001  01001
# 2  212628  Baldwin County, Alabama    01    003  01003
# 3   25270  Barbour County, Alabama    01    005  01005
# 4   22668     Bibb County, Alabama    01    007  01007
# 5   58013   Blount County, Alabama    01    009  01009

# %%
# total POP for all places in the US
POP17place = pd.read_json('https://api.census.gov/data/2017/pep/population?get=POP,GEONAME&for=place:*')
# POP17place.columns = POP17.iloc[0]
POP17place = POP17place[1:]
# POP17place['STCOzip']=list(zip(POP17place.state, POP17.place))

print(POP17place.shape)
POP17place.head()
# Out:
# (19500, 4)
#        0                         1   2      3
# 1   2567   Abbeville city, Alabama  01  00124
# 2   4347  Adamsville city, Alabama  01  00460
# 3    728     Addison town, Alabama  01  00484
# 4    332       Akron town, Alabama  01  00676
# 5  33202   Alabaster city, Alabama  01  00820

# %%
POP17shp = CSAwCounties.merge(POP17, on = 'STCO')
POP17shp = POP17shp.drop(['GEONAME', 'state', 'county'], axis=1)


print(POP17shp.shape)
POP17shp.head()
# Out:
# (269, 7)
#      SHAPE_AREA   STCO                                           geometry  \
# 0  3.124167e+09  06001  POLYGON ((-13618345.0421 4551161.905000001, -1...
# 1  3.158013e+09  06013  POLYGON ((-13628818.5334 4574539.895900004, -1...
# 2  2.298070e+09  06041  (POLYGON ((-13694586.3189 4579361.395599999, -...
# 3  3.344885e+09  06055  POLYGON ((-13652937.1333 4664335.483199999, -1...
# 4  5.596080e+09  06069  POLYGON ((-13541348.2494 4424341.478500001, -1...
#
#     County_name  CSA                            CSA_name      POP
# 0       Alameda  488  San Jose-San Francisco-Oakland, CA  1663190
# 1  Contra Costa  488  San Jose-San Francisco-Oakland, CA  1147439
# 2         Marin  488  San Jose-San Francisco-Oakland, CA   260955
# 3          Napa  488  San Jose-San Francisco-Oakland, CA   140973
# 4    San Benito  488  San Jose-San Francisco-Oakland, CA    60310

# %%
POP17shp.dtypes
# Out:
# SHAPE_AREA     float64
# STCO            object
# geometry        object
# County_name     object
# CSA             object
# CSA_name        object
# POP             object
# dtype: object

# %%
POP17shp['POP'] = POP17shp['POP'].astype('float64')
POP17shp.dtypes
# Out:
# SHAPE_AREA     float64
# STCO            object
# geometry        object
# County_name     object
# CSA             object
# CSA_name        object
# POP            float64
# dtype: object

# %%
POP17shp['POPsqml'] = (POP17shp['POP'] / POP17shp['SHAPE_AREA'] * 1000000)
POP17shp.head()
# Out:
#      SHAPE_AREA   STCO                                           geometry  \
# 0  3.124167e+09  06001  POLYGON ((-13618345.0421 4551161.905000001, -1...
# 1  3.158013e+09  06013  POLYGON ((-13628818.5334 4574539.895900004, -1...
# 2  2.298070e+09  06041  (POLYGON ((-13694586.3189 4579361.395599999, -...
# 3  3.344885e+09  06055  POLYGON ((-13652937.1333 4664335.483199999, -1...
# 4  5.596080e+09  06069  POLYGON ((-13541348.2494 4424341.478500001, -1...
#
#     County_name  CSA                            CSA_name        POP  \
# 0       Alameda  488  San Jose-San Francisco-Oakland, CA  1663190.0
# 1  Contra Costa  488  San Jose-San Francisco-Oakland, CA  1147439.0
# 2         Marin  488  San Jose-San Francisco-Oakland, CA   260955.0
# 3          Napa  488  San Jose-San Francisco-Oakland, CA   140973.0
# 4    San Benito  488  San Jose-San Francisco-Oakland, CA    60310.0
#
#       POPsqml
# 0  532.362732
# 1  363.342084
# 2  113.553986
# 3   42.145842
# 4   10.777187

# %%
POP17shp.dtypes
# Out:
# SHAPE_AREA     float64
# STCO            object
# geometry        object
# County_name     object
# CSA             object
# CSA_name        object
# POP            float64
# POPsqml        float64
# dtype: object

# %%
fig = pl.figure(figsize=(20,8))
ax = fig.add_subplot(111)

POP17shp.plot(ax=ax, column= 'POPsqml', cmap='Blues',
              legend=True, edgecolor='k', linewidth=.3);
ax.grid(linewidth=0.25)

# %%
print(len(POP17shp.CSA_name.unique()))
POP17shp.CSA_name.unique()
# Out:
# 15
# array(['San Jose-San Francisco-Oakland, CA', 'Los Angeles-Long Beach, CA',
#        'Denver-Aurora, CO', 'New York-Newark, NY-NJ-CT-PA',
#        'Boston-Worcester-Providence, MA-RI-NH-CT',
#        'Philadelphia-Reading-Camden, PA-NJ-DE-MD',
#        'Washington-Baltimore-Arlington, DC-MD-VA-WV-PA',
#        'Miami-Fort Lauderdale-Port St. Lucie, FL',
#        'Atlanta--Athens-Clarke County--Sandy Springs, GA',
#        'Chicago-Naperville, IL-IN-WI', 'Detroit-Warren-Ann Arbor, MI',
#        'Minneapolis-St. Paul, MN-WI', 'Dallas-Fort Worth, TX-OK',
#        'Houston-The Woodlands, TX', 'Seattle-Tacoma, WA'], dtype=object)

# %%
len(POP17shp[POP17shp['CSA'] == '408'])
# Out:
# 30

# %%
def plotRegions(column):
    ax = fig.add_subplot(3,5,k+1)
    POP17shp[POP17shp['CSA'] == CSAs.index[k]].plot(ax=ax, column=POP, cmap='Blues',
                                           edgecolor='k',linewidth=.6, alpha=0.8);
    ax.set_title('{} Region'.format(CSAs['CSA_short'][CSAs.index[k]]), fontsize=32, y=1.01)
    ax.grid(linewidth=0.25)

# %%
fig = pl.figure(figsize=(40,24))
sns.set_style("whitegrid")
vmin, vmax = 0, 2500000

cax = fig.add_axes([0.92, 0.1, 0.015, .85])
sm = plt.cm.ScalarMappable(cmap='Blues', norm=plt.Normalize(vmin=vmin, vmax=vmax))
sm._A = []
fig.colorbar(sm, cax=cax, orientation='vertical')


# 8 choroplets of seven major felonies + total
for k in range(len(CSAs_sorted)):
    ax = fig.add_subplot(3,5,k+1)
    POP17shp[POP17shp['CSA'] == CSAs_sorted[k]].plot(ax=ax, column=POP, cmap='Blues',
                                           edgecolor='k',linewidth=.6, alpha=0.8);
    ax.set_title('{} Region'.format(CSAs['CSA_short'][CSAs_sorted[k]]), fontsize=32, y=1.01)
    ax.grid(linewidth=0.25)
    ax.axis('off')

# %% [markdown]
# ----
#
# ## _PLACES -- delete_

# %%
places = pd.read_excel('sub-est2017_all.xlsx')
print(places.shape)
places.head()
# Out:
# (81546, 20)
#    SUMLEV  STATE  COUNTY  PLACE  COUSUB  CONCIT  PRIMGEO_FLAG FUNCSTAT  \
# 0      40      1       0      0       0       0             0        A
# 1     162      1       0    124       0       0             0        A
# 2     162      1       0    460       0       0             0        A
# 3     162      1       0    484       0       0             0        A
# 4     162      1       0    676       0       0             0        A
#
#               NAME   STNAME CENSUS2010POP  ESTIMATESBASE2010  POPESTIMATE2010  \
# 0          Alabama  Alabama       4779736            4780135          4785579
# 1   Abbeville city  Alabama          2688               2688             2684
# 2  Adamsville city  Alabama          4522               4522             4516
# 3     Addison town  Alabama           758                754              751
# 4       Akron town  Alabama           356                356              355
#
#    POPESTIMATE2011  POPESTIMATE2012  POPESTIMATE2013  POPESTIMATE2014  \
# 0          4798649          4813946          4827660          4840037
# 1             2677             2629             2612             2595
# 2             4502             4479             4457             4437
# 3              751              744              743              740
# 4              345              345              341              337
#
#    POPESTIMATE2015  POPESTIMATE2016  POPESTIMATE2017
# 0          4850858          4860545          4874747
# 1             2587             2575             2567
# 2             4409             4376             4347
# 3              734              734              728
# 4              335              332              332

# %% [markdown]
# # 2. Analysis
# # _2.1 Pop 2017_

# %%
fig = pl.figure(figsize(12,7))

(POP17shp['POP'].groupby([POP17shp['CSA']]).sum()).plot(kind="bar", color='SteelBlue', label='Population 2017')

pl.xlabel('CSA', fontsize=16)
pl.ylabel('Population Counts', fontsize=16)
pl.title('Total Population of 15 US Metros, 2017', fontsize=22, y=1.01)
pl.legend(prop={'size': 16})
pl.grid(linewidth=0.25)

# %%
fig = pl.figure(figsize=(40,24))
sns.set_style("whitegrid")
vmin, vmax = POP17shp['POPsqml'].min(), POP17shp['POPsqml'].max()

cax = fig.add_axes([0.92, 0.1, 0.015, .85])
sm = plt.cm.ScalarMappable(cmap='bone_r', norm=plt.Normalize(vmin=vmin, vmax=vmax))
sm._A = []
fig.colorbar(sm, cax=cax, orientation='vertical')

# im = axes[0].imshow(my_image1)
# clim=im.properties()['clim']
# axes[1].imshow(my_image2, clim=clim)
# fig.colorbar(im, ax=axes.ravel().tolist(), shrink=0.5)

# 15 choroplets of 15 major US metros
for k in range(len(CSAs.index)):
    ax = fig.add_subplot(3,5,k+1)
    POP17shp[POP17shp['CSA'] == CSAs.index[k]].plot(ax=ax, column= 'POPsqml', clim=sm, cmap='bone_r',
                            scheme='quantiles', edgecolor='k',linewidth=.6, alpha=0.8);
    ax.set_title('{} Region'.format(CSAs['CSA_short'][CSAs.index[k]]), fontsize=32, y=1.01)
    ax.grid(linewidth=0.25)
    
plt.savefig("POPdens17.pdf", transparent=True)
