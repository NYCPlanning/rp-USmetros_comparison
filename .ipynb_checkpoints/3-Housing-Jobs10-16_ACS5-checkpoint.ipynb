# %% [markdown]
# 07-06-2018
#
# **_Author: Dana Chermesh, Regional Planning intern_**
#
#
# ### US Metros comparison
# comparison by the county level of 15 regions (CSA's) accross the country
#
# ----
#
# ### _Notebook no.3_
# # Housing + Labor force data
# # ACS 1-yesr estimates 2017 using Census API
#
# ----
#
# A user guide for Census Data API:
#
# # [Census Data API User Guide](https://www.census.gov/content/dam/Census/data/developers/api-user-guide/api-guide.pdf)
#
# The Census Data API in an API that gives the public access to raw statistical data from various Census Bureau data
# programs. In terms of space, we aggregate the data and usually associate them with a
# certain Census geographic boundary/area defined by a FIPS code.
#
# ## _get your API key from:_
# https://api.census.gov/data/key_signup.html
#
# **Recommended:** In order to keep your API key confidential, please save your API key in a .py file named **censusAPI.py** as follows:
#
# ```python
# myAPI = 'XXXXXXXXXXXXXXX'
# ```
# Then read into this notebook as in the following cell:
# ```python
# from censusAPI import myAPI
# ```
#
# ### The complete list of all available datasets for the API is located here:
# https://api.census.gov/data.html
#
# ----
#
# ### More on the 2000 Decennial: Summary File 1 (SF1)
# - [geographies](https://api.census.gov/data/2000/sf1/geography.html)
# - [variables](https://api.census.gov/data/2000/sf1/variables.html)

# %% [markdown]
# ----
# # Housing units 2016
# ### _data were obtained from the  ACS 2012-2016 5-year estimate, all counties in the US_
# variables to be acquired:
# - **B25001_001E** |	Total Housing Units (occupied+vacant)
# - **B25003_002E** | Owner occupied
# - **B25003_003E** | Owner occupied

# %%
import pandas as pd
import json
# reading in my api key saved in censusAPI.py as
# myAPI = 'XXXXXXXXXXXXXXX'
# request an api key in: https://api.census.gov/data/key_signup.html
from censusAPI import myAPI

# %%
import json
import requests 
import urllib
import numpy as np

#read in in the variables available. the info you need is in the 1year ACS data
url = "https://api.census.gov/data/2016/acs/acs5/variables.json"
resp = requests.request('GET', url)
aff1y = json.loads(resp.text)

# %%
#turning things into arrays to enable broadcasting
#Python3
affkeys = np.array(list(aff1y['variables'].keys()))

affkeys
# Out:
# array(['B25036_005E', 'B08534_008E', 'B24126_481E', ..., 'B25124_028E',
#        'B24123_413E', 'B24125_205E'], dtype='<U14')

# %%
# keyword for POP estimates
totalHU = 'B25001_001E'
owner = 'B25003_002E'
renter = 'B25003_003E'

aff1y['variables'][totalHU]
# Out:
# {'attributes': 'B25001_001M,B25001_001MA,B25001_001EA',
#  'concept': 'HOUSING UNITS',
#  'group': 'B25001',
#  'label': 'Estimate!!Total',
#  'limit': 0,
#  'predicateType': 'int',
#  'validValues': []}

# %%
# HU2016 data for all counties in the US
totalHU16 = pd.read_json('https://api.census.gov/data/2016/acs/acs5?get='+
                         totalHU + ',' +
                         owner + ',' +
                         renter +',NAME&for=county:*&in=state:*')
totalHU16.columns = totalHU16.iloc[0]
totalHU16 = totalHU16[1:]

totalHU16['state'] = totalHU16['state'].apply(lambda x: '{0:0>2}'.format(x))
totalHU16['county'] = totalHU16['county'].apply(lambda x: '{0:0>3}'.format(x))
totalHU16['STCO'] = totalHU16[['state', 'county']].apply(lambda x: ''.join(x), axis=1)

totalHU16 = totalHU16.drop(['state', 'county'], axis=1)
totalHU16.columns = ['TotalHousing16', 'Owners16', 'renters16',
                     'Name', 'STCO']

print(totalHU16.shape)
totalHU16.head()
# Out:
# (3220, 5)
#   TotalHousing16 Owners16 renters16                     Name   STCO
# 1          22714    15218      5582  Autauga County, Alabama  01001
# 2         107579    53905     21244  Baldwin County, Alabama  01003
# 3          11802     5829      3293  Barbour County, Alabama  01005
# 4           8972     5119      1929     Bibb County, Alabama  01007
# 5          23850    16254      4365   Blount County, Alabama  01009

# %% [markdown]
# ##  Reading in geo-coded dataset
# created on a different notebook, please refer to _**ADD NOTEBOOK NAME**_

# %%
geo = pd.read_csv('data/USmetros_full.csv').iloc[:,:-2] \
            .drop(['Unnamed: 0', 'SHAPE_AREA'], axis=1)
geo['STCO'] = geo['STCO'].apply(lambda x: '{0:0>5}'.format(x))

print(geo.shape)
geo.head()
# Out:
# (270, 4)
#    CSA                            CSA_name   County_name   STCO
# 0  488  San Jose-San Francisco-Oakland, CA       Alameda  06001
# 1  488  San Jose-San Francisco-Oakland, CA  Contra Costa  06013
# 2  488  San Jose-San Francisco-Oakland, CA         Marin  06041
# 3  488  San Jose-San Francisco-Oakland, CA          Napa  06055
# 4  488  San Jose-San Francisco-Oakland, CA    San Benito  06069

# %% [markdown]
# ### Merging datasets

# %%
HOUSING16_CO = totalHU16.merge(geo, on='STCO').set_index('County_name')

print(HOUSING16_CO.shape)
HOUSING16_CO.head()
# Out:
# (270, 7)
#              TotalHousing16 Owners16 renters16  \
# County_name
# Alameda              592796   296634    267659
# Contra Costa         406803   250055    137485
# Los Angeles         3490118  1499576   1782269
# Marin                112259    66200     38200
# Napa                  55301    30411     18964
#
#                                          Name   STCO  CSA  \
# County_name
# Alameda            Alameda County, California  06001  488
# Contra Costa  Contra Costa County, California  06013  488
# Los Angeles    Los Angeles County, California  06037  348
# Marin                Marin County, California  06041  488
# Napa                  Napa County, California  06055  488
#
#                                         CSA_name
# County_name
# Alameda       San Jose-San Francisco-Oakland, CA
# Contra Costa  San Jose-San Francisco-Oakland, CA
# Los Angeles           Los Angeles-Long Beach, CA
# Marin         San Jose-San Francisco-Oakland, CA
# Napa          San Jose-San Francisco-Oakland, CA

# %%
HOUSING16_CO[HOUSING16_CO['CSA']==408].shape
# Out:
# (31, 7)

# %%
# convert numeric columns from str ('object') to int via to_numeric
HOUSING16_CO.iloc[:,:3] = HOUSING16_CO.iloc[:,:3].apply(pd.to_numeric,
                                                      errors='coerce')

HOUSING16_CO.dtypes
# Out:
# TotalHousing16     int64
# Owners16           int64
# renters16          int64
# Name              object
# STCO              object
# CSA                int64
# CSA_name          object
# dtype: object

# %% [markdown]
# ### Exporting all counties Housing data to .csv

# %%
HOUSING16_CO.to_csv('HOUSING16_CO.csv')

# %% [markdown]
# ## Groupby CSAs to sum

# %%
CSA_housing16 = HOUSING16_CO.groupby(['CSA', 'CSA_name']).sum()

print(CSA_housing16.shape)
CSA_housing16
# Out:
# (15, 3)
#                                                       TotalHousing16  \
# CSA CSA_name
# 122 Atlanta--Athens-Clarke County--Sandy Springs, GA         2475969
# 148 Boston-Worcester-Providence, MA-RI-NH-CT                 3412143
# 176 Chicago-Naperville, IL-IN-WI                             1792036
# 206 Dallas-Fort Worth, TX-OK                                 2832798
# 216 Denver-Aurora, CO                                        1350238
# 220 Detroit-Warren-Ann Arbor, MI                             2340603
# 288 Houston-The Woodlands, TX                                2534512
# 348 Los Angeles-Long Beach, CA                               4562239
# 370 Miami-Fort Lauderdale-Port St. Lucie, FL                 2809034
# 378 Minneapolis-St. Paul, MN-WI                              1554227
# 408 New York-Newark, NY-NJ-CT-PA                             8973910
# 428 Philadelphia-Reading-Camden, PA-NJ-DE-MD                 2965130
# 488 San Jose-San Francisco-Oakland, CA                       3202912
# 500 Seattle-Tacoma, WA                                       1893806
# 548 Washington-Baltimore-Arlington, DC-MD-VA-WV-PA           3763493
#
#                                                       Owners16  renters16
# CSA CSA_name
# 122 Atlanta--Athens-Clarke County--Sandy Springs, GA   1396394     824382
# 148 Boston-Worcester-Providence, MA-RI-NH-CT           1934972    1151423
# 176 Chicago-Naperville, IL-IN-WI                       1222063     435630
# 206 Dallas-Fort Worth, TX-OK                           1566020    1034702
# 216 Denver-Aurora, CO                                   814383     464369
# 220 Detroit-Warren-Ann Arbor, MI                       1420760     652609
# 288 Houston-The Woodlands, TX                          1383407     907205
# 348 Los Angeles-Long Beach, CA                         2081082    2217775
# 370 Miami-Fort Lauderdale-Port St. Lucie, FL           1419029     888587
# 378 Minneapolis-St. Paul, MN-WI                        1028692     444354
# 408 New York-Newark, NY-NJ-CT-PA                       4328256    3794128
# 428 Philadelphia-Reading-Camden, PA-NJ-DE-MD           1789788     851882
# 488 San Jose-San Francisco-Oakland, CA                 1671214    1347297
# 500 Seattle-Tacoma, WA                                 1070569     680252
# 548 Washington-Baltimore-Arlington, DC-MD-VA-WV-PA     2235443    1237556

# %% [markdown]
# ### Exporting CSA's Housing data to .csv

# %%
CSA_housing16.to_csv('HOUSING16_CSAs.csv')

# %% [markdown]
# # Housing units 2010
# ### _data were obtained from the Decennial Census 2010, SF1, all counties in the US_
# variables to be acquired:
# - **B25001_001E** |	Total Housing Units (occupied+vacant)
# - **B25003_002E** | Owner occupied
# - **B25003_003E** | Owner occupied

# %%
url10 = "https://api.census.gov/data/2010/sf1/variables.json"
resp10 = requests.request('GET', url10)
aff1y10 = json.loads(resp10.text)

# %%
#turning things into arrays to enable broadcasting
#Python3
affkeys10 = np.array(list(aff1y10['variables'].keys()))

affkeys10
# Out:
# array(['PCT0150019', 'P029E001', 'P031H013', ..., 'PCT012I167',
#        'PCT012C117', 'PCT013C004'], dtype='<U10')

# %%
# keyword for POP estimates
totalHU10 = 'H00010001'
test10 = 'H0030001'
owner10_1 = 'H0040002'
owner10_2 = 'H0040003'
renter10 = 'H0040004'

aff1y10['variables'][totalHU10]
# Out:
# {'concept': 'H1. Housing Units [1]',
#  'group': 'N/A',
#  'label': 'Housing units',
#  'limit': 0,
#  'validValues': []}

# %%
# HU2010 data for all counties in the US
totalHU10 = pd.read_json('https://api.census.gov/data/2010/sf1?get='+
                         totalHU10 + ',' +
                         test10 + ',' +
                         owner10_1 + ',' +
                         owner10_2 + ',' +
                         renter10 +',NAME&for=county:*&in=state:*')
totalHU10.columns = totalHU10.iloc[0]
totalHU10 = totalHU10[1:]

totalHU10['state'] = totalHU10['state'].apply(lambda x: '{0:0>2}'.format(x))
totalHU10['county'] = totalHU10['county'].apply(lambda x: '{0:0>3}'.format(x))
totalHU10['STCO'] = totalHU10[['state', 'county']].apply(lambda x: ''.join(x), axis=1)

totalHU10 = totalHU10.drop(['state', 'county'], axis=1)
# totalHU10.columns = ['TotalHousing16', 'Owners16', 'renters16',
#                      'Name', 'STCO']

print(totalHU10.shape)
totalHU10.head()

# %% [markdown]
# ------
#
# ## Obtaining PLACES 2000 data in order to define cities within major metros

# %% [markdown]
# ### 2000

# %%
# total POP for all counties in the US, 2000
POP00_place = pd.read_json('https://api.census.gov/data/2000/sf1?get=P001001,NAME&for=place:*')
POP00_place.columns = POP00_place.iloc[0]
POP00_place = POP00_place[1:]

POP00_place.rename(columns={'P001001':'2000'}, inplace=True)
POP00_place['GEOID'] = POP00_place[['state', 'place']].apply(lambda x: ''.join(x), axis=1)

print(POP00_place.shape)
POP00_place.head()
# Out:
# (25150, 5)
# 0   2000               NAME state  place    GEOID
# 1    984       Altoona town    01  01660  0101660
# 2   7411          Boaz city    01  07912  0107912
# 3   3158        Calera city    01  11416  0111416
# 4   4927  Childersburg city    01  14464  0114464
# 5  53929       Decatur city    01  20104  0120104

# %%
POP00_place[POP00_place['NAME'] == 'San Francisco city']
# Out:
# 0       2000                NAME state  place    GEOID
# 2330  776733  San Francisco city    06  67000  0667000

# %% [markdown]
# ### Reading in my Geocoded places table
# Created by Dara Goldberg

# %%
cities = pd.read_excel('data/CSA Population+Change_2010-2017.xlsx', 
             sheet_name='Cities_pop+geoinfo')

# setting GEOID to 7 digits to assure match
cities['GEOID'] = cities['GEOID'].apply(lambda x: '{0:0>7}'.format(x))
# setting GEOID to str
cities.GEOID = cities.GEOID.astype(str)

print(cities.shape)
cities
# Out:
# (19, 15)
#       GEOID                               NAMELSAD           NAME  CSA  \
# 0   0644000           Los Angeles city, California    Los Angeles  348
# 1   0653000               Oakland city, California        Oakland  488
# 2   0667000         San Francisco city, California  San Francisco  488
# 3   0668000              San Jose city, California       San Jose  488
# 4   0820000                  Denver city, Colorado         Denver  216
# 5   1150000  Washington city, District of Columbia     Washington  548
# 6   1245000                    Miami city, Florida          Miami  370
# 7   1304000                  Atlanta city, Georgia        Atlanta  122
# 8   1714000                 Chicago city, Illinois        Chicago  176
# 9   2507000             Boston city, Massachusetts         Boston  148
# 10  2622000                 Detroit city, Michigan        Detroit  220
# 11  2743000            Minneapolis city, Minnesota    Minneapolis  378
# 12  2758000               St. Paul city, Minnesota       St. Paul  378
# 13  3651000                New York city, New York       New York  408
# 14  4260000        Philadelphia city, Pennsylvania   Philadelphia  428
# 15  4819000                     Dallas city, Texas         Dallas  206
# 16  4827000                 Fort Worth city, Texas     Fort Worth  206
# 17  4835000                    Houston city, Texas        Houston  288
# 18  5363000               Seattle city, Washington        Seattle  500
#
#      ALAND_mi      Dec      Est     2010     2011     2012     2013     2014  \
# 0   468.65867  3792621  3792724  3796060  3824592  3859267  3891783  3922668
# 1    55.89604   390724   390822   391571   396480   401906   407567   413933
# 2    46.90564   805235   805193   805770   816294   830406   841270   853258
# 3   177.51410   945942   952574   955255   971352   985722  1003735  1016708
# 4   153.30483   600158   599813   603218   619356   633798   648049   663271
# 5    61.13988   601723   601766   605040   620336   635630   650114   660797
# 6    35.98691   399457   399527   400864   410932   416157   421149   431645
# 7   133.43344   420003   420425   422849   431729   443008   447812   455589
# 8   227.34010  2695598  2695620  2697661  2706670  2717989  2724482  2726533
# 9    48.34364   617594   617725   620702   630072   641955   652039   661103
# 10  138.71860   713777   713854   711043   704640   699385   690845   681499
# 11   54.00080   382578   382603   383074   388086   392953   400464   407395
# 12   51.97430   285068   285063   285441   288898   291504   295369   297928
# 13  300.36188  8175133  8174959  8193703  8292688  8383504  8458642  8521135
# 14  134.17818  1526006  1526006  1528271  1539649  1551944  1558109  1564042
# 15  339.95917  1197816  1197824  1200468  1218631  1242035  1258932  1278504
# 16  344.80336   741206   744959   748569   764088   781040   796161   814571
# 17  636.51076  2099451  2094433  2099256  2125450  2159824  2198244  2238795
# 18   83.83377   608660   608664   610333   622532   635974   654176   669641
#
#        2015     2016     2017
# 0   3953459  3981116  3999759
# 1    418929   421566   425195
# 2    866320   876103   884363
# 3   1027560  1031942  1035317
# 4    681618   694777   704621
# 5    672736   684336   693972
# 6    442277   456632   463347
# 7    463479   472967   486290
# 8   2725154  2720275  2716450
# 9    669255   678430   685094
# 10   678250   675480   673104
# 11   411426   415622   422331
# 12   300377   303637   306621
# 13  8582459  8615426  8622698
# 14  1570507  1574765  1580863
# 15  1299793  1322140  1341075
# 16   834968   855504   874168
# 17  2282235  2304482  2312717
# 18   685447   707255   724745

# %% [markdown]
# ### Merging 2000 + cities datasets

# %%
POP_place = cities.merge(POP00_place, on='GEOID')
POP_place = POP_place.drop(['NAME_x', 'Dec', 'Est', 2011, 2012, 2013, 
                           2014, 2015, 2016, 2017, 'state', 'place'], axis=1)
POP_place.columns = ['GEOID', 'NAMELSAD', 'CSA', 'ALAND_mi',
                     '2010', '2000', 'NAME']

POP_place['2000'] = POP_place['2000'].astype(int)
POP_place['2010'] = POP_place['2010'].astype(int)

POP_place['2000-2010_NET'] = POP_place['2010'] - POP_place['2000']
POP_place['2000-2010_%'] = (POP_place['2010'] - POP_place['2000'])/POP_place['2000']

print(POP_place.shape)
POP_place
# Out:
# (19, 9)
#       GEOID                               NAMELSAD  CSA   ALAND_mi     2010  \
# 0   0644000           Los Angeles city, California  348  468.65867  3796060
# 1   0653000               Oakland city, California  488   55.89604   391571
# 2   0667000         San Francisco city, California  488   46.90564   805770
# 3   0668000              San Jose city, California  488  177.51410   955255
# 4   0820000                  Denver city, Colorado  216  153.30483   603218
# 5   1150000  Washington city, District of Columbia  548   61.13988   605040
# 6   1245000                    Miami city, Florida  370   35.98691   400864
# 7   1304000                  Atlanta city, Georgia  122  133.43344   422849
# 8   1714000                 Chicago city, Illinois  176  227.34010  2697661
# 9   2507000             Boston city, Massachusetts  148   48.34364   620702
# 10  2622000                 Detroit city, Michigan  220  138.71860   711043
# 11  2743000            Minneapolis city, Minnesota  378   54.00080   383074
# 12  2758000               St. Paul city, Minnesota  378   51.97430   285441
# 13  3651000                New York city, New York  408  300.36188  8193703
# 14  4260000        Philadelphia city, Pennsylvania  428  134.17818  1528271
# 15  4819000                     Dallas city, Texas  206  339.95917  1200468
# 16  4827000                 Fort Worth city, Texas  206  344.80336   748569
# 17  4835000                    Houston city, Texas  288  636.51076  2099256
# 18  5363000               Seattle city, Washington  500   83.83377   610333
#
#        2000                NAME  2000-2010_NET  2000-2010_%
# 0   3694820    Los Angeles city         101240     0.027401
# 1    399484        Oakland city          -7913    -0.019808
# 2    776733  San Francisco city          29037     0.037384
# 3    894943       San Jose city          60312     0.067392
# 4    554636         Denver city          48582     0.087593
# 5    572059     Washington city          32981     0.057653
# 6    362470          Miami city          38394     0.105923
# 7    416474        Atlanta city           6375     0.015307
# 8   2896016        Chicago city        -198355    -0.068492
# 9    589141         Boston city          31561     0.053571
# 10   951270        Detroit city        -240227    -0.252533
# 11   382618    Minneapolis city            456     0.001192
# 12   287151       St. Paul city          -1710    -0.005955
# 13  8008278       New York city         185425     0.023154
# 14  1517550   Philadelphia city          10721     0.007065
# 15  1188580         Dallas city          11888     0.010002
# 16   534694     Fort Worth city         213875     0.399995
# 17  1953631        Houston city         145625     0.074541
# 18   563374        Seattle city          46959     0.083353

# %% [markdown]
# ### Exporting Places 2000 table to .csv

# %%
POP_place.to_csv('SF1_POP00-10_Places.csv')

# %% [markdown]
# ----
#
#
# ----
#
# # _Another approach to collect census data and export to excel file:_
# * example for the desirable var of this notebook of **population for all counties from SF1 Decennial Census 2000**:
#
# ### Census/Collect_Census_into_Excel.py
# from:
# https://github.com/xbwei/Data-Mining-on-Social-Media/blob/master/Census/Collect_Census_into_Excel.py
#
# - Tutorial on this package:
# https://www.youtube.com/watch?v=5vvAOsIB2fY
#
# The code is as bellow:

# %%
from urllib import request
import json
# from pprint import pprint
import xlwt
# import xlrd
# from xlutils.copy import copy

census_api_key = myAPI #get your key from https://api.census.gov/data/key_signup.html
 
 
url_str = 'https://api.census.gov/data/2000/sf1?get=P001001,NAME'+
          '&for=county:*&in=state:*&key='+census_api_key # create the url of your census data
 
response = request.urlopen(url_str) # read the response into computer
 
 
file = xlwt.Workbook() # create a new excel file
sheet_Co = file.add_sheet('SF1_2000_Co') # add a new sheet named test
html_str = response.read().decode("utf-8") # convert the response into string
i = 0 
if (html_str):
    json_data = json.loads(html_str) # convert the string into json
    for row in json_data:
        cl1, cl2, cl3, cl4 =row
        
        #write format (row_num, col_num, value)
        sheet_Co.write(i,0,cl1)
        sheet_Co.write(i,1,cl2)
        sheet_Co.write(i,2,cl3)
        sheet_Co.write(i,3,cl4)
        i = i+1

file.save('SF1_2000_Co.xlsx') #define the location of your excel file

# %%
# reading in the excel file we extracted from 
POP00all = pd.read_excel('SF1_2000_Co.xlsx')

POP00all['state'] = POP00all['state'].apply(lambda x: '{0:0>2}'.format(x))
POP00all['county'] = POP00all['county'].apply(lambda x: '{0:0>3}'.format(x))

POP00all['STCO'] = POP00all[['state', 'county']].apply(lambda x: ''.join(x), axis=1)

print(POP00all.shape)
POP00all.tail(10)
# Out:
# (3141, 5)
#       P001001               NAME state county   STCO
# 3131     2407    Niobrara County    56    027  56027
# 3132    25786        Park County    56    029  56029
# 3133     8807      Platte County    56    031  56031
# 3134    26560    Sheridan County    56    033  56033
# 3135     5920    Sublette County    56    035  56035
# 3136    37613  Sweetwater County    56    037  56037
# 3137    18251       Teton County    56    039  56039
# 3138    19742       Uinta County    56    041  56041
# 3139     8289    Washakie County    56    043  56043
# 3140     6644      Weston County    56    045  56045
