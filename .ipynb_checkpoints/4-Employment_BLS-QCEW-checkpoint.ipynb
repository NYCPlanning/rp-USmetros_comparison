# %% [markdown]
# Author: Dana Chermesh, Regional Planning intern; NYC DCP<br>
# Summer 2018
#
# ### _US Metros comparison  Notebook no.4_
# # Employment - total industries
# For employment by Industry and owenership please see notebook **4.0-BLS-QCEW_byIndustry.ipynb** in this repo.
# ### Data were obtained from: BLS-QCEW
# Data Source: [Bureau of Labor Statistics, Quarterly Census of Employment and Wages](https://www.bls.gov/cew/datatoc.htm) (BLS-QCEW)

# %% [markdown]
# ----
# # 0 - Imports

# %%
import requests
import pandas as pd
import numpy as np

from __future__ import print_function, division
import matplotlib.pylab as pl
import seaborn as sns
sns.set_style('whitegrid')
# import json

# Spatial
import geopandas as gpd
import fiona
import shapely

import statsmodels.formula.api as smf
import statsmodels.api as sm

# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %% [markdown]
# # 1 - Data acquisition

# %% [markdown]
# ## Download directly from the BLS-QCEW website
#
# The following code was downloaded from the [BLS-QCEW website](https://data.bls.gov/cew/doc/access/data_access_examples.htm#PYTHON), sapmle code for Python 3 ([Download](https://data.bls.gov/cew/doc/access/qcew_python_3x_example.zip))

# %%
import urllib.request
import urllib

# *******************************************************************************
# qcewCreateDataRows : This function takes a raw csv string and splits it into
# a two-dimensional array containing the data and the header row of the csv file
# a try/except block is used to handle for both binary and char encoding
def qcewCreateDataRows(csv):
    dataRows = []
    try: dataLines = csv.decode().split('\r\n')
    except er: dataLines = csv.split('\r\n');
    for row in dataLines:
        dataRows.append(row.split(','))
    return dataRows
# *******************************************************************************


# *******************************************************************************
# qcewGetAreaData : This function takes a year, quarter, and area argument and
# returns an array containing the associated area data. Use 'a' for annual
# averages. 
# For all area codes and titles see:
# http://www.bls.gov/cew/doc/titles/area/area_titles.htm
#
def qcewGetAreaData(year,qtr,area):
    urlPath = "http://data.bls.gov/cew/data/api/[YEAR]/[QTR]/area/[AREA].csv"
    urlPath = urlPath.replace("[YEAR]",year)
    urlPath = urlPath.replace("[QTR]",qtr.lower())
    urlPath = urlPath.replace("[AREA]",area.upper())
    httpStream = urllib.request.urlopen(urlPath)
    csv = httpStream.read()
    httpStream.close()
    return qcewCreateDataRows(csv)
# *******************************************************************************


# *******************************************************************************
# qcewGetIndustryData : This function takes a year, quarter, and industry code
# and returns an array containing the associated industry data. Use 'a' for 
# annual averages. Some industry codes contain hyphens. The CSV files use
# underscores instead of hyphens. So 31-33 becomes 31_33. 
# For all industry codes and titles see:
# http://www.bls.gov/cew/doc/titles/industry/industry_titles.htm
#
def qcewGetIndustryData(year,qtr,industry):
    urlPath = "http://data.bls.gov/cew/data/api/[YEAR]/[QTR]/industry/[IND].csv"
    urlPath = urlPath.replace("[YEAR]",year)
    urlPath = urlPath.replace("[QTR]",qtr.lower())
    urlPath = urlPath.replace("[IND]",industry)
    httpStream = urllib.request.urlopen(urlPath)
    csv = httpStream.read()
    httpStream.close()
    return qcewCreateDataRows(csv)
# *******************************************************************************


# *******************************************************************************
# qcewGetSizeData : This function takes a year and establishment size class code
# and returns an array containing the associated size data. Size data
# is only available for the first quarter of each year.
# For all establishment size classes and titles see:
# http://www.bls.gov/cew/doc/titles/size/size_titles.htm
#
def qcewGetSizeData(year,size):
    urlPath = "http://data.bls.gov/cew/data/api/[YEAR]/1/size/[SIZE].csv"
    urlPath = urlPath.replace("[YEAR]",year)
    urlPath = urlPath.replace("[SIZE]",size)
    httpStream = urllib.request.urlopen(urlPath)
    csv = httpStream.read()
    httpStream.close()
    return qcewCreateDataRows(csv)
# *******************************************************************************

# examples >> (hashed)

# Michigan_Data = qcewGetAreaData("2015","1","26000")
# Auto_Manufacturing = qcewGetIndustryData("2015","1","3361")
# SizeData = qcewGetSizeData("2015","6")

# # prints the industry_code in row 5.
# # remember row zero contains field names
# print(Michigan_Data[5][2])


# # prints the area_fips in row 1.
# # remember row zero contains field names
# print(Auto_Manufacturing[1][0])


# # prints the own_code in row 1.
# # remember row zero contains field names
# print(SizeData[1][1])

# %% [markdown]
# ##  Reading in geo-coded dataset
# created on a different notebook, please refer to [notebook no.0: 0-US_Metro_Comparison_Geographies.ipynb](https://github.com/NYCPlanning/rp-USmetros_comparison/blob/master/0-US_Metro_Comparison_Geographies.ipynb)

# %%
geo = pd.read_csv('../rp-USmetros_comparison/data/USmetros_full_correct.csv')\
                                                .drop(['Unnamed: 0'], axis=1)
geo['STCO'] = geo['STCO'].apply(lambda x: '{0:0>5}'.format(x))

print(geo.shape)
geo.head()
# Out:
# (274, 4)
#    CSA                            CSA_name     County_name   STCO
# 0  348          Los Angeles-Long Beach, CA       Riverside  06065
# 1  348          Los Angeles-Long Beach, CA  San Bernardino  06071
# 2  348          Los Angeles-Long Beach, CA         Ventura  06111
# 3  176        Chicago-Naperville, IL-IN-WI            Cook  17031
# 4  488  San Jose-San Francisco-Oakland, CA         Alameda  06001

# %%
geo.dtypes
# Out:
# CSA             int64
# CSA_name       object
# County_name    object
# STCO           object
# dtype: object

# %%
STCO = list(geo['STCO'])

print(type(STCO))
print(len(STCO))
STCO[:10]
# Out:
# <class 'list'>
# 274
# ['06065',
#  '06071',
#  '06111',
#  '17031',
#  '06001',
#  '06013',
#  '06041',
#  '06055',
#  '06069',
#  '06075']

# %% [markdown]
# ## Getting the 'annual_avg_emplvl' for all industries for every county in the major US metros of this analysis
# using the `qcewGetAreaData()` function built by the BLS QCEW

# %%
JobsCO17 = []

for i in STCO:
    county = qcewGetAreaData("2017","A", i)
    county = pd.DataFrame(county)
    county.columns = county.iloc[0]
    county = county[1:]
    county.columns = [i.replace('"', '') for i in county.columns]
    county = county.replace({'"':''}, regex=True)
    
    county = county[['area_fips','annual_avg_emplvl']][:1]
    
    JobsCO17.append(county)

JobsCO17 = pd.concat(JobsCO17)
JobsCO17.columns = ['STCO', 'Total_emp17']
JobsCO17 = JobsCO17.set_index('STCO')

print(JobsCO17.shape)
JobsCO17.head()
# Out:
# (274, 1)
#       Total_emp17
# STCO
# 06065      713182
# 06071      730004
# 06111      322344
# 17031     2572191
# 06001      771652

# %%
JobsCO17.to_csv('JobsCO17_NEW.csv')

# %% [markdown]
# # 2000 / 2008 / 2010
# ### _** Open data of the BLS QCEW is available from 2013 only; thus data for 2010, 2008 and 2000 were downloaded directly to the local machine**_
#
# Download from https://www.bls.gov/cew/datatoc.htm the .zip files for the selected year under _**CSVs By Area**_ and unzip to your local folder, then run the following code to read in only _**selected counties, 'annual avg emplvl'**_, using python's _streaming_ method.
#
# ## 2000

# %%
# check where your notebook is at, 
# in order to pass the right path in the next cell
# !pwd
# Out:
# /Users/danachermesh/Desktop/rp-USmetros_comparison

# %%
# creating a list of all file names in the unzipped folder

import os

mypath = '/Users/danachermesh/Desktop/rp-USmetros_comparison/data/2000.annual.by_area/'# change to your path
filesList = os.listdir(mypath)

filesList
# Out:
# ['2000.annual 37103 Jones County, North Carolina.csv',
#  '2000.annual 45079 Richland County, South Carolina.csv',
#  '2000.annual 17049 Effingham County, Illinois.csv',
#  '2000.annual 20151 Pratt County, Kansas.csv',
#  '2000.annual C3534 New Iberia, LA MicroSA.csv',
#  '2000.annual 48261 Kenedy County, Texas.csv',
#  '2000.annual C1574 Cambridge, OH MicroSA.csv',
#  '2000.annual 02130 Ketchikan Gateway Borough, Alaska.csv',
#  '2000.annual 33001 Belknap County, New Hampshire.csv',
#  '2000.annual 47141 Putnam County, Tennessee.csv',
#  '2000.annual 08000 Colorado -- Statewide.csv',
#  '2000.annual C4618 Tupelo, MS MicroSA.csv',
#  '2000.annual 39049 Franklin County, Ohio.csv',
#  '2000.annual 20035 Cowley County, Kansas.csv',
#  '2000.annual 13287 Turner County, Georgia.csv',
#  '2000.annual 13137 Habersham County, Georgia.csv',
#  '2000.annual 46081 Lawrence County, South Dakota.csv',
#  '2000.annual 48013 Atascosa County, Texas.csv',
#  '2000.annual 22043 Grant Parish, Louisiana.csv',
#  '2000.annual 48049 Brown County, Texas.csv',
#  '2000.annual 30065 Musselshell County, Montana.csv',
#  '2000.annual C3654 Omaha-Council Bluffs, NE-IA MSA.csv',
#  '2000.annual C1438 Boone, NC MicroSA.csv',
#  '2000.annual 48125 Dickens County, Texas.csv',
#  '2000.annual 48429 Stephens County, Texas.csv',
#  '2000.annual 37045 Cleveland County, North Carolina.csv',
#  '2000.annual 38005 Benson County, North Dakota.csv',
#  '2000.annual 53057 Skagit County, Washington.csv',
#  '2000.annual C4058 Rocky Mount, NC MSA.csv',
#  '2000.annual 48181 Grayson County, Texas.csv',
#  '2000.annual 46111 Sanborn County, South Dakota.csv',
#  '2000.annual 29103 Knox County, Missouri.csv',
#  '2000.annual 32510 Carson City, Nevada.csv',
#  '2000.annual 40059 Harper County, Oklahoma.csv',
#  '2000.annual 18127 Porter County, Indiana.csv',
#  '2000.annual 31177 Washington County, Nebraska.csv',
#  '2000.annual 18011 Boone County, Indiana.csv',
#  '2000.annual 40129 Roger Mills County, Oklahoma.csv',
#  '2000.annual 47123 Monroe County, Tennessee.csv',
#  '2000.annual C4454 Sterling, CO MicroSA.csv',
#  '2000.annual 39133 Portage County, Ohio.csv',
#  '2000.annual C3014 Lebanon, PA MSA.csv',
#  '2000.annual 48391 Refugio County, Texas.csv',
#  '2000.annual 09011 New London County, Connecticut.csv',
#  '2000.annual CS320 Lafayette-West Lafayette-Frankfort, IN CSA.csv',
#  '2000.annual 48315 Marion County, Texas.csv',
#  '2000.annual 19049 Dallas County, Iowa.csv',
#  '2000.annual C2902 Kokomo, IN MSA.csv',
#  '2000.annual 26043 Dickinson County, Michigan.csv',
#  '2000.annual 24029 Kent County, Maryland.csv',
#  '2000.annual 22011 Beauregard Parish, Louisiana.csv',
#  '2000.annual 16075 Payette County, Idaho.csv',
#  '2000.annual 04009 Graham County, Arizona.csv',
#  '2000.annual 72137 Toa Baja Municipio, Puerto Rico.csv',
#  '2000.annual 42007 Beaver County, Pennsylvania.csv',
#  '2000.annual C2682 Idaho Falls, ID MSA.csv',
#  '2000.annual C4406 Spokane-Spokane Valley, WA MSA.csv',
#  '2000.annual 17145 Perry County, Illinois.csv',
#  '2000.annual 45069 Marlboro County, South Carolina.csv',
#  '2000.annual C2226 Fergus Falls, MN MicroSA.csv',
#  '2000.annual C2794 Juneau, AK MicroSA.csv',
#  '2000.annual C3882 Port Angeles, WA MicroSA.csv',
#  '2000.annual 48165 Gaines County, Texas.csv',
#  '2000.annual 26041 Delta County, Michigan.csv',
#  '2000.annual 24015 Cecil County, Maryland.csv',
#  '2000.annual 20051 Ellis County, Kansas.csv',
#  '2000.annual 37025 Cabarrus County, North Carolina.csv',
#  '2000.annual 13249 Schley County, Georgia.csv',
#  '2000.annual C3422 Moultrie, GA MicroSA.csv',
#  '2000.annual C4402 Spirit Lake, IA MicroSA.csv',
#  '2000.annual C2078 Edwards, CO MicroSA.csv',
#  '2000.annual 20045 Douglas County, Kansas.csv',
#  '2000.annual C1330 Beeville, TX MicroSA.csv',
#  '2000.annual 01069 Houston County, Alabama.csv',
#  '2000.annual 22009 Avoyelles Parish, Louisiana.csv',
#  '2000.annual 26029 Charlevoix County, Michigan.csv',
#  '2000.annual 28121 Rankin County, Mississippi.csv',
#  '2000.annual 48325 Medina County, Texas.csv',
#  '2000.annual 41063 Wallowa County, Oregon.csv',
#  '2000.annual CS380 Mobile-Daphne-Fairhope, AL CSA.csv',
#  '2000.annual C2026 Duluth, MN-WI MSA.csv',
#  '2000.annual C2370 Gallup, NM MicroSA.csv',
#  '2000.annual 19027 Carroll County, Iowa.csv',
#  '2000.annual 13217 Newton County, Georgia.csv',
#  '2000.annual C4046 Rockingham, NC MicroSA.csv',
#  '2000.annual 13027 Brooks County, Georgia.csv',
#  '2000.annual 47169 Trousdale County, Tennessee.csv',
#  '2000.annual 19085 Harrison County, Iowa.csv',
#  '2000.annual 17127 Massac County, Illinois.csv',
#  '2000.annual 42039 Crawford County, Pennsylvania.csv',
#  '2000.annual C3934 Provo-Orem, UT MSA.csv',
#  '2000.annual 18071 Jackson County, Indiana.csv',
#  '2000.annual 36031 Essex County, New York.csv',
#  '2000.annual C2186 Fairmont, MN MicroSA.csv',
#  '2000.annual 51009 Amherst County, Virginia.csv',
#  '2000.annual 55015 Calumet County, Wisconsin.csv',
#  '2000.annual 42073 Lawrence County, Pennsylvania.csv',
#  '2000.annual 19149 Plymouth County, Iowa.csv',
#  '2000.annual 36023 Cortland County, New York.csv',
#  '2000.annual 51061 Fauquier County, Virginia.csv',
#  '2000.annual C4610 Tullahoma-Manchester, TN MicroSA.csv',
#  '2000.annual 49045 Tooele County, Utah.csv',
#  '2000.annual 37067 Forsyth County, North Carolina.csv',
#  '2000.annual 40027 Cleveland County, Oklahoma.csv',
#  '2000.annual 47029 Cocke County, Tennessee.csv',
#  '2000.annual 13139 Hall County, Georgia.csv',
#  '2000.annual 04005 Coconino County, Arizona.csv',
#  '2000.annual 37135 Orange County, North Carolina.csv',
#  '2000.annual 48275 Knox County, Texas.csv',
#  '2000.annual 31107 Knox County, Nebraska.csv',
#  '2000.annual 72081 Lares Municipio, Puerto Rico.csv',
#  '2000.annual 38025 Dunn County, North Dakota.csv',
#  '2000.annual 13177 Lee County, Georgia.csv',
#  '2000.annual CS384 Monroe-Ruston-Bastrop, LA CSA.csv',
#  '2000.annual 34017 Hudson County, New Jersey.csv',
#  '2000.annual 28117 Prentiss County, Mississippi.csv',
#  '2000.annual C1294 Baton Rouge, LA MSA.csv',
#  '2000.annual C1282 Bastrop, LA MicroSA.csv',
#  '2000.annual 54103 Wetzel County, West Virginia.csv',
#  '2000.annual CS350 Louisville-Jefferson County--Elizabethtown--Madison, KY-IN CSA.csv',
#  '2000.annual 48445 Terry County, Texas.csv',
#  '2000.annual 25000 Massachusetts -- Statewide.csv',
#  '2000.annual 72015 Arroyo Municipio, Puerto Rico.csv',
#  '2000.annual 05091 Miller County, Arkansas.csv',
#  '2000.annual C1862 Corsicana, TX MicroSA.csv',
#  '2000.annual 19107 Keokuk County, Iowa.csv',
#  '2000.annual 27000 Minnesota -- Statewide.csv',
#  '2000.annual 26163 Wayne County, Michigan.csv',
#  '2000.annual 49023 Juab County, Utah.csv',
#  '2000.annual 20081 Haskell County, Kansas.csv',
#  '2000.annual 20109 Logan County, Kansas.csv',
#  '2000.annual 08059 Jefferson County, Colorado.csv',
#  '2000.annual 21237 Wolfe County, Kentucky.csv',
#  '2000.annual 45081 Saluda County, South Carolina.csv',
#  '2000.annual 08125 Yuma County, Colorado.csv',
#  '2000.annual 40017 Canadian County, Oklahoma.csv',
#  '2000.annual 28129 Smith County, Mississippi.csv',
#  '2000.annual C1162 Ardmore, OK MicroSA.csv',
#  '2000.annual 40077 Latimer County, Oklahoma.csv',
#  '2000.annual 29127 Marion County, Missouri.csv',
#  '2000.annual 13179 Liberty County, Georgia.csv',
#  '2000.annual 19051 Davis County, Iowa.csv',
#  '2000.annual 31071 Garfield County, Nebraska.csv',
#  '2000.annual 24047 Worcester County, Maryland.csv',
#  '2000.annual 18133 Putnam County, Indiana.csv',
#  '2000.annual 18075 Jay County, Indiana.csv',
#  '2000.annual 13257 Stephens County, Georgia.csv',
#  '2000.annual CS248 Findlay-Tiffin, OH CSA.csv',
#  '2000.annual 36017 Chenango County, New York.csv',
#  '2000.annual 33019 Sullivan County, New Hampshire.csv',
#  '2000.annual 35041 Roosevelt County, New Mexico.csv',
#  '2000.annual CS304 Johnson City-Kingsport-Bristol, TN-VA CSA.csv',
#  '2000.annual C3426 Mountain Home, AR MicroSA.csv',
#  '2000.annual 55055 Jefferson County, Wisconsin.csv',
#  '2000.annual 23031 York County, Maine.csv',
#  '2000.annual 31083 Harlan County, Nebraska.csv',
#  '2000.annual C3486 Nacogdoches, TX MicroSA.csv',
#  '2000.annual 27089 Marshall County, Minnesota.csv',
#  '2000.annual C3662 Ontario, OR-ID MicroSA.csv',
#  '2000.annual 15001 Hawaii County, Hawaii.csv',
#  '2000.annual 22001 Acadia Parish, Louisiana.csv',
#  '2000.annual 31119 Madison County, Nebraska.csv',
#  '2000.annual CS472 Sacramento-Roseville, CA CSA.csv',
#  '2000.annual 27009 Benton County, Minnesota.csv',
#  '2000.annual 47027 Clay County, Tennessee.csv',
#  '2000.annual C2534 Harriman, TN MicroSA.csv',
#  '2000.annual 17119 Madison County, Illinois.csv',
#  '2000.annual 06003 Alpine County, California.csv',
#  '2000.annual C1246 Bainbridge, GA MicroSA.csv',
#  '2000.annual 28153 Wayne County, Mississippi.csv',
#  '2000.annual 48319 Mason County, Texas.csv',
#  '2000.annual 78000 Virgin Islands -- Statewide.csv',
#  '2000.annual 13319 Wilkinson County, Georgia.csv',
#  '2000.annual 72117 Rincon Municipio, Puerto Rico.csv',
#  '2000.annual 13013 Barrow County, Georgia.csv',
#  '2000.annual C4518 Talladega-Sylacauga, AL MicroSA.csv',
#  '2000.annual 24031 Montgomery County, Maryland.csv',
#  '2000.annual C4478 Sturgis, MI MicroSA.csv',
#  '2000.annual 01037 Coosa County, Alabama.csv',
#  '2000.annual C1618 Carson City, NV MSA.csv',
#  '2000.annual 46117 Stanley County, South Dakota.csv',
#  '2000.annual C2030 Dumas, TX MicroSA.csv',
#  '2000.annual 16079 Shoshone County, Idaho.csv',
#  '2000.annual 48005 Angelina County, Texas.csv',
#  '2000.annual 29141 Morgan County, Missouri.csv',
#  '2000.annual 08029 Delta County, Colorado.csv',
#  '2000.annual 05095 Monroe County, Arkansas.csv',
#  '2000.annual 23013 Knox County, Maine.csv',
#  '2000.annual 13049 Charlton County, Georgia.csv',
#  '2000.annual 04012 La Paz County, Arizona.csv',
#  '2000.annual 51105 Lee County, Virginia.csv',
#  '2000.annual C1258 Baltimore-Columbia-Towson, MD MSA.csv',
#  '2000.annual 47095 Lake County, Tennessee.csv',
#  '2000.annual 41053 Polk County, Oregon.csv',
#  '2000.annual C2574 Helena, MT MicroSA.csv',
#  '2000.annual 55125 Vilas County, Wisconsin.csv',
#  '2000.annual 20195 Trego County, Kansas.csv',
#  '2000.annual 72153 Yauco Municipio, Puerto Rico.csv',
#  '2000.annual C2870 Kingsport-Bristol-Bristol, TN-VA MSA.csv',
#  '2000.annual C2330 Freeport, IL MicroSA.csv',
#  '2000.annual 06005 Amador County, California.csv',
#  '2000.annual C2810 Kankakee, IL MSA.csv',
#  '2000.annual 40151 Woods County, Oklahoma.csv',
#  '2000.annual 39025 Clermont County, Ohio.csv',
#  '2000.annual C1146 Ann Arbor, MI MSA.csv',
#  '2000.annual 13251 Screven County, Georgia.csv',
#  '2000.annual 28007 Attala County, Mississippi.csv',
#  '2000.annual 46035 Davison County, South Dakota.csv',
#  '2000.annual 54079 Putnam County, West Virginia.csv',
#  '2000.annual 21005 Anderson County, Kentucky.csv',
#  '2000.annual 35003 Catron County, New Mexico.csv',
#  '2000.annual 34019 Hunterdon County, New Jersey.csv',
#  '2000.annual C3034 Lewiston-Auburn, ME MSA.csv',
#  '2000.annual C4638 Ukiah, CA MicroSA.csv',
#  '2000.annual 48221 Hood County, Texas.csv',
#  '2000.annual 01013 Butler County, Alabama.csv',
#  '2000.annual 19177 Van Buren County, Iowa.csv',
#  '2000.annual 47177 Warren County, Tennessee.csv',
#  '2000.annual C3582 North Platte, NE MicroSA.csv',
#  '2000.annual 20037 Crawford County, Kansas.csv',
#  '2000.annual 13101 Echols County, Georgia.csv',
#  '2000.annual 47125 Montgomery County, Tennessee.csv',
#  '2000.annual 37185 Warren County, North Carolina.csv',
#  '2000.annual C1038 Aguadilla-Isabela, PR MSA.csv',
#  '2000.annual 39035 Cuyahoga County, Ohio.csv',
#  '2000.annual 26145 Saginaw County, Michigan.csv',
#  '2000.annual 16071 Oneida County, Idaho.csv',
#  '2000.annual 17159 Richland County, Illinois.csv',
#  '2000.annual 31185 York County, Nebraska.csv',
#  '2000.annual C1198 Athens, TX MicroSA.csv',
#  '2000.annual 19021 Buena Vista County, Iowa.csv',
#  '2000.annual C2062 East Liverpool-Salem, OH MicroSA.csv',
#  '2000.annual 13045 Carroll County, Georgia.csv',
#  '2000.annual 54039 Kanawha County, West Virginia.csv',
#  '2000.annual 31039 Cuming County, Nebraska.csv',
#  '2000.annual C1266 Baraboo, WI MicroSA.csv',
#  '2000.annual 51071 Giles County, Virginia.csv',
#  '2000.annual 26157 Tuscola County, Michigan.csv',
#  '2000.annual CS290 Huntsville-Decatur-Albertville, AL CSA.csv',
#  '2000.annual 13285 Troup County, Georgia.csv',
#  '2000.annual 39155 Trumbull County, Ohio.csv',
#  '2000.annual 01099 Monroe County, Alabama.csv',
#  '2000.annual 29063 DeKalb County, Missouri.csv',
#  '2000.annual C1750 Clewiston, FL MicroSA.csv',
#  '2000.annual C2698 Iowa City, IA MSA.csv',
#  '2000.annual 37075 Graham County, North Carolina.csv',
#  '2000.annual 39075 Holmes County, Ohio.csv',
#  '2000.annual C4008 Richmond-Berea, KY MicroSA.csv',
#  '2000.annual 12099 Palm Beach County, Florida.csv',
#  '2000.annual 17065 Hamilton County, Illinois.csv',
#  '2000.annual 17163 St. Clair County, Illinois.csv',
#  '2000.annual 51550 Chesapeake City, Virginia.csv',
#  '2000.annual 40071 Kay County, Oklahoma.csv',
#  '2000.annual 13095 Dougherty County, Georgia.csv',
#  '2000.annual 24011 Caroline County, Maryland.csv',
#  '2000.annual C4070 Roseburg, OR MicroSA.csv',
#  '2000.annual 47103 Lincoln County, Tennessee.csv',
#  '2000.annual 44001 Bristol County, Rhode Island.csv',
#  '2000.annual C1830 Coos Bay, OR MicroSA.csv',
#  '2000.annual 08055 Huerfano County, Colorado.csv',
#  '2000.annual 28105 Oktibbeha County, Mississippi.csv',
#  '2000.annual C1098 Alpena, MI MicroSA.csv',
#  '2000.annual 40021 Cherokee County, Oklahoma.csv',
#  '2000.annual 08077 Mesa County, Colorado.csv',
#  '2000.annual 42109 Snyder County, Pennsylvania.csv',
#  '2000.annual 18027 Daviess County, Indiana.csv',
#  '2000.annual 31069 Garden County, Nebraska.csv',
#  '2000.annual 34011 Cumberland County, New Jersey.csv',
#  '2000.annual 37079 Greene County, North Carolina.csv',
#  '2000.annual C1326 Bedford, IN MicroSA.csv',
#  '2000.annual 51169 Scott County, Virginia.csv',
#  '2000.annual 39151 Stark County, Ohio.csv',
#  '2000.annual C4794 Waterloo-Cedar Falls, IA MSA.csv',
#  '2000.annual 37039 Cherokee County, North Carolina.csv',
#  '2000.annual 38029 Emmons County, North Dakota.csv',
#  '2000.annual 48331 Milam County, Texas.csv',
#  '2000.annual 31125 Nance County, Nebraska.csv',
#  '2000.annual 40011 Blaine County, Oklahoma.csv',
#  '2000.annual 05001 Arkansas County, Arkansas.csv',
#  '2000.annual C4698 Vicksburg, MS MicroSA.csv',
#  '2000.annual 28049 Hinds County, Mississippi.csv',
#  '2000.annual 01123 Tallapoosa County, Alabama.csv',
#  '2000.annual 47163 Sullivan County, Tennessee.csv',
#  '2000.annual CS274 Greenville-Washington, NC CSA.csv',
#  '2000.annual 08007 Archuleta County, Colorado.csv',
#  '2000.annual 30007 Broadwater County, Montana.csv',
#  '2000.annual 40035 Craig County, Oklahoma.csv',
#  '2000.annual 40103 Noble County, Oklahoma.csv',
#  '2000.annual 29149 Oregon County, Missouri.csv',
#  '2000.annual 44000 Rhode Island -- Statewide.csv',
#  '2000.annual 48027 Bell County, Texas.csv',
#  '2000.annual C3958 Raleigh, NC MSA.csv',
#  '2000.annual 51075 Goochland County, Virginia.csv',
#  '2000.annual C3182 Manitowoc, WI MicroSA.csv',
#  '2000.annual 01115 St. Clair County, Alabama.csv',
#  '2000.annual 37000 North Carolina -- Statewide.csv',
#  '2000.annual 05053 Grant County, Arkansas.csv',
#  '2000.annual 39081 Jefferson County, Ohio.csv',
#  '2000.annual 51005 Alleghany County, Virginia.csv',
#  '2000.annual 54091 Taylor County, West Virginia.csv',
#  '2000.annual 47003 Bedford County, Tennessee.csv',
#  '2000.annual C2648 Humboldt, TN MicroSA.csv',
#  '2000.annual 37109 Lincoln County, North Carolina.csv',
#  '2000.annual 34025 Monmouth County, New Jersey.csv',
#  '2000.annual 37151 Randolph County, North Carolina.csv',
#  '2000.annual C1090 Allentown-Bethlehem-Easton, PA-NJ MSA.csv',
#  '2000.annual 37041 Chowan County, North Carolina.csv',
#  '2000.annual 17151 Pope County, Illinois.csv',
#  '2000.annual 29087 Holt County, Missouri.csv',
#  '2000.annual 54073 Pleasants County, West Virginia.csv',
#  '2000.annual 45073 Oconee County, South Carolina.csv',
#  '2000.annual C1742 Cleveland, TN MSA.csv',
#  '2000.annual 29043 Christian County, Missouri.csv',
#  '2000.annual C4090 Sacramento--Roseville--Arden-Arcade, CA MSA.csv',
#  '2000.annual C3438 Mount Pleasant, MI MicroSA.csv',
#  '2000.annual 19185 Wayne County, Iowa.csv',
#  '2000.annual 22085 Sabine Parish, Louisiana.csv',
#  '2000.annual 72007 Aguas Buenas Municipio, Puerto Rico.csv',
#  '2000.annual 48191 Hall County, Texas.csv',
#  '2000.annual 51177 Spotsylvania County, Virginia.csv',
#  '2000.annual 53037 Kittitas County, Washington.csv',
#  '2000.annual C2498 Grenada, MS MicroSA.csv',
#  '2000.annual 18179 Wells County, Indiana.csv',
#  '2000.annual 18135 Randolph County, Indiana.csv',
#  '2000.annual 48271 Kinney County, Texas.csv',
#  '2000.annual C3482 Myrtle Beach-Conway-North Myrtle Beach, SC-NC MSA.csv',
#  '2000.annual 47009 Blount County, Tennessee.csv',
#  '2000.annual C1366 Big Rapids, MI MicroSA.csv',
#  '2000.annual 36067 Onondaga County, New York.csv',
#  '2000.annual 17001 Adams County, Illinois.csv',
#  '2000.annual 72000 Puerto Rico -- Statewide.csv',
#  '2000.annual 26067 Ionia County, Michigan.csv',
#  '2000.annual 48407 San Jacinto County, Texas.csv',
#  '2000.annual C1846 Cornelia, GA MicroSA.csv',
#  '2000.annual 39069 Henry County, Ohio.csv',
#  '2000.annual 17115 Macon County, Illinois.csv',
#  '2000.annual C1088 Allegan, MI MicroSA.csv',
#  '2000.annual 21075 Fulton County, Kentucky.csv',
#  '2000.annual 40141 Tillman County, Oklahoma.csv',
#  '2000.annual CS142 Birmingham-Hoover-Talladega, AL CSA.csv',
#  '2000.annual 48277 Lamar County, Texas.csv',
#  '2000.annual C1230 Augusta-Waterville, ME MicroSA.csv',
#  '2000.annual 18113 Noble County, Indiana.csv',
#  '2000.annual 27079 Le Sueur County, Minnesota.csv',
#  '2000.annual 13001 Appling County, Georgia.csv',
#  '2000.annual 05035 Crittenden County, Arkansas.csv',
#  '2000.annual C3298 Merrill, WI MicroSA.csv',
#  '2000.annual 31111 Lincoln County, Nebraska.csv',
#  '2000.annual 20055 Finney County, Kansas.csv',
#  '2000.annual 08063 Kit Carson County, Colorado.csv',
#  '2000.annual 48103 Crane County, Texas.csv',
#  '2000.annual 48189 Hale County, Texas.csv',
#  '2000.annual 20075 Hamilton County, Kansas.csv',
#  '2000.annual 49055 Wayne County, Utah.csv',
#  '2000.annual C1054 Albany, OR MSA.csv',
#  '2000.annual 48355 Nueces County, Texas.csv',
#  '2000.annual C4950 Yauco, PR MSA.csv',
#  '2000.annual 46115 Spink County, South Dakota.csv',
#  '2000.annual C1042 Akron, OH MSA.csv',
#  '2000.annual 22027 Claiborne Parish, Louisiana.csv',
#  '2000.annual 28089 Madison County, Mississippi.csv',
#  '2000.annual 41043 Linn County, Oregon.csv',
#  '2000.annual 31165 Sioux County, Nebraska.csv',
#  '2000.annual C2646 Hudson, NY MicroSA.csv',
#  '2000.annual 39019 Carroll County, Ohio.csv',
#  '2000.annual 13017 Ben Hill County, Georgia.csv',
#  '2000.annual 22057 Lafourche Parish, Louisiana.csv',
#  '2000.annual 36057 Montgomery County, New York.csv',
#  '2000.annual 53049 Pacific County, Washington.csv',
#  '2000.annual 02100 Haines Borough, Alaska.csv',
#  '2000.annual 27017 Carlton County, Minnesota.csv',
#  '2000.annual C2878 Kingsville, TX MicroSA.csv',
#  '2000.annual 28127 Simpson County, Mississippi.csv',
#  '2000.annual 25021 Norfolk County, Massachusetts.csv',
#  '2000.annual C2386 Georgetown, SC MicroSA.csv',
#  '2000.annual 05099 Nevada County, Arkansas.csv',
#  '2000.annual C2198 Fallon, NV MicroSA.csv',
#  '2000.annual 39057 Greene County, Ohio.csv',
#  '2000.annual 51107 Loudoun County, Virginia.csv',
#  '2000.annual C3330 Milledgeville, GA MicroSA.csv',
#  '2000.annual 72057 Guayama Municipio, Puerto Rico.csv',
#  '2000.annual C4398 Spencer, IA MicroSA.csv',
#  '2000.annual 55000 Wisconsin -- Statewide.csv',
#  '2000.annual 26087 Lapeer County, Michigan.csv',
#  '2000.annual C2334 Fremont, NE MicroSA.csv',
#  '2000.annual 21205 Rowan County, Kentucky.csv',
#  '2000.annual C3966 Rapid City, SD MSA.csv',
#  '2000.annual 39165 Warren County, Ohio.csv',
#  '2000.annual 36039 Greene County, New York.csv',
#  '2000.annual 08109 Saguache County, Colorado.csv',
#  '2000.annual C1494 Brigham City, UT MicroSA.csv',
#  '2000.annual 35031 Mckinley County, New Mexico.csv',
#  '2000.annual C4882 Willmar, MN MicroSA.csv',
#  '2000.annual 04003 Cochise County, Arizona.csv',
#  '2000.annual C1714 Cincinnati, OH-KY-IN MSA.csv',
#  '2000.annual C4426 Starkville, MS MicroSA.csv',
#  '2000.annual C2394 Gillette, WY MicroSA.csv',
#  '2000.annual C3242 Mayaguez, PR MSA.csv',
#  '2000.annual 38039 Griggs County, North Dakota.csv',
#  '2000.annual 48419 Shelby County, Texas.csv',
#  '2000.annual 19179 Wapello County, Iowa.csv',
#  '2000.annual CS566 Youngstown-Warren, OH-PA CSA.csv',
#  '2000.annual 32027 Pershing County, Nevada.csv',
#  '2000.annual 45001 Abbeville County, South Carolina.csv',
#  '2000.annual 19055 Delaware County, Iowa.csv',
#  '2000.annual 37099 Jackson County, North Carolina.csv',
#  '2000.annual 37027 Caldwell County, North Carolina.csv',
#  '2000.annual C4442 Staunton-Waynesboro, VA MSA.csv',
#  '2000.annual 37093 Hoke County, North Carolina.csv',
#  '2000.annual 19081 Hancock County, Iowa.csv',
#  '2000.annual 08049 Grand County, Colorado.csv',
#  '2000.annual 17083 Jersey County, Illinois.csv',
#  '2000.annual 36007 Broome County, New York.csv',
#  '2000.annual 51510 Alexandria City, Virginia.csv',
#  '2000.annual 46047 Fall River County, South Dakota.csv',
#  '2000.annual 06031 Kings County, California.csv',
#  '2000.annual 22071 Orleans Parish, Louisiana.csv',
#  '2000.annual 17079 Jasper County, Illinois.csv',
#  '2000.annual 37115 Madison County, North Carolina.csv',
#  '2000.annual C1976 DeRidder, LA MicroSA.csv',
#  '2000.annual 18013 Brown County, Indiana.csv',
#  '2000.annual 45075 Orangeburg County, South Carolina.csv',
#  '2000.annual C1150 Anniston-Oxford-Jacksonville, AL MSA.csv',
#  '2000.annual 37113 Macon County, North Carolina.csv',
#  '2000.annual 13000 Georgia -- Statewide.csv',
#  '2000.annual 12049 Hardee County, Florida.csv',
#  '2000.annual 47081 Hickman County, Tennessee.csv',
#  '2000.annual 48493 Wilson County, Texas.csv',
#  '2000.annual 19119 Lyon County, Iowa.csv',
#  '2000.annual C1686 Chattanooga, TN-GA MSA.csv',
#  '2000.annual 48453 Travis County, Texas.csv',
#  '2000.annual C4582 Topeka, KS MSA.csv',
#  '2000.annual 16053 Jerome County, Idaho.csv',
#  '2000.annual 37197 Yadkin County, North Carolina.csv',
#  '2000.annual 54087 Roane County, West Virginia.csv',
#  '2000.annual 26055 Grand Traverse County, Michigan.csv',
#  '2000.annual 35006 Cibola County, New Mexico.csv',
#  '2000.annual 01075 Lamar County, Alabama.csv',
#  '2000.annual 40139 Texas County, Oklahoma.csv',
#  '2000.annual 40093 Major County, Oklahoma.csv',
#  '2000.annual C1962 Del Rio, TX MicroSA.csv',
#  '2000.annual C2518 Hagerstown-Martinsburg, MD-WV MSA.csv',
#  '2000.annual 39013 Belmont County, Ohio.csv',
#  '2000.annual 26077 Kalamazoo County, Michigan.csv',
#  '2000.annual C4362 Sioux Falls, SD MSA.csv',
#  '2000.annual 48421 Sherman County, Texas.csv',
#  '2000.annual 26037 Clinton County, Michigan.csv',
#  '2000.annual 55121 Trempealeau County, Wisconsin.csv',
#  '2000.annual 72047 Corozal Municipio, Puerto Rico.csv',
#  '2000.annual 48031 Blanco County, Texas.csv',
#  '2000.annual 22101 St. Mary Parish, Louisiana.csv',
#  '2000.annual 20103 Leavenworth County, Kansas.csv',
#  '2000.annual 55115 Shawano County, Wisconsin.csv',
#  '2000.annual 29057 Dade County, Missouri.csv',
#  '2000.annual 27051 Grant County, Minnesota.csv',
#  '2000.annual 18153 Sullivan County, Indiana.csv',
#  '2000.annual 46033 Custer County, South Dakota.csv',
#  '2000.annual 41049 Morrow County, Oregon.csv',
#  '2000.annual 05125 Saline County, Arkansas.csv',
#  '2000.annual 55127 Walworth County, Wisconsin.csv',
#  '2000.annual C3022 Levelland, TX MicroSA.csv',
#  '2000.annual 36113 Warren County, New York.csv',
#  '2000.annual 55137 Waushara County, Wisconsin.csv',
#  '2000.annual C1806 Columbus, MS MicroSA.csv',
#  '2000.annual 42101 Philadelphia County, Pennsylvania.csv',
#  '2000.annual 55027 Dodge County, Wisconsin.csv',
#  '2000.annual 27151 Swift County, Minnesota.csv',
#  '2000.annual 17183 Vermilion County, Illinois.csv',
#  '2000.annual 37019 Brunswick County, North Carolina.csv',
#  '2000.annual 26017 Bay County, Michigan.csv',
#  '2000.annual 39149 Shelby County, Ohio.csv',
#  '2000.annual 31081 Hamilton County, Nebraska.csv',
#  '2000.annual 18019 Clark County, Indiana.csv',
#  '2000.annual C3566 Niles-Benton Harbor, MI MSA.csv',
#  '2000.annual C4514 Tahlequah, OK MicroSA.csv',
#  '2000.annual 35043 Sandoval County, New Mexico.csv',
#  '2000.annual C4262 Searcy, AR MicroSA.csv',
#  '2000.annual 49013 Duchesne County, Utah.csv',
#  '2000.annual 13297 Walton County, Georgia.csv',
#  '2000.annual 31079 Hall County, Nebraska.csv',
#  '2000.annual 21197 Powell County, Kentucky.csv',
#  '2000.annual 37163 Sampson County, North Carolina.csv',
#  '2000.annual C4026 Roanoke Rapids, NC MicroSA.csv',
#  '2000.annual 20135 Ness County, Kansas.csv',
#  '2000.annual C3238 Mason City, IA MicroSA.csv',
#  '2000.annual CS324 Lake Charles-Jennings, LA CSA.csv',
#  '2000.annual 29147 Nodaway County, Missouri.csv',
#  '2000.annual 42111 Somerset County, Pennsylvania.csv',
#  '2000.annual 31131 Otoe County, Nebraska.csv',
#  '2000.annual 30037 Golden Valley County, Montana.csv',
#  '2000.annual 31179 Wayne County, Nebraska.csv',
#  '2000.annual 17041 Douglas County, Illinois.csv',
#  '2000.annual 19033 Cerro Gordo County, Iowa.csv',
#  '2000.annual 23019 Penobscot County, Maine.csv',
#  '2000.annual 29093 Iron County, Missouri.csv',
#  '2000.annual C2522 Hammond, LA MSA.csv',
#  '2000.annual C2362 Gainesville, TX MicroSA.csv',
#  '2000.annual 19157 Poweshiek County, Iowa.csv',
#  '2000.annual 17033 Crawford County, Illinois.csv',
#  '2000.annual 19133 Monona County, Iowa.csv',
#  '2000.annual 01087 Macon County, Alabama.csv',
#  '2000.annual 13223 Paulding County, Georgia.csv',
#  '2000.annual 18073 Jasper County, Indiana.csv',
#  '2000.annual 21117 Kenton County, Kentucky.csv',
#  '2000.annual 37033 Caswell County, North Carolina.csv',
#  '2000.annual 29157 Perry County, Missouri.csv',
#  '2000.annual 39079 Jackson County, Ohio.csv',
#  '2000.annual 17121 Marion County, Illinois.csv',
#  '2000.annual 05105 Perry County, Arkansas.csv',
#  '2000.annual 20199 Wallace County, Kansas.csv',
#  '2000.annual 17039 DeWitt County, Illinois.csv',
#  '2000.annual 29167 Polk County, Missouri.csv',
#  '2000.annual 29027 Callaway County, Missouri.csv',
#  '2000.annual 28063 Jefferson County, Mississippi.csv',
#  '2000.annual 42063 Indiana County, Pennsylvania.csv',
#  '2000.annual 36095 Schoharie County, New York.csv',
#  '2000.annual 42025 Carbon County, Pennsylvania.csv',
#  '2000.annual 45027 Clarendon County, South Carolina.csv',
#  '2000.annual 31115 Loup County, Nebraska.csv',
#  '2000.annual 48463 Uvalde County, Texas.csv',
#  '2000.annual 56015 Goshen County, Wyoming.csv',
#  '2000.annual 48299 Llano County, Texas.csv',
#  '2000.annual 20061 Geary County, Kansas.csv',
#  '2000.annual 29023 Butler County, Missouri.csv',
#  '2000.annual 46137 Ziebach County, South Dakota.csv',
#  '2000.annual 48483 Wheeler County, Texas.csv',
#  '2000.annual 48385 Real County, Texas.csv',
#  '2000.annual 01109 Pike County, Alabama.csv',
#  '2000.annual 27153 Todd County, Minnesota.csv',
#  '2000.annual 51051 Dickenson County, Virginia.csv',
#  '2000.annual 46107 Potter County, South Dakota.csv',
#  '2000.annual C4642 Union, SC MicroSA.csv',
#  '2000.annual 17107 Logan County, Illinois.csv',
#  '2000.annual C4502 Sweetwater, TX MicroSA.csv',
#  '2000.annual C4458 Sterling, IL MicroSA.csv',
#  '2000.annual C4018 Riverton, WY MicroSA.csv',
#  '2000.annual 42085 Mercer County, Pennsylvania.csv',
#  '2000.annual C1114 Americus, GA MicroSA.csv',
#  '2000.annual C3086 Logan, UT-ID MSA.csv',
#  '2000.annual C3738 Palm Coast, FL MicroSA.csv',
#  '2000.annual C4118 St. Louis, MO-IL MSA.csv',
#  '2000.annual 20119 Meade County, Kansas.csv',
#  '2000.annual 18057 Hamilton County, Indiana.csv',
#  '2000.annual 40149 Washita County, Oklahoma.csv',
#  '2000.annual 48093 Comanche County, Texas.csv',
#  '2000.annual 48123 DeWitt County, Texas.csv',
#  '2000.annual 30101 Toole County, Montana.csv',
#  '2000.annual C4254 Scranton--Wilkes-Barre--Hazleton, PA MSA.csv',
#  '2000.annual C4918 Winston-Salem, NC MSA.csv',
#  '2000.annual 48361 Orange County, Texas.csv',
#  '2000.annual 05041 Desha County, Arkansas.csv',
#  '2000.annual C1842 Corinth, MS MicroSA.csv',
#  '2000.annual 34041 Warren County, New Jersey.csv',
#  '2000.annual 27099 Mower County, Minnesota.csv',
#  '2000.annual 28065 Jefferson Davis County, Mississippi.csv',
#  '2000.annual 37139 Pasquotank County, North Carolina.csv',
#  '2000.annual 72051 Dorado Municipio, Puerto Rico.csv',
#  '2000.annual 20155 Reno County, Kansas.csv',
#  '2000.annual 48075 Childress County, Texas.csv',
#  '2000.annual 20209 Wyandotte County, Kansas.csv',
#  '2000.annual 13115 Floyd County, Georgia.csv',
#  '2000.annual 06099 Stanislaus County, California.csv',
#  '2000.annual C4622 Tuscaloosa, AL MSA.csv',
#  '2000.annual 27061 Itasca County, Minnesota.csv',
#  '2000.annual 29143 New Madrid County, Missouri.csv',
#  '2000.annual 18039 Elkhart County, Indiana.csv',
#  '2000.annual 72141 Utuado Municipio, Puerto Rico.csv',
#  '2000.annual 20189 Stevens County, Kansas.csv',
#  '2000.annual C4526 Tallulah, LA MicroSA.csv',
#  '2000.annual 46051 Grant County, South Dakota.csv',
#  '2000.annual 06079 San Luis Obispo County, California.csv',
#  '2000.annual C1342 Bemidji, MN MicroSA.csv',
#  '2000.annual 37011 Avery County, North Carolina.csv',
#  '2000.annual 26053 Gogebic County, Michigan.csv',
#  '2000.annual 13199 Meriwether County, Georgia.csv',
#  '2000.annual C3402 Morgan City, LA MicroSA.csv',
#  '2000.annual 48043 Brewster County, Texas.csv',
#  '2000.annual 05033 Crawford County, Arkansas.csv',
#  '2000.annual 20015 Butler County, Kansas.csv',
#  '2000.annual 51031 Campbell County, Virginia.csv',
#  '2000.annual 39129 Pickaway County, Ohio.csv',
#  '2000.annual 22035 East Carroll Parish, Louisiana.csv',
#  '2000.annual 16043 Fremont County, Idaho.csv',
#  '2000.annual 26069 Iosco County, Michigan.csv',
#  '2000.annual 27049 Goodhue County, Minnesota.csv',
#  '2000.annual 51650 Hampton City, Virginia.csv',
#  '2000.annual 40019 Carter County, Oklahoma.csv',
#  '2000.annual C3774 Payson, AZ MicroSA.csv',
#  '2000.annual CS266 Grand Rapids-Wyoming-Muskegon, MI CSA.csv',
#  '2000.annual 27103 Nicollet County, Minnesota.csv',
#  '2000.annual 17189 Washington County, Illinois.csv',
#  '2000.annual CS392 Morristown-Newport, TN CSA.csv',
#  '2000.annual 13075 Cook County, Georgia.csv',
#  '2000.annual C3030 Lewiston, ID-WA MSA.csv',
#  '2000.annual 16083 Twin Falls County, Idaho.csv',
#  '2000.annual C1062 Albemarle, NC MicroSA.csv',
#  '2000.annual 72149 Villalba Municipio, Puerto Rico.csv',
#  '2000.annual 01059 Franklin County, Alabama.csv',
#  '2000.annual 45065 McCormick County, South Carolina.csv',
#  '2000.annual 31087 Hitchcock County, Nebraska.csv',
#  '2000.annual 41015 Curry County, Oregon.csv',
#  '2000.annual 46017 Buffalo County, South Dakota.csv',
#  '2000.annual C2858 Key West, FL MicroSA.csv',
#  '2000.annual C1362 Berlin, NH-VT MicroSA.csv',
#  '2000.annual C3614 Ocean City, NJ MSA.csv',
#  '2000.annual 21047 Christian County, Kentucky.csv',
#  '2000.annual C1290 Batesville, AR MicroSA.csv',
#  '2000.annual C4722 Vineland-Bridgeton, NJ MSA.csv',
#  '2000.annual 13089 DeKalb County, Georgia.csv',
#  '2000.annual 12011 Broward County, Florida.csv',
#  '2000.annual 26073 Isabella County, Michigan.csv',
#  '2000.annual C2998 Lawrenceburg, TN MicroSA.csv',
#  '2000.annual C4466 Stillwater, OK MicroSA.csv',
#  '2000.annual 06091 Sierra County, California.csv',
#  '2000.annual 48495 Winkler County, Texas.csv',
#  '2000.annual C2190 Fairmont, WV MicroSA.csv',
#  '2000.annual 39147 Seneca County, Ohio.csv',
#  '2000.annual C1346 Bend-Redmond, OR MSA.csv',
#  '2000.annual C3118 Lubbock, TX MSA.csv',
#  '2000.annual 06025 Imperial County, California.csv',
#  '2000.annual C4630 Twin Falls, ID MicroSA.csv',
#  '2000.annual 28017 Chickasaw County, Mississippi.csv',
#  '2000.annual 31183 Wheeler County, Nebraska.csv',
#  '2000.annual C2398 Glasgow, KY MicroSA.csv',
#  '2000.annual C2898 Kodiak, AK MicroSA.csv',
#  '2000.annual 01021 Chilton County, Alabama.csv',
#  '2000.annual 20153 Rawlins County, Kansas.csv',
#  '2000.annual 40145 Wagoner County, Oklahoma.csv',
#  '2000.annual 20117 Marshall County, Kansas.csv',
#  '2000.annual 22119 Webster Parish, Louisiana.csv',
#  '2000.annual 42095 Northampton County, Pennsylvania.csv',
#  '2000.annual C1442 Borger, TX MicroSA.csv',
#  '2000.annual 05075 Lawrence County, Arkansas.csv',
#  '2000.annual C1774 Coldwater, MI MicroSA.csv',
#  '2000.annual 37133 Onslow County, North Carolina.csv',
#  '2000.annual 21161 Mason County, Kentucky.csv',
#  '2000.annual C3102 Longview, WA MSA.csv',
#  '2000.annual C2762 Jefferson City, MO MSA.csv',
#  '2000.annual CS258 Fort Wayne-Huntington-Auburn, IN CSA.csv',
#  '2000.annual 20069 Gray County, Kansas.csv',
#  '2000.annual 39113 Montgomery County, Ohio.csv',
#  '2000.annual 17175 Stark County, Illinois.csv',
#  '2000.annual 31053 Dodge County, Nebraska.csv',
#  '2000.annual C3278 Medford, OR MSA.csv',
#  '2000.annual 45049 Hampton County, South Carolina.csv',
#  '2000.annual C2474 Greenville, MS MicroSA.csv',
#  '2000.annual 56041 Uinta County, Wyoming.csv',
#  '2000.annual 13151 Henry County, Georgia.csv',
#  '2000.annual 22103 St. Tammany Parish, Louisiana.csv',
#  '2000.annual C4494 Sumter, SC MSA.csv',
#  '2000.annual 55081 Monroe County, Wisconsin.csv',
#  '2000.annual 05093 Mississippi County, Arkansas.csv',
#  '2000.annual 39109 Miami County, Ohio.csv',
#  '2000.annual 27129 Renville County, Minnesota.csv',
#  '2000.annual 10003 New Castle County, Delaware.csv',
#  '2000.annual C3094 London, KY MicroSA.csv',
#  '2000.annual 05051 Garland County, Arkansas.csv',
#  '2000.annual 01073 Jefferson County, Alabama.csv',
#  '2000.annual 48413 Schleicher County, Texas.csv',
#  '2000.annual CS154 Brownsville-Harlingen-Raymondville, TX CSA.csv',
#  '2000.annual C2482 Greenville, OH MicroSA.csv',
#  '2000.annual C2842 Kennewick-Richland, WA MSA.csv',
#  '2000.annual 40043 Dewey County, Oklahoma.csv',
#  '2000.annual 54005 Boone County, West Virginia.csv',
#  '2000.annual 22109 Terrebonne Parish, Louisiana.csv',
#  '2000.annual 48283 La Salle County, Texas.csv',
#  '2000.annual 19163 Scott County, Iowa.csv',
#  '2000.annual 12033 Escambia County, Florida.csv',
#  '2000.annual 45037 Edgefield County, South Carolina.csv',
#  '2000.annual 49025 Kane County, Utah.csv',
#  '2000.annual 29197 Schuyler County, Missouri.csv',
#  '2000.annual 31047 Dawson County, Nebraska.csv',
#  '2000.annual 13317 Wilkes County, Georgia.csv',
#  '2000.annual 48443 Terrell County, Texas.csv',
#  '2000.annual 21043 Carter County, Kentucky.csv',
#  '2000.annual 12023 Columbia County, Florida.csv',
#  '2000.annual 47155 Sevier County, Tennessee.csv',
#  '2000.annual 37005 Alleghany County, North Carolina.csv',
#  '2000.annual 19041 Clay County, Iowa.csv',
#  '2000.annual C2982 Las Vegas-Henderson-Paradise, NV MSA.csv',
#  '2000.annual 28033 DeSoto County, Mississippi.csv',
#  '2000.annual C1418 Blytheville, AR MicroSA.csv',
#  '2000.annual 13037 Calhoun County, Georgia.csv',
#  '2000.annual 24025 Harford County, Maryland.csv',
#  '2000.annual 18145 Shelby County, Indiana.csv',
#  '2000.annual C3082 Lock Haven, PA MicroSA.csv',
#  '2000.annual 48077 Clay County, Texas.csv',
#  '2000.annual 51750 Radford City, Virginia.csv',
#  '2000.annual C3646 Olean, NY MicroSA.csv',
#  '2000.annual 37105 Lee County, North Carolina.csv',
#  '2000.annual C1526 Brunswick, GA MSA.csv',
#  '2000.annual 18061 Harrison County, Indiana.csv',
#  '2000.annual 55049 Iowa County, Wisconsin.csv',
#  '2000.annual 12129 Wakulla County, Florida.csv',
#  '2000.annual 17149 Pike County, Illinois.csv',
#  '2000.annual 17071 Henderson County, Illinois.csv',
#  '2000.annual 30005 Blaine County, Montana.csv',
#  '2000.annual 31099 Kearney County, Nebraska.csv',
#  '2000.annual C2906 Laconia, NH MicroSA.csv',
#  '2000.annual C4854 Wheeling, WV-OH MSA.csv',
#  '2000.annual 05021 Clay County, Arkansas.csv',
#  '2000.annual 28085 Lincoln County, Mississippi.csv',
#  '2000.annual 20133 Neosho County, Kansas.csv',
#  '2000.annual 51620 Franklin City, Virginia.csv',
#  '2000.annual 37183 Wake County, North Carolina.csv',
#  '2000.annual 21087 Green County, Kentucky.csv',
#  '2000.annual CS336 Lexington-Fayette--Richmond--Frankfort, KY CSA.csv',
#  '2000.annual 01023 Choctaw County, Alabama.csv',
#  '2000.annual 31019 Buffalo County, Nebraska.csv',
#  '2000.annual 48269 King County, Texas.csv',
#  '2000.annual C4506 Syracuse, NY MSA.csv',
#  '2000.annual C4470 Stockton-Lodi, CA MSA.csv',
#  '2000.annual 21109 Jackson County, Kentucky.csv',
#  '2000.annual 44005 Newport County, Rhode Island.csv',
#  '2000.annual 13071 Colquitt County, Georgia.csv',
#  '2000.annual 13205 Mitchell County, Georgia.csv',
#  '2000.annual 17027 Clinton County, Illinois.csv',
#  '2000.annual 21101 Henderson County, Kentucky.csv',
#  '2000.annual 41011 Coos County, Oregon.csv',
#  '2000.annual 27127 Redwood County, Minnesota.csv',
#  '2000.annual 35013 Dona Ana County, New Mexico.csv',
#  '2000.annual 51127 New Kent County, Virginia.csv',
#  '2000.annual 29069 Dunklin County, Missouri.csv',
#  '2000.annual C1558 Butte-Silver Bow, MT MicroSA.csv',
#  '2000.annual C2102 Elizabeth City, NC MicroSA.csv',
#  '2000.annual 40061 Haskell County, Oklahoma.csv',
#  '2000.annual 24510 Baltimore City, Maryland.csv',
#  '2000.annual 26025 Calhoun County, Michigan.csv',
#  '2000.annual 26115 Monroe County, Michigan.csv',
#  '2000.annual 12063 Jackson County, Florida.csv',
#  '2000.annual 48281 Lampasas County, Texas.csv',
#  '2000.annual 51095 James City County, Virginia.csv',
#  '2000.annual C2218 Fayetteville, NC MSA.csv',
#  '2000.annual 46067 Hutchinson County, South Dakota.csv',
#  '2000.annual 13129 Gordon County, Georgia.csv',
#  '2000.annual 29205 Shelby County, Missouri.csv',
#  '2000.annual 17057 Fulton County, Illinois.csv',
#  '2000.annual 47013 Campbell County, Tennessee.csv',
#  '2000.annual 19077 Guthrie County, Iowa.csv',
#  '2000.annual C2242 Flint, MI MSA.csv',
#  '2000.annual 72001 Adjuntas Municipio, Puerto Rico.csv',
#  '2000.annual 47045 Dyer County, Tennessee.csv',
#  '2000.annual 06017 El Dorado County, California.csv',
#  '2000.annual 40147 Washington County, Oklahoma.csv',
#  '2000.annual 36059 Nassau County, New York.csv',
#  '2000.annual 05003 Ashley County, Arkansas.csv',
#  '2000.annual 13237 Putnam County, Georgia.csv',
#  '2000.annual C4594 Trenton, NJ MSA.csv',
#  '2000.annual 39053 Gallia County, Ohio.csv',
#  '2000.annual 02164 Lake and Peninsula Borough, Alaska.csv',
#  '2000.annual 05115 Pope County, Arkansas.csv',
#  '2000.annual 26093 Livingston County, Michigan.csv',
#  '2000.annual 48163 Frio County, Texas.csv',
#  '2000.annual 47127 Moore County, Tennessee.csv',
#  '2000.annual 30051 Liberty County, Montana.csv',
#  '2000.annual 17105 Livingston County, Illinois.csv',
#  '2000.annual 30053 Lincoln County, Montana.csv',
#  '2000.annual 26045 Eaton County, Michigan.csv',
#  '2000.annual 46135 Yankton County, South Dakota.csv',
#  '2000.annual 05017 Chicot County, Arkansas.csv',
#  '2000.annual C1866 Cortland, NY MicroSA.csv',
#  '2000.annual 12131 Walton County, Florida.csv',
#  '2000.annual 53000 Washington -- Statewide.csv',
#  '2000.annual 38045 LaMoure County, North Dakota.csv',
#  '2000.annual 48207 Haskell County, Texas.csv',
#  '2000.annual 48415 Scurry County, Texas.csv',
#  '2000.annual 12031 Duval County, Florida.csv',
#  '2000.annual CS214 Deltona-Daytona Beach-Palm Coast, FL CSA.csv',
#  '2000.annual 08105 Rio Grande County, Colorado.csv',
#  '2000.annual 34033 Salem County, New Jersey.csv',
#  '2000.annual 50009 Essex County, Vermont.csv',
#  '2000.annual 51740 Portsmouth City, Virginia.csv',
#  '2000.annual 13015 Bartow County, Georgia.csv',
#  '2000.annual C3982 Redding, CA MSA.csv',
#  '2000.annual 01095 Marshall County, Alabama.csv',
#  '2000.annual 31151 Saline County, Nebraska.csv',
#  '2000.annual C2410 Gloversville, NY MicroSA.csv',
#  '2000.annual 46113 Shannon County, South Dakota.csv',
#  '2000.annual 42005 Armstrong County, Pennsylvania.csv',
#  '2000.annual 21067 Fayette County, Kentucky.csv',
#  '2000.annual C4014 Riverside-San Bernardino-Ontario, CA MSA.csv',
#  '2000.annual 20141 Osborne County, Kansas.csv',
#  '2000.annual 13079 Crawford County, Georgia.csv',
#  '2000.annual C1634 Cedartown, GA MicroSA.csv',
#  '2000.annual 72115 Quebradillas Municipio, Puerto Rico.csv',
#  '2000.annual 39145 Scioto County, Ohio.csv',
#  '2000.annual 29075 Gentry County, Missouri.csv',
#  '2000.annual 21133 Letcher County, Kentucky.csv',
#  '2000.annual C1382 Birmingham-Hoover, AL MSA.csv',
#  '2000.annual 46045 Edmunds County, South Dakota.csv',
#  '2000.annual C1734 Clearlake, CA MicroSA.csv',
#  '2000.annual C2278 Fort Leonard Wood, MO MicroSA.csv',
#  '2000.annual 29171 Putnam County, Missouri.csv',
#  '2000.annual 01105 Perry County, Alabama.csv',
#  '2000.annual 55077 Marquette County, Wisconsin.csv',
#  '2000.annual 30047 Lake County, Montana.csv',
#  '2000.annual 55123 Vernon County, Wisconsin.csv',
#  '2000.annual C3626 Ogden-Clearfield, UT MSA.csv',
#  '2000.annual C2678 Hutchinson, MN MicroSA.csv',
#  '2000.annual 53025 Grant County, Washington.csv',
#  '2000.annual C1698 Chicago-Naperville-Elgin, IL-IN-WI MSA.csv',
#  '2000.annual 05097 Montgomery County, Arkansas.csv',
#  '2000.annual 55009 Brown County, Wisconsin.csv',
#  '2000.annual 04011 Greenlee County, Arizona.csv',
#  '2000.annual 02201 Prince of Wales-Outer Ketchikan Census Area, Alaska.csv',
#  '2000.annual 37031 Carteret County, North Carolina.csv',
#  '2000.annual 51540 Charlottesville City, Virginia.csv',
#  '2000.annual 27027 Clay County, Minnesota.csv',
#  '2000.annual C2742 Jamestown, ND MicroSA.csv',
#  '2000.annual C3706 Oxford, MS MicroSA.csv',
#  '2000.annual C1610 Carlsbad-Artesia, NM MicroSA.csv',
#  '2000.annual C2434 Grand Rapids-Wyoming, MI MSA.csv',
#  '2000.annual 27011 Big Stone County, Minnesota.csv',
#  '2000.annual 38085 Sioux County, North Dakota.csv',
#  '2000.annual 54025 Greenbrier County, West Virginia.csv',
#  '2000.annual 53071 Walla Walla County, Washington.csv',
#  '2000.annual 08041 El Paso County, Colorado.csv',
#  '2000.annual 32023 Nye County, Nevada.csv',
#  '2000.annual 20059 Franklin County, Kansas.csv',
#  '2000.annual 12117 Seminole County, Florida.csv',
#  '2000.annual 17177 Stephenson County, Illinois.csv',
#  '2000.annual C2530 Hannibal, MO MicroSA.csv',
#  '2000.annual 18083 Knox County, Indiana.csv',
#  '2000.annual 21183 Ohio County, Kentucky.csv',
#  '2000.annual 08019 Clear Creek County, Colorado.csv',
#  '2000.annual 39015 Brown County, Ohio.csv',
#  '2000.annual 47061 Grundy County, Tennessee.csv',
#  '2000.annual C2770 Jesup, GA MicroSA.csv',
#  '2000.annual C4158 Salisbury, NC MicroSA.csv',
#  '2000.annual 28161 Yalobusha County, Mississippi.csv',
#  '2000.annual C2526 Hanford-Corcoran, CA MSA.csv',
#  '2000.annual 48347 Nacogdoches County, Texas.csv',
#  '2000.annual 18089 Lake County, Indiana.csv',
#  '2000.annual C4094 Safford, AZ MicroSA.csv',
#  '2000.annual 32001 Churchill County, Nevada.csv',
#  '2000.annual C2630 Hot Springs, AR MSA.csv',
#  '2000.annual C3226 Marshalltown, IA MicroSA.csv',
#  '2000.annual 54007 Braxton County, West Virginia.csv',
#  '2000.annual C2470 Greensburg, IN MicroSA.csv',
#  '2000.annual C4078 Russellville, AR MicroSA.csv',
#  '2000.annual 08013 Boulder County, Colorado.csv',
#  '2000.annual C3174 Manhattan, KS MSA.csv',
#  '2000.annual 28021 Claiborne County, Mississippi.csv',
#  '2000.annual 33017 Strafford County, New Hampshire.csv',
#  '2000.annual 21177 Muhlenberg County, Kentucky.csv',
#  '2000.annual 72109 Patillas Municipio, Puerto Rico.csv',
#  '2000.annual C3210 Marquette, MI MicroSA.csv',
#  '2000.annual 47175 Van Buren County, Tennessee.csv',
#  '2000.annual 27015 Brown County, Minnesota.csv',
#  '2000.annual 45085 Sumter County, South Carolina.csv',
#  '2000.annual C2206 Faribault-Northfield, MN MicroSA.csv',
#  '2000.annual CS466 Rockford-Freeport-Rochelle, IL CSA.csv',
#  '2000.annual 48341 Moore County, Texas.csv',
#  '2000.annual 28115 Pontotoc County, Mississippi.csv',
#  '2000.annual 48135 Ector County, Texas.csv',
#  '2000.annual 51680 Lynchburg City, Virginia.csv',
#  '2000.annual 22093 St. James Parish, Louisiana.csv',
#  '2000.annual 47159 Smith County, Tennessee.csv',
#  '2000.annual USCMS U.S. Combined Statistical Areas (combined).csv',
#  '2000.annual 27067 Kandiyohi County, Minnesota.csv',
#  '2000.annual 18165 Vermillion County, Indiana.csv',
#  '2000.annual C4902 Winchester, VA-WV MSA.csv',
#  '2000.annual 39039 Defiance County, Ohio.csv',
#  '2000.annual C2938 Lake City, FL MicroSA.csv',
#  '2000.annual C3446 Mount Sterling, KY MicroSA.csv',
#  '2000.annual C1130 Anderson, IN MSA.csv',
#  '2000.annual 05145 White County, Arkansas.csv',
#  '2000.annual 29187 St. Francois County, Missouri.csv',
#  '2000.annual CS273 Greenville-Spartanburg-Anderson, SC CSA.csv',
#  '2000.annual 06095 Solano County, California.csv',
#  '2000.annual 21083 Graves County, Kentucky.csv',
#  '2000.annual 18087 Lagrange County, Indiana.csv',
#  '2000.annual 22023 Cameron Parish, Louisiana.csv',
#  '2000.annual 51720 Norton City, Virginia.csv',
#  '2000.annual 05061 Howard County, Arkansas.csv',
#  '2000.annual 25007 Dukes County, Massachusetts.csv',
#  '2000.annual 48167 Galveston County, Texas.csv',
#  '2000.annual 51683 Manassas City, Virginia.csv',
#  '2000.annual 13087 Decatur County, Georgia.csv',
#  '2000.annual 19193 Woodbury County, Iowa.csv',
#  '2000.annual CS492 Santa Fe-Espanola, NM CSA.csv',
#  '2000.annual 51157 Rappahannock County, Virginia.csv',
#  '2000.annual 06089 Shasta County, California.csv',
#  '2000.annual CS292 Idaho Falls-Rexburg-Blackfoot, ID CSA.csv',
#  '2000.annual 46053 Gregory County, South Dakota.csv',
#  '2000.annual C3070 Lincoln, NE MSA.csv',
#  '2000.annual 08015 Chaffee County, Colorado.csv',
#  '2000.annual 08047 Gilpin County, Colorado.csv',
#  '2000.annual 20023 Cheyenne County, Kansas.csv',
#  '2000.annual C3850 Plymouth, IN MicroSA.csv',
#  '2000.annual 31095 Jefferson County, Nebraska.csv',
#  '2000.annual C3790 Peoria, IL MSA.csv',
#  '2000.annual C4678 Van Wert, OH MicroSA.csv',
#  '2000.annual 35047 San Miguel County, New Mexico.csv',
#  '2000.annual 42093 Montour County, Pennsylvania.csv',
#  '2000.annual 01061 Geneva County, Alabama.csv',
#  '2000.annual 19127 Marshall County, Iowa.csv',
#  '2000.annual 21211 Shelby County, Kentucky.csv',
#  '2000.annual 29085 Hickory County, Missouri.csv',
#  '2000.annual 48295 Lipscomb County, Texas.csv',
#  '2000.annual 18099 Marshall County, Indiana.csv',
#  '2000.annual 39101 Marion County, Ohio.csv',
#  '2000.annual C4578 Toledo, OH MSA.csv',
#  '2000.annual 16023 Butte County, Idaho.csv',
#  '2000.annual 72073 Jayuya Municipio, Puerto Rico.csv',
#  '2000.annual 72009 Aibonito Municipio, Puerto Rico.csv',
#  '2000.annual 13127 Glynn County, Georgia.csv',
#  '2000.annual C4670 Vallejo-Fairfield, CA MSA.csv',
#  '2000.annual 48021 Bastrop County, Texas.csv',
#  '2000.annual 13197 Marion County, Georgia.csv',
#  '2000.annual C3902 Portsmouth, OH MicroSA.csv',
#  '2000.annual 13227 Pickens County, Georgia.csv',
#  '2000.annual 56037 Sweetwater County, Wyoming.csv',
#  '2000.annual 29107 Lafayette County, Missouri.csv',
#  '2000.annual 18177 Wayne County, Indiana.csv',
#  '2000.annual 04023 Santa Cruz County, Arizona.csv',
#  '2000.annual 13209 Montgomery County, Georgia.csv',
#  '2000.annual C2466 Greensboro-High Point, NC MSA.csv',
#  '2000.annual 38057 Mercer County, North Dakota.csv',
#  '2000.annual 08101 Pueblo County, Colorado.csv',
#  '2000.annual 20183 Smith County, Kansas.csv',
#  '2000.annual 30029 Flathead County, Montana.csv',
#  '2000.annual 21061 Edmonson County, Kentucky.csv',
#  '2000.annual 13173 Lanier County, Georgia.csv',
#  '2000.annual 45015 Berkeley County, South Carolina.csv',
#  '2000.annual 02150 Kodiak Island Borough, Alaska.csv',
#  '2000.annual C2442 Grants Pass, OR MSA.csv',
#  '2000.annual C2662 Huntsville, AL MSA.csv',
#  '2000.annual 72061 Guaynabo Municipio, Puerto Rico.csv',
#  '2000.annual 30093 Silver Bow County, Montana.csv',
#  '2000.annual 51193 Westmoreland County, Virginia.csv',
#  '2000.annual 12029 Dixie County, Florida.csv',
#  '2000.annual 21127 Lawrence County, Kentucky.csv',
#  '2000.annual 18141 St. Joseph County, Indiana.csv',
#  '2000.annual 48131 Duval County, Texas.csv',
#  '2000.annual 19035 Cherokee County, Iowa.csv',
#  '2000.annual 48141 El Paso County, Texas.csv',
#  '2000.annual 47157 Shelby County, Tennessee.csv',
#  '2000.annual 37179 Union County, North Carolina.csv',
#  '2000.annual 18041 Fayette County, Indiana.csv',
#  '2000.annual 42037 Columbia County, Pennsylvania.csv',
#  '2000.annual 45077 Pickens County, South Carolina.csv',
#  '2000.annual CS558 Williamsport-Lock Haven, PA CSA.csv',
#  '2000.annual CS378 Minneapolis-St. Paul, MN-WI CSA.csv',
#  '2000.annual C3526 New Castle, PA MicroSA.csv',
#  '2000.annual 51036 Charles City County, Virginia.csv',
#  '2000.annual 51073 Gloucester County, Virginia.csv',
#  '2000.annual C2730 Jacksonville, IL MicroSA.csv',
#  '2000.annual 26135 Oscoda County, Michigan.csv',
#  '2000.annual C3690 Ottumwa, IA MicroSA.csv',
#  '2000.annual C3870 Pontiac, IL MicroSA.csv',
#  '2000.annual 35051 Sierra County, New Mexico.csv',
#  '2000.annual 20171 Scott County, Kansas.csv',
#  '2000.annual 56033 Sheridan County, Wyoming.csv',
#  '2000.annual 36049 Lewis County, New York.csv',
#  '2000.annual C3798 Philadelphia-Camden-Wilmington, PA-NJ-DE-MD MSA.csv',
#  '2000.annual 22099 St. Martin Parish, Louisiana.csv',
#  '2000.annual 13283 Treutlen County, Georgia.csv',
#  '2000.annual 21223 Trimble County, Kentucky.csv',
#  '2000.annual 53015 Cowlitz County, Washington.csv',
#  '2000.annual 51179 Stafford County, Virginia.csv',
#  '2000.annual 28141 Tishomingo County, Mississippi.csv',
#  '2000.annual 16007 Bear Lake County, Idaho.csv',
#  '2000.annual 16049 Idaho County, Idaho.csv',
#  '2000.annual 21235 Whitley County, Kentucky.csv',
#  '2000.annual 17053 Ford County, Illinois.csv',
#  '2000.annual C1582 Campbellsville, KY MicroSA.csv',
#  '2000.annual 08001 Adams County, Colorado.csv',
#  '2000.annual C4498 Sunbury, PA MicroSA.csv',
#  '2000.annual 37167 Stanly County, North Carolina.csv',
#  '2000.annual 47145 Roane County, Tennessee.csv',
#  '2000.annual 51678 Lexington City, Virginia.csv',
#  '2000.annual 72054 Florida Municipio, Puerto Rico.csv',
#  '2000.annual C1174 Ashland, OH MicroSA.csv',
#  '2000.annual 08107 Routt County, Colorado.csv',
#  '2000.annual 20089 Jewell County, Kansas.csv',
#  '2000.annual 18109 Morgan County, Indiana.csv',
#  '2000.annual 13185 Lowndes County, Georgia.csv',
#  '2000.annual 54083 Randolph County, West Virginia.csv',
#  '2000.annual 31007 Banner County, Nebraska.csv',
#  '2000.annual 19195 Worth County, Iowa.csv',
#  '2000.annual 48389 Reeves County, Texas.csv',
#  '2000.annual C2690 Indianapolis-Carmel-Anderson, IN MSA.csv',
#  '2000.annual 37097 Iredell County, North Carolina.csv',
#  '2000.annual C4318 Shelbyville, TN MicroSA.csv',
#  '2000.annual 47041 DeKalb County, Tennessee.csv',
#  '2000.annual 31145 Red Willow County, Nebraska.csv',
#  '2000.annual C2554 Hartford-West Hartford-East Hartford, CT MSA.csv',
#  '2000.annual 19095 Iowa County, Iowa.csv',
#  '2000.annual 27055 Houston County, Minnesota.csv',
#  '2000.annual 13061 Clay County, Georgia.csv',
#  '2000.annual 40029 Coal County, Oklahoma.csv',
#  '2000.annual 47005 Benton County, Tennessee.csv',
#  '2000.annual CS376 Milwaukee-Racine-Waukesha, WI CSA.csv',
#  '2000.annual C4366 Snyder, TX MicroSA.csv',
#  '2000.annual 53017 Douglas County, Washington.csv',
#  '2000.annual 36101 Steuben County, New York.csv',
#  '2000.annual 48397 Rockwall County, Texas.csv',
#  '2000.annual 49001 Beaver County, Utah.csv',
#  '2000.annual 19075 Grundy County, Iowa.csv',
#  ...]

# %%
# creating a list of the selected files for data to be obtained from
# these are only the counties that we are interested in

Co_files00 = []

for filename in filesList:
    for i in STCO:
        if i in filename:
            Co_files00.append(filename)
            
len(Co_files00)
# Out:
# 273

# %%
# streaming method: reduces computer memory consumption, more efficient
# reading in only the value (row+column) we need

import csv

# function to read in data from csv in a streamable mode
def csvRows(filename):
    with open(filename, 'r') as fi:
        reader = csv.DictReader(x.replace('\0', '') for x in fi)
        for row in reader:
            return row['area_fips'], row['annual_avg_emplvl']
        
# creating a path for the folder where all the .csv files are in
# change to your folder if needed
# path = '../DCP Internship/2000.annual.by_area/'

# creating an empty dict to store the data
JobsCO00 = {}

for i in Co_files00:
    row = csvRows(mypath + i)
    # append the data to the empty dict; STCO as key and total_emp as value 
    JobsCO00[row[0]] = row[1]


# making it a DataFrame
JobsCO00 = pd.DataFrame.from_dict(JobsCO00, orient='index', columns=['Total_emp00'])
JobsCO00 = JobsCO00.sort_index()

print(JobsCO00.shape)
print(type(JobsCO00))
print(JobsCO00.dtypes)
JobsCO00.head()
# Out:
# (273, 1)
# <class 'pandas.core.frame.DataFrame'>
# Total_emp00    object
# dtype: object
#       Total_emp00
# 06001      697215
# 06013      337924
# 06037     4110915
# 06041      112454
# 06055       60552

# %%
JobsCO00['Total_emp00'] = JobsCO00['Total_emp00'].astype(int)

# %% [markdown]
# ## 2008

# %%
# creating a list of all file names in the unzipped folder

import os

mypath08 = '/Users/danachermesh/Desktop/rp-USmetros_comparison/data/2008.annual.by_area/'# change to your path
filesList08 = os.listdir(mypath08)

filesList08
# Out:
# ['2008.annual 48107 Crosby County, Texas.csv',
#  '2008.annual 21005 Anderson County, Kentucky.csv',
#  '2008.annual 37153 Richmond County, North Carolina.csv',
#  '2008.annual 78020 St. John, Virgin Islands.csv',
#  '2008.annual 35003 Catron County, New Mexico.csv',
#  '2008.annual 26093 Livingston County, Michigan.csv',
#  '2008.annual C4494 Sumter, SC MSA.csv',
#  '2008.annual 17105 Livingston County, Illinois.csv',
#  '2008.annual 13083 Dade County, Georgia.csv',
#  '2008.annual 06005 Amador County, California.csv',
#  '2008.annual 54069 Ohio County, West Virginia.csv',
#  '2008.annual 08105 Rio Grande County, Colorado.csv',
#  '2008.annual C1586 Canon City, CO MicroSA.csv',
#  '2008.annual 18021 Clay County, Indiana.csv',
#  '2008.annual 13211 Morgan County, Georgia.csv',
#  '2008.annual 45043 Georgetown County, South Carolina.csv',
#  '2008.annual 29051 Cole County, Missouri.csv',
#  '2008.annual C3218 Marshall, MO MicroSA.csv',
#  '2008.annual 72119 Rio Grande Municipio, Puerto Rico.csv',
#  '2008.annual CS434 Ponce-Coamo-Santa Isabel, PR CSA.csv',
#  '2008.annual 19129 Mills County, Iowa.csv',
#  '2008.annual 56025 Natrona County, Wyoming.csv',
#  '2008.annual 72069 Humacao Municipio, Puerto Rico.csv',
#  '2008.annual CS252 Fond du Lac-Beaver Dam, WI CSA.csv',
#  '2008.annual 35013 Dona Ana County, New Mexico.csv',
#  '2008.annual 19045 Clinton County, Iowa.csv',
#  '2008.annual 31091 Hooker County, Nebraska.csv',
#  '2008.annual 72049 Culebra Municipio, Puerto Rico.csv',
#  '2008.annual 20197 Wabaunsee County, Kansas.csv',
#  '2008.annual 40147 Washington County, Oklahoma.csv',
#  '2008.annual 72141 Utuado Municipio, Puerto Rico.csv',
#  '2008.annual C1682 Charlottesville, VA MSA.csv',
#  '2008.annual 51095 James City County, Virginia.csv',
#  '2008.annual 21185 Oldham County, Kentucky.csv',
#  '2008.annual 21025 Breathitt County, Kentucky.csv',
#  '2008.annual C4758 Warner Robins, GA MSA.csv',
#  '2008.annual CS396 Myrtle Beach-Conway, SC-NC CSA.csv',
#  '2008.annual 29111 Lewis County, Missouri.csv',
#  '2008.annual C2546 Harrison, AR MicroSA.csv',
#  '2008.annual 37133 Onslow County, North Carolina.csv',
#  '2008.annual C4634 Tyler, TX MSA.csv',
#  '2008.annual 06003 Alpine County, California.csv',
#  '2008.annual 55073 Marathon County, Wisconsin.csv',
#  '2008.annual 28057 Itawamba County, Mississippi.csv',
#  '2008.annual 48169 Garza County, Texas.csv',
#  '2008.annual C2106 Elizabethtown-Fort Knox, KY MSA.csv',
#  '2008.annual 30057 Madison County, Montana.csv',
#  '2008.annual C3250 Maysville, KY MicroSA.csv',
#  '2008.annual C1898 Cullman, AL MicroSA.csv',
#  '2008.annual CS148 Boston-Worcester-Providence, MA-RI-NH-CT CSA.csv',
#  '2008.annual 13319 Wilkinson County, Georgia.csv',
#  '2008.annual 48029 Bexar County, Texas.csv',
#  '2008.annual 55077 Marquette County, Wisconsin.csv',
#  '2008.annual 28153 Wayne County, Mississippi.csv',
#  '2008.annual 26035 Clare County, Michigan.csv',
#  '2008.annual 48465 Val Verde County, Texas.csv',
#  '2008.annual 28017 Chickasaw County, Mississippi.csv',
#  '2008.annual 24041 Talbot County, Maryland.csv',
#  '2008.annual 05097 Montgomery County, Arkansas.csv',
#  '2008.annual 48343 Morris County, Texas.csv',
#  '2008.annual C3426 Mountain Home, AR MicroSA.csv',
#  '2008.annual CS260 Fresno-Madera, CA CSA.csv',
#  '2008.annual C4418 Springfield, MO MSA.csv',
#  '2008.annual 27075 Lake County, Minnesota.csv',
#  '2008.annual C1010 Aberdeen, SD MicroSA.csv',
#  '2008.annual C4490 Summerville, GA MicroSA.csv',
#  '2008.annual 13063 Clayton County, Georgia.csv',
#  '2008.annual 30021 Dawson County, Montana.csv',
#  '2008.annual 36017 Chenango County, New York.csv',
#  '2008.annual 31071 Garfield County, Nebraska.csv',
#  '2008.annual 72019 Barranquitas Municipio, Puerto Rico.csv',
#  '2008.annual 20185 Stafford County, Kansas.csv',
#  '2008.annual 39999 Unknown Or Undefined, Ohio.csv',
#  '2008.annual 48229 Hudspeth County, Texas.csv',
#  '2008.annual 28129 Smith County, Mississippi.csv',
#  '2008.annual C3714 Paducah, KY-IL MicroSA.csv',
#  '2008.annual 05013 Calhoun County, Arkansas.csv',
#  '2008.annual 23017 Oxford County, Maine.csv',
#  '2008.annual 22077 Pointe Coupee Parish, Louisiana.csv',
#  '2008.annual 05137 Stone County, Arkansas.csv',
#  '2008.annual 48193 Hamilton County, Texas.csv',
#  '2008.annual 44000 Rhode Island -- Statewide.csv',
#  '2008.annual C3890 Portland-Vancouver-Hillsboro, OR-WA MSA.csv',
#  '2008.annual C2070 East Stroudsburg, PA MSA.csv',
#  '2008.annual 48395 Robertson County, Texas.csv',
#  '2008.annual 12091 Okaloosa County, Florida.csv',
#  '2008.annual 01115 St. Clair County, Alabama.csv',
#  '2008.annual C1794 Columbia, TN MicroSA.csv',
#  '2008.annual 48197 Hardeman County, Texas.csv',
#  '2008.annual 41051 Multnomah County, Oregon.csv',
#  '2008.annual US000 U.S. TOTAL.csv',
#  '2008.annual C3538 New Orleans-Metairie, LA MSA.csv',
#  '2008.annual 48447 Throckmorton County, Texas.csv',
#  '2008.annual C2986 Laurel, MS MicroSA.csv',
#  '2008.annual 28049 Hinds County, Mississippi.csv',
#  '2008.annual 05001 Arkansas County, Arkansas.csv',
#  '2008.annual 51775 Salem City, Virginia.csv',
#  '2008.annual 06041 Marin County, California.csv',
#  '2008.annual 51515 Bedford City, Virginia.csv',
#  '2008.annual 55029 Door County, Wisconsin.csv',
#  '2008.annual 19169 Story County, Iowa.csv',
#  '2008.annual C4222 Santa Rosa, CA MSA.csv',
#  '2008.annual 27011 Big Stone County, Minnesota.csv',
#  '2008.annual 26071 Iron County, Michigan.csv',
#  '2008.annual 26085 Lake County, Michigan.csv',
#  '2008.annual 27121 Pope County, Minnesota.csv',
#  '2008.annual 13051 Chatham County, Georgia.csv',
#  '2008.annual 39047 Fayette County, Ohio.csv',
#  '2008.annual C3098 Longview, TX MSA.csv',
#  '2008.annual 40015 Caddo County, Oklahoma.csv',
#  '2008.annual 13147 Hart County, Georgia.csv',
#  '2008.annual 54009 Brooke County, West Virginia.csv',
#  '2008.annual 38067 Pembina County, North Dakota.csv',
#  '2008.annual 51083 Halifax County, Virginia.csv',
#  '2008.annual 28137 Tate County, Mississippi.csv',
#  '2008.annual 31123 Morrill County, Nebraska.csv',
#  '2008.annual 22103 St. Tammany Parish, Louisiana.csv',
#  '2008.annual 17177 Stephenson County, Illinois.csv',
#  '2008.annual 36121 Wyoming County, New York.csv',
#  '2008.annual 41019 Douglas County, Oregon.csv',
#  '2008.annual 40105 Nowata County, Oklahoma.csv',
#  '2008.annual C1754 Clinton, IA MicroSA.csv',
#  '2008.annual 49027 Millard County, Utah.csv',
#  '2008.annual 24011 Caroline County, Maryland.csv',
#  '2008.annual C3630 Ogdensburg-Massena, NY MicroSA.csv',
#  '2008.annual 13095 Dougherty County, Georgia.csv',
#  '2008.annual 17065 Hamilton County, Illinois.csv',
#  '2008.annual 51550 Chesapeake City, Virginia.csv',
#  '2008.annual 08055 Huerfano County, Colorado.csv',
#  '2008.annual 41061 Union County, Oregon.csv',
#  '2008.annual 22093 St. James Parish, Louisiana.csv',
#  '2008.annual C1974 Denver-Aurora-Lakewood, CO MSA.csv',
#  '2008.annual 48351 Newton County, Texas.csv',
#  '2008.annual 40021 Cherokee County, Oklahoma.csv',
#  '2008.annual CS297 Jackson-Humboldt, TN CSA.csv',
#  '2008.annual 47103 Lincoln County, Tennessee.csv',
#  '2008.annual 13133 Greene County, Georgia.csv',
#  '2008.annual 27067 Kandiyohi County, Minnesota.csv',
#  '2008.annual C3818 Pierre, SD MicroSA.csv',
#  '2008.annual 13221 Oglethorpe County, Georgia.csv',
#  '2008.annual 13035 Butts County, Georgia.csv',
#  '2008.annual 06077 San Joaquin County, California.csv',
#  '2008.annual 39103 Medina County, Ohio.csv',
#  '2008.annual 25007 Dukes County, Massachusetts.csv',
#  '2008.annual C2814 Kansas City, MO-KS MSA.csv',
#  '2008.annual 16047 Gooding County, Idaho.csv',
#  '2008.annual C1562 Cadillac, MI MicroSA.csv',
#  '2008.annual 21177 Muhlenberg County, Kentucky.csv',
#  '2008.annual 22117 Washington Parish, Louisiana.csv',
#  '2008.annual 47175 Van Buren County, Tennessee.csv',
#  '2008.annual C2974 Las Cruces, NM MSA.csv',
#  '2008.annual 48119 Delta County, Texas.csv',
#  '2008.annual 29011 Barton County, Missouri.csv',
#  '2008.annual 17159 Richland County, Illinois.csv',
#  '2008.annual 40037 Creek County, Oklahoma.csv',
#  '2008.annual C3734 Palm Bay-Melbourne-Titusville, FL MSA.csv',
#  '2008.annual C1038 Aguadilla-Isabela, PR MSA.csv',
#  '2008.annual 30001 Beaverhead County, Montana.csv',
#  '2008.annual 27001 Aitkin County, Minnesota.csv',
#  '2008.annual C4422 Springfield, OH MSA.csv',
#  '2008.annual 48455 Trinity County, Texas.csv',
#  '2008.annual 39087 Lawrence County, Ohio.csv',
#  '2008.annual CS538 Tulsa-Muskogee-Bartlesville, OK CSA.csv',
#  '2008.annual 13087 Decatur County, Georgia.csv',
#  '2008.annual 51683 Manassas City, Virginia.csv',
#  '2008.annual 17189 Washington County, Illinois.csv',
#  '2008.annual C4370 Somerset, KY MicroSA.csv',
#  '2008.annual CS554 Wausau-Stevens Point-Wisconsin Rapids, WI CSA.csv',
#  '2008.annual 45087 Union County, South Carolina.csv',
#  '2008.annual 13069 Coffee County, Georgia.csv',
#  '2008.annual C3202 Marion, OH MicroSA.csv',
#  '2008.annual 05015 Carroll County, Arkansas.csv',
#  '2008.annual C3542 New Philadelphia-Dover, OH MicroSA.csv',
#  '2008.annual 33999 Unknown Or Undefined, New Hampshire.csv',
#  '2008.annual 20023 Cheyenne County, Kansas.csv',
#  '2008.annual 08047 Gilpin County, Colorado.csv',
#  '2008.annual 18171 Warren County, Indiana.csv',
#  '2008.annual 39111 Monroe County, Ohio.csv',
#  '2008.annual 06083 Santa Barbara County, California.csv',
#  '2008.annual 21211 Shelby County, Kentucky.csv',
#  '2008.annual 20079 Harvey County, Kansas.csv',
#  '2008.annual 31000 Nebraska -- Statewide.csv',
#  '2008.annual 72113 Ponce Municipio, Puerto Rico.csv',
#  '2008.annual 29143 New Madrid County, Missouri.csv',
#  '2008.annual 48201 Harris County, Texas.csv',
#  '2008.annual 37181 Vance County, North Carolina.csv',
#  '2008.annual 48183 Gregg County, Texas.csv',
#  '2008.annual 29225 Webster County, Missouri.csv',
#  '2008.annual 49005 Cache County, Utah.csv',
#  '2008.annual 26005 Allegan County, Michigan.csv',
#  '2008.annual 25003 Berkshire County, Massachusetts.csv',
#  '2008.annual 29185 St. Clair County, Missouri.csv',
#  '2008.annual 47107 McMinn County, Tennessee.csv',
#  '2008.annual 40003 Alfalfa County, Oklahoma.csv',
#  '2008.annual 48499 Wood County, Texas.csv',
#  '2008.annual 28143 Tunica County, Mississippi.csv',
#  '2008.annual 26063 Huron County, Michigan.csv',
#  '2008.annual 24023 Garrett County, Maryland.csv',
#  '2008.annual 41069 Wheeler County, Oregon.csv',
#  '2008.annual 13227 Pickens County, Georgia.csv',
#  '2008.annual 46083 Lincoln County, South Dakota.csv',
#  '2008.annual 22105 Tangipahoa Parish, Louisiana.csv',
#  '2008.annual 22121 West Baton Rouge Parish, Louisiana.csv',
#  '2008.annual 08101 Pueblo County, Colorado.csv',
#  '2008.annual C2278 Fort Leonard Wood, MO MicroSA.csv',
#  '2008.annual C2490 Greenwood, MS MicroSA.csv',
#  '2008.annual 53057 Skagit County, Washington.csv',
#  '2008.annual 54097 Upshur County, West Virginia.csv',
#  '2008.annual 23999 Unknown Or Undefined, Maine.csv',
#  '2008.annual 27143 Sibley County, Minnesota.csv',
#  '2008.annual C3070 Lincoln, NE MSA.csv',
#  '2008.annual 13137 Habersham County, Georgia.csv',
#  '2008.annual C2090 El Campo, TX MicroSA.csv',
#  '2008.annual 40097 Mayes County, Oklahoma.csv',
#  '2008.annual 13215 Muscogee County, Georgia.csv',
#  '2008.annual 35999 Unknown Or Undefined, New Mexico.csv',
#  '2008.annual 18041 Fayette County, Indiana.csv',
#  '2008.annual C2754 Jasper, IN MicroSA.csv',
#  '2008.annual 06025 Imperial County, California.csv',
#  '2008.annual C1138 Andrews, TX MicroSA.csv',
#  '2008.annual 21193 Perry County, Kentucky.csv',
#  '2008.annual 48073 Cherokee County, Texas.csv',
#  '2008.annual 28161 Yalobusha County, Mississippi.csv',
#  '2008.annual C4146 Salina, KS MicroSA.csv',
#  '2008.annual C2958 Lancaster, SC MicroSA.csv',
#  '2008.annual 54007 Braxton County, West Virginia.csv',
#  '2008.annual 40017 Canadian County, Oklahoma.csv',
#  '2008.annual 26135 Oscoda County, Michigan.csv',
#  '2008.annual 78030 St. Thomas, Virgin Islands.csv',
#  '2008.annual 39093 Lorain County, Ohio.csv',
#  '2008.annual 51003 Albemarle County, Virginia.csv',
#  '2008.annual 48063 Camp County, Texas.csv',
#  '2008.annual C2094 El Centro, CA MSA.csv',
#  '2008.annual 31117 McPherson County, Nebraska.csv',
#  '2008.annual C4342 Sierra Vista-Douglas, AZ MSA.csv',
#  '2008.annual 22127 Winn Parish, Louisiana.csv',
#  '2008.annual 16007 Bear Lake County, Idaho.csv',
#  '2008.annual C2010 Dover, DE MSA.csv',
#  '2008.annual 48471 Walker County, Texas.csv',
#  '2008.annual C2142 Enid, OK MicroSA.csv',
#  '2008.annual 47145 Roane County, Tennessee.csv',
#  '2008.annual 54005 Boone County, West Virginia.csv',
#  '2008.annual 34017 Hudson County, New Jersey.csv',
#  '2008.annual 10003 New Castle County, Delaware.csv',
#  '2008.annual 13185 Lowndes County, Georgia.csv',
#  '2008.annual 38025 Dunn County, North Dakota.csv',
#  '2008.annual 31007 Banner County, Nebraska.csv',
#  '2008.annual 36023 Cortland County, New York.csv',
#  '2008.annual 51061 Fauquier County, Virginia.csv',
#  '2008.annual 29187 St. Francois County, Missouri.csv',
#  '2008.annual 37183 Wake County, North Carolina.csv',
#  '2008.annual C4110 St. George, UT MSA.csv',
#  '2008.annual 37175 Transylvania County, North Carolina.csv',
#  '2008.annual C4318 Shelbyville, TN MicroSA.csv',
#  '2008.annual C2690 Indianapolis-Carmel-Anderson, IN MSA.csv',
#  '2008.annual C2266 Fort Collins, CO MSA.csv',
#  '2008.annual 37121 Mitchell County, North Carolina.csv',
#  '2008.annual 37129 New Hanover County, North Carolina.csv',
#  '2008.annual 32019 Lyon County, Nevada.csv',
#  '2008.annual 55015 Calumet County, Wisconsin.csv',
#  '2008.annual 39153 Summit County, Ohio.csv',
#  '2008.annual C2034 Duncan, OK MicroSA.csv',
#  '2008.annual 36053 Madison County, New York.csv',
#  '2008.annual 45085 Sumter County, South Carolina.csv',
#  '2008.annual C4742 Wahpeton, ND-MN MicroSA.csv',
#  '2008.annual 13195 Madison County, Georgia.csv',
#  '2008.annual 23011 Kennebec County, Maine.csv',
#  '2008.annual 40045 Ellis County, Oklahoma.csv',
#  '2008.annual 28021 Claiborne County, Mississippi.csv',
#  '2008.annual 28085 Lincoln County, Mississippi.csv',
#  '2008.annual 48503 Young County, Texas.csv',
#  '2008.annual 47173 Union County, Tennessee.csv',
#  '2008.annual 27169 Winona County, Minnesota.csv',
#  '2008.annual C3450 Mount Vernon, IL MicroSA.csv',
#  '2008.annual C2506 Gulfport-Biloxi-Pascagoula, MS MSA.csv',
#  '2008.annual 39011 Auglaize County, Ohio.csv',
#  '2008.annual 72073 Jayuya Municipio, Puerto Rico.csv',
#  '2008.annual 48217 Hill County, Texas.csv',
#  '2008.annual 38035 Grand Forks County, North Dakota.csv',
#  '2008.annual 27167 Wilkin County, Minnesota.csv',
#  '2008.annual 46019 Butte County, South Dakota.csv',
#  '2008.annual 55065 Lafayette County, Wisconsin.csv',
#  '2008.annual 12063 Jackson County, Florida.csv',
#  '2008.annual 26115 Monroe County, Michigan.csv',
#  '2008.annual 17033 Crawford County, Illinois.csv',
#  '2008.annual 27087 Mahnomen County, Minnesota.csv',
#  '2008.annual 19173 Taylor County, Iowa.csv',
#  '2008.annual CS278 Hartford-West Hartford, CT CSA.csv',
#  '2008.annual C2738 Jacksonville, TX MicroSA.csv',
#  '2008.annual 48000 Texas -- Statewide.csv',
#  '2008.annual 17057 Fulton County, Illinois.csv',
#  '2008.annual 29205 Shelby County, Missouri.csv',
#  '2008.annual 41017 Deschutes County, Oregon.csv',
#  '2008.annual 01117 Shelby County, Alabama.csv',
#  '2008.annual 13191 McIntosh County, Georgia.csv',
#  '2008.annual C1894 Crowley, LA MicroSA.csv',
#  '2008.annual 05003 Ashley County, Arkansas.csv',
#  '2008.annual 36059 Nassau County, New York.csv',
#  '2008.annual 30053 Lincoln County, Montana.csv',
#  '2008.annual CS496 Savannah-Hinesville-Statesboro, GA CSA.csv',
#  '2008.annual 30051 Liberty County, Montana.csv',
#  '2008.annual 47127 Moore County, Tennessee.csv',
#  '2008.annual C3982 Redding, CA MSA.csv',
#  '2008.annual 31081 Hamilton County, Nebraska.csv',
#  '2008.annual 53000 Washington -- Statewide.csv',
#  '2008.annual 45059 Laurens County, South Carolina.csv',
#  '2008.annual 35047 San Miguel County, New Mexico.csv',
#  '2008.annual 05017 Chicot County, Arkansas.csv',
#  '2008.annual 37073 Gates County, North Carolina.csv',
#  '2008.annual 13253 Seminole County, Georgia.csv',
#  '2008.annual 39175 Wyandot County, Ohio.csv',
#  '2008.annual 23015 Lincoln County, Maine.csv',
#  '2008.annual 55109 St. Croix County, Wisconsin.csv',
#  '2008.annual CS348 Los Angeles-Long Beach, CA CSA.csv',
#  '2008.annual 33005 Cheshire County, New Hampshire.csv',
#  '2008.annual 21103 Henry County, Kentucky.csv',
#  '2008.annual C4666 Valdosta, GA MSA.csv',
#  '2008.annual 51157 Rappahannock County, Virginia.csv',
#  '2008.annual 42037 Columbia County, Pennsylvania.csv',
#  '2008.annual 02150 Kodiak Island Borough, Alaska.csv',
#  '2008.annual 51063 Floyd County, Virginia.csv',
#  '2008.annual 51191 Washington County, Virginia.csv',
#  '2008.annual 31151 Saline County, Nebraska.csv',
#  '2008.annual C2066 Easton, MD MicroSA.csv',
#  '2008.annual 55115 Shawano County, Wisconsin.csv',
#  '2008.annual 29075 Gentry County, Missouri.csv',
#  '2008.annual 13281 Towns County, Georgia.csv',
#  '2008.annual 51193 Westmoreland County, Virginia.csv',
#  '2008.annual 48309 McLennan County, Texas.csv',
#  '2008.annual CS330 Lansing-East Lansing-Owosso, MI CSA.csv',
#  '2008.annual C2466 Greensboro-High Point, NC MSA.csv',
#  '2008.annual 29171 Putnam County, Missouri.csv',
#  '2008.annual 48095 Concho County, Texas.csv',
#  '2008.annual 48437 Swisher County, Texas.csv',
#  '2008.annual 35006 Cibola County, New Mexico.csv',
#  '2008.annual CS206 Dallas-Fort Worth, TX-OK CSA.csv',
#  '2008.annual C4594 Trenton, NJ MSA.csv',
#  '2008.annual 12061 Indian River County, Florida.csv',
#  '2008.annual 47081 Hickman County, Tennessee.csv',
#  '2008.annual 13231 Pike County, Georgia.csv',
#  '2008.annual 17000 Illinois -- Statewide.csv',
#  '2008.annual 55009 Brown County, Wisconsin.csv',
#  '2008.annual 48399 Runnels County, Texas.csv',
#  '2008.annual 08103 Rio Blanco County, Colorado.csv',
#  '2008.annual 48037 Bowie County, Texas.csv',
#  '2008.annual 39085 Lake County, Ohio.csv',
#  '2008.annual C3190 Mansfield, OH MSA.csv',
#  '2008.annual 37167 Stanly County, North Carolina.csv',
#  '2008.annual 32015 Lander County, Nevada.csv',
#  '2008.annual C4378 South Bend-Mishawaka, IN-MI MSA.csv',
#  '2008.annual 12089 Nassau County, Florida.csv',
#  '2008.annual 39000 Ohio -- Statewide.csv',
#  '2008.annual 34041 Warren County, New Jersey.csv',
#  '2008.annual C3746 Panama City, FL MSA.csv',
#  '2008.annual C2418 Granbury, TX MicroSA.csv',
#  '2008.annual 27083 Lyon County, Minnesota.csv',
#  '2008.annual 27123 Ramsey County, Minnesota.csv',
#  '2008.annual C2826 Kearney, NE MicroSA.csv',
#  '2008.annual 46089 McPherson County, South Dakota.csv',
#  '2008.annual 20059 Franklin County, Kansas.csv',
#  '2008.annual C3478 Muskogee, OK MicroSA.csv',
#  '2008.annual C3790 Peoria, IL MSA.csv',
#  '2008.annual 48199 Hardin County, Texas.csv',
#  '2008.annual 19101 Jefferson County, Iowa.csv',
#  '2008.annual 12005 Bay County, Florida.csv',
#  '2008.annual 39065 Hardin County, Ohio.csv',
#  '2008.annual 51036 Charles City County, Virginia.csv',
#  '2008.annual 05009 Boone County, Arkansas.csv',
#  '2008.annual 20091 Johnson County, Kansas.csv',
#  '2008.annual C4578 Toledo, OH MSA.csv',
#  '2008.annual 17077 Jackson County, Illinois.csv',
#  '2008.annual C3150 Madison, IN MicroSA.csv',
#  '2008.annual C1338 Bellingham, WA MSA.csv',
#  '2008.annual 16073 Owyhee County, Idaho.csv',
#  '2008.annual 42075 Lebanon County, Pennsylvania.csv',
#  '2008.annual CS304 Johnson City-Kingsport-Bristol, TN-VA CSA.csv',
#  '2008.annual 46099 Minnehaha County, South Dakota.csv',
#  '2008.annual 27015 Brown County, Minnesota.csv',
#  '2008.annual 08083 Montezuma County, Colorado.csv',
#  '2008.annual 28015 Carroll County, Mississippi.csv',
#  '2008.annual 16045 Gem County, Idaho.csv',
#  '2008.annual 29027 Callaway County, Missouri.csv',
#  '2008.annual C4778 Washington, IN MicroSA.csv',
#  '2008.annual 27091 Martin County, Minnesota.csv',
#  '2008.annual 46063 Harding County, South Dakota.csv',
#  '2008.annual 54021 Gilmer County, West Virginia.csv',
#  '2008.annual 05143 Washington County, Arkansas.csv',
#  '2008.annual 22029 Concordia Parish, Louisiana.csv',
#  '2008.annual 47159 Smith County, Tennessee.csv',
#  '2008.annual C4522 Tallahassee, FL MSA.csv',
#  '2008.annual 08113 San Miguel County, Colorado.csv',
#  '2008.annual C3494 Naples-Immokalee-Marco Island, FL MSA.csv',
#  '2008.annual C3246 Mayfield, KY MicroSA.csv',
#  '2008.annual C3274 Meadville, PA MicroSA.csv',
#  '2008.annual 22019 Calcasieu Parish, Louisiana.csv',
#  '2008.annual C2306 Fort Wayne, IN MSA.csv',
#  '2008.annual 21083 Graves County, Kentucky.csv',
#  '2008.annual 47051 Franklin County, Tennessee.csv',
#  '2008.annual 01017 Chambers County, Alabama.csv',
#  '2008.annual C2046 Durant, OK MicroSA.csv',
#  '2008.annual C1566 Calhoun, GA MicroSA.csv',
#  '2008.annual 48167 Galveston County, Texas.csv',
#  '2008.annual 05061 Howard County, Arkansas.csv',
#  '2008.annual 18053 Grant County, Indiana.csv',
#  '2008.annual C1190 Athens, OH MicroSA.csv',
#  '2008.annual 06037 Los Angeles County, California.csv',
#  '2008.annual 18039 Elkhart County, Indiana.csv',
#  '2008.annual 02050 Bethel Census Area, Alaska.csv',
#  '2008.annual 06105 Trinity County, California.csv',
#  '2008.annual C4390 Spartanburg, SC MSA.csv',
#  '2008.annual C3382 Monroe, WI MicroSA.csv',
#  '2008.annual 54075 Pocahontas County, West Virginia.csv',
#  '2008.annual 48407 San Jacinto County, Texas.csv',
#  '2008.annual 13003 Atkinson County, Georgia.csv',
#  '2008.annual C3402 Morgan City, LA MicroSA.csv',
#  '2008.annual C3866 Ponce, PR MSA.csv',
#  '2008.annual 36063 Niagara County, New York.csv',
#  '2008.annual 08025 Crowley County, Colorado.csv',
#  '2008.annual 20999 Unknown Or Undefined, Kansas.csv',
#  '2008.annual 21123 Larue County, Kentucky.csv',
#  '2008.annual 42067 Juniata County, Pennsylvania.csv',
#  '2008.annual 36067 Onondaga County, New York.csv',
#  '2008.annual 40019 Carter County, Oklahoma.csv',
#  '2008.annual 17023 Clark County, Illinois.csv',
#  '2008.annual C3118 Lubbock, TX MSA.csv',
#  '2008.annual C1506 Brookings, OR MicroSA.csv',
#  '2008.annual 48211 Hemphill County, Texas.csv',
#  '2008.annual 20131 Nemaha County, Kansas.csv',
#  '2008.annual 29213 Taney County, Missouri.csv',
#  '2008.annual 51025 Brunswick County, Virginia.csv',
#  '2008.annual C1378 Binghamton, NY MSA.csv',
#  '2008.annual 21191 Pendleton County, Kentucky.csv',
#  '2008.annual 45009 Bamberg County, South Carolina.csv',
#  '2008.annual 05119 Pulaski County, Arkansas.csv',
#  '2008.annual 29510 St. Louis City, Missouri.csv',
#  '2008.annual 31001 Adams County, Nebraska.csv',
#  '2008.annual 48401 Rusk County, Texas.csv',
#  '2008.annual 46101 Moody County, South Dakota.csv',
#  '2008.annual C4942 Yakima, WA MSA.csv',
#  '2008.annual 13119 Franklin County, Georgia.csv',
#  '2008.annual 01047 Dallas County, Alabama.csv',
#  '2008.annual 12011 Broward County, Florida.csv',
#  '2008.annual 47143 Rhea County, Tennessee.csv',
#  '2008.annual 08011 Bent County, Colorado.csv',
#  '2008.annual 53001 Adams County, Washington.csv',
#  '2008.annual 29123 Madison County, Missouri.csv',
#  '2008.annual C1822 Connersville, IN MicroSA.csv',
#  '2008.annual 01021 Chilton County, Alabama.csv',
#  '2008.annual 48403 Sabine County, Texas.csv',
#  '2008.annual 21111 Jefferson County, Kentucky.csv',
#  '2008.annual 55057 Juneau County, Wisconsin.csv',
#  '2008.annual 39061 Hamilton County, Ohio.csv',
#  '2008.annual 34005 Burlington County, New Jersey.csv',
#  '2008.annual 25005 Bristol County, Massachusetts.csv',
#  '2008.annual 26027 Cass County, Michigan.csv',
#  '2008.annual 47003 Bedford County, Tennessee.csv',
#  '2008.annual C4162 Salt Lake City, UT MSA.csv',
#  '2008.annual 12037 Franklin County, Florida.csv',
#  '2008.annual C2050 Durham-Chapel Hill, NC MSA.csv',
#  '2008.annual 20117 Marshall County, Kansas.csv',
#  '2008.annual 37141 Pender County, North Carolina.csv',
#  '2008.annual 21107 Hopkins County, Kentucky.csv',
#  '2008.annual 39113 Montgomery County, Ohio.csv',
#  '2008.annual 38057 Mercer County, North Dakota.csv',
#  '2008.annual CS258 Fort Wayne-Huntington-Auburn, IN CSA.csv',
#  '2008.annual 26999 Unknown Or Undefined, Michigan.csv',
#  '2008.annual 54049 Marion County, West Virginia.csv',
#  '2008.annual 51089 Henry County, Virginia.csv',
#  '2008.annual 18097 Marion County, Indiana.csv',
#  '2008.annual C3454 Mount Vernon, OH MicroSA.csv',
#  '2008.annual 48363 Palo Pinto County, Texas.csv',
#  '2008.annual C3090 Logansport, IN MicroSA.csv',
#  '2008.annual 45011 Barnwell County, South Carolina.csv',
#  '2008.annual 22071 Orleans Parish, Louisiana.csv',
#  '2008.annual 48373 Polk County, Texas.csv',
#  '2008.annual 27105 Nobles County, Minnesota.csv',
#  '2008.annual 45063 Lexington County, South Carolina.csv',
#  '2008.annual 54077 Preston County, West Virginia.csv',
#  '2008.annual 20169 Saline County, Kansas.csv',
#  '2008.annual CS476 St. Louis-St. Charles-Farmington, MO-IL CSA.csv',
#  '2008.annual C1486 Bridgeport-Stamford-Norwalk, CT MSA.csv',
#  '2008.annual 17067 Hancock County, Illinois.csv',
#  '2008.annual C4258 Seaford, DE MicroSA.csv',
#  '2008.annual 28039 George County, Mississippi.csv',
#  '2008.annual 51510 Alexandria City, Virginia.csv',
#  '2008.annual 26131 Ontonagon County, Michigan.csv',
#  '2008.annual 51073 Gloucester County, Virginia.csv',
#  '2008.annual 36119 Westchester County, New York.csv',
#  '2008.annual C3770 Pascagoula, MS MSA.csv',
#  '2008.annual C1386 Bishop, CA MicroSA.csv',
#  '2008.annual C2594 Hilton Head Island-Bluffton-Beaufort, SC MSA.csv',
#  '2008.annual C2430 Grand Junction, CO MSA.csv',
#  '2008.annual 08109 Saguache County, Colorado.csv',
#  '2008.annual 26081 Kent County, Michigan.csv',
#  '2008.annual 18025 Crawford County, Indiana.csv',
#  '2008.annual 21043 Carter County, Kentucky.csv',
#  '2008.annual 13279 Toombs County, Georgia.csv',
#  '2008.annual 27085 McLeod County, Minnesota.csv',
#  '2008.annual 31047 Dawson County, Nebraska.csv',
#  '2008.annual 39127 Perry County, Ohio.csv',
#  '2008.annual 48083 Coleman County, Texas.csv',
#  '2008.annual 29073 Gasconade County, Missouri.csv',
#  '2008.annual C2982 Las Vegas-Henderson-Paradise, NV MSA.csv',
#  '2008.annual 16027 Canyon County, Idaho.csv',
#  '2008.annual 22075 Plaquemines Parish, Louisiana.csv',
#  '2008.annual 13007 Baker County, Georgia.csv',
#  '2008.annual C2582 Hereford, TX MicroSA.csv',
#  '2008.annual C3330 Milledgeville, GA MicroSA.csv',
#  '2008.annual C1630 Cedar Rapids, IA MSA.csv',
#  '2008.annual 13037 Calhoun County, Georgia.csv',
#  '2008.annual C1418 Blytheville, AR MicroSA.csv',
#  '2008.annual 28113 Pike County, Mississippi.csv',
#  '2008.annual 46093 Meade County, South Dakota.csv',
#  '2008.annual C4726 Virginia Beach-Norfolk-Newport News, VA-NC MSA.csv',
#  '2008.annual 12129 Wakulla County, Florida.csv',
#  '2008.annual 29049 Clinton County, Missouri.csv',
#  '2008.annual 55075 Marinette County, Wisconsin.csv',
#  '2008.annual 38013 Burke County, North Dakota.csv',
#  '2008.annual 47059 Greene County, Tennessee.csv',
#  '2008.annual 27017 Carlton County, Minnesota.csv',
#  '2008.annual 19105 Jones County, Iowa.csv',
#  '2008.annual 13059 Clarke County, Georgia.csv',
#  '2008.annual C2562 Hattiesburg, MS MSA.csv',
#  '2008.annual 20177 Shawnee County, Kansas.csv',
#  '2008.annual C2598 Hinesville, GA MSA.csv',
#  '2008.annual 48501 Yoakum County, Texas.csv',
#  '2008.annual 48127 Dimmit County, Texas.csv',
#  '2008.annual 01053 Escambia County, Alabama.csv',
#  '2008.annual 31145 Red Willow County, Nebraska.csv',
#  '2008.annual 48431 Sterling County, Texas.csv',
#  '2008.annual 27021 Cass County, Minnesota.csv',
#  '2008.annual 51620 Franklin City, Virginia.csv',
#  '2008.annual 48435 Sutton County, Texas.csv',
#  '2008.annual 51053 Dinwiddie County, Virginia.csv',
#  '2008.annual 48285 Lavaca County, Texas.csv',
#  '2008.annual C3066 Lincoln, IL MicroSA.csv',
#  '2008.annual C3278 Medford, OR MSA.csv',
#  '2008.annual 01023 Choctaw County, Alabama.csv',
#  '2008.annual 13161 Jeff Davis County, Georgia.csv',
#  '2008.annual 37053 Currituck County, North Carolina.csv',
#  '2008.annual 31149 Rock County, Nebraska.csv',
#  '2008.annual 55035 Eau Claire County, Wisconsin.csv',
#  '2008.annual 08079 Mineral County, Colorado.csv',
#  '2008.annual 25011 Franklin County, Massachusetts.csv',
#  '2008.annual 27047 Freeborn County, Minnesota.csv',
#  '2008.annual 19003 Adams County, Iowa.csv',
#  '2008.annual C1390 Bismarck, ND MSA.csv',
#  '2008.annual 34999 Unknown Or Undefined, New Jersey.csv',
#  '2008.annual 34031 Passaic County, New Jersey.csv',
#  '2008.annual C2934 Lake Charles, LA MSA.csv',
#  '2008.annual CS174 Chattanooga-Cleveland-Dalton, TN-GA-AL CSA.csv',
#  '2008.annual 46105 Perkins County, South Dakota.csv',
#  '2008.annual 19083 Hardin County, Iowa.csv',
#  '2008.annual 55055 Jefferson County, Wisconsin.csv',
#  '2008.annual 01000 Alabama -- Statewide.csv',
#  '2008.annual C3350 Minot, ND MicroSA.csv',
#  '2008.annual 05127 Scott County, Arkansas.csv',
#  '2008.annual 16029 Caribou County, Idaho.csv',
#  '2008.annual 78000 Virgin Islands -- Statewide.csv',
#  '2008.annual 18181 White County, Indiana.csv',
#  '2008.annual 37023 Burke County, North Carolina.csv',
#  '2008.annual 24031 Montgomery County, Maryland.csv',
#  '2008.annual C2154 Escanaba, MI MicroSA.csv',
#  '2008.annual C4166 San Angelo, TX MSA.csv',
#  '2008.annual C2522 Hammond, LA MSA.csv',
#  '2008.annual 01029 Cleburne County, Alabama.csv',
#  '2008.annual 13135 Gwinnett County, Georgia.csv',
#  '2008.annual 01077 Lauderdale County, Alabama.csv',
#  '2008.annual C4202 San Luis Obispo-Paso Robles-Arroyo Grande, CA MSA.csv',
#  '2008.annual 13171 Lamar County, Georgia.csv',
#  '2008.annual C4374 Somerset, PA MicroSA.csv',
#  '2008.annual C1410 Bloomsburg-Berwick, PA MSA.csv',
#  '2008.annual 50017 Orange County, Vermont.csv',
#  '2008.annual 39017 Butler County, Ohio.csv',
#  '2008.annual C1382 Birmingham-Hoover, AL MSA.csv',
#  '2008.annual 41001 Baker County, Oregon.csv',
#  '2008.annual 46081 Lawrence County, South Dakota.csv',
#  '2008.annual C4326 Sheridan, WY MicroSA.csv',
#  '2008.annual C3590 North Wilkesboro, NC MicroSA.csv',
#  '2008.annual 30075 Powder River County, Montana.csv',
#  '2008.annual 13245 Richmond County, Georgia.csv',
#  '2008.annual 51740 Portsmouth City, Virginia.csv',
#  '2008.annual C4154 Salisbury, MD-DE MSA.csv',
#  '2008.annual 27051 Grant County, Minnesota.csv',
#  '2008.annual 33001 Belknap County, New Hampshire.csv',
#  '2008.annual 36113 Warren County, New York.csv',
#  '2008.annual C2114 Elkhart-Goshen, IN MSA.csv',
#  '2008.annual 38001 Adams County, North Dakota.csv',
#  '2008.annual 05125 Saline County, Arkansas.csv',
#  '2008.annual 12007 Bradford County, Florida.csv',
#  '2008.annual 04017 Navajo County, Arizona.csv',
#  '2008.annual 27151 Swift County, Minnesota.csv',
#  '2008.annual 06013 Contra Costa County, California.csv',
#  '2008.annual 55027 Dodge County, Wisconsin.csv',
#  '2008.annual 72045 Comerio Municipio, Puerto Rico.csv',
#  '2008.annual CS216 Denver-Aurora, CO CSA.csv',
#  '2008.annual 28149 Warren County, Mississippi.csv',
#  '2008.annual 16061 Lewis County, Idaho.csv',
#  '2008.annual 48265 Kerr County, Texas.csv',
#  '2008.annual 01093 Marion County, Alabama.csv',
#  '2008.annual C4074 Roswell, NM MicroSA.csv',
#  '2008.annual CS512 Sioux City-Vermillion, IA-SD-NE CSA.csv',
#  '2008.annual 29045 Clark County, Missouri.csv',
#  '2008.annual C3950 Quincy, IL-MO MicroSA.csv',
#  '2008.annual 21197 Powell County, Kentucky.csv',
#  '2008.annual 56011 Crook County, Wyoming.csv',
#  '2008.annual 34013 Essex County, New Jersey.csv',
#  '2008.annual C2650 Huntingdon, PA MicroSA.csv',
#  '2008.annual 08033 Dolores County, Colorado.csv',
#  '2008.annual 31105 Kimball County, Nebraska.csv',
#  '2008.annual C4500 Susanville, CA MicroSA.csv',
#  '2008.annual 27029 Clearwater County, Minnesota.csv',
#  '2008.annual 19061 Dubuque County, Iowa.csv',
#  '2008.annual C4866 Wichita Falls, TX MSA.csv',
#  '2008.annual 48393 Roberts County, Texas.csv',
#  '2008.annual 48203 Harrison County, Texas.csv',
#  '2008.annual C3638 Okeechobee, FL MicroSA.csv',
#  '2008.annual C1982 Detroit-Warren-Dearborn, MI MSA.csv',
#  '2008.annual 32017 Lincoln County, Nevada.csv',
#  '2008.annual 48335 Mitchell County, Texas.csv',
#  '2008.annual 20013 Brown County, Kansas.csv',
#  '2008.annual 19063 Emmet County, Iowa.csv',
#  '2008.annual 21225 Union County, Kentucky.csv',
#  '2008.annual C3346 Minneapolis-St. Paul-Bloomington, MN-WI MSA.csv',
#  '2008.annual C2362 Gainesville, TX MicroSA.csv',
#  '2008.annual 23019 Penobscot County, Maine.csv',
#  '2008.annual 51127 New Kent County, Virginia.csv',
#  '2008.annual 27127 Redwood County, Minnesota.csv',
#  '2008.annual 27135 Roseau County, Minnesota.csv',
#  '2008.annual 51153 Prince William County, Virginia.csv',
#  '2008.annual C4086 Rutland, VT MicroSA.csv',
#  '2008.annual 06095 Solano County, California.csv',
#  '2008.annual 42127 Wayne County, Pennsylvania.csv',
#  '2008.annual 45041 Florence County, South Carolina.csv',
#  '2008.annual C2862 Kill Devil Hills, NC MicroSA.csv',
#  '2008.annual 55111 Sauk County, Wisconsin.csv',
#  '2008.annual C3078 Little Rock-North Little Rock-Conway, AR MSA.csv',
#  '2008.annual 21233 Webster County, Kentucky.csv',
#  '2008.annual 37135 Orange County, North Carolina.csv',
#  '2008.annual 22023 Cameron Parish, Louisiana.csv',
#  '2008.annual 21117 Kenton County, Kentucky.csv',
#  '2008.annual C2314 Frankfort, IN MicroSA.csv',
#  '2008.annual 21051 Clay County, Kentucky.csv',
#  '2008.annual 42039 Crawford County, Pennsylvania.csv',
#  '2008.annual 17121 Marion County, Illinois.csv',
#  '2008.annual 30027 Fergus County, Montana.csv',
#  '2008.annual 42073 Lawrence County, Pennsylvania.csv',
#  '2008.annual 24009 Calvert County, Maryland.csv',
#  '2008.annual 17039 DeWitt County, Illinois.csv',
#  '2008.annual C1158 Arcadia, FL MicroSA.csv',
#  '2008.annual CS138 Beckley-Oak Hill, WV CSA.csv',
#  '2008.annual 51023 Botetourt County, Virginia.csv',
#  '2008.annual C3780 Pella, IA MicroSA.csv',
#  '2008.annual 23000 Maine -- Statewide.csv',
#  '2008.annual 31077 Greeley County, Nebraska.csv',
#  '2008.annual C2950 Lamesa, TX MicroSA.csv',
#  '2008.annual C4534 Taos, NM MicroSA.csv',
#  '2008.annual 29023 Butler County, Missouri.csv',
#  '2008.annual 05071 Johnson County, Arkansas.csv',
#  '2008.annual 48313 Madison County, Texas.csv',
#  '2008.annual C4034 Rochester, MN MSA.csv',
#  '2008.annual 28999 Unknown Or Undefined, Mississippi.csv',
#  '2008.annual 30999 Unknown Or Undefined, Montana.csv',
#  '2008.annual C1718 City of The Dalles, OR MicroSA.csv',
#  '2008.annual 48347 Nacogdoches County, Texas.csv',
#  '2008.annual C2902 Kokomo, IN MSA.csv',
#  '2008.annual CS140 Bend-Redmond-Prineville, OR CSA.csv',
#  '2008.annual 45081 Saluda County, South Carolina.csv',
#  '2008.annual 21085 Grayson County, Kentucky.csv',
#  '2008.annual 72015 Arroyo Municipio, Puerto Rico.csv',
#  '2008.annual C1954 Decatur, IN MicroSA.csv',
#  '2008.annual C4450 Stephenville, TX MicroSA.csv',
#  '2008.annual 21143 Lyon County, Kentucky.csv',
#  '2008.annual 17095 Knox County, Illinois.csv',
#  '2008.annual 48115 Dawson County, Texas.csv',
#  '2008.annual 25023 Plymouth County, Massachusetts.csv',
#  '2008.annual 31015 Boyd County, Nebraska.csv',
#  '2008.annual 42109 Snyder County, Pennsylvania.csv',
#  '2008.annual 01097 Mobile County, Alabama.csv',
#  '2008.annual 13219 Oconee County, Georgia.csv',
#  '2008.annual 27099 Mower County, Minnesota.csv',
#  '2008.annual 16003 Adams County, Idaho.csv',
#  '2008.annual 20137 Norton County, Kansas.csv',
#  '2008.annual 13269 Taylor County, Georgia.csv',
#  '2008.annual 48003 Andrews County, Texas.csv',
#  '2008.annual C3754 Paris, TN MicroSA.csv',
#  '2008.annual 17181 Union County, Illinois.csv',
#  '2008.annual 13109 Evans County, Georgia.csv',
#  '2008.annual 48075 Childress County, Texas.csv',
#  '2008.annual 38029 Emmons County, North Dakota.csv',
#  '2008.annual 51035 Carroll County, Virginia.csv',
#  '2008.annual CS384 Monroe-Ruston-Bastrop, LA CSA.csv',
#  '2008.annual 38005 Benson County, North Dakota.csv',
#  '2008.annual 05075 Lawrence County, Arkansas.csv',
#  '2008.annual 30065 Musselshell County, Montana.csv',
#  '2008.annual 72117 Rincon Municipio, Puerto Rico.csv',
#  '2008.annual C3028 Lewisburg, TN MicroSA.csv',
#  '2008.annual 37143 Perquimans County, North Carolina.csv',
#  '2008.annual 20031 Coffey County, Kansas.csv',
#  '2008.annual 48111 Dallam County, Texas.csv',
#  '2008.annual C2222 Fayetteville-Springdale-Rogers, AR-MO MSA.csv',
#  '2008.annual CS564 York-Hanover-Gettysburg, PA CSA.csv',
#  '2008.annual 31177 Washington County, Nebraska.csv',
#  '2008.annual C4346 Sikeston, MO MicroSA.csv',
#  '2008.annual 19001 Adair County, Iowa.csv',
#  '2008.annual 22119 Webster Parish, Louisiana.csv',
#  '2008.annual C3970 Raymondville, TX MicroSA.csv',
#  '2008.annual 41025 Harney County, Oregon.csv',
#  '2008.annual 06091 Sierra County, California.csv',
#  '2008.annual 02280 Wrangell-Petersburg Census Area, Alaska.csv',
#  '2008.annual 26073 Isabella County, Michigan.csv',
#  '2008.annual 21049 Clark County, Kentucky.csv',
#  '2008.annual C1354 Bennington, VT MicroSA.csv',
#  '2008.annual 39091 Logan County, Ohio.csv',
#  '2008.annual 47189 Wilson County, Tennessee.csv',
#  '2008.annual 39097 Madison County, Ohio.csv',
#  '2008.annual C1186 Atchison, KS MicroSA.csv',
#  '2008.annual C3978 Red Bluff, CA MicroSA.csv',
#  '2008.annual 12101 Pasco County, Florida.csv',
#  '2008.annual 05109 Pike County, Arkansas.csv',
#  '2008.annual C1094 Alma, MI MicroSA.csv',
#  '2008.annual 26047 Emmet County, Michigan.csv',
#  '2008.annual 48475 Ward County, Texas.csv',
#  '2008.annual 20001 Allen County, Kansas.csv',
#  '2008.annual 37051 Cumberland County, North Carolina.csv',
#  '2008.annual C4906 Winfield, KS MicroSA.csv',
#  '2008.annual 39001 Adams County, Ohio.csv',
#  '2008.annual 46025 Clark County, South Dakota.csv',
#  '2008.annual C4650 Urbana, OH MicroSA.csv',
#  '2008.annual 27049 Goodhue County, Minnesota.csv',
#  '2008.annual 12083 Marion County, Florida.csv',
#  '2008.annual 46039 Deuel County, South Dakota.csv',
#  '2008.annual 05033 Crawford County, Arkansas.csv',
#  '2008.annual 48505 Zapata County, Texas.csv',
#  '2008.annual C2302 Fort Walton Beach-Crestview-Destin, FL MSA.csv',
#  '2008.annual 39141 Ross County, Ohio.csv',
#  '2008.annual C4826 Weirton-Steubenville, WV-OH MSA.csv',
#  '2008.annual 51031 Campbell County, Virginia.csv',
#  '2008.annual 48023 Baylor County, Texas.csv',
#  '2008.annual 21075 Fulton County, Kentucky.csv',
#  '2008.annual C4558 Thomaston, GA MicroSA.csv',
#  '2008.annual 42007 Beaver County, Pennsylvania.csv',
#  '2008.annual 39005 Ashland County, Ohio.csv',
#  '2008.annual 13001 Appling County, Georgia.csv',
#  '2008.annual 46077 Kingsbury County, South Dakota.csv',
#  '2008.annual 20075 Hamilton County, Kansas.csv',
#  '2008.annual CS178 Cincinnati-Wilmington-Maysville, OH-KY-IN CSA.csv',
#  '2008.annual 21021 Boyle County, Kentucky.csv',
#  '2008.annual 22021 Caldwell Parish, Louisiana.csv',
#  '2008.annual 08043 Fremont County, Colorado.csv',
#  '2008.annual 48209 Hays County, Texas.csv',
#  '2008.annual 28105 Oktibbeha County, Mississippi.csv',
#  '2008.annual 47169 Trousdale County, Tennessee.csv',
#  '2008.annual C4674 Valley, AL MicroSA.csv',
#  '2008.annual C4686 Vernal, UT MicroSA.csv',
#  '2008.annual C3914 Prescott, AZ MSA.csv',
#  '2008.annual 08014 Broomfield County, Colorado.csv',
#  '2008.annual 54999 Unknown Or Undefined, West Virginia.csv',
#  '2008.annual C2746 Jamestown-Dunkirk-Fredonia, NY MicroSA.csv',
#  '2008.annual 37075 Graham County, North Carolina.csv',
#  '2008.annual 54039 Kanawha County, West Virginia.csv',
#  '2008.annual 11001 District of Columbia.csv',
#  '2008.annual 49057 Weber County, Utah.csv',
#  '2008.annual 49000 Utah -- Statewide.csv',
#  '2008.annual 48311 McMullen County, Texas.csv',
#  '2008.annual 22009 Avoyelles Parish, Louisiana.csv',
#  '2008.annual 26029 Charlevoix County, Michigan.csv',
#  '2008.annual 19087 Henry County, Iowa.csv',
#  '2008.annual 05099 Nevada County, Arkansas.csv',
#  '2008.annual 31085 Hayes County, Nebraska.csv',
#  '2008.annual 37185 Warren County, North Carolina.csv',
#  '2008.annual C1674 Charlotte-Concord-Gastonia, NC-SC MSA.csv',
#  '2008.annual 01131 Wilcox County, Alabama.csv',
#  '2008.annual 26087 Lapeer County, Michigan.csv',
#  '2008.annual 13021 Bibb County, Georgia.csv',
#  '2008.annual C4286 Seneca, SC MicroSA.csv',
#  '2008.annual 32003 Clark County, Nevada.csv',
#  '2008.annual 16063 Lincoln County, Idaho.csv',
#  '2008.annual 36039 Greene County, New York.csv',
#  '2008.annual 20111 Lyon County, Kansas.csv',
#  '2008.annual 12093 Okeechobee County, Florida.csv',
#  '2008.annual 04003 Cochise County, Arizona.csv',
#  '2008.annual 13029 Bryan County, Georgia.csv',
#  '2008.annual 12069 Lake County, Florida.csv',
#  '2008.annual 13005 Bacon County, Georgia.csv',
#  '2008.annual 46023 Charles Mix County, South Dakota.csv',
#  '2008.annual 31035 Clay County, Nebraska.csv',
#  '2008.annual 18017 Cass County, Indiana.csv',
#  '2008.annual 12075 Levy County, Florida.csv',
#  '2008.annual 29197 Schuyler County, Missouri.csv',
#  '2008.annual 01019 Cherokee County, Alabama.csv',
#  '2008.annual CS274 Greenville-Washington, NC CSA.csv',
#  '2008.annual 05031 Craighead County, Arkansas.csv',
#  '2008.annual C3650 Olympia-Tumwater, WA MSA.csv',
#  '2008.annual 49031 Piute County, Utah.csv',
#  '2008.annual 32027 Pershing County, Nevada.csv',
#  '2008.annual C1670 Charleston-North Charleston, SC MSA.csv',
#  '2008.annual 72029 Canovanas Municipio, Puerto Rico.csv',
#  '2008.annual 56001 Albany County, Wyoming.csv',
#  '2008.annual 36007 Broome County, New York.csv',
#  '2008.annual 17083 Jersey County, Illinois.csv',
#  '2008.annual C4602 Truckee-Grass Valley, CA MicroSA.csv',
#  '2008.annual C2962 Lansing-East Lansing, MI MSA.csv',
#  '2008.annual 56007 Carbon County, Wyoming.csv',
#  '2008.annual C2586 Hickory-Lenoir-Morganton, NC MSA.csv',
#  '2008.annual 01073 Jefferson County, Alabama.csv',
#  '2008.annual 13073 Columbia County, Georgia.csv',
#  '2008.annual 38047 Logan County, North Dakota.csv',
#  '2008.annual 17079 Jasper County, Illinois.csv',
#  '2008.annual 18051 Gibson County, Indiana.csv',
#  '2008.annual CS180 Claremont-Lebanon, NH-VT CSA.csv',
#  '2008.annual CS312 Kansas City-Overland Park-Kansas City, MO-KS CSA.csv',
#  '2008.annual 29189 St. Louis County, Missouri.csv',
#  '2008.annual 37079 Greene County, North Carolina.csv',
#  '2008.annual 01007 Bibb County, Alabama.csv',
#  '2008.annual 19029 Cass County, Iowa.csv',
#  '2008.annual 34011 Cumberland County, New Jersey.csv',
#  '2008.annual C1150 Anniston-Oxford-Jacksonville, AL MSA.csv',
#  '2008.annual 40135 Sequoyah County, Oklahoma.csv',
#  '2008.annual C2758 Jayuya, PR MicroSA.csv',
#  '2008.annual 22037 East Feliciana Parish, Louisiana.csv',
#  '2008.annual 40009 Beckham County, Oklahoma.csv',
#  '2008.annual 45073 Oconee County, South Carolina.csv',
#  '2008.annual C1054 Albany, OR MSA.csv',
#  '2008.annual 10000 Delaware -- Statewide.csv',
#  '2008.annual 19139 Muscatine County, Iowa.csv',
#  '2008.annual 29127 Marion County, Missouri.csv',
#  '2008.annual 24017 Charles County, Maryland.csv',
#  '2008.annual 48143 Erath County, Texas.csv',
#  '2008.annual 19007 Appanoose County, Iowa.csv',
#  '2008.annual C1662 Charleston, WV MSA.csv',
#  '2008.annual 26057 Gratiot County, Michigan.csv',
#  '2008.annual CS194 Columbus-Auburn-Opelika, GA-AL CSA.csv',
#  '2008.annual 37171 Surry County, North Carolina.csv',
#  '2008.annual C3114 Louisville-Jefferson County, KY-IN MSA.csv',
#  '2008.annual 45007 Anderson County, South Carolina.csv',
#  '2008.annual 29133 Mississippi County, Missouri.csv',
#  '2008.annual C2806 Kalispell, MT MicroSA.csv',
#  '2008.annual 13179 Liberty County, Georgia.csv',
#  '2008.annual 53061 Snohomish County, Washington.csv',
#  '2008.annual C2018 DuBois, PA MicroSA.csv',
#  '2008.annual CS222 Dothan-Enterprise-Ozark, AL CSA.csv',
#  '2008.annual 42133 York County, Pennsylvania.csv',
#  '2008.annual 46033 Custer County, South Dakota.csv',
#  '2008.annual 31083 Harlan County, Nebraska.csv',
#  '2008.annual 27053 Hennepin County, Minnesota.csv',
#  '2008.annual 18067 Howard County, Indiana.csv',
#  '2008.annual 29199 Scotland County, Missouri.csv',
#  '2008.annual 22045 Iberia Parish, Louisiana.csv',
#  '2008.annual 54067 Nicholas County, West Virginia.csv',
#  '2008.annual 37041 Chowan County, North Carolina.csv',
#  '2008.annual 16033 Clark County, Idaho.csv',
#  '2008.annual 05047 Franklin County, Arkansas.csv',
#  '2008.annual C3486 Nacogdoches, TX MicroSA.csv',
#  '2008.annual C4354 Silverthorne, CO MicroSA.csv',
#  '2008.annual 46009 Bon Homme County, South Dakota.csv',
#  '2008.annual 13131 Grady County, Georgia.csv',
#  '2008.annual 39083 Knox County, Ohio.csv',
#  '2008.annual 35011 De Baca County, New Mexico.csv',
#  '2008.annual CS218 Des Moines-Ames-West Des Moines, IA CSA.csv',
#  '2008.annual 21207 Russell County, Kentucky.csv',
#  '2008.annual C1370 Big Spring, TX MicroSA.csv',
#  '2008.annual 17111 McHenry County, Illinois.csv',
#  '2008.annual 54087 Roane County, West Virginia.csv',
#  '2008.annual 30109 Wibaux County, Montana.csv',
#  '2008.annual C1302 Bay City, MI MSA.csv',
#  '2008.annual 05095 Monroe County, Arkansas.csv',
#  '2008.annual C3502 Natchez, MS-LA MicroSA.csv',
#  '2008.annual 53007 Chelan County, Washington.csv',
#  '2008.annual 29141 Morgan County, Missouri.csv',
#  '2008.annual 29201 Scott County, Missouri.csv',
#  '2008.annual 32031 Washoe County, Nevada.csv',
#  '2008.annual 55125 Vilas County, Wisconsin.csv',
#  '2008.annual 56003 Big Horn County, Wyoming.csv',
#  '2008.annual 22073 Ouachita Parish, Louisiana.csv',
#  '2008.annual 21089 Greenup County, Kentucky.csv',
#  '2008.annual 40081 Lincoln County, Oklahoma.csv',
#  '2008.annual 27081 Lincoln County, Minnesota.csv',
#  '2008.annual C2870 Kingsport-Bristol-Bristol, TN-VA MSA.csv',
#  '2008.annual 37003 Alexander County, North Carolina.csv',
#  '2008.annual 36085 Richmond County, New York.csv',
#  '2008.annual C2846 Keokuk-Fort Madison, IA-MO MicroSA.csv',
#  '2008.annual 13251 Screven County, Georgia.csv',
#  '2008.annual CS482 Salt Lake City-Provo-Orem, UT CSA.csv',
#  '2008.annual 42031 Clarion County, Pennsylvania.csv',
#  '2008.annual 39067 Harrison County, Ohio.csv',
#  '2008.annual 35043 Sandoval County, New Mexico.csv',
#  '2008.annual C3034 Lewiston-Auburn, ME MSA.csv',
#  '2008.annual 51177 Spotsylvania County, Virginia.csv',
#  '2008.annual 55005 Barron County, Wisconsin.csv',
#  '2008.annual 20037 Crawford County, Kansas.csv',
#  '2008.annual 13293 Upson County, Georgia.csv',
#  '2008.annual C3566 Niles-Benton Harbor, MI MSA.csv',
#  '2008.annual 42025 Carbon County, Pennsylvania.csv',
#  '2008.annual C1926 Danville, VA MicroSA.csv',
#  '2008.annual 06039 Madera County, California.csv',
#  '2008.annual C1922 Danville, KY MicroSA.csv',
#  '2008.annual 08045 Garfield County, Colorado.csv',
#  '2008.annual CS508 Shreveport-Bossier City-Minden, LA CSA.csv',
#  '2008.annual 72129 San Lorenzo Municipio, Puerto Rico.csv',
#  '2008.annual 38049 McHenry County, North Dakota.csv',
#  '2008.annual 48367 Parker County, Texas.csv',
#  '2008.annual C3894 Port St. Lucie, FL MSA.csv',
#  '2008.annual 31039 Cuming County, Nebraska.csv',
#  '2008.annual C3958 Raleigh, NC MSA.csv',
#  '2008.annual 24999 Unknown Or Undefined, Maryland.csv',
#  '2008.annual 13045 Carroll County, Georgia.csv',
#  '2008.annual 25021 Norfolk County, Massachusetts.csv',
#  '2008.annual 39115 Morgan County, Ohio.csv',
#  '2008.annual 28097 Montgomery County, Mississippi.csv',
#  '2008.annual C4870 Williamsport, PA MSA.csv',
#  '2008.annual 28025 Clay County, Mississippi.csv',
#  '2008.annual C3794 Peru, IN MicroSA.csv',
#  '2008.annual 55003 Ashland County, Wisconsin.csv',
#  '2008.annual C3642 Oklahoma City, OK MSA.csv',
#  '2008.annual C2774 Johnson City, TN MSA.csv',
#  '2008.annual 17117 Macoupin County, Illinois.csv',
#  '2008.annual 29063 DeKalb County, Missouri.csv',
#  '2008.annual 20207 Woodson County, Kansas.csv',
#  '2008.annual 47001 Anderson County, Tennessee.csv',
#  '2008.annual 31013 Box Butte County, Nebraska.csv',
#  '2008.annual 27023 Chippewa County, Minnesota.csv',
#  '2008.annual 45021 Cherokee County, South Carolina.csv',
#  '2008.annual 32029 Storey County, Nevada.csv',
#  '2008.annual 17169 Schuyler County, Illinois.csv',
#  '2008.annual 48055 Caldwell County, Texas.csv',
#  '2008.annual 31069 Garden County, Nebraska.csv',
#  '2008.annual 18027 Daviess County, Indiana.csv',
#  '2008.annual 49017 Garfield County, Utah.csv',
#  '2008.annual C3198 Marion, IN MicroSA.csv',
#  '2008.annual 08021 Conejos County, Colorado.csv',
#  '2008.annual 40101 Muskogee County, Oklahoma.csv',
#  '2008.annual C2550 Harrisonburg, VA MSA.csv',
#  '2008.annual CS438 Portland-Lewiston-South Portland, ME CSA.csv',
#  '2008.annual 40011 Blaine County, Oklahoma.csv',
#  '2008.annual 17059 Gallatin County, Illinois.csv',
#  '2008.annual 40041 Delaware County, Oklahoma.csv',
#  '2008.annual C4946 Yankton, SD MicroSA.csv',
#  '2008.annual 17171 Scott County, Illinois.csv',
#  '2008.annual 19037 Chickasaw County, Iowa.csv',
#  '2008.annual 29071 Franklin County, Missouri.csv',
#  '2008.annual 36093 Schenectady County, New York.csv',
#  '2008.annual 46107 Potter County, South Dakota.csv',
#  '2008.annual 20041 Dickinson County, Kansas.csv',
#  '2008.annual C4574 Toccoa, GA MicroSA.csv',
#  '2008.annual 22059 LaSalle Parish, Louisiana.csv',
#  '2008.annual 29149 Oregon County, Missouri.csv',
#  '2008.annual 49047 Uintah County, Utah.csv',
#  '2008.annual C2158 Espanola, NM MicroSA.csv',
#  '2008.annual 27107 Norman County, Minnesota.csv',
#  '2008.annual 26015 Barry County, Michigan.csv',
#  '2008.annual 30031 Gallatin County, Montana.csv',
#  '2008.annual 04007 Gila County, Arizona.csv',
#  '2008.annual 49037 San Juan County, Utah.csv',
#  '2008.annual 42085 Mercer County, Pennsylvania.csv',
#  '2008.annual 12103 Pinellas County, Florida.csv',
#  '2008.annual 49021 Iron County, Utah.csv',
#  '2008.annual 16087 Washington County, Idaho.csv',
#  '2008.annual 48117 Deaf Smith County, Texas.csv',
#  '2008.annual C2250 Florence, SC MSA.csv',
#  '2008.annual 26091 Lenawee County, Michigan.csv',
#  '2008.annual 37159 Rowan County, North Carolina.csv',
#  '2008.annual 40113 Osage County, Oklahoma.csv',
#  '2008.annual C2290 Fort Smith, AR-OK MSA.csv',
#  '2008.annual 55121 Trempealeau County, Wisconsin.csv',
#  '2008.annual 48151 Fisher County, Texas.csv',
#  '2008.annual 21061 Edmonson County, Kentucky.csv',
#  '2008.annual 21127 Lawrence County, Kentucky.csv',
#  '2008.annual 28037 Franklin County, Mississippi.csv',
#  '2008.annual C1226 Augusta-Richmond County, GA-SC MSA.csv',
#  '2008.annual 06001 Alameda County, California.csv',
#  '2008.annual 36123 Yates County, New York.csv',
#  '2008.annual C2450 Great Falls, MT MSA.csv',
#  '2008.annual 37000 North Carolina -- Statewide.csv',
#  '2008.annual 30017 Custer County, Montana.csv',
#  '2008.annual 37197 Yadkin County, North Carolina.csv',
#  '2008.annual 05149 Yell County, Arkansas.csv',
#  '2008.annual 22043 Grant Parish, Louisiana.csv',
#  '2008.annual C3014 Lebanon, PA MSA.csv',
#  '2008.annual 13011 Banks County, Georgia.csv',
#  '2008.annual C3294 Meridian, MS MicroSA.csv',
#  '2008.annual 39099 Mahoning County, Ohio.csv',
#  '2008.annual 34025 Monmouth County, New Jersey.csv',
#  '2008.annual 51059 Fairfax County, Virginia.csv',
#  '2008.annual 19147 Palo Alto County, Iowa.csv',
#  '2008.annual 27013 Blue Earth County, Minnesota.csv',
#  '2008.annual 40059 Harper County, Oklahoma.csv',
#  '2008.annual 48449 Titus County, Texas.csv',
#  '2008.annual 21119 Knott County, Kentucky.csv',
#  '2008.annual 28047 Harrison County, Mississippi.csv',
#  '2008.annual 27115 Pine County, Minnesota.csv',
#  '2008.annual 47117 Marshall County, Tennessee.csv',
#  '2008.annual 13057 Cherokee County, Georgia.csv',
#  '2008.annual 22097 St. Landry Parish, Louisiana.csv',
#  '2008.annual 19165 Shelby County, Iowa.csv',
#  '2008.annual 54105 Wirt County, West Virginia.csv',
#  '2008.annual C4670 Vallejo-Fairfield, CA MSA.csv',
#  '2008.annual 26143 Roscommon County, Michigan.csv',
#  '2008.annual CS324 Lake Charles-Jennings, LA CSA.csv',
#  '2008.annual 05035 Crittenden County, Arkansas.csv',
#  ...]

# %%
Co_files08 = []

for filename in filesList08:
    for i in STCO:
        if i in filename:
            Co_files08.append(filename)
            
len(Co_files08)
# Out:
# 274

# %%
# creating an empty dict to store the data
JobsCO08 = {}

for i in Co_files08:
    row = csvRows(mypath08 + i)
    # append the data to the empty dict; STCO as key and total_emp as value 
    JobsCO08[row[0]] = row[1]


# making it a DataFrame
JobsCO08 = pd.DataFrame.from_dict(JobsCO08, orient='index', columns=['Total_emp08'])
JobsCO08 = JobsCO08.sort_index()

print(JobsCO08.shape)
print(type(JobsCO08))
print(JobsCO08.dtypes)
JobsCO08.head()
# Out:
# (274, 1)
# <class 'pandas.core.frame.DataFrame'>
# Total_emp08    object
# dtype: object
#       Total_emp08
# 06001      683099
# 06013      339547
# 06037     4168699
# 06041      109340
# 06055       68850

# %% [markdown]
# ## Merging Jobs00 + Jobs08 + Jobs17

# %%
JobsCO = JobsCO00.merge(JobsCO08, left_index=True,
                                  right_index=True)

JobsCO = JobsCO.merge(JobsCO17, left_index=True,
                                right_index=True)

JobsCO['Total_emp08'] = JobsCO['Total_emp08'].fillna(0).astype(int)
JobsCO['Total_emp17'] = JobsCO['Total_emp17'].fillna(0).astype(int)

JobsCO['emp_NET00-08'] = JobsCO['Total_emp08'] - JobsCO['Total_emp00']
JobsCO['emp_%00-08'] = (JobsCO['Total_emp08'] - JobsCO['Total_emp00']) \
                    / JobsCO['Total_emp00']

JobsCO['emp_NET08-17'] = JobsCO['Total_emp17'] - JobsCO['Total_emp08']
JobsCO['emp_%08-17'] = (JobsCO['Total_emp17'] - JobsCO['Total_emp08']) \
                    / JobsCO['Total_emp08']

print(JobsCO.dtypes)
print(JobsCO.shape)
JobsCO.head()
# Out:
# Total_emp00       int64
# Total_emp08       int64
# Total_emp17       int64
# emp_NET00-08      int64
# emp_%00-08      float64
# emp_NET08-17      int64
# emp_%08-17      float64
# dtype: object
# (273, 7)
#        Total_emp00  Total_emp08  Total_emp17  emp_NET00-08  emp_%00-08  \
# 06001       697215       683099       771652        -14116   -0.020246
# 06013       337924       339547       366720          1623    0.004803
# 06037      4110915      4168699      4381836         57784    0.014056
# 06041       112454       109340       115432         -3114   -0.027691
# 06055        60552        68850        76762          8298    0.137039
#
#        emp_NET08-17  emp_%08-17
# 06001         88553    0.129634
# 06013         27173    0.080027
# 06037        213137    0.051128
# 06041          6092    0.055716
# 06055          7912    0.114916

# %% [markdown]
# ### Exporting all counties employment 00-08-17 data to .csv

# %%
JobsCO.to_csv('exports/Jobs00-08-17CO_NEW.csv')

# %% [markdown]
# ### Merging with geo-coded data in order to groupby CSA's

# %%
JobsCO_CSA = JobsCO.iloc[:,:3].merge(geo, left_index=True, 
                                right_on='STCO').set_index('County_name')

print(JobsCO_CSA.shape)
JobsCO_CSA.tail()
# Out:
# (273, 6)
#              Total_emp00  Total_emp08  Total_emp17  CSA  \
# County_name
# Hampshire           3735         4121         3742  548
# Jefferson          12776        14337        15448  548
# Kenosha            50952        54781        66392  176
# Pierce              9283         9328        10026  378
# St. Croix          25792        28959        33521  378
#
#                                                    CSA_name   STCO
# County_name
# Hampshire    Washington-Baltimore-Arlington, DC-MD-VA-WV-PA  54027
# Jefferson    Washington-Baltimore-Arlington, DC-MD-VA-WV-PA  54037
# Kenosha                        Chicago-Naperville, IL-IN-WI  55059
# Pierce                          Minneapolis-St. Paul, MN-WI  55093
# St. Croix                       Minneapolis-St. Paul, MN-WI  55109

# %%
JobsCSA = JobsCO_CSA.groupby(['CSA', 'CSA_name']).sum()

JobsCSA['emp_NET00-08'] = JobsCSA['Total_emp08'] - JobsCSA['Total_emp00']
JobsCSA['emp_%00-08'] = (JobsCSA['Total_emp08'] - JobsCSA['Total_emp00']) \
                                                / JobsCSA['Total_emp00']

JobsCSA['emp_NET08-17'] = JobsCSA['Total_emp17'] - JobsCSA['Total_emp08']
JobsCSA['emp_%08-17'] = (JobsCSA['Total_emp17'] - JobsCSA['Total_emp08']) \
                                                / JobsCSA['Total_emp08']

print(JobsCSA.shape)
JobsCSA
# Out:
# (15, 7)
#                                                       Total_emp00  \
# CSA CSA_name
# 122 Atlanta--Athens-Clarke County--Sandy Springs, GA      2413348
# 148 Boston-Worcester-Providence, MA-RI-NH-CT              3834847
# 176 Chicago-Naperville, IL-IN-WI                          4534271
# 206 Dallas-Fort Worth, TX-OK                              2844521
# 216 Denver-Aurora, CO                                     1426753
# 220 Detroit-Warren-Ann Arbor, MI                          2531382
# 288 Houston-The Woodlands, TX                             2271793
# 348 Los Angeles-Long Beach, CA                            6793720
# 370 Miami-Fort Lauderdale-Port St. Lucie, FL              2254815
# 378 Minneapolis-St. Paul, MN-WI                           1878800
# 408 New York-Newark, NY-NJ-CT-PA                          9482723
# 428 Philadelphia-Reading-Camden, PA-NJ-DE-MD              3068950
# 488 San Jose-San Francisco-Oakland, CA                    3863329
# 500 Seattle-Tacoma, WA                                    1864356
# 548 Washington-Baltimore-Arlington, DC-MD-VA-WV-PA        4096584
#
#                                                       Total_emp08  \
# CSA CSA_name
# 122 Atlanta--Athens-Clarke County--Sandy Springs, GA      2551161
# 148 Boston-Worcester-Providence, MA-RI-NH-CT              3824178
# 176 Chicago-Naperville, IL-IN-WI                          4478885
# 206 Dallas-Fort Worth, TX-OK                              3071476
# 216 Denver-Aurora, CO                                     1451976
# 220 Detroit-Warren-Ann Arbor, MI                          2198794
# 288 Houston-The Woodlands, TX                             2617373
# 348 Los Angeles-Long Beach, CA                            7225774
# 370 Miami-Fort Lauderdale-Port St. Lucie, FL              2460406
# 378 Minneapolis-St. Paul, MN-WI                           1916797
# 408 New York-Newark, NY-NJ-CT-PA                          9712955
# 428 Philadelphia-Reading-Camden, PA-NJ-DE-MD              3161286
# 488 San Jose-San Francisco-Oakland, CA                    3673486
# 500 Seattle-Tacoma, WA                                    2005741
# 548 Washington-Baltimore-Arlington, DC-MD-VA-WV-PA        4445562
#
#                                                       Total_emp17  \
# CSA CSA_name
# 122 Atlanta--Athens-Clarke County--Sandy Springs, GA      2844774
# 148 Boston-Worcester-Providence, MA-RI-NH-CT              4121641
# 176 Chicago-Naperville, IL-IN-WI                          4631371
# 206 Dallas-Fort Worth, TX-OK                              3586036
# 216 Denver-Aurora, CO                                     1692477
# 220 Detroit-Warren-Ann Arbor, MI                          2312726
# 288 Houston-The Woodlands, TX                             2969515
# 348 Los Angeles-Long Beach, CA                            7741633
# 370 Miami-Fort Lauderdale-Port St. Lucie, FL              2720909
# 378 Minneapolis-St. Paul, MN-WI                           2063304
# 408 New York-Newark, NY-NJ-CT-PA                         10423589
# 428 Philadelphia-Reading-Camden, PA-NJ-DE-MD              3219771
# 488 San Jose-San Francisco-Oakland, CA                    4232644
# 500 Seattle-Tacoma, WA                                    2249890
# 548 Washington-Baltimore-Arlington, DC-MD-VA-WV-PA        4731197
#
#                                                       emp_NET00-08  \
# CSA CSA_name
# 122 Atlanta--Athens-Clarke County--Sandy Springs, GA        137813
# 148 Boston-Worcester-Providence, MA-RI-NH-CT                -10669
# 176 Chicago-Naperville, IL-IN-WI                            -55386
# 206 Dallas-Fort Worth, TX-OK                                226955
# 216 Denver-Aurora, CO                                        25223
# 220 Detroit-Warren-Ann Arbor, MI                           -332588
# 288 Houston-The Woodlands, TX                               345580
# 348 Los Angeles-Long Beach, CA                              432054
# 370 Miami-Fort Lauderdale-Port St. Lucie, FL                205591
# 378 Minneapolis-St. Paul, MN-WI                              37997
# 408 New York-Newark, NY-NJ-CT-PA                            230232
# 428 Philadelphia-Reading-Camden, PA-NJ-DE-MD                 92336
# 488 San Jose-San Francisco-Oakland, CA                     -189843
# 500 Seattle-Tacoma, WA                                      141385
# 548 Washington-Baltimore-Arlington, DC-MD-VA-WV-PA          348978
#
#                                                       emp_%00-08  \
# CSA CSA_name
# 122 Atlanta--Athens-Clarke County--Sandy Springs, GA    0.057104
# 148 Boston-Worcester-Providence, MA-RI-NH-CT           -0.002782
# 176 Chicago-Naperville, IL-IN-WI                       -0.012215
# 206 Dallas-Fort Worth, TX-OK                            0.079787
# 216 Denver-Aurora, CO                                   0.017679
# 220 Detroit-Warren-Ann Arbor, MI                       -0.131386
# 288 Houston-The Woodlands, TX                           0.152118
# 348 Los Angeles-Long Beach, CA                          0.063596
# 370 Miami-Fort Lauderdale-Port St. Lucie, FL            0.091179
# 378 Minneapolis-St. Paul, MN-WI                         0.020224
# 408 New York-Newark, NY-NJ-CT-PA                        0.024279
# 428 Philadelphia-Reading-Camden, PA-NJ-DE-MD            0.030087
# 488 San Jose-San Francisco-Oakland, CA                 -0.049140
# 500 Seattle-Tacoma, WA                                  0.075836
# 548 Washington-Baltimore-Arlington, DC-MD-VA-WV-PA      0.085188
#
#                                                       emp_NET08-17  emp_%08-17
# CSA CSA_name
# 122 Atlanta--Athens-Clarke County--Sandy Springs, GA        293613    0.115090
# 148 Boston-Worcester-Providence, MA-RI-NH-CT                297463    0.077785
# 176 Chicago-Naperville, IL-IN-WI                            152486    0.034046
# 206 Dallas-Fort Worth, TX-OK                                514560    0.167529
# 216 Denver-Aurora, CO                                       240501    0.165637
# 220 Detroit-Warren-Ann Arbor, MI                            113932    0.051816
# 288 Houston-The Woodlands, TX                               352142    0.134540
# 348 Los Angeles-Long Beach, CA                              515859    0.071392
# 370 Miami-Fort Lauderdale-Port St. Lucie, FL                260503    0.105878
# 378 Minneapolis-St. Paul, MN-WI                             146507    0.076433
# 408 New York-Newark, NY-NJ-CT-PA                            710634    0.073164
# 428 Philadelphia-Reading-Camden, PA-NJ-DE-MD                 58485    0.018500
# 488 San Jose-San Francisco-Oakland, CA                      559158    0.152215
# 500 Seattle-Tacoma, WA                                      244149    0.121725
# 548 Washington-Baltimore-Arlington, DC-MD-VA-WV-PA          285635    0.064252

# %%
JobsCSA.to_csv('exports/Jobs00-08-17CSA_NEW.csv')

# %% [markdown]
# ## 2010 -- _wasn't in use in this analysis_

# %%
mypath2 = '/Users/danachermesh/Desktop/rp-USmetros_comparison/data/2010.annual.by_area/'# change to your path
filesList2 = os.listdir(mypath2)

filesList2
# Out:
# ['2010.annual 37059 Davie County, North Carolina.csv',
#  '2010.annual 49045 Tooele County, Utah.csv',
#  '2010.annual 17045 Edgar County, Illinois.csv',
#  '2010.annual 45085 Sumter County, South Carolina.csv',
#  '2010.annual 55073 Marathon County, Wisconsin.csv',
#  '2010.annual 21085 Grayson County, Kentucky.csv',
#  '2010.annual 26055 Grand Traverse County, Michigan.csv',
#  '2010.annual 48327 Menard County, Texas.csv',
#  '2010.annual 28021 Claiborne County, Mississippi.csv',
#  '2010.annual C4450 Stephenville, TX MicroSA.csv',
#  '2010.annual C4682 Vermillion, SD MicroSA.csv',
#  '2010.annual 13115 Floyd County, Georgia.csv',
#  '2010.annual 72131 San Sebastian Municipio, Puerto Rico.csv',
#  '2010.annual 48121 Denton County, Texas.csv',
#  '2010.annual 39999 Unknown Or Undefined, Ohio.csv',
#  '2010.annual 29187 St. Francois County, Missouri.csv',
#  '2010.annual C4918 Winston-Salem, NC MSA.csv',
#  '2010.annual 10003 New Castle County, Delaware.csv',
#  '2010.annual 27051 Grant County, Minnesota.csv',
#  '2010.annual 22063 Livingston Parish, Louisiana.csv',
#  '2010.annual 36113 Warren County, New York.csv',
#  '2010.annual C3142 Macon, GA MSA.csv',
#  '2010.annual 51035 Carroll County, Virginia.csv',
#  '2010.annual 54005 Boone County, West Virginia.csv',
#  '2010.annual 18115 Ohio County, Indiana.csv',
#  '2010.annual C2182 Fairbanks, AK MSA.csv',
#  '2010.annual 05125 Saline County, Arkansas.csv',
#  '2010.annual 30101 Toole County, Montana.csv',
#  '2010.annual 37183 Wake County, North Carolina.csv',
#  '2010.annual 55027 Dodge County, Wisconsin.csv',
#  '2010.annual 21221 Trigg County, Kentucky.csv',
#  '2010.annual 27151 Swift County, Minnesota.csv',
#  '2010.annual 29167 Polk County, Missouri.csv',
#  '2010.annual C1946 Decatur, AL MSA.csv',
#  '2010.annual 21233 Webster County, Kentucky.csv',
#  '2010.annual 46077 Kingsbury County, South Dakota.csv',
#  '2010.annual 19107 Keokuk County, Iowa.csv',
#  '2010.annual 42121 Venango County, Pennsylvania.csv',
#  '2010.annual 48417 Shackelford County, Texas.csv',
#  '2010.annual 72079 Lajas Municipio, Puerto Rico.csv',
#  '2010.annual 21197 Powell County, Kentucky.csv',
#  '2010.annual C2130 Elmira, NY MSA.csv',
#  '2010.annual 54069 Ohio County, West Virginia.csv',
#  '2010.annual 01087 Macon County, Alabama.csv',
#  '2010.annual 24009 Calvert County, Maryland.csv',
#  '2010.annual 54007 Braxton County, West Virginia.csv',
#  '2010.annual CS138 Beckley-Oak Hill, WV CSA.csv',
#  '2010.annual C1298 Battle Creek, MI MSA.csv',
#  '2010.annual 48483 Wheeler County, Texas.csv',
#  '2010.annual 12055 Highlands County, Florida.csv',
#  '2010.annual 48445 Terry County, Texas.csv',
#  '2010.annual 28161 Yalobusha County, Mississippi.csv',
#  '2010.annual C3206 Marion-Herrin, IL MicroSA.csv',
#  '2010.annual 48163 Frio County, Texas.csv',
#  '2010.annual C1282 Bastrop, LA MicroSA.csv',
#  '2010.annual C1294 Baton Rouge, LA MSA.csv',
#  '2010.annual 01039 Covington County, Alabama.csv',
#  '2010.annual C4962 York-Hanover, PA MSA.csv',
#  '2010.annual C1554 Burlington-South Burlington, VT MSA.csv',
#  '2010.annual 21025 Breathitt County, Kentucky.csv',
#  '2010.annual 48105 Crockett County, Texas.csv',
#  '2010.annual C2362 Gainesville, TX MicroSA.csv',
#  '2010.annual 31115 Loup County, Nebraska.csv',
#  '2010.annual 31077 Greeley County, Nebraska.csv',
#  '2010.annual 48001 Anderson County, Texas.csv',
#  '2010.annual 23019 Penobscot County, Maine.csv',
#  '2010.annual 28085 Lincoln County, Mississippi.csv',
#  '2010.annual 05071 Johnson County, Arkansas.csv',
#  '2010.annual 13177 Lee County, Georgia.csv',
#  '2010.annual 32510 Carson City, Nevada.csv',
#  '2010.annual 31079 Hall County, Nebraska.csv',
#  '2010.annual 49013 Duchesne County, Utah.csv',
#  '2010.annual 29179 Reynolds County, Missouri.csv',
#  '2010.annual 48175 Goliad County, Texas.csv',
#  '2010.annual 29005 Atchison County, Missouri.csv',
#  '2010.annual 18019 Clark County, Indiana.csv',
#  '2010.annual C1134 Anderson, SC MSA.csv',
#  '2010.annual C4514 Tahlequah, OK MicroSA.csv',
#  '2010.annual 21117 Kenton County, Kentucky.csv',
#  '2010.annual 17189 Washington County, Illinois.csv',
#  '2010.annual 27113 Pennington County, Minnesota.csv',
#  '2010.annual C4230 Sault Ste. Marie, MI MicroSA.csv',
#  '2010.annual 46007 Bennett County, South Dakota.csv',
#  '2010.annual C2342 Fresno, CA MSA.csv',
#  '2010.annual 48049 Brown County, Texas.csv',
#  '2010.annual 17121 Marion County, Illinois.csv',
#  '2010.annual 13221 Oglethorpe County, Georgia.csv',
#  '2010.annual 17039 DeWitt County, Illinois.csv',
#  '2010.annual C4058 Rocky Mount, NC MSA.csv',
#  '2010.annual 34013 Essex County, New Jersey.csv',
#  '2010.annual 34023 Middlesex County, New Jersey.csv',
#  '2010.annual 21033 Caldwell County, Kentucky.csv',
#  '2010.annual 17193 White County, Illinois.csv',
#  '2010.annual 08033 Dolores County, Colorado.csv',
#  '2010.annual 31105 Kimball County, Nebraska.csv',
#  '2010.annual 29143 New Madrid County, Missouri.csv',
#  '2010.annual 29093 Iron County, Missouri.csv',
#  '2010.annual 19153 Polk County, Iowa.csv',
#  '2010.annual 31131 Otoe County, Nebraska.csv',
#  '2010.annual 49049 Utah County, Utah.csv',
#  '2010.annual 01027 Clay County, Alabama.csv',
#  '2010.annual 29023 Butler County, Missouri.csv',
#  '2010.annual 27135 Roseau County, Minnesota.csv',
#  '2010.annual 30001 Beaverhead County, Montana.csv',
#  '2010.annual CS198 Columbus-Marion-Zanesville, OH CSA.csv',
#  '2010.annual C2278 Fort Leonard Wood, MO MicroSA.csv',
#  '2010.annual 01075 Lamar County, Alabama.csv',
#  '2010.annual 48039 Brazoria County, Texas.csv',
#  '2010.annual 40013 Bryan County, Oklahoma.csv',
#  '2010.annual C3706 Oxford, MS MicroSA.csv',
#  '2010.annual C2078 Edwards, CO MicroSA.csv',
#  '2010.annual 32023 Nye County, Nevada.csv',
#  '2010.annual 34037 Sussex County, New Jersey.csv',
#  '2010.annual 46023 Charles Mix County, South Dakota.csv',
#  '2010.annual 13135 Gwinnett County, Georgia.csv',
#  '2010.annual 48185 Grimes County, Texas.csv',
#  '2010.annual 01029 Cleburne County, Alabama.csv',
#  '2010.annual 48447 Throckmorton County, Texas.csv',
#  '2010.annual 39015 Brown County, Ohio.csv',
#  '2010.annual C3490 Napa, CA MSA.csv',
#  '2010.annual 41049 Morrow County, Oregon.csv',
#  '2010.annual C1998 Dodge City, KS MicroSA.csv',
#  '2010.annual C2146 Enterprise, AL MicroSA.csv',
#  '2010.annual C3022 Levelland, TX MicroSA.csv',
#  '2010.annual C2682 Idaho Falls, ID MSA.csv',
#  '2010.annual 05083 Logan County, Arkansas.csv',
#  '2010.annual 29057 Dade County, Missouri.csv',
#  '2010.annual 23999 Unknown Or Undefined, Maine.csv',
#  '2010.annual 32021 Mineral County, Nevada.csv',
#  '2010.annual 48133 Eastland County, Texas.csv',
#  '2010.annual 13245 Richmond County, Georgia.csv',
#  '2010.annual 27099 Mower County, Minnesota.csv',
#  '2010.annual C4602 Truckee-Grass Valley, CA MicroSA.csv',
#  '2010.annual 15999 Unknown Or Undefined, Hawaii.csv',
#  '2010.annual C2586 Hickory-Lenoir-Morganton, NC MSA.csv',
#  '2010.annual 02198 Prince of Wales-Hyder Census Area, Alaska.csv',
#  '2010.annual 48421 Sherman County, Texas.csv',
#  '2010.annual 19049 Dallas County, Iowa.csv',
#  '2010.annual 72029 Canovanas Municipio, Puerto Rico.csv',
#  '2010.annual 12007 Bradford County, Florida.csv',
#  '2010.annual 48075 Childress County, Texas.csv',
#  '2010.annual 45075 Orangeburg County, South Carolina.csv',
#  '2010.annual 06025 Imperial County, California.csv',
#  '2010.annual CS500 Seattle-Tacoma, WA CSA.csv',
#  '2010.annual 48053 Burnet County, Texas.csv',
#  '2010.annual 44999 Unknown Or Undefined, Rhode Island.csv',
#  '2010.annual 38033 Golden Valley County, North Dakota.csv',
#  '2010.annual C1718 City of The Dalles, OR MicroSA.csv',
#  '2010.annual 19171 Tama County, Iowa.csv',
#  '2010.annual 41007 Clatsop County, Oregon.csv',
#  '2010.annual 13145 Harris County, Georgia.csv',
#  '2010.annual 37151 Randolph County, North Carolina.csv',
#  '2010.annual 01019 Cherokee County, Alabama.csv',
#  '2010.annual 34999 Unknown Or Undefined, New Jersey.csv',
#  '2010.annual 39075 Holmes County, Ohio.csv',
#  '2010.annual C1266 Baraboo, WI MicroSA.csv',
#  '2010.annual 06057 Nevada County, California.csv',
#  '2010.annual 39089 Licking County, Ohio.csv',
#  '2010.annual C1442 Borger, TX MicroSA.csv',
#  '2010.annual C2518 Hagerstown-Martinsburg, MD-WV MSA.csv',
#  '2010.annual C3650 Olympia-Tumwater, WA MSA.csv',
#  '2010.annual 27011 Big Stone County, Minnesota.csv',
#  '2010.annual 25023 Plymouth County, Massachusetts.csv',
#  '2010.annual CS542 Union City-Martin, TN-KY CSA.csv',
#  '2010.annual 18013 Brown County, Indiana.csv',
#  '2010.annual C2898 Kodiak, AK MicroSA.csv',
#  '2010.annual 13073 Columbia County, Georgia.csv',
#  '2010.annual 38000 North Dakota -- Statewide.csv',
#  '2010.annual 29135 Moniteau County, Missouri.csv',
#  '2010.annual 54073 Pleasants County, West Virginia.csv',
#  '2010.annual 25999 Unknown Or Undefined, Massachusetts.csv',
#  '2010.annual 22039 Evangeline Parish, Louisiana.csv',
#  '2010.annual 17177 Stephenson County, Illinois.csv',
#  '2010.annual 36097 Schuyler County, New York.csv',
#  '2010.annual 19055 Delaware County, Iowa.csv',
#  '2010.annual 22093 St. James Parish, Louisiana.csv',
#  '2010.annual CS164 Cape Girardeau-Sikeston, MO-IL CSA.csv',
#  '2010.annual 42101 Philadelphia County, Pennsylvania.csv',
#  '2010.annual 08043 Fremont County, Colorado.csv',
#  '2010.annual 27067 Kandiyohi County, Minnesota.csv',
#  '2010.annual 18125 Pike County, Indiana.csv',
#  '2010.annual C4830 Wenatchee, WA MSA.csv',
#  '2010.annual 22103 St. Tammany Parish, Louisiana.csv',
#  '2010.annual 41027 Hood River County, Oregon.csv',
#  '2010.annual 18007 Benton County, Indiana.csv',
#  '2010.annual 25007 Dukes County, Massachusetts.csv',
#  '2010.annual C3774 Payson, AZ MicroSA.csv',
#  '2010.annual 48331 Milam County, Texas.csv',
#  '2010.annual 37173 Swain County, North Carolina.csv',
#  '2010.annual 21177 Muhlenberg County, Kentucky.csv',
#  '2010.annual 20071 Greeley County, Kansas.csv',
#  '2010.annual 31061 Franklin County, Nebraska.csv',
#  '2010.annual 21075 Fulton County, Kentucky.csv',
#  '2010.annual 47175 Van Buren County, Tennessee.csv',
#  '2010.annual 28143 Tunica County, Mississippi.csv',
#  '2010.annual 72041 Cidra Municipio, Puerto Rico.csv',
#  '2010.annual 47017 Carroll County, Tennessee.csv',
#  '2010.annual 12027 DeSoto County, Florida.csv',
#  '2010.annual 12043 Glades County, Florida.csv',
#  '2010.annual 29185 St. Clair County, Missouri.csv',
#  '2010.annual C3614 Ocean City, NJ MSA.csv',
#  '2010.annual 21157 Marshall County, Kentucky.csv',
#  '2010.annual C1326 Bedford, IN MicroSA.csv',
#  '2010.annual 13001 Appling County, Georgia.csv',
#  '2010.annual C3802 Phoenix Lake-Cedar Ridge, CA MicroSA.csv',
#  '2010.annual C3114 Louisville-Jefferson County, KY-IN MSA.csv',
#  '2010.annual C1170 Asheville, NC MSA.csv',
#  '2010.annual 06047 Merced County, California.csv',
#  '2010.annual 20075 Hamilton County, Kansas.csv',
#  '2010.annual 26093 Livingston County, Michigan.csv',
#  '2010.annual 17105 Livingston County, Illinois.csv',
#  '2010.annual 26097 Mackinac County, Michigan.csv',
#  '2010.annual 48077 Clay County, Texas.csv',
#  '2010.annual 48319 Mason County, Texas.csv',
#  '2010.annual 72045 Comerio Municipio, Puerto Rico.csv',
#  '2010.annual 18179 Wells County, Indiana.csv',
#  '2010.annual 31029 Chase County, Nebraska.csv',
#  '2010.annual 08105 Rio Grande County, Colorado.csv',
#  '2010.annual 48065 Carson County, Texas.csv',
#  '2010.annual C1050 Albany, GA MSA.csv',
#  '2010.annual C3002 Lawton, OK MSA.csv',
#  '2010.annual 20055 Finney County, Kansas.csv',
#  '2010.annual 18075 Jay County, Indiana.csv',
#  '2010.annual 35013 Dona Ana County, New Mexico.csv',
#  '2010.annual C3334 Milwaukee-Waukesha-West Allis, WI MSA.csv',
#  '2010.annual 45025 Chesterfield County, South Carolina.csv',
#  '2010.annual 37133 Onslow County, North Carolina.csv',
#  '2010.annual 36009 Cattaraugus County, New York.csv',
#  '2010.annual 18113 Noble County, Indiana.csv',
#  '2010.annual C2594 Hilton Head Island-Bluffton-Beaufort, SC MSA.csv',
#  '2010.annual 36025 Delaware County, New York.csv',
#  '2010.annual 51095 James City County, Virginia.csv',
#  '2010.annual C1162 Ardmore, OK MicroSA.csv',
#  '2010.annual 05099 Nevada County, Arkansas.csv',
#  '2010.annual 27119 Polk County, Minnesota.csv',
#  '2010.annual 48269 King County, Texas.csv',
#  '2010.annual 40147 Washington County, Oklahoma.csv',
#  '2010.annual 28017 Chickasaw County, Mississippi.csv',
#  '2010.annual 26087 Lapeer County, Michigan.csv',
#  '2010.annual 78030 St. Thomas, Virgin Islands.csv',
#  '2010.annual 36039 Greene County, New York.csv',
#  '2010.annual C3046 Lexington-Fayette, KY MSA.csv',
#  '2010.annual 39109 Miami County, Ohio.csv',
#  '2010.annual 34021 Mercer County, New Jersey.csv',
#  '2010.annual 55077 Marquette County, Wisconsin.csv',
#  '2010.annual CS406 New Orleans-Metairie-Hammond, LA-MS CSA.csv',
#  '2010.annual 19187 Webster County, Iowa.csv',
#  '2010.annual 04003 Cochise County, Arizona.csv',
#  '2010.annual C3306 Miami, OK MicroSA.csv',
#  '2010.annual C3094 London, KY MicroSA.csv',
#  '2010.annual 18159 Tipton County, Indiana.csv',
#  '2010.annual 05097 Montgomery County, Arkansas.csv',
#  '2010.annual C3970 Raymondville, TX MicroSA.csv',
#  '2010.annual 18149 Starke County, Indiana.csv',
#  '2010.annual 51003 Albemarle County, Virginia.csv',
#  '2010.annual 27999 Unknown Or Undefined, Minnesota.csv',
#  '2010.annual 51840 Winchester City, Virginia.csv',
#  '2010.annual 72141 Utuado Municipio, Puerto Rico.csv',
#  '2010.annual 32027 Pershing County, Nevada.csv',
#  '2010.annual C1966 Deltona-Daytona Beach-Ormond Beach, FL MSA.csv',
#  '2010.annual 17083 Jersey County, Illinois.csv',
#  '2010.annual 37027 Caldwell County, North Carolina.csv',
#  '2010.annual 36007 Broome County, New York.csv',
#  '2010.annual 29087 Holt County, Missouri.csv',
#  '2010.annual CS508 Shreveport-Bossier City-Minden, LA CSA.csv',
#  '2010.annual 19163 Scott County, Iowa.csv',
#  '2010.annual 16041 Franklin County, Idaho.csv',
#  '2010.annual 46047 Fall River County, South Dakota.csv',
#  '2010.annual 41053 Polk County, Oregon.csv',
#  '2010.annual 48009 Archer County, Texas.csv',
#  '2010.annual 31117 McPherson County, Nebraska.csv',
#  '2010.annual 37139 Pasquotank County, North Carolina.csv',
#  '2010.annual 17079 Jasper County, Illinois.csv',
#  '2010.annual 47189 Wilson County, Tennessee.csv',
#  '2010.annual C4478 Sturgis, MI MicroSA.csv',
#  '2010.annual C1618 Carson City, NV MSA.csv',
#  '2010.annual C1434 Boone, IA MicroSA.csv',
#  '2010.annual 17151 Pope County, Illinois.csv',
#  '2010.annual 20011 Bourbon County, Kansas.csv',
#  '2010.annual C3430 Mountain Home, ID MicroSA.csv',
#  '2010.annual C4398 Spencer, IA MicroSA.csv',
#  '2010.annual 39057 Greene County, Ohio.csv',
#  '2010.annual C2334 Fremont, NE MicroSA.csv',
#  '2010.annual 31101 Keith County, Nebraska.csv',
#  '2010.annual 08021 Conejos County, Colorado.csv',
#  '2010.annual 29127 Marion County, Missouri.csv',
#  '2010.annual 02130 Ketchikan Gateway Borough, Alaska.csv',
#  '2010.annual 13179 Liberty County, Georgia.csv',
#  '2010.annual C3694 Owatonna, MN MicroSA.csv',
#  '2010.annual 17123 Marshall County, Illinois.csv',
#  '2010.annual 13067 Cobb County, Georgia.csv',
#  '2010.annual 16000 Idaho -- Statewide.csv',
#  '2010.annual 41043 Linn County, Oregon.csv',
#  '2010.annual C3182 Manitowoc, WI MicroSA.csv',
#  '2010.annual 31083 Harlan County, Nebraska.csv',
#  '2010.annual 51073 Gloucester County, Virginia.csv',
#  '2010.annual C3486 Nacogdoches, TX MicroSA.csv',
#  '2010.annual 18077 Jefferson County, Indiana.csv',
#  '2010.annual 20041 Dickinson County, Kansas.csv',
#  '2010.annual 13105 Elbert County, Georgia.csv',
#  '2010.annual C1126 Anchorage, AK MSA.csv',
#  '2010.annual 48103 Crane County, Texas.csv',
#  '2010.annual 27107 Norman County, Minnesota.csv',
#  '2010.annual C4698 Vicksburg, MS MicroSA.csv',
#  '2010.annual 12103 Pinellas County, Florida.csv',
#  '2010.annual 30043 Jefferson County, Montana.csv',
#  '2010.annual 30031 Gallatin County, Montana.csv',
#  '2010.annual 48117 Deaf Smith County, Texas.csv',
#  '2010.annual C1118 Ames, IA MSA.csv',
#  '2010.annual C4518 Talladega-Sylacauga, AL MicroSA.csv',
#  '2010.annual 16087 Washington County, Idaho.csv',
#  '2010.annual 30045 Judith Basin County, Montana.csv',
#  '2010.annual 27087 Mahnomen County, Minnesota.csv',
#  '2010.annual 13285 Troup County, Georgia.csv',
#  '2010.annual 46019 Butte County, South Dakota.csv',
#  '2010.annual 55075 Marinette County, Wisconsin.csv',
#  '2010.annual 39155 Trumbull County, Ohio.csv',
#  '2010.annual 05095 Monroe County, Arkansas.csv',
#  '2010.annual 04000 Arizona -- Statewide.csv',
#  '2010.annual C2122 Elko, NV MicroSA.csv',
#  '2010.annual 12111 St. Lucie County, Florida.csv',
#  '2010.annual 29141 Morgan County, Missouri.csv',
#  '2010.annual 51093 Isle of Wight County, Virginia.csv',
#  '2010.annual 08085 Montrose County, Colorado.csv',
#  '2010.annual 27065 Kanabec County, Minnesota.csv',
#  '2010.annual 22075 Plaquemines Parish, Louisiana.csv',
#  '2010.annual 31155 Saunders County, Nebraska.csv',
#  '2010.annual CS148 Boston-Worcester-Providence, MA-RI-NH-CT CSA.csv',
#  '2010.annual 55125 Vilas County, Wisconsin.csv',
#  '2010.annual 31185 York County, Nebraska.csv',
#  '2010.annual 28025 Clay County, Mississippi.csv',
#  '2010.annual 39035 Cuyahoga County, Ohio.csv',
#  '2010.annual C2202 Fargo, ND-MN MSA.csv',
#  '2010.annual 48067 Cass County, Texas.csv',
#  '2010.annual 39031 Coshocton County, Ohio.csv',
#  '2010.annual 45051 Horry County, South Carolina.csv',
#  '2010.annual 54077 Preston County, West Virginia.csv',
#  '2010.annual 08077 Mesa County, Colorado.csv',
#  '2010.annual 19113 Linn County, Iowa.csv',
#  '2010.annual 72139 Trujillo Alto Municipio, Puerto Rico.csv',
#  '2010.annual 31145 Red Willow County, Nebraska.csv',
#  '2010.annual 13251 Screven County, Georgia.csv',
#  '2010.annual C3034 Lewiston-Auburn, ME MSA.csv',
#  '2010.annual 12045 Gulf County, Florida.csv',
#  '2010.annual 51001 Accomack County, Virginia.csv',
#  '2010.annual 39165 Warren County, Ohio.csv',
#  '2010.annual C1750 Clewiston, FL MicroSA.csv',
#  '2010.annual 20037 Crawford County, Kansas.csv',
#  '2010.annual C4882 Willmar, MN MicroSA.csv',
#  '2010.annual 16055 Kootenai County, Idaho.csv',
#  '2010.annual 08095 Phillips County, Colorado.csv',
#  '2010.annual 08083 Montezuma County, Colorado.csv',
#  '2010.annual C3698 Owensboro, KY MSA.csv',
#  '2010.annual 12057 Hillsborough County, Florida.csv',
#  '2010.annual 34005 Burlington County, New Jersey.csv',
#  '2010.annual 25005 Bristol County, Massachusetts.csv',
#  '2010.annual 31039 Cuming County, Nebraska.csv',
#  '2010.annual CS554 Wausau-Stevens Point-Wisconsin Rapids, WI CSA.csv',
#  '2010.annual 13045 Carroll County, Georgia.csv',
#  '2010.annual 53039 Klickitat County, Washington.csv',
#  '2010.annual 01037 Coosa County, Alabama.csv',
#  '2010.annual 37141 Pender County, North Carolina.csv',
#  '2010.annual 32005 Douglas County, Nevada.csv',
#  '2010.annual 40081 Lincoln County, Oklahoma.csv',
#  '2010.annual 21089 Greenup County, Kentucky.csv',
#  '2010.annual 56003 Big Horn County, Wyoming.csv',
#  '2010.annual 29063 DeKalb County, Missouri.csv',
#  '2010.annual 13301 Warren County, Georgia.csv',
#  '2010.annual 05037 Cross County, Arkansas.csv',
#  '2010.annual C4738 Waco, TX MSA.csv',
#  '2010.annual 12051 Hendry County, Florida.csv',
#  '2010.annual 55005 Barron County, Wisconsin.csv',
#  '2010.annual 39025 Clermont County, Ohio.csv',
#  '2010.annual 55051 Iron County, Wisconsin.csv',
#  '2010.annual 47051 Franklin County, Tennessee.csv',
#  '2010.annual 30055 McCone County, Montana.csv',
#  '2010.annual 40009 Beckham County, Oklahoma.csv',
#  '2010.annual 18027 Daviess County, Indiana.csv',
#  '2010.annual 31069 Garden County, Nebraska.csv',
#  '2010.annual 06019 Fresno County, California.csv',
#  '2010.annual 48277 Lamar County, Texas.csv',
#  '2010.annual 24017 Charles County, Maryland.csv',
#  '2010.annual C3298 Merrill, WI MicroSA.csv',
#  '2010.annual 26057 Gratiot County, Michigan.csv',
#  '2010.annual 42035 Clinton County, Pennsylvania.csv',
#  '2010.annual 38999 Unknown Or Undefined, North Dakota.csv',
#  '2010.annual C3610 Ocala, FL MSA.csv',
#  '2010.annual C4934 Worcester, MA-CT MSA.csv',
#  '2010.annual 37039 Cherokee County, North Carolina.csv',
#  '2010.annual C1810 Columbus, NE MicroSA.csv',
#  '2010.annual 40011 Blaine County, Oklahoma.csv',
#  '2010.annual 48129 Donley County, Texas.csv',
#  '2010.annual C1088 Allegan, MI MicroSA.csv',
#  '2010.annual C2990 Laurinburg, NC MicroSA.csv',
#  '2010.annual C2074 Eau Claire, WI MSA.csv',
#  '2010.annual 22045 Iberia Parish, Louisiana.csv',
#  '2010.annual 06009 Calaveras County, California.csv',
#  '2010.annual C2954 Lancaster, PA MSA.csv',
#  '2010.annual 56029 Park County, Wyoming.csv',
#  '2010.annual C4354 Silverthorne, CO MicroSA.csv',
#  '2010.annual C2498 Grenada, MS MicroSA.csv',
#  '2010.annual 29149 Oregon County, Missouri.csv',
#  '2010.annual C1310 Beatrice, NE MicroSA.csv',
#  '2010.annual 29119 McDonald County, Missouri.csv',
#  '2010.annual 38057 Mercer County, North Dakota.csv',
#  '2010.annual 15001 Hawaii County, Hawaii.csv',
#  '2010.annual C2746 Jamestown-Dunkirk-Fredonia, NY MicroSA.csv',
#  '2010.annual CS172 Charlotte-Concord, NC-SC CSA.csv',
#  '2010.annual C1790 Columbia, SC MSA.csv',
#  '2010.annual 21207 Russell County, Kentucky.csv',
#  '2010.annual 28147 Walthall County, Mississippi.csv',
#  '2010.annual 17111 McHenry County, Illinois.csv',
#  '2010.annual 31135 Perkins County, Nebraska.csv',
#  '2010.annual 46101 Moody County, South Dakota.csv',
#  '2010.annual 21059 Daviess County, Kentucky.csv',
#  '2010.annual 45079 Richland County, South Carolina.csv',
#  '2010.annual 48299 Llano County, Texas.csv',
#  '2010.annual 21191 Pendleton County, Kentucky.csv',
#  '2010.annual CS273 Greenville-Spartanburg-Anderson, SC CSA.csv',
#  '2010.annual 48247 Jim Hogg County, Texas.csv',
#  '2010.annual 22037 East Feliciana Parish, Louisiana.csv',
#  '2010.annual 13315 Wilcox County, Georgia.csv',
#  '2010.annual 47115 Marion County, Tennessee.csv',
#  '2010.annual 31107 Knox County, Nebraska.csv',
#  '2010.annual 08125 Yuma County, Colorado.csv',
#  '2010.annual C2050 Durham-Chapel Hill, NC MSA.csv',
#  '2010.annual C3654 Omaha-Council Bluffs, NE-IA MSA.csv',
#  '2010.annual 22043 Grant Parish, Louisiana.csv',
#  '2010.annual 21111 Jefferson County, Kentucky.csv',
#  '2010.annual C2662 Huntsville, AL MSA.csv',
#  '2010.annual 19103 Johnson County, Iowa.csv',
#  '2010.annual 13111 Fannin County, Georgia.csv',
#  '2010.annual C4614 Tulsa, OK MSA.csv',
#  '2010.annual 27069 Kittson County, Minnesota.csv',
#  '2010.annual 20139 Osage County, Kansas.csv',
#  '2010.annual 06011 Colusa County, California.csv',
#  '2010.annual 40059 Harper County, Oklahoma.csv',
#  '2010.annual C1862 Corsicana, TX MicroSA.csv',
#  '2010.annual 06105 Trinity County, California.csv',
#  '2010.annual 28015 Carroll County, Mississippi.csv',
#  '2010.annual C1694 Cheyenne, WY MSA.csv',
#  '2010.annual 13233 Polk County, Georgia.csv',
#  '2010.annual 02050 Bethel Census Area, Alaska.csv',
#  '2010.annual 21029 Bullitt County, Kentucky.csv',
#  '2010.annual 21115 Johnson County, Kentucky.csv',
#  '2010.annual 20155 Reno County, Kansas.csv',
#  '2010.annual 06045 Mendocino County, California.csv',
#  '2010.annual 51091 Highland County, Virginia.csv',
#  '2010.annual 20047 Edwards County, Kansas.csv',
#  '2010.annual 26021 Berrien County, Michigan.csv',
#  '2010.annual 72037 Ceiba Municipio, Puerto Rico.csv',
#  '2010.annual C3326 Midland, TX MSA.csv',
#  '2010.annual 28077 Lawrence County, Mississippi.csv',
#  '2010.annual 27059 Isanti County, Minnesota.csv',
#  '2010.annual 28097 Montgomery County, Mississippi.csv',
#  '2010.annual 05143 Washington County, Arkansas.csv',
#  '2010.annual 08075 Logan County, Colorado.csv',
#  '2010.annual 72137 Toa Baja Municipio, Puerto Rico.csv',
#  '2010.annual 16001 Ada County, Idaho.csv',
#  '2010.annual 51036 Charles City County, Virginia.csv',
#  '2010.annual 16035 Clearwater County, Idaho.csv',
#  '2010.annual C1842 Corinth, MS MicroSA.csv',
#  '2010.annual 24999 Unknown Or Undefined, Maryland.csv',
#  '2010.annual C1258 Baltimore-Columbia-Towson, MD MSA.csv',
#  '2010.annual 13229 Pierce County, Georgia.csv',
#  '2010.annual 08113 San Miguel County, Colorado.csv',
#  '2010.annual 45069 Marlboro County, South Carolina.csv',
#  '2010.annual C2166 Eugene, OR MSA.csv',
#  '2010.annual 37167 Stanly County, North Carolina.csv',
#  '2010.annual 22029 Concordia Parish, Louisiana.csv',
#  '2010.annual 26051 Gladwin County, Michigan.csv',
#  '2010.annual 19111 Lee County, Iowa.csv',
#  '2010.annual 55141 Wood County, Wisconsin.csv',
#  '2010.annual CS548 Washington-Baltimore-Arlington, DC-MD-VA-WV-PA CSA.csv',
#  '2010.annual 37003 Alexander County, North Carolina.csv',
#  '2010.annual 51025 Brunswick County, Virginia.csv',
#  '2010.annual 27057 Hubbard County, Minnesota.csv',
#  '2010.annual 56031 Platte County, Wyoming.csv',
#  '2010.annual C4402 Spirit Lake, IA MicroSA.csv',
#  '2010.annual 05111 Poinsett County, Arkansas.csv',
#  '2010.annual 19149 Plymouth County, Iowa.csv',
#  '2010.annual 29223 Wayne County, Missouri.csv',
#  '2010.annual 37025 Cabarrus County, North Carolina.csv',
#  '2010.annual 22019 Calcasieu Parish, Louisiana.csv',
#  '2010.annual 19085 Harrison County, Iowa.csv',
#  '2010.annual 31173 Thurston County, Nebraska.csv',
#  '2010.annual 55065 Lafayette County, Wisconsin.csv',
#  '2010.annual 38013 Burke County, North Dakota.csv',
#  '2010.annual 17167 Sangamon County, Illinois.csv',
#  '2010.annual 01069 Houston County, Alabama.csv',
#  '2010.annual 13057 Cherokee County, Georgia.csv',
#  '2010.annual 48033 Borden County, Texas.csv',
#  '2010.annual 24029 Kent County, Maryland.csv',
#  '2010.annual 46093 Meade County, South Dakota.csv',
#  '2010.annual 16075 Payette County, Idaho.csv',
#  '2010.annual 19195 Worth County, Iowa.csv',
#  '2010.annual C2126 Ellensburg, WA MicroSA.csv',
#  '2010.annual C2466 Greensboro-High Point, NC MSA.csv',
#  '2010.annual C4366 Snyder, TX MicroSA.csv',
#  '2010.annual C1722 Clarksburg, WV MicroSA.csv',
#  '2010.annual C4362 Sioux Falls, SD MSA.csv',
#  '2010.annual 18011 Boone County, Indiana.csv',
#  '2010.annual 48391 Refugio County, Texas.csv',
#  '2010.annual 01121 Talladega County, Alabama.csv',
#  '2010.annual 18071 Jackson County, Indiana.csv',
#  '2010.annual 13161 Jeff Davis County, Georgia.csv',
#  '2010.annual 48177 Gonzales County, Texas.csv',
#  '2010.annual 51053 Dinwiddie County, Virginia.csv',
#  '2010.annual CS354 Lumberton-Laurinburg, NC CSA.csv',
#  '2010.annual 17127 Massac County, Illinois.csv',
#  '2010.annual C1962 Del Rio, TX MicroSA.csv',
#  '2010.annual 42037 Columbia County, Pennsylvania.csv',
#  '2010.annual 55109 St. Croix County, Wisconsin.csv',
#  '2010.annual C1626 Cedar City, UT MicroSA.csv',
#  '2010.annual 51193 Westmoreland County, Virginia.csv',
#  '2010.annual C2894 Knoxville, TN MSA.csv',
#  '2010.annual 02150 Kodiak Island Borough, Alaska.csv',
#  '2010.annual 05019 Clark County, Arkansas.csv',
#  '2010.annual 24013 Carroll County, Maryland.csv',
#  '2010.annual 01045 Dale County, Alabama.csv',
#  '2010.annual 39027 Clinton County, Ohio.csv',
#  '2010.annual 27047 Freeborn County, Minnesota.csv',
#  '2010.annual 27033 Cottonwood County, Minnesota.csv',
#  '2010.annual 47029 Cocke County, Tennessee.csv',
#  '2010.annual 16039 Elmore County, Idaho.csv',
#  '2010.annual 35047 San Miguel County, New Mexico.csv',
#  '2010.annual 20035 Cowley County, Kansas.csv',
#  '2010.annual 31057 Dundy County, Nebraska.csv',
#  '2010.annual 51065 Fluvanna County, Virginia.csv',
#  '2010.annual 26091 Lenawee County, Michigan.csv',
#  '2010.annual 08000 Colorado -- Statewide.csv',
#  '2010.annual C1802 Columbus, IN MSA.csv',
#  '2010.annual 19133 Monona County, Iowa.csv',
#  '2010.annual 39049 Franklin County, Ohio.csv',
#  '2010.annual C1574 Cambridge, OH MicroSA.csv',
#  '2010.annual C3910 Poughkeepsie-Newburgh-Middletown, NY MSA.csv',
#  '2010.annual CS340 Little Rock-North Little Rock, AR CSA.csv',
#  '2010.annual 26131 Ontonagon County, Michigan.csv',
#  '2010.annual 20135 Ness County, Kansas.csv',
#  '2010.annual 51157 Rappahannock County, Virginia.csv',
#  '2010.annual C4782 Washington, NC MicroSA.csv',
#  '2010.annual 51600 Fairfax City, Virginia.csv',
#  '2010.annual 51191 Washington County, Virginia.csv',
#  '2010.annual 28039 George County, Mississippi.csv',
#  '2010.annual C4790 Washington-Arlington-Alexandria, DC-VA-MD-WV MSA.csv',
#  '2010.annual 13263 Talbot County, Georgia.csv',
#  '2010.annual C2614 Homosassa Springs, FL MSA.csv',
#  '2010.annual 54067 Nicholas County, West Virginia.csv',
#  '2010.annual 05091 Miller County, Arkansas.csv',
#  '2010.annual 39149 Shelby County, Ohio.csv',
#  '2010.annual 20039 Decatur County, Kansas.csv',
#  '2010.annual 72073 Jayuya Municipio, Puerto Rico.csv',
#  '2010.annual 42079 Luzerne County, Pennsylvania.csv',
#  '2010.annual 29103 Knox County, Missouri.csv',
#  '2010.annual 17191 Wayne County, Illinois.csv',
#  '2010.annual 31051 Dixon County, Nebraska.csv',
#  '2010.annual 08103 Rio Blanco County, Colorado.csv',
#  '2010.annual 51710 Norfolk City, Virginia.csv',
#  '2010.annual CS372 Midland-Odessa, TX CSA.csv',
#  '2010.annual 51059 Fairfax County, Virginia.csv',
#  '2010.annual 29073 Gasconade County, Missouri.csv',
#  '2010.annual 48181 Grayson County, Texas.csv',
#  '2010.annual 41013 Crook County, Oregon.csv',
#  '2010.annual 46009 Bon Homme County, South Dakota.csv',
#  '2010.annual 48125 Dickens County, Texas.csv',
#  '2010.annual 19071 Fremont County, Iowa.csv',
#  '2010.annual 47169 Trousdale County, Tennessee.csv',
#  '2010.annual 51185 Tazewell County, Virginia.csv',
#  '2010.annual 12109 St. Johns County, Florida.csv',
#  '2010.annual 06083 Santa Barbara County, California.csv',
#  '2010.annual 23013 Knox County, Maine.csv',
#  '2010.annual C2174 Evanston, WY MicroSA.csv',
#  '2010.annual 28149 Warren County, Mississippi.csv',
#  '2010.annual C4954 Yazoo City, MS MicroSA.csv',
#  '2010.annual CS297 Jackson-Humboldt, TN CSA.csv',
#  '2010.annual 37079 Greene County, North Carolina.csv',
#  '2010.annual 34011 Cumberland County, New Jersey.csv',
#  '2010.annual C2574 Helena, MT MicroSA.csv',
#  '2010.annual 37119 Mecklenburg County, North Carolina.csv',
#  '2010.annual 08014 Broomfield County, Colorado.csv',
#  '2010.annual C2270 Fort Dodge, IA MicroSA.csv',
#  '2010.annual C2366 Galesburg, IL MicroSA.csv',
#  '2010.annual 56039 Teton County, Wyoming.csv',
#  '2010.annual 26119 Montmorency County, Michigan.csv',
#  '2010.annual 56025 Natrona County, Wyoming.csv',
#  '2010.annual 22009 Avoyelles Parish, Louisiana.csv',
#  '2010.annual 26029 Charlevoix County, Michigan.csv',
#  '2010.annual 30099 Teton County, Montana.csv',
#  '2010.annual 01063 Greene County, Alabama.csv',
#  '2010.annual 18105 Monroe County, Indiana.csv',
#  '2010.annual 51133 Northumberland County, Virginia.csv',
#  '2010.annual 21099 Hart County, Kentucky.csv',
#  '2010.annual C3134 Lynchburg, VA MSA.csv',
#  '2010.annual 31091 Hooker County, Nebraska.csv',
#  '2010.annual 48221 Hood County, Texas.csv',
#  '2010.annual CS274 Greenville-Washington, NC CSA.csv',
#  '2010.annual 23021 Piscataquis County, Maine.csv',
#  '2010.annual 21185 Oldham County, Kentucky.csv',
#  '2010.annual C1682 Charlottesville, VA MSA.csv',
#  '2010.annual 27001 Aitkin County, Minnesota.csv',
#  '2010.annual C2070 East Stroudsburg, PA MSA.csv',
#  '2010.annual 31113 Logan County, Nebraska.csv',
#  '2010.annual 44007 Providence County, Rhode Island.csv',
#  '2010.annual 30057 Madison County, Montana.csv',
#  '2010.annual 12091 Okaloosa County, Florida.csv',
#  '2010.annual 54039 Kanawha County, West Virginia.csv',
#  '2010.annual C4050 Rockland, ME MicroSA.csv',
#  '2010.annual 41011 Coos County, Oregon.csv',
#  '2010.annual 34031 Passaic County, New Jersey.csv',
#  '2010.annual 42087 Mifflin County, Pennsylvania.csv',
#  '2010.annual 41051 Multnomah County, Oregon.csv',
#  '2010.annual C1522 Brownwood, TX MicroSA.csv',
#  '2010.annual 48465 Val Verde County, Texas.csv',
#  '2010.annual 38079 Rolette County, North Dakota.csv',
#  '2010.annual 49009 Daggett County, Utah.csv',
#  '2010.annual 24041 Talbot County, Maryland.csv',
#  '2010.annual 06041 Marin County, California.csv',
#  '2010.annual 19051 Davis County, Iowa.csv',
#  '2010.annual C1086 Alice, TX MicroSA.csv',
#  '2010.annual C3862 Ponca City, OK MicroSA.csv',
#  '2010.annual C2670 Huron, SD MicroSA.csv',
#  '2010.annual C4490 Summerville, GA MicroSA.csv',
#  '2010.annual 13063 Clayton County, Georgia.csv',
#  '2010.annual 37185 Warren County, North Carolina.csv',
#  '2010.annual 28105 Oktibbeha County, Mississippi.csv',
#  '2010.annual C1154 Appleton, WI MSA.csv',
#  '2010.annual C1222 Auburn-Opelika, AL MSA.csv',
#  '2010.annual 20185 Stafford County, Kansas.csv',
#  '2010.annual 29001 Adair County, Missouri.csv',
#  '2010.annual C1410 Bloomsburg-Berwick, PA MSA.csv',
#  '2010.annual 23031 York County, Maine.csv',
#  '2010.annual 51083 Halifax County, Virginia.csv',
#  '2010.annual C2906 Laconia, NH MicroSA.csv',
#  '2010.annual C4854 Wheeling, WV-OH MSA.csv',
#  '2010.annual 01077 Lauderdale County, Alabama.csv',
#  '2010.annual 48359 Oldham County, Texas.csv',
#  '2010.annual 31123 Morrill County, Nebraska.csv',
#  '2010.annual 38001 Adams County, North Dakota.csv',
#  '2010.annual CS358 Manhattan-Junction City, KS CSA.csv',
#  '2010.annual CS346 Longview-Marshall, TX CSA.csv',
#  '2010.annual 28137 Tate County, Mississippi.csv',
#  '2010.annual 37075 Graham County, North Carolina.csv',
#  '2010.annual 36121 Wyoming County, New York.csv',
#  '2010.annual 17103 Lee County, Illinois.csv',
#  '2010.annual 35999 Unknown Or Undefined, New Mexico.csv',
#  '2010.annual C2890 Klamath Falls, OR MicroSA.csv',
#  '2010.annual 51045 Craig County, Virginia.csv',
#  '2010.annual C2718 Jackson, TN MSA.csv',
#  '2010.annual 48395 Robertson County, Texas.csv',
#  '2010.annual 30065 Musselshell County, Montana.csv',
#  '2010.annual 16031 Cassia County, Idaho.csv',
#  '2010.annual 38005 Benson County, North Dakota.csv',
#  '2010.annual 53051 Pend Oreille County, Washington.csv',
#  '2010.annual 04001 Apache County, Arizona.csv',
#  '2010.annual 05000 Arkansas -- Statewide.csv',
#  '2010.annual 06107 Tulare County, California.csv',
#  '2010.annual 29177 Ray County, Missouri.csv',
#  '2010.annual C3030 Lewiston, ID-WA MSA.csv',
#  '2010.annual 39151 Stark County, Ohio.csv',
#  '2010.annual 31177 Washington County, Nebraska.csv',
#  '2010.annual 19143 Osceola County, Iowa.csv',
#  '2010.annual 13051 Chatham County, Georgia.csv',
#  '2010.annual 21081 Grant County, Kentucky.csv',
#  '2010.annual C3878 Portales, NM MicroSA.csv',
#  '2010.annual 13091 Dodge County, Georgia.csv',
#  '2010.annual 22061 Lincoln Parish, Louisiana.csv',
#  '2010.annual C1994 Dixon, IL MicroSA.csv',
#  '2010.annual 48259 Kendall County, Texas.csv',
#  '2010.annual 18055 Greene County, Indiana.csv',
#  '2010.annual 05013 Calhoun County, Arkansas.csv',
#  '2010.annual 40105 Nowata County, Oklahoma.csv',
#  '2010.annual 08089 Otero County, Colorado.csv',
#  '2010.annual 48469 Victoria County, Texas.csv',
#  '2010.annual C2572 Heber, UT MicroSA.csv',
#  '2010.annual C1342 Bemidji, MN MicroSA.csv',
#  '2010.annual 48027 Bell County, Texas.csv',
#  '2010.annual 31049 Deuel County, Nebraska.csv',
#  '2010.annual 78020 St. John, Virgin Islands.csv',
#  '2010.annual 20069 Gray County, Kansas.csv',
#  '2010.annual USMSA U.S. Metropolitan Statistical Areas (combined).csv',
#  '2010.annual 29209 Stone County, Missouri.csv',
#  '2010.annual C1198 Athens, TX MicroSA.csv',
#  '2010.annual 42127 Wayne County, Pennsylvania.csv',
#  '2010.annual C2398 Glasgow, KY MicroSA.csv',
#  '2010.annual 48337 Montague County, Texas.csv',
#  '2010.annual CS376 Milwaukee-Racine-Waukesha, WI CSA.csv',
#  '2010.annual 32011 Eureka County, Nevada.csv',
#  '2010.annual 72117 Rincon Municipio, Puerto Rico.csv',
#  '2010.annual 39147 Seneca County, Ohio.csv',
#  '2010.annual C2750 Janesville-Beloit, WI MSA.csv',
#  '2010.annual 48317 Martin County, Texas.csv',
#  '2010.annual 51023 Botetourt County, Virginia.csv',
#  '2010.annual C1122 Amsterdam, NY MicroSA.csv',
#  '2010.annual C3378 Monroe, MI MSA.csv',
#  '2010.annual 29011 Barton County, Missouri.csv',
#  '2010.annual 20197 Wabaunsee County, Kansas.csv',
#  '2010.annual C1098 Alpena, MI MicroSA.csv',
#  '2010.annual C2618 Honolulu, HI MSA.csv',
#  '2010.annual C4062 Rolla, MO MicroSA.csv',
#  '2010.annual 13321 Worth County, Georgia.csv',
#  '2010.annual C4006 Richmond, VA MSA.csv',
#  '2010.annual 48241 Jasper County, Texas.csv',
#  '2010.annual 42007 Beaver County, Pennsylvania.csv',
#  '2010.annual C4702 Victoria, TX MSA.csv',
#  '2010.annual 21037 Campbell County, Kentucky.csv',
#  '2010.annual CS338 Lima-Van Wert-Celina, OH CSA.csv',
#  '2010.annual CS232 Eau Claire-Menomonie, WI CSA.csv',
#  '2010.annual C1974 Denver-Aurora-Lakewood, CO MSA.csv',
#  '2010.annual 40029 Coal County, Oklahoma.csv',
#  '2010.annual C4094 Safford, AZ MicroSA.csv',
#  '2010.annual 51683 Manassas City, Virginia.csv',
#  '2010.annual CS434 Ponce-Coamo-Santa Isabel, PR CSA.csv',
#  '2010.annual 13087 Decatur County, Georgia.csv',
#  '2010.annual C3110 Los Angeles-Long Beach-Santa Ana, CA MSA.csv',
#  '2010.annual C1274 Barre, VT MicroSA.csv',
#  '2010.annual C3510 New Bern, NC MSA.csv',
#  '2010.annual C3630 Ogdensburg-Massena, NY MicroSA.csv',
#  '2010.annual 20099 Labette County, Kansas.csv',
#  '2010.annual C2630 Hot Springs, AR MSA.csv',
#  '2010.annual 40051 Grady County, Oklahoma.csv',
#  '2010.annual 55097 Portage County, Wisconsin.csv',
#  '2010.annual 51175 Southampton County, Virginia.csv',
#  '2010.annual 46039 Deuel County, South Dakota.csv',
#  '2010.annual 08047 Gilpin County, Colorado.csv',
#  '2010.annual 20023 Cheyenne County, Kansas.csv',
#  '2010.annual CS384 Monroe-Ruston-Bastrop, LA CSA.csv',
#  '2010.annual 46025 Clark County, South Dakota.csv',
#  '2010.annual 06077 San Joaquin County, California.csv',
#  '2010.annual C4598 Troy, AL MicroSA.csv',
#  '2010.annual 47063 Hamblen County, Tennessee.csv',
#  '2010.annual C2794 Juneau, AK MicroSA.csv',
#  '2010.annual 21211 Shelby County, Kentucky.csv',
#  '2010.annual 36053 Madison County, New York.csv',
#  '2010.annual 45081 Saluda County, South Carolina.csv',
#  '2010.annual 30999 Unknown Or Undefined, Montana.csv',
#  '2010.annual 51000 Virginia -- Statewide.csv',
#  '2010.annual C4310 Sheboygan, WI MSA.csv',
#  '2010.annual C3450 Mount Vernon, IL MicroSA.csv',
#  '2010.annual 04027 Yuma County, Arizona.csv',
#  '2010.annual 27169 Winona County, Minnesota.csv',
#  '2010.annual 11000 District of Columbia.csv',
#  '2010.annual 72009 Aibonito Municipio, Puerto Rico.csv',
#  '2010.annual 72015 Arroyo Municipio, Puerto Rico.csv',
#  '2010.annual 48323 Maverick County, Texas.csv',
#  '2010.annual 23007 Franklin County, Maine.csv',
#  '2010.annual 13227 Pickens County, Georgia.csv',
#  '2010.annual 31045 Dawes County, Nebraska.csv',
#  '2010.annual CS496 Savannah-Hinesville-Statesboro, GA CSA.csv',
#  '2010.annual 08101 Pueblo County, Colorado.csv',
#  '2010.annual 22033 East Baton Rouge Parish, Louisiana.csv',
#  '2010.annual C4618 Tupelo, MS MicroSA.csv',
#  '2010.annual 51033 Caroline County, Virginia.csv',
#  '2010.annual 37135 Orange County, North Carolina.csv',
#  '2010.annual 48341 Moore County, Texas.csv',
#  '2010.annual 42109 Snyder County, Pennsylvania.csv',
#  '2010.annual 20089 Jewell County, Kansas.csv',
#  '2010.annual 45015 Berkeley County, South Carolina.csv',
#  '2010.annual 21001 Adair County, Kentucky.csv',
#  '2010.annual 72061 Guaynabo Municipio, Puerto Rico.csv',
#  '2010.annual 17053 Ford County, Illinois.csv',
#  '2010.annual 48135 Ector County, Texas.csv',
#  '2010.annual 51057 Essex County, Virginia.csv',
#  '2010.annual 42073 Lawrence County, Pennsylvania.csv',
#  '2010.annual 18041 Fayette County, Indiana.csv',
#  '2010.annual 38029 Emmons County, North Dakota.csv',
#  '2010.annual 19161 Sac County, Iowa.csv',
#  '2010.annual 42039 Crawford County, Pennsylvania.csv',
#  '2010.annual CS558 Williamsport-Lock Haven, PA CSA.csv',
#  '2010.annual CS378 Minneapolis-St. Paul, MN-WI CSA.csv',
#  '2010.annual 55055 Jefferson County, Wisconsin.csv',
#  '2010.annual 40153 Woodward County, Oklahoma.csv',
#  '2010.annual 24023 Garrett County, Maryland.csv',
#  '2010.annual 12093 Okeechobee County, Florida.csv',
#  '2010.annual C4098 Saginaw, MI MSA.csv',
#  '2010.annual 48275 Knox County, Texas.csv',
#  '2010.annual 26135 Oscoda County, Michigan.csv',
#  '2010.annual 29215 Texas County, Missouri.csv',
#  '2010.annual 20085 Jackson County, Kansas.csv',
#  '2010.annual 41065 Wasco County, Oregon.csv',
#  '2010.annual C1606 Carbondale-Marion, IL MSA.csv',
#  '2010.annual 16037 Custer County, Idaho.csv',
#  '2010.annual 18177 Wayne County, Indiana.csv',
#  '2010.annual 51117 Mecklenburg County, Virginia.csv',
#  '2010.annual 78000 Virgin Islands -- Statewide.csv',
#  '2010.annual 19059 Dickinson County, Iowa.csv',
#  '2010.annual C4178 Sandusky, OH MicroSA.csv',
#  '2010.annual 24031 Montgomery County, Maryland.csv',
#  '2010.annual 27143 Sibley County, Minnesota.csv',
#  '2010.annual C4270 Sebring, FL MSA.csv',
#  '2010.annual 12041 Gilchrist County, Florida.csv',
#  '2010.annual 48141 El Paso County, Texas.csv',
#  '2010.annual 16007 Bear Lake County, Idaho.csv',
#  '2010.annual 13215 Muscogee County, Georgia.csv',
#  '2010.annual 30077 Powell County, Montana.csv',
#  '2010.annual 39053 Gallia County, Ohio.csv',
#  '2010.annual 19035 Cherokee County, Iowa.csv',
#  '2010.annual C2714 Jackson, MS MSA.csv',
#  '2010.annual 05031 Craighead County, Arkansas.csv',
#  '2010.annual 46109 Roberts County, South Dakota.csv',
#  '2010.annual 47145 Roane County, Tennessee.csv',
#  '2010.annual C2038 Dunn, NC MicroSA.csv',
#  '2010.annual 29189 St. Louis County, Missouri.csv',
#  '2010.annual 42029 Chester County, Pennsylvania.csv',
#  '2010.annual 12029 Dixie County, Florida.csv',
#  '2010.annual 38047 Logan County, North Dakota.csv',
#  '2010.annual 30009 Carbon County, Montana.csv',
#  '2010.annual 13185 Lowndes County, Georgia.csv',
#  '2010.annual 46081 Lawrence County, South Dakota.csv',
#  '2010.annual 36091 Saratoga County, New York.csv',
#  '2010.annual 20163 Rooks County, Kansas.csv',
#  '2010.annual 31007 Banner County, Nebraska.csv',
#  '2010.annual 16013 Blaine County, Idaho.csv',
#  '2010.annual 05023 Cleburne County, Arkansas.csv',
#  '2010.annual 19109 Kossuth County, Iowa.csv',
#  '2010.annual C4318 Shelbyville, TN MicroSA.csv',
#  '2010.annual 22021 Caldwell Parish, Louisiana.csv',
#  '2010.annual 12107 Putnam County, Florida.csv',
#  '2010.annual 33001 Belknap County, New Hampshire.csv',
#  '2010.annual 05015 Carroll County, Arkansas.csv',
#  '2010.annual C1886 Crescent City, CA MicroSA.csv',
#  '2010.annual 55047 Green Lake County, Wisconsin.csv',
#  '2010.annual 19193 Woodbury County, Iowa.csv',
#  '2010.annual C2370 Gallup, NM MicroSA.csv',
#  '2010.annual C4754 Wapakoneta, OH MicroSA.csv',
#  '2010.annual 13127 Glynn County, Georgia.csv',
#  '2010.annual 72049 Culebra Municipio, Puerto Rico.csv',
#  '2010.annual C1474 Bremerton-Silverdale, WA MSA.csv',
#  '2010.annual 48021 Bastrop County, Texas.csv',
#  '2010.annual C1958 Defiance, OH MicroSA.csv',
#  '2010.annual 24039 Somerset County, Maryland.csv',
#  '2010.annual 13195 Madison County, Georgia.csv',
#  '2010.annual C4742 Wahpeton, ND-MN MicroSA.csv',
#  '2010.annual CS252 Fond du Lac-Beaver Dam, WI CSA.csv',
#  '2010.annual 72069 Humacao Municipio, Puerto Rico.csv',
#  '2010.annual C3678 Oshkosh-Neenah, WI MSA.csv',
#  '2010.annual C3934 Provo-Orem, UT MSA.csv',
#  '2010.annual 39145 Scioto County, Ohio.csv',
#  '2010.annual 29225 Webster County, Missouri.csv',
#  '2010.annual 13183 Long County, Georgia.csv',
#  '2010.annual 40119 Payne County, Oklahoma.csv',
#  '2010.annual 41041 Lincoln County, Oregon.csv',
#  '2010.annual C4974 Yuma, AZ MSA.csv',
#  '2010.annual 46999 Unknown Or Undefined, South Dakota.csv',
#  '2010.annual CS396 Myrtle Beach-Conway, SC-NC CSA.csv',
#  '2010.annual 47173 Union County, Tennessee.csv',
#  '2010.annual 47107 McMinn County, Tennessee.csv',
#  '2010.annual 40003 Alfalfa County, Oklahoma.csv',
#  '2010.annual 37131 Northampton County, North Carolina.csv',
#  '2010.annual 26005 Allegan County, Michigan.csv',
#  '2010.annual 19121 Madison County, Iowa.csv',
#  '2010.annual 19127 Marshall County, Iowa.csv',
#  '2010.annual 22057 Lafourche Parish, Louisiana.csv',
#  '2010.annual 36057 Montgomery County, New York.csv',
#  '2010.annual C1174 Ashland, OH MicroSA.csv',
#  '2010.annual C4498 Sunbury, PA MicroSA.csv',
#  '2010.annual 12063 Jackson County, Florida.csv',
#  '2010.annual 28127 Simpson County, Mississippi.csv',
#  '2010.annual 54075 Pocahontas County, West Virginia.csv',
#  '2010.annual 18033 DeKalb County, Indiana.csv',
#  '2010.annual 18000 Indiana -- Statewide.csv',
#  '2010.annual 26115 Monroe County, Michigan.csv',
#  '2010.annual C4262 Searcy, AR MicroSA.csv',
#  '2010.annual 46067 Hutchinson County, South Dakota.csv',
#  '2010.annual C3210 Marquette, MI MicroSA.csv',
#  '2010.annual 19043 Clayton County, Iowa.csv',
#  '2010.annual 29205 Shelby County, Missouri.csv',
#  '2010.annual 17057 Fulton County, Illinois.csv',
#  '2010.annual 72001 Adjuntas Municipio, Puerto Rico.csv',
#  '2010.annual 27091 Martin County, Minnesota.csv',
#  '2010.annual 05003 Ashley County, Arkansas.csv',
#  '2010.annual 16049 Idaho County, Idaho.csv',
#  '2010.annual CS178 Cincinnati-Wilmington-Maysville, OH-KY-IN CSA.csv',
#  '2010.annual 36059 Nassau County, New York.csv',
#  '2010.annual 30051 Liberty County, Montana.csv',
#  '2010.annual 47127 Moore County, Tennessee.csv',
#  '2010.annual 06099 Stanislaus County, California.csv',
#  '2010.annual 30053 Lincoln County, Montana.csv',
#  '2010.annual C2566 Havre, MT MicroSA.csv',
#  '2010.annual 51720 Norton City, Virginia.csv',
#  '2010.annual 36041 Hamilton County, New York.csv',
#  '2010.annual 08063 Kit Carson County, Colorado.csv',
#  '2010.annual 72051 Dorado Municipio, Puerto Rico.csv',
#  '2010.annual 26039 Crawford County, Michigan.csv',
#  '2010.annual 51021 Bland County, Virginia.csv',
#  '2010.annual CS122 Atlanta--Athens-Clarke County--Sandy Springs, GA CSA.csv',
#  '2010.annual 46059 Hand County, South Dakota.csv',
#  '2010.annual 53000 Washington -- Statewide.csv',
#  '2010.annual 22073 Ouachita Parish, Louisiana.csv',
#  '2010.annual 05017 Chicot County, Arkansas.csv',
#  '2010.annual 38101 Ward County, North Dakota.csv',
#  '2010.annual 22027 Claiborne Parish, Louisiana.csv',
#  '2010.annual C2210 Farmington, MO MicroSA.csv',
#  '2010.annual C4902 Winchester, VA-WV MSA.csv',
#  '2010.annual C2938 Lake City, FL MicroSA.csv',
#  '2010.annual 39039 Defiance County, Ohio.csv',
#  '2010.annual 05065 Izard County, Arkansas.csv',
#  '2010.annual 28089 Madison County, Mississippi.csv',
#  '2010.annual 01017 Chambers County, Alabama.csv',
#  '2010.annual 53005 Benton County, Washington.csv',
#  '2010.annual 02999 Unknown Or Undefined, Alaska.csv',
#  '2010.annual C3870 Pontiac, IL MicroSA.csv',
#  '2010.annual C3690 Ottumwa, IA MicroSA.csv',
#  '2010.annual 25011 Franklin County, Massachusetts.csv',
#  '2010.annual C4442 Staunton-Waynesboro, VA MSA.csv',
#  '2010.annual 37093 Hoke County, North Carolina.csv',
#  '2010.annual 16025 Camas County, Idaho.csv',
#  '2010.annual 19039 Clarke County, Iowa.csv',
#  '2010.annual 47075 Haywood County, Tennessee.csv',
#  '2010.annual 27123 Ramsey County, Minnesota.csv',
#  '2010.annual 49001 Beaver County, Utah.csv',
#  '2010.annual 31151 Saline County, Nebraska.csv',
#  '2010.annual 19075 Grundy County, Iowa.csv',
#  '2010.annual 29075 Gentry County, Missouri.csv',
#  '2010.annual 40001 Adair County, Oklahoma.csv',
#  '2010.annual C2742 Jamestown, ND MicroSA.csv',
#  '2010.annual 22007 Assumption Parish, Louisiana.csv',
#  '2010.annual C1206 Atlanta-Sandy Springs-Roswell, GA MSA.csv',
#  '2010.annual C1502 Brookhaven, MS MicroSA.csv',
#  '2010.annual 29171 Putnam County, Missouri.csv',
#  '2010.annual 35031 Mckinley County, New Mexico.csv',
#  '2010.annual 08061 Kiowa County, Colorado.csv',
#  '2010.annual 27053 Hennepin County, Minnesota.csv',
#  '2010.annual 21183 Ohio County, Kentucky.csv',
#  '2010.annual C4158 Salisbury, NC MicroSA.csv',
#  '2010.annual 51730 Petersburg City, Virginia.csv',
#  '2010.annual 17073 Henry County, Illinois.csv',
#  '2010.annual 35011 De Baca County, New Mexico.csv',
#  '2010.annual 26105 Mason County, Michigan.csv',
#  '2010.annual 28063 Jefferson County, Mississippi.csv',
#  '2010.annual 17077 Jackson County, Illinois.csv',
#  '2010.annual 55009 Brown County, Wisconsin.csv',
#  '2010.annual C1726 Clarksdale, MS MicroSA.csv',
#  '2010.annual 38039 Griggs County, North Dakota.csv',
#  '2010.annual 37031 Carteret County, North Carolina.csv',
#  '2010.annual C1634 Cedartown, GA MicroSA.csv',
#  '2010.annual 16023 Butte County, Idaho.csv',
#  '2010.annual 48147 Fannin County, Texas.csv',
#  '2010.annual C1734 Clearlake, CA MicroSA.csv',
#  '2010.annual 51131 Northampton County, Virginia.csv',
#  '2010.annual 48287 Lee County, Texas.csv',
#  '2010.annual 21073 Franklin County, Kentucky.csv',
#  '2010.annual 45009 Bamberg County, South Carolina.csv',
#  '2010.annual 45063 Lexington County, South Carolina.csv',
#  '2010.annual 01065 Hale County, Alabama.csv',
#  '2010.annual C3078 Little Rock-North Little Rock-Conway, AR MSA.csv',
#  '2010.annual 39101 Marion County, Ohio.csv',
#  '2010.annual 50009 Essex County, Vermont.csv',
#  '2010.annual 20059 Franklin County, Kansas.csv',
#  '2010.annual 37000 North Carolina -- Statewide.csv',
#  '2010.annual 29173 Ralls County, Missouri.csv',
#  '2010.annual C4202 San Luis Obispo-Paso Robles-Arroyo Grande, CA MSA.csv',
#  '2010.annual CS350 Louisville-Jefferson County--Elizabethtown--Madison, KY-IN CSA.csv',
#  '2010.annual 53069 Wahkiakum County, Washington.csv',
#  '2010.annual 31011 Boone County, Nebraska.csv',
#  '2010.annual C4622 Tuscaloosa, AL MSA.csv',
#  '2010.annual 42111 Somerset County, Pennsylvania.csv',
#  '2010.annual C3758 Paris, TX MicroSA.csv',
#  '2010.annual 28093 Marshall County, Mississippi.csv',
#  '2010.annual 30037 Golden Valley County, Montana.csv',
#  '2010.annual 26999 Unknown Or Undefined, Michigan.csv',
#  '2010.annual 13077 Coweta County, Georgia.csv',
#  '2010.annual CS324 Lake Charles-Jennings, LA CSA.csv',
#  '2010.annual 29025 Caldwell County, Missouri.csv',
#  '2010.annual 34025 Monmouth County, New Jersey.csv',
#  '2010.annual 01105 Perry County, Alabama.csv',
#  '2010.annual 27131 Rice County, Minnesota.csv',
#  '2010.annual 36109 Tompkins County, New York.csv',
#  '2010.annual 53077 Yakima County, Washington.csv',
#  '2010.annual 27167 Wilkin County, Minnesota.csv',
#  '2010.annual 18117 Orange County, Indiana.csv',
#  '2010.annual 33017 Strafford County, New Hampshire.csv',
#  '2010.annual 27015 Brown County, Minnesota.csv',
#  '2010.annual 72109 Patillas Municipio, Puerto Rico.csv',
#  '2010.annual 20019 Chautauqua County, Kansas.csv',
#  '2010.annual 39045 Fairfield County, Ohio.csv',
#  '2010.annual 37197 Yadkin County, North Carolina.csv',
#  '2010.annual 06037 Los Angeles County, California.csv',
#  '2010.annual C2738 Jacksonville, TX MicroSA.csv',
#  '2010.annual C2442 Grants Pass, OR MSA.csv',
#  '2010.annual 41017 Deschutes County, Oregon.csv',
#  '2010.annual 26117 Montcalm County, Michigan.csv',
#  '2010.annual 13191 McIntosh County, Georgia.csv',
#  '2010.annual 05035 Crittenden County, Arkansas.csv',
#  '2010.annual 48131 Duval County, Texas.csv',
#  '2010.annual 47001 Anderson County, Tennessee.csv',
#  '2010.annual 12031 Duval County, Florida.csv',
#  '2010.annual 53037 Kittitas County, Washington.csv',
#  '2010.annual 47159 Smith County, Tennessee.csv',
#  '2010.annual 37053 Currituck County, North Carolina.csv',
#  '2010.annual 48207 Haskell County, Texas.csv',
#  '2010.annual 21083 Graves County, Kentucky.csv',
#  '2010.annual 13253 Seminole County, Georgia.csv',
#  '2010.annual 48385 Real County, Texas.csv',
#  '2010.annual 55121 Trempealeau County, Wisconsin.csv',
#  '2010.annual 55011 Buffalo County, Wisconsin.csv',
#  '2010.annual 48167 Galveston County, Texas.csv',
#  '2010.annual 05115 Pope County, Arkansas.csv',
#  '2010.annual 27023 Chippewa County, Minnesota.csv',
#  '2010.annual C4246 Scottsboro, AL MicroSA.csv',
#  '2010.annual 31013 Box Butte County, Nebraska.csv',
#  ...]

# %%
# creating a list of the selected files for data to be obtained from
# these are only the counties that we are interested in

Co_files10 = []

for filename in filesList2:
    for i in STCO:
        if i in filename:
            Co_files10.append(filename)
            
len(Co_files10)
# Out:
# 274

# %%
JobsCO10 = {}

for i in Co_files10:
    row = csvRows(mypath2 + i)
    # append the data to the empty dict; STCO as key and total_emp as value 
    JobsCO10[row[0]] = row[1]


# making it a DataFrame
JobsCO10 = pd.DataFrame.from_dict(JobsCO10, orient='index', columns=['Total_emp10'])
JobsCO10 = JobsCO10.sort_index()

print(JobsCO10.shape)
print(type(JobsCO10))
print(JobsCO10.dtypes)
JobsCO10.head()
# Out:
# (274, 1)
# <class 'pandas.core.frame.DataFrame'>
# Total_emp10    object
# dtype: object
#       Total_emp10
# 06001      630343
# 06013      313615
# 06037     3856789
# 06041      102062
# 06055       64073

# %% [markdown]
# ### Merge 2010 w 2017 data

# %%
JobsCO10 = JobsCO10.merge(JobsCO17, left_index=True,
                                 right_index=True)

JobsCO10['Total_emp17'] = JobsCO10['Total_emp17'].fillna(0).astype(int)
JobsCO10['Total_emp10'] = JobsCO10['Total_emp10'].fillna(0).astype(int)


print(JobsCO10.dtypes)
print(JobsCO10.shape)
JobsCO10.head()
# Out:
# Total_emp10    int64
# Total_emp17    int64
# dtype: object
# (274, 2)
#        Total_emp10  Total_emp17
# 06001       630343       771652
# 06013       313615       366720
# 06037      3856789      4381836
# 06041       102062       115432
# 06055        64073        76762

# %% [markdown]
# ### Merging with geo-coded data in order to groupby CSA's

# %%
JobsCO_CSA10 = JobsCO10.merge(geo, left_index=True, 
                              right_on='STCO').set_index('County_name')

print(JobsCO_CSA10.shape)
JobsCO_CSA10.tail(2)
# Out:
# (274, 5)
#              Total_emp10  Total_emp17  CSA                     CSA_name   STCO
# County_name
# Pierce              9508        10026  378  Minneapolis-St. Paul, MN-WI  55093
# St. Croix          27950        33521  378  Minneapolis-St. Paul, MN-WI  55109

# %%
JobsCSA10_17 = JobsCO_CSA10.groupby(['CSA', 'CSA_name']).sum()

JobsCSA10_17['emp_NET00-17'] = JobsCSA10_17['Total_emp17'] - JobsCSA10_17['Total_emp10']
JobsCSA10_17['emp_%00-17'] = (JobsCSA10_17['Total_emp17'] - JobsCSA10_17['Total_emp10']) \
                                                          / JobsCSA10_17['Total_emp10']

print(JobsCSA10_17.shape)
JobsCSA10_17
# Out:
# (15, 4)
#                                                       Total_emp10  \
# CSA CSA_name
# 122 Atlanta--Athens-Clarke County--Sandy Springs, GA      2372462
# 148 Boston-Worcester-Providence, MA-RI-NH-CT              3691234
# 176 Chicago-Naperville, IL-IN-WI                          4192303
# 206 Dallas-Fort Worth, TX-OK                              2944870
# 216 Denver-Aurora, CO                                     1405857
# 220 Detroit-Warren-Ann Arbor, MI                          2022604
# 288 Houston-The Woodlands, TX                             2541934
# 348 Los Angeles-Long Beach, CA                            6655146
# 370 Miami-Fort Lauderdale-Port St. Lucie, FL              2286983
# 378 Minneapolis-St. Paul, MN-WI                           1823091
# 408 New York-Newark, NY-NJ-CT-PA                          9347507
# 428 Philadelphia-Reading-Camden, PA-NJ-DE-MD              3020134
# 488 San Jose-San Francisco-Oakland, CA                    3421777
# 500 Seattle-Tacoma, WA                                    1891548
# 548 Washington-Baltimore-Arlington, DC-MD-VA-WV-PA        4347320
#
#                                                       Total_emp17  \
# CSA CSA_name
# 122 Atlanta--Athens-Clarke County--Sandy Springs, GA      2844774
# 148 Boston-Worcester-Providence, MA-RI-NH-CT              4121641
# 176 Chicago-Naperville, IL-IN-WI                          4631371
# 206 Dallas-Fort Worth, TX-OK                              3586036
# 216 Denver-Aurora, CO                                     1730344
# 220 Detroit-Warren-Ann Arbor, MI                          2312726
# 288 Houston-The Woodlands, TX                             2969515
# 348 Los Angeles-Long Beach, CA                            7741633
# 370 Miami-Fort Lauderdale-Port St. Lucie, FL              2720909
# 378 Minneapolis-St. Paul, MN-WI                           2063304
# 408 New York-Newark, NY-NJ-CT-PA                         10423589
# 428 Philadelphia-Reading-Camden, PA-NJ-DE-MD              3219771
# 488 San Jose-San Francisco-Oakland, CA                    4232644
# 500 Seattle-Tacoma, WA                                    2249890
# 548 Washington-Baltimore-Arlington, DC-MD-VA-WV-PA        4731197
#
#                                                       emp_NET00-17  emp_%00-17
# CSA CSA_name
# 122 Atlanta--Athens-Clarke County--Sandy Springs, GA        472312    0.199081
# 148 Boston-Worcester-Providence, MA-RI-NH-CT                430407    0.116602
# 176 Chicago-Naperville, IL-IN-WI                            439068    0.104732
# 206 Dallas-Fort Worth, TX-OK                                641166    0.217723
# 216 Denver-Aurora, CO                                       324487    0.230811
# 220 Detroit-Warren-Ann Arbor, MI                            290122    0.143440
# 288 Houston-The Woodlands, TX                               427581    0.168211
# 348 Los Angeles-Long Beach, CA                             1086487    0.163255
# 370 Miami-Fort Lauderdale-Port St. Lucie, FL                433926    0.189737
# 378 Minneapolis-St. Paul, MN-WI                             240213    0.131761
# 408 New York-Newark, NY-NJ-CT-PA                           1076082    0.115120
# 428 Philadelphia-Reading-Camden, PA-NJ-DE-MD                199637    0.066102
# 488 San Jose-San Francisco-Oakland, CA                      810867    0.236972
# 500 Seattle-Tacoma, WA                                      358342    0.189444
# 548 Washington-Baltimore-Arlington, DC-MD-VA-WV-PA          383877    0.088302

# %%
JobsCSA10_17.to_csv('exports/Jobs10-17CSA_NEW.csv')

# %% [markdown]
# ---
# # Housing / Jobs Balance analysis
#
#
# ## _All the Housing / Jobs Balance analysis can be found in a separated notebook in this repo: 6-Pop-Hou-Jobs-balance_
#
# - PEP/2017/housing
# - BLS QCEW 2017 annually
#
# # 1. Counties - for mapping

# %% [markdown]
# ## Total Housing from PEP housing 2017
#
# - Detailing on Population and Housing Estimates APIs: https://www.census.gov/data/developers/data-sets/popest-popproj/popest.2000-2010_Intercensals.html
#
# - [examples for /data/2017/pep/housing](https://api.census.gov/data/2017/pep/housing/examples.html)

# %%
# HU2017 data for all counties in the US
totalHU17 = pd.read_json('https://api.census.gov/data/2017/pep/housing?get='+
                         'HUEST,GEONAME&for=county:*&DATE=10')

totalHU17.columns = totalHU17.iloc[0]
totalHU17 = totalHU17[1:]

totalHU17['state'] = totalHU17['state'].apply(lambda x: '{0:0>2}'.format(x))
totalHU17['county'] = totalHU17['county'].apply(lambda x: '{0:0>3}'.format(x))
totalHU17['STCO'] = totalHU17[['state', 'county']].apply(lambda x: ''.join(x), axis=1)

totalHU17 = totalHU17.drop(['state', 'county','DATE'], axis=1)
totalHU17.columns = ['TotalHousing17','Name', 'STCO']

print(totalHU17.shape)
totalHU17.head(20)
# Out:
# (3142, 3)
#    TotalHousing17                            Name   STCO
# 1          372981   Fairfield County, Connecticut  09001
# 2          379719    Hartford County, Connecticut  09003
# 3           88285  Litchfield County, Connecticut  09005
# 4           76339   Middlesex County, Connecticut  09007
# 5          367195   New Haven County, Connecticut  09009
# 6          123398  New London County, Connecticut  09011
# 7           59729     Tolland County, Connecticut  09013
# 8           49742     Windham County, Connecticut  09015
# 9           49825      Androscoggin County, Maine  23001
# 10          39911         Aroostook County, Maine  23003
# 11         144433        Cumberland County, Maine  23005
# 12          22183          Franklin County, Maine  23007
# 13          41263           Hancock County, Maine  23009
# 14          62664          Kennebec County, Maine  23011
# 15          24408              Knox County, Maine  23013
# 16          23979           Lincoln County, Maine  23015
# 17          36958            Oxford County, Maine  23017
# 18          75853         Penobscot County, Maine  23019
# 19          15473       Piscataquis County, Maine  23021
# 20          18825         Sagadahoc County, Maine  23023

# %% [markdown]
# ## Total Housing 2010 PEP 2010 -- Not in use
#
# This data set is called "int_housingunits 2000" and it includes both 2000 and 2010 Census Decennials data.
#
# - API Call: api.census.gov/data/2000/pep/int_housingunits
# - [examples](https://api.census.gov/data/2000/pep/int_housingunits.html)
# - [variables](https://api.census.gov/data/2000/pep/int_housingunits/variables.html) in /data/2000/pep/int_housingunits/variables

# %%
# HU2010 data for all counties in the US, from PEP housing 2000-2010
totalHU10 = pd.read_json('https://api.census.gov/data/2000/pep/int_housingunits?get='+
                         'HUEST,GEONAME&for=county:*&DATE=10')

totalHU10.columns = totalHU10.iloc[0]
totalHU10 = totalHU10[1:]

totalHU10['state'] = totalHU10['state'].apply(lambda x: '{0:0>2}'.format(x))
totalHU10['county'] = totalHU10['county'].apply(lambda x: '{0:0>3}'.format(x))
totalHU10['STCO'] = totalHU10[['state', 'county']].apply(lambda x: ''.join(x), axis=1)

totalHU10 = totalHU10.drop(['state', 'county', 'DATE'], axis=1)
totalHU10.columns = ['TotalHousing10','Name', 'STCO']

print(totalHU10.shape)
totalHU10.head()
# Out:
# (3143, 3)
#   TotalHousing10                            Name   STCO
# 1         358484   Fairfield County, Connecticut  09001
# 2         372325    Hartford County, Connecticut  09003
# 3          86754  Litchfield County, Connecticut  09005
# 4          74172   Middlesex County, Connecticut  09007
# 5         359866   New Haven County, Connecticut  09009

# %% [markdown]
# ## Total Pop + Total Housing 2010 from US Census Bureau Decennial Census 2010

# %%
# total HU for all counties in the US, 2010
totalHU10_sf = pd.read_json('https://api.census.gov/data/2010/sf1?get='+
                            'P0010001,H00010001,NAME&for=county:*')
totalHU10_sf.columns = totalHU10_sf.iloc[0]
totalHU10_sf = totalHU10_sf[1:]

totalHU10_sf['state'] = totalHU10_sf['state'].apply(lambda x: '{0:0>2}'.format(x))
totalHU10_sf['county'] = totalHU10_sf['county'].apply(lambda x: '{0:0>3}'.format(x))
totalHU10_sf['STCO'] = totalHU10_sf[['state', 'county']].apply(lambda x: ''.join(x), axis=1)

totalHU10_sf = totalHU10_sf.drop(['state', 'county'], axis=1)
totalHU10_sf.columns = ['TotalPop00','TotalHousing00','Name', 'STCO']

print(totalHU10_sf.shape)
totalHU10_sf.head()
# Out:
# (3221, 4)
#   TotalPop00 TotalHousing00            Name   STCO
# 1      54571          22135  Autauga County  01001
# 2     182265         104061  Baldwin County  01003
# 3      27457          11829  Barbour County  01005
# 4      22915           8981     Bibb County  01007
# 5      57322          23887   Blount County  01009

# %% [markdown]
# ## Total Pop + Total Housing 2000 from US Census Bureau Decennial Census 2000

# %%
# total HU for all counties in the US, 2000
totalHU00 = pd.read_json('https://api.census.gov/data/2000/sf1?get='+
                         'P001001,H001001,NAME&for=county:*')
totalHU00.columns = totalHU00.iloc[0]
totalHU00 = totalHU00[1:]

totalHU00['state'] = totalHU00['state'].apply(lambda x: '{0:0>2}'.format(x))
totalHU00['county'] = totalHU00['county'].apply(lambda x: '{0:0>3}'.format(x))
totalHU00['STCO'] = totalHU00[['state', 'county']].apply(lambda x: ''.join(x), axis=1)

totalHU00 = totalHU00.drop(['state', 'county'], axis=1)
totalHU00.columns = ['TotalPop00','TotalHousing00','Name', 'STCO']

print(totalHU00.shape)
totalHU00.head()
# Out:
# (3141, 4)
#   TotalPop00 TotalHousing00            Name   STCO
# 1      43671          17662  Autauga County  01001
# 2     140415          74285  Baldwin County  01003
# 3      29038          12461  Barbour County  01005
# 4      20826           8345     Bibb County  01007
# 5      51024          21158   Blount County  01009

# %% [markdown]
# ------
#
# ## CSA's

# %%
HouJobs = pd.read_excel('BPS_HousingPermits_analysis.xlsx', 
                        sheet_name='HousingJobs_Balance')[:-2].set_index('Name')

HouJobs['housing / jobs 2010'] = HouJobs['housing / jobs 2010'].round(decimals=2)
HouJobs['housing / jobs 2016'] = HouJobs['housing / jobs 2016'].round(decimals=2)
HouJobs['housing / jobs 10-16 NET'] = HouJobs['housing / jobs 10-16 NET'].round(decimals=2)

HouJobs['CSA'] = HouJobs['CSA'].astype(int)

print(HouJobs .shape)
HouJobs
# Out:
# (15, 5)
#                CSA                                          FullName  \
# Name
# New York       408                      New York-Newark, NY-NJ-CT-PA
# Los Angeles    348                        Los Angeles-Long Beach, CA
# Chicago        176                      Chicago-Naperville, IL-IN-WI
# Washington     548    Washington-Baltimore-Arlington, DC-MD-VA-WV-PA
# San Francisco  488                San Jose-San Francisco-Oakland, CA
# Boston         148          Boston-Worcester-Providence, MA-RI-NH-CT
# Dallas         206                          Dallas-Fort Worth, TX-OK
# Philadelphia   428          Philadelphia-Reading-Camden, PA-NJ-DE-MD
# Houston        288                         Houston-The Woodlands, TX
# Miami          370          Miami-Fort Lauderdale-Port St. Lucie, FL
# Atlanta        122  Atlanta--Athens-Clarke County--Sandy Springs, GA
# Detroit        220                      Detroit-Warren-Ann Arbor, MI
# Seattle        500                                Seattle-Tacoma, WA
# Minneapolis    378                       Minneapolis-St. Paul, MN-WI
# Denver         216                                 Denver-Aurora, CO
#
#                housing / jobs 2010  housing / jobs 2016  \
# Name
# New York                      0.92                 0.84
# Los Angeles                   0.68                 0.60
# Chicago                       0.42                 0.39
# Washington                    0.84                 0.80
# San Francisco                 0.92                 0.77
# Boston                        0.92                 0.84
# Dallas                        0.92                 0.81
# Philadelphia                  0.97                 0.93
# Houston                       0.94                 0.86
# Miami                         1.21                 1.05
# Atlanta                       1.02                 0.90
# Detroit                       1.15                 1.02
# Seattle                       0.97                 0.86
# Minneapolis                   0.84                 0.77
# Denver                        0.93                 0.80
#
#                housing / jobs 10-16 NET
# Name
# New York                          -0.07
# Los Angeles                       -0.08
# Chicago                           -0.03
# Washington                        -0.04
# San Francisco                     -0.14
# Boston                            -0.08
# Dallas                            -0.11
# Philadelphia                      -0.04
# Houston                           -0.08
# Miami                             -0.16
# Atlanta                           -0.13
# Detroit                           -0.13
# Seattle                           -0.11
# Minneapolis                       -0.07
# Denver                            -0.13
