# %% [markdown]
# # _Updates to make -- from Carolyn's notes, 082018:_
#
# - Baseline data for +65 workforce
# - Overall % of aging workforce
# - Draw conclusions
#
# ----
# Author: Dana Chermesh, Regional Planning intern;
# 07-20-2018
#
# ### _US Metros comparison  Notebook no.2_
# # Labor force
# - **_ACS 5-yesr estimates 2012-2016 using Census API_**
# - **_ACS 5-yesr estimates 2006-2010 using Census API_**
#
#
#
#
# ----
#
# A user guide for Census Data API:
#
# # [Census Data API User Guide](https://www.census.gov/content/dam/Census/data/developers/api-user-guide/api-guide.pdf)
#
# The Census Data API in an API that gives the public access to raw statistical data from various Census Bureau data
# programs. In terms of space, we aggregate the data and usually associate them with a
# certain Census geographic boundary/area defined by a FIPS code.
#
# ## _get your API key from:_
# https://api.census.gov/data/key_signup.html
#
# **Recommended:** In order to keep your API key confidential, please save your API key in a .py file named **censusAPI.py** as follows:
#
# ```python
# myAPI = 'XXXXXXXXXXXXXXX'
# ```
# Then read into this notebook as in the following cell:
# ```python
# from censusAPI import myAPI
# ```
#
# ### The complete list of all available datasets for the API is located here:
# https://api.census.gov/data.html

# %% [markdown]
# ----
# ## Labor Force 2016
# ### _data were obtained from the ACS 2012-2016 5-year estimate, all counties in the US_
#
# [list of variables](https://api.census.gov/data/2016/acs/acs5/variables)
#
# variables to be acquired:
# - **B23025_001E** |	All pop at age 16 and over
# - **B23025_007E** | All pop at age 16 and over, not in labor force
#
# for prime age (25-54):
# - **B23001_025E** | Male 25 to 29 in labor force
# - **B23001_032E** | Male 30 to 34 in labor force
# - **B23001_039E** | Male 35 to 44 in labor force
# - **B23001_046E** | Male 45 to 54 in labor force
# - **B23001_111E** | Female 25 to 29 in labor force
# - **B23001_118E** | Female 30 to 34 in labor force
# - **B23001_125E** | Female 35 to 44 in labor force
# - **B23001_132E** | Female 45 to 54 in labor force
#
# for over 65:
# - **B23001_074E** | Male 65 to 69 in labor force
# - **B23001_079E** | Male 70 to 74 in labor force
# - **B23001_084E** | Male 75 and over in labor force
# - **B23001_160E** | Female 65 to 69 in labor force
# - **B23001_165E** | Female 70 to 74 in labor force
# - **B23001_170E** | Female 75 and over in labor force
#
# for 55-64:
# - **B23001_053E** | Male 54 to 59 in labor force
# - **B23001_060E** | Male 60 to 61 in labor force
# - **B23001_067E** | Male 62 and 64 in labor force
# - **B23001_139E** | Female 54 to 59 in labor force
# - **B23001_146E** | Female 60 to 61 in labor force
# - **B23001_153E** | Female 62 and 64 in labor force

# %%
import pandas as pd
import json
# reading in my api key saved in censusAPI.py as
# myAPI = 'XXXXXXXXXXXXXXX'
# request an api key in: https://api.census.gov/data/key_signup.html
from censusAPI import myAPI

# %%
import json
import requests 
import urllib
import numpy as np

#read in in the variables available. the info you need is in the 1year ACS data
url = "https://api.census.gov/data/2016/acs/acs5/variables.json"
resp = requests.request('GET', url)
aff1y = json.loads(resp.text)

# %%
#turning things into arrays to enable broadcasting
#Python3
affkeys = np.array(list(aff1y['variables'].keys()))

affkeys
# Out:
# array(['B17022_029E', 'B07404GPR_004E', 'C23002E_002E', ...,
#        'B20005E_037E', 'B24012_045E', 'B17022_049E'], dtype='<U14')

# %%
print(aff1y['variables']['B23025_001E'])
print(aff1y['variables']['B23025_007E'])
# Out:
# {'limit': 0, 'predicateType': 'int', 'label': 'Estimate!!Total', 'attributes': 'B23025_001M,B23025_001MA,B23025_001EA', 'concept': 'EMPLOYMENT STATUS FOR THE POPULATION 16 YEARS AND OVER', 'group': 'B23025'}
# {'limit': 0, 'predicateType': 'int', 'label': 'Estimate!!Total!!Not in labor force', 'attributes': 'B23025_007M,B23025_007MA,B23025_007EA', 'concept': 'EMPLOYMENT STATUS FOR THE POPULATION 16 YEARS AND OVER', 'group': 'B23025'}

# %%
Labor16vars = ['B23025_001E', 'B23025_007E', 'B23001_025E', 'B23001_032E',
               'B23001_039E', 'B23001_046E', 'B23001_053E', 'B23001_060E',
               'B23001_067E', 'B23001_139E', 'B23001_146E', 'B23001_111E',
               'B23001_153E', 'B23001_118E', 'B23001_125E', 'B23001_132E', 
               'B23001_074E', 'B23001_079E', 'B23001_084E', 'B23001_160E',
               'B23001_165E', 'B23001_170E']

Labor16str = ",".join(Labor16vars)
Labor16str
# Out:
# 'B23025_001E,B23025_007E,B23001_025E,B23001_032E,B23001_039E,B23001_046E,B23001_053E,B23001_060E,B23001_067E,B23001_139E,B23001_146E,B23001_111E,B23001_153E,B23001_118E,B23001_125E,B23001_132E,B23001_074E,B23001_079E,B23001_084E,B23001_160E,B23001_165E,B23001_170E'

# %%
# Labor Force data for all counties in the US, 2016
Labor16 = pd.read_json('https://api.census.gov/data/2016/acs/acs5?get='+
                          Labor16str +
                         ',NAME&for=county:*&in=state:*')
Labor16.columns = Labor16.iloc[0]
Labor16 = Labor16[1:]

Labor16['state'] = Labor16['state'].apply(lambda x: '{0:0>2}'.format(x))
Labor16['county'] = Labor16['county'].apply(lambda x: '{0:0>3}'.format(x))
Labor16['STCO'] = Labor16[['state', 'county']].apply(lambda x: ''.join(x), axis=1)

# converting dtypes to int
for col in Labor16vars:
    Labor16[col] = Labor16[col].astype(int)

# aggregating age groups and calculations
Labor16['LaborForce'] = Labor16['B23025_001E'] - Labor16['B23025_007E']
Labor16['PrimeAge'] = Labor16['B23001_025E'] + Labor16['B23001_032E'] +\
                      Labor16['B23001_039E'] + Labor16['B23001_046E'] +\
                      Labor16['B23001_111E'] + Labor16['B23001_118E'] +\
                      Labor16['B23001_125E'] + Labor16['B23001_132E']
Labor16['Over65'] = Labor16['B23001_074E'] + Labor16['B23001_079E'] +\
                    Labor16['B23001_084E'] + Labor16['B23001_160E'] +\
                    Labor16['B23001_165E'] + Labor16['B23001_170E']
Labor16['55-64'] = Labor16['B23001_053E'] + Labor16['B23001_060E'] +\
                   Labor16['B23001_067E'] + Labor16['B23001_139E'] +\
                   Labor16['B23001_146E'] + Labor16['B23001_153E']
Labor16['Under25'] = Labor16['LaborForce'] - Labor16['PrimeAge'] -\
                     Labor16['Over65'] - Labor16['55-64']

Labor16 = Labor16.drop(['state', 'county', 'B23025_001E', 'B23025_007E',
                        'B23001_025E', 'B23001_032E', 'B23001_039E',
                        'B23001_046E', 'B23001_111E', 'B23001_118E', 
                        'B23001_125E', 'B23001_132E', 'B23001_074E',
                        'B23001_079E', 'B23001_084E', 'B23001_160E',
                        'B23001_139E', 'B23001_146E', 'B23001_153E',
                        'B23001_053E', 'B23001_060E', 'B23001_067E',
                        'B23001_165E', 'B23001_170E'], axis=1)
Labor16.columns = ['Name', 'STCO', 'LaborForce', 'PrimeAge', 
                   'Over65', '55-64', 'Under25']

print(Labor16.shape)
print(Labor16.dtypes)
Labor16.head()
# Out:
# (3220, 7)
# Name          object
# STCO          object
# LaborForce     int64
# PrimeAge       int64
# Over65         int64
# 55-64          int64
# Under25        int64
# dtype: object
#                       Name   STCO  LaborForce  PrimeAge  Over65  55-64  \
# 1  Autauga County, Alabama  01001       26008     17356     978   4086
# 2  Baldwin County, Alabama  01003       93872     59889    5505  16197
# 3  Barbour County, Alabama  01005       10316      6397     814   1720
# 4     Bibb County, Alabama  01007        9002      6019     600   1364
# 5   Blount County, Alabama  01009       22969     15351    1129   3829
#
#    Under25
# 1     3588
# 2    12281
# 3     1385
# 4     1019
# 5     2660

# %% [markdown]
# ----
# ## Labor Force 2000
# ### _data were obtained from US Census Bureau Decennial 2000 Census, SF3_
#
# [list of variables](https://api.census.gov/data/2000/sf3/variables.html)
#
# variables to be acquired:
# - **P043003** | Male In labor force
# - **P043010** | Female In labor force
#
# for prime age (25-54):
# - **PCT035025** | Male 25 to 29 in labor force
# - **PCT035032** | Male 30 to 34 in labor force
# - **PCT035039** | Male 35 to 44 in labor force
# - **PCT035046** | Male 45 to 54 in labor force
# - **PCT035117** | Female 25 to 29 in labor force
# - **PCT035124** | Female 30 to 34 in labor force
# - **PCT035131** | Female 35 to 44 in labor force
# - **PCT035138** | Female 45 to 54 in labor force
#
# for over 65:
# - **PCT035074** | Male 65 to 69 in labor force
# - **PCT035081** | Male 70 to 74 in labor force
# - **PCT035088** | Male 75 and over in labor force
# - **PCT035166** | Female 65 to 69 in labor force
# - **PCT035173** | Female 70 to 74 in labor force
# - **PCT035180** | Female 75 and over in labor force
#
# for 55-64:
# - **PCT035053** | Male 55 to 59 in labor force
# - **PCT035060** | Male 60 to 61 in labor force
# - **PCT035067** | Male 62 to 64 in labor force
# - **PCT035145** | Female 55 to 59 in labor force
# - **PCT035152** | Female 60 to 61 in labor force
# - **PCT035159** | Female 62 to 64 in labor force

# %%
Labor00vars = ['P043003', 'P043010', 'PCT035025', 'PCT035032',
               'PCT035039', 'PCT035046', 'PCT035053', 'PCT035060',
               'PCT035067', 'PCT035145', 'PCT035152', 'PCT035159',
               'PCT035117', 'PCT035124', 'PCT035131', 'PCT035138',
               'PCT035074', 'PCT035081', 'PCT035088', 'PCT035166', 
               'PCT035173', 'PCT035180']

Labor00str = ",".join(Labor00vars)
Labor00str
# Out:
# 'P043003,P043010,PCT035025,PCT035032,PCT035039,PCT035046,PCT035053,PCT035060,PCT035067,PCT035145,PCT035152,PCT035159,PCT035117,PCT035124,PCT035131,PCT035138,PCT035074,PCT035081,PCT035088,PCT035166,PCT035173,PCT035180'

# %%
# Labor Force data for all counties in the US, 2000
Labor00 = pd.read_json('https://api.census.gov/data/2000/sf3?get='+
                        Labor00str +
                        ',NAME&for=county:*&in=state:*')
Labor00.columns = Labor00.iloc[0]
Labor00 = Labor00[1:]

Labor00['state'] = Labor00['state'].apply(lambda x: '{0:0>2}'.format(x))
Labor00['county'] = Labor00['county'].apply(lambda x: '{0:0>3}'.format(x))
Labor00['STCO'] = Labor00[['state', 'county']].apply(lambda x: ''.join(x), axis=1)

# converting dtypes to int
for col in Labor00vars:
    Labor00[col] = Labor00[col].astype(int)

Labor00['LaborForce00'] = Labor00['P043003'] + Labor00['P043010']
Labor00['PrimeAge00'] = Labor00['PCT035025'] + Labor00['PCT035032'] +\
                      Labor00['PCT035039'] + Labor00['PCT035046'] +\
                      Labor00['PCT035117'] + Labor00['PCT035124'] +\
                      Labor00['PCT035131'] + Labor00['PCT035138']
Labor00['Over65_00'] = Labor00['PCT035074'] + Labor00['PCT035081'] +\
                       Labor00['PCT035088'] + Labor00['PCT035166'] +\
                       Labor00['PCT035173'] + Labor00['PCT035180']
Labor00['55-64_00'] = Labor00['PCT035053'] + Labor00['PCT035060'] +\
                      Labor00['PCT035067'] + Labor00['PCT035145'] +\
                      Labor00['PCT035152'] + Labor00['PCT035159']
Labor00['Under25_00'] = Labor00['LaborForce00'] - Labor00['PrimeAge00'] -\
                        Labor00['Over65_00'] - Labor00['55-64_00']

Labor00 = Labor00.drop(['state', 'county', 'P043003', 'P043010',
                        'PCT035025', 'PCT035032', 'PCT035039',
                        'PCT035046', 'PCT035117', 'PCT035124', 
                        'PCT035131', 'PCT035138', 'PCT035074',
                        'PCT035081', 'PCT035088', 'PCT035166',
                        'PCT035053', 'PCT035060', 'PCT035067',
                        'PCT035145', 'PCT035152', 'PCT035159',
                        'PCT035173', 'PCT035180'], axis=1)
Labor00.columns = ['Name', 'STCO', 'LaborForce00', 'PrimeAge00',
                   'Over65_00', '55-64_00', 'Under25_00']

print(Labor00.shape)
print(Labor00.dtypes)
Labor00.head()
# Out:
# (3219, 7)
# Name            object
# STCO            object
# LaborForce00     int64
# PrimeAge00       int64
# Over65_00        int64
# 55-64_00         int64
# Under25_00       int64
# dtype: object
#              Name   STCO  LaborForce00  PrimeAge00  Over65_00  55-64_00  \
# 1  Autauga County  01001         21167       15026        588      2262
# 2  Baldwin County  01003         65960       46800       2499      7771
# 3  Barbour County  01005         10826        7656        473      1130
# 4     Bibb County  01007          8521        6144        204       917
# 5   Blount County  01009         23896       16867        832      2869
#
#    Under25_00
# 1        3291
# 2        8890
# 3        1567
# 4        1256
# 5        3328

# %% [markdown]
# ## Merging 2000 and 2016 data

# %%
Labor = Labor00.merge(Labor16, on='STCO')

Labor = Labor.drop(['Name_x'], axis=1)
Labor = Labor.append(Labor.sum(numeric_only=True), ignore_index=True)
Labor = Labor.set_index('Name_y').fillna(0).astype(int)

Labor['over65_%_16'] = Labor['Over65'] / Labor['LaborForce']
Labor['over65_%_00'] = Labor['Over65_00'] / Labor['LaborForce00']

Labor['over65_%change'] = Labor['over65_%_16'] - Labor['over65_%_00']

Labor['NET_LaborTotal'] = Labor['LaborForce'] - Labor['LaborForce00']
Labor['%_LaborTotal'] = (Labor['LaborForce'] - Labor['LaborForce00']) \
                         / Labor['LaborForce00']
Labor['NET_PrimeAge'] = Labor['PrimeAge'] - Labor['PrimeAge00']
Labor['%_PrimeAge'] = (Labor['PrimeAge'] - Labor['PrimeAge00']) \
                      / Labor['PrimeAge00']
Labor['NET_Over65'] = Labor['LaborForce'] - Labor['LaborForce00']
Labor['%_Over65'] = (Labor['Over65'] - Labor['Over65_00']) \
                     / Labor['Over65_00']
Labor['NET_55-64'] = Labor['55-64'] - Labor['55-64_00']
Labor['%_55-64'] = (Labor['55-64'] - Labor['55-64_00']) \
                      / Labor['55-64_00']
Labor['NET_Under25'] = Labor['Under25'] - Labor['Under25_00']
Labor['%_Under25'] = (Labor['Under25'] - Labor['Under25_00']) \
                     / Labor['Under25_00']


Labor.index = Labor.index.fillna('UStotal')

print(Labor.shape)
Labor.tail()
# Out:
# (3213, 24)
#                                   STCO  LaborForce00  PrimeAge00  Over65_00  \
# Name_y
# Vieques Municipio, Puerto Rico   72147          2395        1657         33
# Villalba Municipio, Puerto Rico  72149          7463        5547         87
# Yabucoa Municipio, Puerto Rico   72151          9498        6812         52
# Yauco Municipio, Puerto Rico     72153         13622       10020        163
# UStotal                              0     139958254    98706665    4663882
#
#                                  55-64_00  Under25_00  LaborForce   PrimeAge  \
# Name_y
# Vieques Municipio, Puerto Rico        343         362        3342       2096
# Villalba Municipio, Puerto Rico       355        1474        9278       6407
# Yabucoa Municipio, Puerto Rico        477        2157       10802       7863
# Yauco Municipio, Puerto Rico         1076        2363       11931       8941
# UStotal                          14095193    22492514   162051329  104821609
#
#                                   Over65     55-64    ...      NET_LaborTotal  \
# Name_y                                                ...
# Vieques Municipio, Puerto Rico       161       558    ...                 947
# Villalba Municipio, Puerto Rico      131      1077    ...                1815
# Yabucoa Municipio, Puerto Rico       109       932    ...                1304
# Yauco Municipio, Puerto Rico         333      1492    ...               -1691
# UStotal                          8002699  25906804    ...            22093075
#
#                                  %_LaborTotal  NET_PrimeAge  %_PrimeAge  \
# Name_y
# Vieques Municipio, Puerto Rico       0.395407           439    0.264937
# Villalba Municipio, Puerto Rico      0.243200           860    0.155039
# Yabucoa Municipio, Puerto Rico       0.137292          1051    0.154287
# Yauco Municipio, Puerto Rico        -0.124137         -1079   -0.107685
# UStotal                              0.157855       6114944    0.061951
#
#                                  NET_Over65  %_Over65  NET_55-64   %_55-64  \
# Name_y
# Vieques Municipio, Puerto Rico          947  3.878788        215  0.626822
# Villalba Municipio, Puerto Rico        1815  0.505747        722  2.033803
# Yabucoa Municipio, Puerto Rico         1304  1.096154        455  0.953878
# Yauco Municipio, Puerto Rico          -1691  1.042945        416  0.386617
# UStotal                            22093075  0.715888   11811611  0.837989
#
#                                  NET_Under25  %_Under25
# Name_y
# Vieques Municipio, Puerto Rico           165   0.455801
# Villalba Municipio, Puerto Rico          189   0.128223
# Yabucoa Municipio, Puerto Rico          -259  -0.120074
# Yauco Municipio, Puerto Rico           -1198  -0.506983
# UStotal                               827703   0.036799
#
# [5 rows x 24 columns]

# %%
Labor.dtypes
# Out:
# STCO                int64
# LaborForce00        int64
# PrimeAge00          int64
# Over65_00           int64
# 55-64_00            int64
# Under25_00          int64
# LaborForce          int64
# PrimeAge            int64
# Over65              int64
# 55-64               int64
# Under25             int64
# over65_%_16       float64
# over65_%_00       float64
# over65_%change    float64
# NET_LaborTotal      int64
# %_LaborTotal      float64
# NET_PrimeAge        int64
# %_PrimeAge        float64
# NET_Over65          int64
# %_Over65          float64
# NET_55-64           int64
# %_55-64           float64
# NET_Under25         int64
# %_Under25         float64
# dtype: object

# %%
Labor['STCO'] = Labor['STCO'].astype(str)
Labor['STCO'] = Labor['STCO'].apply(lambda x: '{0:0>5}'.format(x))

Labor.dtypes[:1]
# Out:
# STCO    object
# dtype: object

# %% [markdown]
# ##  Reading in geo-coded dataset
# created on a different notebook, please refer to _**ADD NOTEBOOK NAME**_

# %%
geo = pd.read_csv('../rp-USmetros_comparison/data/USmetros_full.csv').iloc[:,:-2] \
                                .drop(['Unnamed: 0', 'SHAPE_AREA'], axis=1)
geo['STCO'] = geo['STCO'].apply(lambda x: '{0:0>5}'.format(x))

print(geo.shape)
geo.head()
# Out:
# (270, 4)
#    CSA                            CSA_name   County_name   STCO
# 0  488  San Jose-San Francisco-Oakland, CA       Alameda  06001
# 1  488  San Jose-San Francisco-Oakland, CA  Contra Costa  06013
# 2  488  San Jose-San Francisco-Oakland, CA         Marin  06041
# 3  488  San Jose-San Francisco-Oakland, CA          Napa  06055
# 4  488  San Jose-San Francisco-Oakland, CA    San Benito  06069

# %% [markdown]
# ### Merging datasets

# %%
Labor_CO = Labor.merge(geo, on='STCO').set_index('County_name')

print(Labor_CO.shape)
Labor_CO.tail()
# Out:
# (269, 26)
#               STCO  LaborForce00  PrimeAge00  Over65_00  55-64_00  Under25_00  \
# County_name
# Hampshire    54027          9056        6431        350      1063        1212
# Jefferson    54037         22669       15828        737      2454        3650
# Kenosha      55059         77980       55476       1895      7099       13510
# Pierce       55093         22165       13868        621      1839        5837
# St. Croix    55109         35867       26097       1024      3228        5518
#
#              LaborForce  PrimeAge  Over65  55-64  \
# County_name
# Hampshire          9700      6402     440   1813
# Jefferson         29404     18728    1738   5268
# Kenosha           88879     58245    2995  13362
# Pierce            23604     13421    1000   3881
# St. Croix         48805     32472    1851   8192
#
#                                   ...                        NET_PrimeAge  \
# County_name                       ...
# Hampshire                         ...                                 -29
# Jefferson                         ...                                2900
# Kenosha                           ...                                2769
# Pierce                            ...                                -447
# St. Croix                         ...                                6375
#
#              %_PrimeAge  NET_Over65  %_Over65  NET_55-64   %_55-64  \
# County_name
# Hampshire     -0.004509         644  0.257143        750  0.705550
# Jefferson      0.183220        6735  1.358209       2814  1.146699
# Kenosha        0.049913       10899  0.580475       6263  0.882237
# Pierce        -0.032232        1439  0.610306       2042  1.110386
# St. Croix      0.244281       12938  0.807617       4964  1.537794
#
#              NET_Under25  %_Under25  CSA  \
# County_name
# Hampshire           -167  -0.137789  548
# Jefferson             20   0.005479  548
# Kenosha              767   0.056773  176
# Pierce              -535  -0.091657  378
# St. Croix            772   0.139906  378
#
#                                                    CSA_name
# County_name
# Hampshire    Washington-Baltimore-Arlington, DC-MD-VA-WV-PA
# Jefferson    Washington-Baltimore-Arlington, DC-MD-VA-WV-PA
# Kenosha                        Chicago-Naperville, IL-IN-WI
# Pierce                          Minneapolis-St. Paul, MN-WI
# St. Croix                       Minneapolis-St. Paul, MN-WI
#
# [5 rows x 26 columns]

# %%
Labor_CO[Labor_CO['CSA']==408].shape
# Out:
# (31, 26)

# %% [markdown]
# ### Exporting all counties Housing data to .csv

# %%
Labor_CO.to_csv('exports/Labor_Counties.csv')

# %% [markdown]
# ## Groupby CSAs to sum

# %%
Labor_CSA = Labor_CO.groupby(['CSA', 'CSA_name']).sum()

print(Labor_CSA.shape)
Labor_CSA
# Out:
# (15, 23)
#                                                       LaborForce00  \
# CSA CSA_name
# 122 Atlanta--Athens-Clarke County--Sandy Springs, GA       2538045
# 148 Boston-Worcester-Providence, MA-RI-NH-CT               4013723
# 176 Chicago-Naperville, IL-IN-WI                           2119798
# 206 Dallas-Fort Worth, TX-OK                               2868730
# 216 Denver-Aurora, CO                                      1456374
# 220 Detroit-Warren-Ann Arbor, MI                           2696073
# 288 Houston-The Woodlands, TX                              2355212
# 348 Los Angeles-Long Beach, CA                             5724165
# 370 Miami-Fort Lauderdale-Port St. Lucie, FL               2522648
# 378 Minneapolis-St. Paul, MN-WI                            1882490
# 408 New York-Newark, NY-NJ-CT-PA                          10362713
# 428 Philadelphia-Reading-Camden, PA-NJ-DE-MD               3321285
# 488 San Jose-San Francisco-Oakland, CA                     3943034
# 500 Seattle-Tacoma, WA                                     2009210
# 548 Washington-Baltimore-Arlington, DC-MD-VA-WV-PA         4281273
#
#                                                       PrimeAge00  Over65_00  \
# CSA CSA_name
# 122 Atlanta--Athens-Clarke County--Sandy Springs, GA     1870205      58002
# 148 Boston-Worcester-Providence, MA-RI-NH-CT             2870795     139818
# 176 Chicago-Naperville, IL-IN-WI                         1516128      59594
# 206 Dallas-Fort Worth, TX-OK                             2071787      77125
# 216 Denver-Aurora, CO                                    1065179      37734
# 220 Detroit-Warren-Ann Arbor, MI                         1952779      74461
# 288 Houston-The Woodlands, TX                            1712443      59110
# 348 Los Angeles-Long Beach, CA                           4130260     173676
# 370 Miami-Fort Lauderdale-Port St. Lucie, FL             1784755     125264
# 378 Minneapolis-St. Paul, MN-WI                          1349682      50862
# 408 New York-Newark, NY-NJ-CT-PA                         7496275     377323
# 428 Philadelphia-Reading-Camden, PA-NJ-DE-MD             2354577     127896
# 488 San Jose-San Francisco-Oakland, CA                   2901145     118745
# 500 Seattle-Tacoma, WA                                   1472616      47895
# 548 Washington-Baltimore-Arlington, DC-MD-VA-WV-PA       3131931     126904
#
#                                                       55-64_00  Under25_00  \
# CSA CSA_name
# 122 Atlanta--Athens-Clarke County--Sandy Springs, GA    216304      393534
# 148 Boston-Worcester-Providence, MA-RI-NH-CT            421332      581778
# 176 Chicago-Naperville, IL-IN-WI                        212143      331933
# 206 Dallas-Fort Worth, TX-OK                            257825      461993
# 216 Denver-Aurora, CO                                   129402      224059
# 220 Detroit-Warren-Ann Arbor, MI                        251732      417101
# 288 Houston-The Woodlands, TX                           211555      372104
# 348 Los Angeles-Long Beach, CA                          532771      887458
# 370 Miami-Fort Lauderdale-Port St. Lucie, FL            284949      327680
# 378 Minneapolis-St. Paul, MN-WI                         172298      309648
# 408 New York-Newark, NY-NJ-CT-PA                       1139337     1349778
# 428 Philadelphia-Reading-Camden, PA-NJ-DE-MD            356052      482760
# 488 San Jose-San Francisco-Oakland, CA                  393070      530074
# 500 Seattle-Tacoma, WA                                  185656      303043
# 548 Washington-Baltimore-Arlington, DC-MD-VA-WV-PA      443642      578796
#
#                                                       LaborForce  PrimeAge  \
# CSA CSA_name
# 122 Atlanta--Athens-Clarke County--Sandy Springs, GA     3220087   2211700
# 148 Boston-Worcester-Providence, MA-RI-NH-CT             4500566   2828692
# 176 Chicago-Naperville, IL-IN-WI                         2471875   1584629
# 206 Dallas-Fort Worth, TX-OK                             3821344   2583048
# 216 Denver-Aurora, CO                                    1819491   1218564
# 220 Detroit-Warren-Ann Arbor, MI                         2637416   1697656
# 288 Houston-The Woodlands, TX                            3378973   2287083
# 348 Los Angeles-Long Beach, CA                           6818638   4629945
# 370 Miami-Fort Lauderdale-Port St. Lucie, FL             3317864   2203373
# 378 Minneapolis-St. Paul, MN-WI                          2166725   1414085
# 408 New York-Newark, NY-NJ-CT-PA                        11875886   7897562
# 428 Philadelphia-Reading-Camden, PA-NJ-DE-MD             3725506   2383843
# 488 San Jose-San Francisco-Oakland, CA                   4567612   3099519
# 500 Seattle-Tacoma, WA                                   2423576   1615680
# 548 Washington-Baltimore-Arlington, DC-MD-VA-WV-PA       5295351   3547988
#
#                                                       Over65    55-64  \
# CSA CSA_name
# 122 Atlanta--Athens-Clarke County--Sandy Springs, GA  122914   458259
# 148 Boston-Worcester-Providence, MA-RI-NH-CT          253765   775288
# 176 Chicago-Naperville, IL-IN-WI                      113805   413335
# 206 Dallas-Fort Worth, TX-OK                          164325   545704
# 216 Denver-Aurora, CO                                  80426   276459
# 220 Detroit-Warren-Ann Arbor, MI                      110282   430378
# 288 Houston-The Woodlands, TX                         142711   491314
# 348 Los Angeles-Long Beach, CA                        305515   997166
# 370 Miami-Fort Lauderdale-Port St. Lucie, FL          191049   540022
# 378 Minneapolis-St. Paul, MN-WI                        89754   350318
# 408 New York-Newark, NY-NJ-CT-PA                      640853  1950102
# 428 Philadelphia-Reading-Camden, PA-NJ-DE-MD          204174   636327
# 488 San Jose-San Francisco-Oakland, CA                220734   714867
# 500 Seattle-Tacoma, WA                                104285   390552
# 548 Washington-Baltimore-Arlington, DC-MD-VA-WV-PA    268824   829255
#
#                                                       Under25    ...      \
# CSA CSA_name                                                     ...
# 122 Atlanta--Athens-Clarke County--Sandy Springs, GA   427214    ...
# 148 Boston-Worcester-Providence, MA-RI-NH-CT           642821    ...
# 176 Chicago-Naperville, IL-IN-WI                       360106    ...
# 206 Dallas-Fort Worth, TX-OK                           528267    ...
# 216 Denver-Aurora, CO                                  244042    ...
# 220 Detroit-Warren-Ann Arbor, MI                       399100    ...
# 288 Houston-The Woodlands, TX                          457865    ...
# 348 Los Angeles-Long Beach, CA                         886012    ...
# 370 Miami-Fort Lauderdale-Port St. Lucie, FL           383420    ...
# 378 Minneapolis-St. Paul, MN-WI                        312568    ...
# 408 New York-Newark, NY-NJ-CT-PA                      1387369    ...
# 428 Philadelphia-Reading-Camden, PA-NJ-DE-MD           501162    ...
# 488 San Jose-San Francisco-Oakland, CA                 532492    ...
# 500 Seattle-Tacoma, WA                                 313059    ...
# 548 Washington-Baltimore-Arlington, DC-MD-VA-WV-PA     649284    ...
#
#                                                       NET_LaborTotal  \
# CSA CSA_name
# 122 Atlanta--Athens-Clarke County--Sandy Springs, GA          682042
# 148 Boston-Worcester-Providence, MA-RI-NH-CT                  486843
# 176 Chicago-Naperville, IL-IN-WI                              352077
# 206 Dallas-Fort Worth, TX-OK                                  952614
# 216 Denver-Aurora, CO                                         363117
# 220 Detroit-Warren-Ann Arbor, MI                              -58657
# 288 Houston-The Woodlands, TX                                1023761
# 348 Los Angeles-Long Beach, CA                               1094473
# 370 Miami-Fort Lauderdale-Port St. Lucie, FL                  795216
# 378 Minneapolis-St. Paul, MN-WI                               284235
# 408 New York-Newark, NY-NJ-CT-PA                             1513173
# 428 Philadelphia-Reading-Camden, PA-NJ-DE-MD                  404221
# 488 San Jose-San Francisco-Oakland, CA                        624578
# 500 Seattle-Tacoma, WA                                        414366
# 548 Washington-Baltimore-Arlington, DC-MD-VA-WV-PA           1014078
#
#                                                       %_LaborTotal  \
# CSA CSA_name
# 122 Atlanta--Athens-Clarke County--Sandy Springs, GA      9.964193
# 148 Boston-Worcester-Providence, MA-RI-NH-CT              1.835709
# 176 Chicago-Naperville, IL-IN-WI                          3.265963
# 206 Dallas-Fort Worth, TX-OK                              6.056987
# 216 Denver-Aurora, CO                                     2.544742
# 220 Detroit-Warren-Ann Arbor, MI                          0.009534
# 288 Houston-The Woodlands, TX                             4.168630
# 348 Los Angeles-Long Beach, CA                            0.365121
# 370 Miami-Fort Lauderdale-Port St. Lucie, FL              2.082441
# 378 Minneapolis-St. Paul, MN-WI                           4.301386
# 408 New York-Newark, NY-NJ-CT-PA                          3.832606
# 428 Philadelphia-Reading-Camden, PA-NJ-DE-MD              1.944796
# 488 San Jose-San Francisco-Oakland, CA                    1.840530
# 500 Seattle-Tacoma, WA                                    1.608621
# 548 Washington-Baltimore-Arlington, DC-MD-VA-WV-PA       10.580408
#
#                                                       NET_PrimeAge  \
# CSA CSA_name
# 122 Atlanta--Athens-Clarke County--Sandy Springs, GA        341495
# 148 Boston-Worcester-Providence, MA-RI-NH-CT                -42103
# 176 Chicago-Naperville, IL-IN-WI                             68501
# 206 Dallas-Fort Worth, TX-OK                                511261
# 216 Denver-Aurora, CO                                       153385
# 220 Detroit-Warren-Ann Arbor, MI                           -255123
# 288 Houston-The Woodlands, TX                               574640
# 348 Los Angeles-Long Beach, CA                              499685
# 370 Miami-Fort Lauderdale-Port St. Lucie, FL                418618
# 378 Minneapolis-St. Paul, MN-WI                              64403
# 408 New York-Newark, NY-NJ-CT-PA                            401287
# 428 Philadelphia-Reading-Camden, PA-NJ-DE-MD                 29266
# 488 San Jose-San Francisco-Oakland, CA                      198374
# 500 Seattle-Tacoma, WA                                      143064
# 548 Washington-Baltimore-Arlington, DC-MD-VA-WV-PA          416057
#
#                                                       %_PrimeAge  NET_Over65  \
# CSA CSA_name
# 122 Atlanta--Athens-Clarke County--Sandy Springs, GA    6.106380      682042
# 148 Boston-Worcester-Providence, MA-RI-NH-CT           -1.123138      486843
# 176 Chicago-Naperville, IL-IN-WI                        1.323389      352077
# 206 Dallas-Fort Worth, TX-OK                            3.997507      952614
# 216 Denver-Aurora, CO                                   0.693678      363117
# 220 Detroit-Warren-Ann Arbor, MI                       -1.154306      -58657
# 288 Houston-The Woodlands, TX                           2.383241     1023761
# 348 Los Angeles-Long Beach, CA                          0.208421     1094473
# 370 Miami-Fort Lauderdale-Port St. Lucie, FL            1.356908      795216
# 378 Minneapolis-St. Paul, MN-WI                         2.045584      284235
# 408 New York-Newark, NY-NJ-CT-PA                        0.030323     1513173
# 428 Philadelphia-Reading-Camden, PA-NJ-DE-MD           -0.040221      404221
# 488 San Jose-San Francisco-Oakland, CA                  0.503236      624578
# 500 Seattle-Tacoma, WA                                  0.373036      414366
# 548 Washington-Baltimore-Arlington, DC-MD-VA-WV-PA      5.781225     1014078
#
#                                                        %_Over65  NET_55-64  \
# CSA CSA_name
# 122 Atlanta--Athens-Clarke County--Sandy Springs, GA  44.846761     241955
# 148 Boston-Worcester-Providence, MA-RI-NH-CT          16.709620     353956
# 176 Chicago-Naperville, IL-IN-WI                      15.562390     201192
# 206 Dallas-Fort Worth, TX-OK                          23.723630     287879
# 216 Denver-Aurora, CO                                 20.294435     147057
# 220 Detroit-Warren-Ann Arbor, MI                       6.108782     178646
# 288 Houston-The Woodlands, TX                         17.174346     279759
# 348 Los Angeles-Long Beach, CA                         1.593505     464395
# 370 Miami-Fort Lauderdale-Port St. Lucie, FL           3.458144     255073
# 378 Minneapolis-St. Paul, MN-WI                       18.581366     178020
# 408 New York-Newark, NY-NJ-CT-PA                      26.607781     810765
# 428 Philadelphia-Reading-Camden, PA-NJ-DE-MD          10.913227     280275
# 488 San Jose-San Francisco-Oakland, CA                11.116436     321797
# 500 Seattle-Tacoma, WA                                11.980190     204896
# 548 Washington-Baltimore-Arlington, DC-MD-VA-WV-PA    47.041035     385613
#
#                                                         %_55-64  NET_Under25  \
# CSA CSA_name
# 122 Atlanta--Athens-Clarke County--Sandy Springs, GA  38.912911        33680
# 148 Boston-Worcester-Providence, MA-RI-NH-CT          16.555633        61043
# 176 Chicago-Naperville, IL-IN-WI                      16.412937        28173
# 206 Dallas-Fort Worth, TX-OK                          19.243305        66274
# 216 Denver-Aurora, CO                                 16.274107        19983
# 220 Detroit-Warren-Ann Arbor, MI                       7.855947       -18001
# 288 Houston-The Woodlands, TX                         15.500204        85761
# 348 Los Angeles-Long Beach, CA                         1.699893        -1446
# 370 Miami-Fort Lauderdale-Port St. Lucie, FL           6.369128        55740
# 378 Minneapolis-St. Paul, MN-WI                       23.485376         2920
# 408 New York-Newark, NY-NJ-CT-PA                      22.934036        37591
# 428 Philadelphia-Reading-Camden, PA-NJ-DE-MD          12.849855        18402
# 488 San Jose-San Francisco-Oakland, CA                10.329315         2418
# 500 Seattle-Tacoma, WA                                 9.631707        10016
# 548 Washington-Baltimore-Arlington, DC-MD-VA-WV-PA    40.661894        70488
#
#                                                       %_Under25
# CSA CSA_name
# 122 Atlanta--Athens-Clarke County--Sandy Springs, GA   5.456478
# 148 Boston-Worcester-Providence, MA-RI-NH-CT           1.963579
# 176 Chicago-Naperville, IL-IN-WI                       1.158686
# 206 Dallas-Fort Worth, TX-OK                           3.152351
# 216 Denver-Aurora, CO                                  1.264906
# 220 Detroit-Warren-Ann Arbor, MI                      -0.307643
# 288 Houston-The Woodlands, TX                          2.477587
# 348 Los Angeles-Long Beach, CA                         0.029400
# 370 Miami-Fort Lauderdale-Port St. Lucie, FL           1.451164
# 378 Minneapolis-St. Paul, MN-WI                        1.335435
# 408 New York-Newark, NY-NJ-CT-PA                       2.969712
# 428 Philadelphia-Reading-Camden, PA-NJ-DE-MD           1.342497
# 488 San Jose-San Francisco-Oakland, CA                 0.466488
# 500 Seattle-Tacoma, WA                                 0.417633
# 548 Washington-Baltimore-Arlington, DC-MD-VA-WV-PA     8.122110
#
# [15 rows x 23 columns]

# %% [markdown]
# ### Exporting CSA's Housing data to .csv

# %%
Labor_CSA.to_csv('exports/Labor_CSA.csv')

# %% [markdown]
# ----
#
# # Labor Force by Places
# _Identifying City vs Suburb trends_

# %%
# Labor Force data for all counties in the US, 2016
Labor16_place = pd.read_json('https://api.census.gov/data/2016/acs/acs5?get='+
                              Labor16str +
                             ',NAME&for=place:*&in=state:*')
Labor16_place.columns = Labor16_place.iloc[0]
Labor16_place = Labor16_place[1:]

Labor16_place['state'] = Labor16_place['state'].apply(lambda x: '{0:0>2}'.format(x))
Labor16_place['place'] = Labor16_place['place'].apply(lambda x: '{0:0>3}'.format(x))
Labor16_place['STPL'] = Labor16_place[['state', 'place']].apply(lambda x: ''.join(x), axis=1)

# converting dtypes to int
for col in Labor16vars:
    Labor16_place[col] = Labor16_place[col].astype(int)

# aggregating age groups and calculations
Labor16_place['LaborForce'] = Labor16_place['B23025_001E'] - Labor16_place['B23025_007E']
Labor16_place['PrimeAge'] = Labor16_place['B23001_025E'] + Labor16_place['B23001_032E'] +\
                            Labor16_place['B23001_039E'] + Labor16_place['B23001_046E'] +\
                            Labor16_place['B23001_111E'] + Labor16_place['B23001_118E'] +\
                            Labor16_place['B23001_125E'] + Labor16_place['B23001_132E']
Labor16_place['Over65'] = Labor16_place['B23001_074E'] + Labor16_place['B23001_079E'] +\
                          Labor16_place['B23001_084E'] + Labor16_place['B23001_160E'] +\
                          Labor16_place['B23001_165E'] + Labor16_place['B23001_170E']
Labor16_place['55-64'] = Labor16_place['B23001_053E'] + Labor16_place['B23001_060E'] +\
                         Labor16_place['B23001_067E'] + Labor16_place['B23001_139E'] +\
                         Labor16_place['B23001_146E'] + Labor16_place['B23001_153E']
Labor16_place['Under25'] = Labor16_place['LaborForce'] - Labor16_place['PrimeAge'] -\
                           Labor16_place['Over65'] - Labor16_place['55-64']

Labor16_place = Labor16_place.drop(['state', 'place', 'B23025_001E', 'B23025_007E',
                                    'B23001_025E', 'B23001_032E', 'B23001_039E',
                                    'B23001_046E', 'B23001_111E', 'B23001_118E', 
                                    'B23001_125E', 'B23001_132E', 'B23001_074E',
                                    'B23001_079E', 'B23001_084E', 'B23001_160E',
                                    'B23001_139E', 'B23001_146E', 'B23001_153E',
                                    'B23001_053E', 'B23001_060E', 'B23001_067E',
                                    'B23001_165E', 'B23001_170E'], axis=1)
Labor16_place.columns = ['Name', 'STPL', 'LaborForce', 'PrimeAge', 
                         'Over65', '55-64', 'Under25']

print(Labor16_place.shape)
print(Labor16_place.dtypes)
Labor16_place.head()
# Out:
# (29574, 7)
# Name          object
# STPL          object
# LaborForce     int64
# PrimeAge       int64
# Over65         int64
# 55-64          int64
# Under25        int64
# dtype: object
#                        Name     STPL  LaborForce  PrimeAge  Over65  55-64  \
# 1       Abanda CDP, Alabama  0100100          74        34       0     40
# 2   Abbeville city, Alabama  0100124         855       466      56    204
# 3  Adamsville city, Alabama  0100460        2107      1314     104    425
# 4     Addison town, Alabama  0100484         317       184      14     60
# 5       Akron town, Alabama  0100676          93        56       2     11
#
#    Under25
# 1        0
# 2      129
# 3      264
# 4       59
# 5       24

# %% [markdown]
# # CONTINUE ^^^ FROM 0820
