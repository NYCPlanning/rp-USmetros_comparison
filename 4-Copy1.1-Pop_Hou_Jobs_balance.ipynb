# %% [markdown]
# July, 2018
#
# **_Author: Dana Chermesh, Regional Planning intern_**
#
# ### US Metros comparison
# comparison by the county level of 17 regions (CSA's) accross the country
#
# ### _Notebook no.4_
# # Housing-Jobs balance
# ### - _Employment data were obtained from: BLS-QCEW_
# Data Source: [Bureau of Labor Statistics, Quarterly Census of Employment and Wages](https://www.bls.gov/cew/datatoc.htm) (BLS-QCEW)
# ### - _Housing data were obtained from PEP/2017/housing_

# %% [markdown]
# ----
# # 0 - Imports

# %%
import requests
import pandas as pd
import numpy as np

from __future__ import print_function, division
import matplotlib.pylab as pl
# from pandas.tools.plotting import scatter_matrix
import seaborn as sns
sns.set_style('whitegrid')
# import json

# Spatial
import geopandas as gpd
import fiona
import shapely

import statsmodels.formula.api as smf
import statsmodels.api as sm

# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %% [markdown]
# ##  Reading in geo-coded dataset
# created on a different notebook, please refer to _**0_US_Metro_Comparison_Geographies**_

# %%
geo = pd.read_csv('../rp-USmetros_comparison/data/USmetros_full.csv').iloc[:,:-2] \
            .drop(['Unnamed: 0', 'SHAPE_AREA'], axis=1)
geo['STCO'] = geo['STCO'].apply(lambda x: '{0:0>5}'.format(x))

print(geo.shape)
geo.head()
# Out:
# (270, 4)
#    CSA                            CSA_name   County_name   STCO
# 0  488  San Jose-San Francisco-Oakland, CA       Alameda  06001
# 1  488  San Jose-San Francisco-Oakland, CA  Contra Costa  06013
# 2  488  San Jose-San Francisco-Oakland, CA         Marin  06041
# 3  488  San Jose-San Francisco-Oakland, CA          Napa  06055
# 4  488  San Jose-San Francisco-Oakland, CA    San Benito  06069

# %%
geo.dtypes
# Out:
# CSA             int64
# CSA_name       object
# County_name    object
# STCO           object
# dtype: object

# %%
STCO = list(geo['STCO'])

print(type(STCO))
print(len(STCO))
STCO[:10]
# Out:
# <class 'list'>
# 270
# ['06001',
#  '06013',
#  '06041',
#  '06055',
#  '06069',
#  '06075',
#  '06077',
#  '06081',
#  '06085',
#  '06087']

# %% [markdown]
# # Housing / Jobs Balance analysis
#
# - PEP/2017/housing
# - BLS QCEW 2017 annually
#
# # 1. Counties - for mapping
#
# # Total Employement 2000-2017
# - 'annual_avg_emplvl'
#
# The data set had been created in notebook **4-EMPLOYMENT_BLS-QCEW10-17** in this repo.
#
# Employment data were obtained from the _**[Bureau of Labor Statistics, Quarterly Census of Employment and Wages](https://www.bls.gov/cew/datatoc.htm) (BLS-QCEW)**_

# %%
JobsCO00_17 = pd.read_csv('exports/Jobs00-17CO.csv').iloc[:,:-2]

JobsCO00_17.rename(columns={'Unnamed: 0':'STCO'}, inplace=True)

JobsCO00_17['STCO'] = JobsCO00_17['STCO'].astype(str)
JobsCO00_17['STCO'] = JobsCO00_17['STCO'].apply(lambda x: '{0:0>5}'.format(x))

JobsCO00_17 = JobsCO00_17.set_index('STCO')

print(JobsCO00_17.shape)
JobsCO00_17.head()
# Out:
# (269, 2)
#        Total_emp00  Total_emp17
# STCO
# 06001       697215       772071
# 06013       337924       366799
# 06037      4110915      4394364
# 06041       112454       115421
# 06055        60552        76765

# %% [markdown]
# # 2017
#
# ## Total Population from PEP housing 2017
# Detailing on Population and Housing Estimates APIs: https://www.census.gov/data/developers/data-sets/popest-popproj/popest.2000-2010_Intercensals.html
#
# - [examples for /data/2017/pep/population](https://api.census.gov/data/2017/pep/population/examples.html)

# %%
# POP2017 data for all counties in the US
POP2017 = pd.read_json('https://api.census.gov/data/2017/pep/population?get='+
                         'POP,GEONAME&for=county:*')

POP2017.columns = POP2017.iloc[0]
POP2017 = POP2017[1:]

POP2017['state'] = POP2017['state'].apply(lambda x: '{0:0>2}'.format(x))
POP2017['county'] = POP2017['county'].apply(lambda x: '{0:0>3}'.format(x))
POP2017['STCO'] = POP2017[['state', 'county']].apply(lambda x: ''.join(x), axis=1)

POP2017 = POP2017.drop(['state', 'county'], axis=1)
POP2017.columns = ['TotalPOP17','Name', 'STCO']

print(POP2017.shape)
POP2017.head()
# Out:
# (3220, 3)
#   TotalPOP17                     Name   STCO
# 1      55504  Autauga County, Alabama  01001
# 2     212628  Baldwin County, Alabama  01003
# 3      25270  Barbour County, Alabama  01005
# 4      22668     Bibb County, Alabama  01007
# 5      58013   Blount County, Alabama  01009

# %% [markdown]
# ## Total Housing from PEP housing 2017
#
# - [examples for /data/2017/pep/housing](https://api.census.gov/data/2017/pep/housing/examples.html)

# %%
# HU2017 data for all counties in the US
totalHU17 = pd.read_json('https://api.census.gov/data/2017/pep/housing?get='+
                         'HUEST,GEONAME&for=county:*&DATE=10')

totalHU17.columns = totalHU17.iloc[0]
totalHU17 = totalHU17[1:]

totalHU17['state'] = totalHU17['state'].apply(lambda x: '{0:0>2}'.format(x))
totalHU17['county'] = totalHU17['county'].apply(lambda x: '{0:0>3}'.format(x))
totalHU17['STCO'] = totalHU17[['state', 'county']].apply(lambda x: ''.join(x), axis=1)

totalHU17 = totalHU17.drop(['state', 'county','DATE'], axis=1)
totalHU17.columns = ['TotalHousing17','Name', 'STCO']

print(totalHU17.shape)
totalHU17.head()
# Out:
# (3142, 3)
#   TotalHousing17                            Name   STCO
# 1         372981   Fairfield County, Connecticut  09001
# 2         379719    Hartford County, Connecticut  09003
# 3          88285  Litchfield County, Connecticut  09005
# 4          76339   Middlesex County, Connecticut  09007
# 5         367195   New Haven County, Connecticut  09009

# %% [markdown]
# ## Merge Population + Housing year 2017

# %%
PEP17 = POP2017.merge(totalHU17, on='STCO')

PEP17 = PEP17.drop(['Name_x'], axis=1)
PEP17.rename(columns={'Name_y':'Name'}, inplace=True)

print(PEP17.shape)
PEP17.head()
# Out:
# (3142, 4)
#   TotalPOP17   STCO TotalHousing17                     Name
# 0      55504  01001          23495  Autauga County, Alabama
# 1     212628  01003         114162  Baldwin County, Alabama
# 2      25270  01005          11970  Barbour County, Alabama
# 3      22668  01007           9187     Bibb County, Alabama
# 4      58013  01009          24314   Blount County, Alabama

# %% [markdown]
# ----
#
# # 2010
#
# ## Total Housing 2010 PEP 2010 -- Not in use
#
# This data set is called "int_housingunits 2000" and it includes both 2000 and 2010 Census Decennials data.
#
# - API Call: api.census.gov/data/2000/pep/int_housingunits
# - [examples](https://api.census.gov/data/2000/pep/int_housingunits.html)
# - [variables](https://api.census.gov/data/2000/pep/int_housingunits/variables.html) in /data/2000/pep/int_housingunits/variables

# %%
# HU2010 data for all counties in the US, from PEP housing 2000-2010
totalHU10 = pd.read_json('https://api.census.gov/data/2000/pep/int_housingunits?get='+
                         'HUEST,GEONAME&for=county:*&DATE=10')

totalHU10.columns = totalHU10.iloc[0]
totalHU10 = totalHU10[1:]

totalHU10['state'] = totalHU10['state'].apply(lambda x: '{0:0>2}'.format(x))
totalHU10['county'] = totalHU10['county'].apply(lambda x: '{0:0>3}'.format(x))
totalHU10['STCO'] = totalHU10[['state', 'county']].apply(lambda x: ''.join(x), axis=1)

totalHU10 = totalHU10.drop(['state', 'county', 'DATE'], axis=1)
totalHU10.columns = ['TotalHousing10','Name', 'STCO']

print(totalHU10.shape)
totalHU10.head()
# Out:
# (3143, 3)
#   TotalHousing10                            Name   STCO
# 1         358484   Fairfield County, Connecticut  09001
# 2         372325    Hartford County, Connecticut  09003
# 3          86754  Litchfield County, Connecticut  09005
# 4          74172   Middlesex County, Connecticut  09007
# 5         359866   New Haven County, Connecticut  09009

# %% [markdown]
# ## Total Pop + Total Housing 2010 from US Census Bureau Decennial Census 2010

# %%
# total HU for all counties in the US, 2010
totalHU10_sf = pd.read_json('https://api.census.gov/data/2010/sf1?get='+
                            'P0010001,H00010001,NAME&for=county:*')
totalHU10_sf.columns = totalHU10_sf.iloc[0]
totalHU10_sf = totalHU10_sf[1:]

totalHU10_sf['state'] = totalHU10_sf['state'].apply(lambda x: '{0:0>2}'.format(x))
totalHU10_sf['county'] = totalHU10_sf['county'].apply(lambda x: '{0:0>3}'.format(x))
totalHU10_sf['STCO'] = totalHU10_sf[['state', 'county']].apply(lambda x: ''.join(x), axis=1)

totalHU10_sf = totalHU10_sf.drop(['state', 'county'], axis=1)
totalHU10_sf.columns = ['TotalPop10','TotalHousing10','Name', 'STCO']

print(totalHU10_sf.shape)
totalHU10_sf.head()
# Out:
# (3221, 4)
#   TotalPop10 TotalHousing10            Name   STCO
# 1      54571          22135  Autauga County  01001
# 2     182265         104061  Baldwin County  01003
# 3      27457          11829  Barbour County  01005
# 4      22915           8981     Bibb County  01007
# 5      57322          23887   Blount County  01009

# %% [markdown]
# ----
#
# # 2000
#
# ## Total Pop + Total Housing 2000 from US Census Bureau Decennial Census 2000

# %%
# total HU for all counties in the US, 2000
totalHU00 = pd.read_json('https://api.census.gov/data/2000/sf1?get='+
                         'P001001,H001001,NAME&for=county:*')
totalHU00.columns = totalHU00.iloc[0]
totalHU00 = totalHU00[1:]

totalHU00['state'] = totalHU00['state'].apply(lambda x: '{0:0>2}'.format(x))
totalHU00['county'] = totalHU00['county'].apply(lambda x: '{0:0>3}'.format(x))
totalHU00['STCO'] = totalHU00[['state', 'county']].apply(lambda x: ''.join(x), axis=1)

totalHU00 = totalHU00.drop(['state', 'county'], axis=1)
totalHU00.columns = ['TotalPop00','TotalHousing00','Name', 'STCO']

print(totalHU00.shape)
totalHU00.head()
# Out:
# (3141, 4)
#   TotalPop00 TotalHousing00            Name   STCO
# 1      43671          17662  Autauga County  01001
# 2     140415          74285  Baldwin County  01003
# 3      29038          12461  Barbour County  01005
# 4      20826           8345     Bibb County  01007
# 5      51024          21158   Blount County  01009

# %% [markdown]
# ----
# # Population + Housing + Employment change 00-17
#
# ## Merge pop+housing 2000, 2017, then merge with Jobs

# %%
# merge pop+hou 2000 with pop+hou 2017
popHou00_17 = totalHU00.merge(PEP17, on='STCO')

popHou00_17 = popHou00_17.drop(['Name_x'], axis=1)
popHou00_17.rename(columns={'Name_y':'Name'}, inplace=True)
popHou00_17 = popHou00_17.set_index(['STCO','Name'])
# make dtypes numeric
popHou00_17 = popHou00_17.apply(pd.to_numeric,
                                errors='coerce').reset_index()

# merge popHou with Jobs00-17
ALL_co00_17 = popHou00_17.merge(JobsCO00_17, left_on='STCO',
                                right_index=True).set_index(['STCO','Name'])

print(ALL_co00_17.shape)
print(ALL_co00_17.dtypes)
ALL_co00_17.head()
# Out:
# (269, 6)
# TotalPop00        int64
# TotalHousing00    int64
# TotalPOP17        int64
# TotalHousing17    int64
# Total_emp00       int64
# Total_emp17       int64
# dtype: object
#                                        TotalPop00  TotalHousing00  TotalPOP17  \
# STCO  Name
# 06001 Alameda County, California          1443741          540183     1663190
# 06013 Contra Costa County, California      948816          354577     1147439
# 06037 Los Angeles County, California      9519338         3270909    10163507
# 06041 Marin County, California             247289          104990      260955
# 06055 Napa County, California              124279           48554      140973
#
#                                        TotalHousing17  Total_emp00  \
# STCO  Name
# 06001 Alameda County, California               606052       697215
# 06013 Contra Costa County, California          414007       337924
# 06037 Los Angeles County, California          3542636      4110915
# 06041 Marin County, California                 113126       112454
# 06055 Napa County, California                   55847        60552
#
#                                        Total_emp17
# STCO  Name
# 06001 Alameda County, California            772071
# 06013 Contra Costa County, California       366799
# 06037 Los Angeles County, California       4394364
# 06041 Marin County, California              115421
# 06055 Napa County, California                76765

# %% [markdown]
# ### Exporting to .csv

# %%
ALL_co00_17.to_csv('exports/popHouEmp_co00_17.csv')

# %% [markdown]
# ## Not exported; for plotting - change claculations

# %%
ALL_co00_17['Pop_NET00-17'] = ALL_co00_17['TotalPOP17'] - ALL_co00_17['TotalPop00']
ALL_co00_17['Pop_%00-17'] = (ALL_co00_17['TotalPOP17'] - ALL_co00_17['TotalPop00']) \
                            / ALL_co00_17['TotalPop00']

ALL_co00_17['hu_NET00-17'] = ALL_co00_17['TotalHousing17'] - ALL_co00_17['TotalHousing00']
ALL_co00_17['hu_%00-17'] = (ALL_co00_17['TotalHousing17'] - ALL_co00_17['TotalHousing00']) \
                           / ALL_co00_17['TotalHousing00']

ALL_co00_17['emp_NET00-17'] = ALL_co00_17['Total_emp17'] - ALL_co00_17['Total_emp00']
ALL_co00_17['emp_%00-17'] = (ALL_co00_17['Total_emp17'] - ALL_co00_17['Total_emp00']) \
                           / ALL_co00_17['Total_emp00']

print(ALL_co00_17.shape)
print(ALL_co00_17.dtypes)
ALL_co00_17.head()
# Out:
# (269, 12)
# TotalPop00          int64
# TotalHousing00      int64
# TotalPOP17          int64
# TotalHousing17      int64
# Total_emp00         int64
# Total_emp17         int64
# Pop_NET00-17        int64
# Pop_%00-17        float64
# hu_NET00-17         int64
# hu_%00-17         float64
# emp_NET00-17        int64
# emp_%00-17        float64
# dtype: object
#                                        TotalPop00  TotalHousing00  TotalPOP17  \
# STCO  Name
# 06001 Alameda County, California          1443741          540183     1663190
# 06013 Contra Costa County, California      948816          354577     1147439
# 06037 Los Angeles County, California      9519338         3270909    10163507
# 06041 Marin County, California             247289          104990      260955
# 06055 Napa County, California              124279           48554      140973
#
#                                        TotalHousing17  Total_emp00  \
# STCO  Name
# 06001 Alameda County, California               606052       697215
# 06013 Contra Costa County, California          414007       337924
# 06037 Los Angeles County, California          3542636      4110915
# 06041 Marin County, California                 113126       112454
# 06055 Napa County, California                   55847        60552
#
#                                        Total_emp17  Pop_NET00-17  Pop_%00-17  \
# STCO  Name
# 06001 Alameda County, California            772071        219449    0.152000
# 06013 Contra Costa County, California       366799        198623    0.209338
# 06037 Los Angeles County, California       4394364        644169    0.067670
# 06041 Marin County, California              115421         13666    0.055263
# 06055 Napa County, California                76765         16694    0.134327
#
#                                        hu_NET00-17  hu_%00-17  emp_NET00-17  \
# STCO  Name
# 06001 Alameda County, California             65869   0.121938         74856
# 06013 Contra Costa County, California        59430   0.167608         28875
# 06037 Los Angeles County, California        271727   0.083074        283449
# 06041 Marin County, California                8136   0.077493          2967
# 06055 Napa County, California                 7293   0.150204         16213
#
#                                        emp_%00-17
# STCO  Name
# 06001 Alameda County, California         0.107364
# 06013 Contra Costa County, California    0.085448
# 06037 Los Angeles County, California     0.068950
# 06041 Marin County, California           0.026384
# 06055 Napa County, California            0.267753

# %% [markdown]
# # CSAs aggregation for Pop-Housing-Employment balance

# %%
# merging with geo data to get CSA's
ALL_co00_17_1 = ALL_co00_17.iloc[:,:-6].reset_index()

ALL_co00_17_1 = ALL_co00_17_1.merge(geo, on='STCO').set_index('County_name')
ALL_co00_17_1 = ALL_co00_17_1.drop('Name', axis=1)

print(ALL_co00_17_1.shape)
ALL_co00_17_1.head()
# Out:
# (269, 9)
#                STCO  TotalPop00  TotalHousing00  TotalPOP17  TotalHousing17  \
# County_name
# Alameda       06001     1443741          540183     1663190          606052
# Contra Costa  06013      948816          354577     1147439          414007
# Los Angeles   06037     9519338         3270909    10163507         3542636
# Marin         06041      247289          104990      260955          113126
# Napa          06055      124279           48554      140973           55847
#
#               Total_emp00  Total_emp17  CSA  \
# County_name
# Alameda            697215       772071  488
# Contra Costa       337924       366799  488
# Los Angeles       4110915      4394364  348
# Marin              112454       115421  488
# Napa                60552        76765  488
#
#                                         CSA_name
# County_name
# Alameda       San Jose-San Francisco-Oakland, CA
# Contra Costa  San Jose-San Francisco-Oakland, CA
# Los Angeles           Los Angeles-Long Beach, CA
# Marin         San Jose-San Francisco-Oakland, CA
# Napa          San Jose-San Francisco-Oakland, CA

# %%
CSAs_00_17 = ALL_co00_17_1.groupby(['CSA', 'CSA_name']).sum().reset_index()

CSAs_00_17['CSA_short'] = CSAs_00_17['CSA_name'].str.split('-').str[0]
CSAs_00_17['CSA_short'] = CSAs_00_17['CSA_short'].replace(['San Jose'], ['San Francisco']) 
CSAs_00_17 = CSAs_00_17.set_index(['CSA', 'CSA_name', 'CSA_short'])

print(CSAs_00_17.shape)
CSAs_00_17
# Out:
# (15, 6)
#                                                                     TotalPop00  \
# CSA CSA_name                                         CSA_short
# 122 Atlanta--Athens-Clarke County--Sandy Springs, GA Atlanta           4778990
# 148 Boston-Worcester-Providence, MA-RI-NH-CT         Boston            7630016
# 176 Chicago-Naperville, IL-IN-WI                     Chicago           4088612
# 206 Dallas-Fort Worth, TX-OK                         Dallas            5565005
# 216 Denver-Aurora, CO                                Denver            2629980
# 220 Detroit-Warren-Ann Arbor, MI                     Detroit           5456428
# 288 Houston-The Woodlands, TX                        Houston           4878216
# 348 Los Angeles-Long Beach, CA                       Los Angeles      12365627
# 370 Miami-Fort Lauderdale-Port St. Lucie, FL         Miami             5475847
# 378 Minneapolis-St. Paul, MN-WI                      Minneapolis       3335000
# 408 New York-Newark, NY-NJ-CT-PA                     New York         21491898
# 428 Philadelphia-Reading-Camden, PA-NJ-DE-MD         Philadelphia      6688798
# 488 San Jose-San Francisco-Oakland, CA               San Francisco     7656194
# 500 Seattle-Tacoma, WA                               Seattle           3775744
# 548 Washington-Baltimore-Arlington, DC-MD-VA-WV-PA   Washington        7981257
#
#                                                                     TotalHousing00  \
# CSA CSA_name                                         CSA_short
# 122 Atlanta--Athens-Clarke County--Sandy Springs, GA Atlanta               1853158
# 148 Boston-Worcester-Providence, MA-RI-NH-CT         Boston                3135867
# 176 Chicago-Naperville, IL-IN-WI                     Chicago               1516964
# 206 Dallas-Fort Worth, TX-OK                         Dallas                2180002
# 216 Denver-Aurora, CO                                Denver                1068646
# 220 Detroit-Warren-Ann Arbor, MI                     Detroit               2208124
# 288 Houston-The Woodlands, TX                        Houston               1865805
# 348 Los Angeles-Long Beach, CA                       Los Angeles           4240393
# 370 Miami-Fort Lauderdale-Port St. Lucie, FL         Miami                 2379888
# 378 Minneapolis-St. Paul, MN-WI                      Minneapolis           1312902
# 408 New York-Newark, NY-NJ-CT-PA                     New York              8341615
# 428 Philadelphia-Reading-Camden, PA-NJ-DE-MD         Philadelphia          2740528
# 488 San Jose-San Francisco-Oakland, CA               San Francisco         2856934
# 500 Seattle-Tacoma, WA                               Seattle               1564957
# 548 Washington-Baltimore-Arlington, DC-MD-VA-WV-PA   Washington            3204298
#
#                                                                     TotalPOP17  \
# CSA CSA_name                                         CSA_short
# 122 Atlanta--Athens-Clarke County--Sandy Springs, GA Atlanta           6555956
# 148 Boston-Worcester-Providence, MA-RI-NH-CT         Boston            8233270
# 176 Chicago-Naperville, IL-IN-WI                     Chicago           4690448
# 206 Dallas-Fort Worth, TX-OK                         Dallas            7811847
# 216 Denver-Aurora, CO                                Denver            3447033
# 220 Detroit-Warren-Ann Arbor, MI                     Detroit           5336286
# 288 Houston-The Woodlands, TX                        Houston           7093190
# 348 Los Angeles-Long Beach, CA                       Los Angeles      13353907
# 370 Miami-Fort Lauderdale-Port St. Lucie, FL         Miami             6828241
# 378 Minneapolis-St. Paul, MN-WI                      Minneapolis       3946533
# 408 New York-Newark, NY-NJ-CT-PA                     New York         22994151
# 378 Minneapolis-St. Paul, MN-WI                      Minneapolis        2063585
# 408 New York-Newark, NY-NJ-CT-PA                     New York          10420967
# 428 Philadelphia-Reading-Camden, PA-NJ-DE-MD         Philadelphia       3219678
# 488 San Jose-San Francisco-Oakland, CA               San Francisco      4233345
# 500 Seattle-Tacoma, WA                               Seattle            2249725
# 548 Washington-Baltimore-Arlington, DC-MD-VA-WV-PA   Washington         4731047

# %%
CSAs_00_17['Pop_NET00-17'] = CSAs_00_17['TotalPOP17'] - CSAs_00_17['TotalPop00']
CSAs_00_17['Pop_%00-17'] = (CSAs_00_17['TotalPOP17'] - CSAs_00_17['TotalPop00']) \
                           / CSAs_00_17['TotalPop00']

CSAs_00_17['hu_NET00-17'] = CSAs_00_17['TotalHousing17'] - CSAs_00_17['TotalHousing00']
CSAs_00_17['hu_%00-17'] = (CSAs_00_17['TotalHousing17'] - CSAs_00_17['TotalHousing00']) \
                           / CSAs_00_17['TotalHousing00']

CSAs_00_17['emp_NET00-17'] = CSAs_00_17['Total_emp17'] - CSAs_00_17['Total_emp00']
CSAs_00_17['emp_%00-17'] = (CSAs_00_17['Total_emp17'] - CSAs_00_17['Total_emp00']) \
                           / CSAs_00_17['Total_emp00']

print(CSAs_00_17.shape)
print(CSAs_00_17.dtypes)
CSAs_00_17
# Out:
# (15, 12)
# TotalPop00          int64
# TotalHousing00      int64
# TotalPOP17          int64
# TotalHousing17      int64
# Total_emp00         int64
# Total_emp17         int64
# Pop_NET00-17        int64
# Pop_%00-17        float64
# hu_NET00-17         int64
# hu_%00-17         float64
# emp_NET00-17        int64
# emp_%00-17        float64
# dtype: object
#                                                                     TotalPop00  \
# CSA CSA_name                                         CSA_short
# 122 Atlanta--Athens-Clarke County--Sandy Springs, GA Atlanta           4778990
# 148 Boston-Worcester-Providence, MA-RI-NH-CT         Boston            7630016
# 176 Chicago-Naperville, IL-IN-WI                     Chicago           4088612
# 206 Dallas-Fort Worth, TX-OK                         Dallas            5565005
# 216 Denver-Aurora, CO                                Denver            2629980
# 220 Detroit-Warren-Ann Arbor, MI                     Detroit           5456428
# 288 Houston-The Woodlands, TX                        Houston           4878216
# 348 Los Angeles-Long Beach, CA                       Los Angeles      12365627
# 370 Miami-Fort Lauderdale-Port St. Lucie, FL         Miami             5475847
# 378 Minneapolis-St. Paul, MN-WI                      Minneapolis       3335000
# 408 New York-Newark, NY-NJ-CT-PA                     New York         21491898
# 428 Philadelphia-Reading-Camden, PA-NJ-DE-MD         Philadelphia      6688798
# 488 San Jose-San Francisco-Oakland, CA               San Francisco     7656194
# 500 Seattle-Tacoma, WA                               Seattle           3775744
# 548 Washington-Baltimore-Arlington, DC-MD-VA-WV-PA   Washington        7981257
#
#                                                                     TotalHousing00  \
# CSA CSA_name                                         CSA_short
# 122 Atlanta--Athens-Clarke County--Sandy Springs, GA Atlanta               1853158
# 148 Boston-Worcester-Providence, MA-RI-NH-CT         Boston                3135867
# 176 Chicago-Naperville, IL-IN-WI                     Chicago               1516964
# 206 Dallas-Fort Worth, TX-OK                         Dallas                2180002
# 548 Washington-Baltimore-Arlington, DC-MD-VA-WV-PA   Washington      0.196126
#
#                                                                     emp_NET00-17  \
# CSA CSA_name                                         CSA_short
# 122 Atlanta--Athens-Clarke County--Sandy Springs, GA Atlanta              431411
# 148 Boston-Worcester-Providence, MA-RI-NH-CT         Boston               285154
# 176 Chicago-Naperville, IL-IN-WI                     Chicago              211332
# 206 Dallas-Fort Worth, TX-OK                         Dallas               740105
# 216 Denver-Aurora, CO                                Denver               265303
# 220 Detroit-Warren-Ann Arbor, MI                     Detroit             -218854
# 288 Houston-The Woodlands, TX                        Houston              696232
# 348 Los Angeles-Long Beach, CA                       Los Angeles          483737
# 370 Miami-Fort Lauderdale-Port St. Lucie, FL         Miami                465689
# 378 Minneapolis-St. Paul, MN-WI                      Minneapolis          184785
# 408 New York-Newark, NY-NJ-CT-PA                     New York             938244
# 428 Philadelphia-Reading-Camden, PA-NJ-DE-MD         Philadelphia         150728
# 488 San Jose-San Francisco-Oakland, CA               San Francisco        370016
# 500 Seattle-Tacoma, WA                               Seattle              385369
# 548 Washington-Baltimore-Arlington, DC-MD-VA-WV-PA   Washington           634463
#
#                                                                     emp_%00-17
# CSA CSA_name                                         CSA_short
# 122 Atlanta--Athens-Clarke County--Sandy Springs, GA Atlanta          0.178760
# 148 Boston-Worcester-Providence, MA-RI-NH-CT         Boston           0.074359
# 176 Chicago-Naperville, IL-IN-WI                     Chicago          0.114422
# 206 Dallas-Fort Worth, TX-OK                         Dallas           0.260186
# 216 Denver-Aurora, CO                                Denver           0.185949
# 220 Detroit-Warren-Ann Arbor, MI                     Detroit         -0.086456
# 288 Houston-The Woodlands, TX                        Houston          0.306468
# 348 Los Angeles-Long Beach, CA                       Los Angeles      0.087864
# 370 Miami-Fort Lauderdale-Port St. Lucie, FL         Miami            0.206531
# 378 Minneapolis-St. Paul, MN-WI                      Minneapolis      0.098353
# 408 New York-Newark, NY-NJ-CT-PA                     New York         0.098942
# 428 Philadelphia-Reading-Camden, PA-NJ-DE-MD         Philadelphia     0.049114
# 488 San Jose-San Francisco-Oakland, CA               San Francisco    0.095776
# 500 Seattle-Tacoma, WA                               Seattle          0.206704
# 548 Washington-Baltimore-Arlington, DC-MD-VA-WV-PA   Washington       0.154876

# %% [markdown]
# ### Exporting to .csv

# %%
CSAs_00_17.to_csv('exports/CSA_popHouEmp_00_17_1.csv')

# %% [markdown]
# ----
# # Housing / Jobs Balance: County level for mapping

# %% [markdown]
# ### Merging with geo

# %%
# merging with geo data to get CSA's
ALL_co00_17_2 = ALL_co00_17.iloc[:,:-6].reset_index()

Balance_CO = ALL_co00_17_2.merge(geo, on='STCO').set_index('County_name')
Balance_CO = Balance_CO.drop(['Name', 'TotalPop00', 'TotalPOP17'], axis=1)
Balance_CO = Balance_CO.reset_index().set_index(['STCO', 'County_name'])

print(Balance_CO.shape)
Balance_CO.head()
# Out:
# (269, 6)
#                     TotalHousing00  TotalHousing17  Total_emp00  Total_emp17  \
# STCO  County_name
# 06001 Alameda               540183          606052       697215       772071
# 06013 Contra Costa          354577          414007       337924       366799
# 06037 Los Angeles          3270909         3542636      4110915      4394364
# 06041 Marin                 104990          113126       112454       115421
# 06055 Napa                   48554           55847        60552        76765
#
#                     CSA                            CSA_name
# STCO  County_name
# 06001 Alameda       488  San Jose-San Francisco-Oakland, CA
# 06013 Contra Costa  488  San Jose-San Francisco-Oakland, CA
# 06037 Los Angeles   348          Los Angeles-Long Beach, CA
# 06041 Marin         488  San Jose-San Francisco-Oakland, CA
# 06055 Napa          488  San Jose-San Francisco-Oakland, CA

# %%
Balance_CO.dtypes
# Out:
# TotalHousing00     int64
# TotalHousing17     int64
# Total_emp00        int64
# Total_emp17        int64
# CSA                int64
# CSA_name          object
# dtype: object

# %% [markdown]
# ## Calculating Balance for years 2000, 2017

# %%
Balance_CO['housing/jobs2017'] = Balance_CO['TotalHousing17'] / Balance_CO['Total_emp17']
Balance_CO['housing/jobs2000'] = Balance_CO['TotalHousing00'] / Balance_CO['Total_emp00']

print(Balance_CO.shape)
Balance_CO.head()
# Out:
# (269, 8)
#                     TotalHousing00  TotalHousing17  Total_emp00  Total_emp17  \
# STCO  County_name
# 06001 Alameda               540183          606052       697215       772071
# 06013 Contra Costa          354577          414007       337924       366799
# 06037 Los Angeles          3270909         3542636      4110915      4394364
# 06041 Marin                 104990          113126       112454       115421
# 06055 Napa                   48554           55847        60552        76765
#
#                     CSA                            CSA_name  housing/jobs2017  \
# STCO  County_name
# 06001 Alameda       488  San Jose-San Francisco-Oakland, CA          0.784969
# 06013 Contra Costa  488  San Jose-San Francisco-Oakland, CA          1.128703
# 06037 Los Angeles   348          Los Angeles-Long Beach, CA          0.806177
# 06041 Marin         488  San Jose-San Francisco-Oakland, CA          0.980116
# 06055 Napa          488  San Jose-San Francisco-Oakland, CA          0.727506
#
#                     housing/jobs2000
# STCO  County_name
# 06001 Alameda               0.774772
# 06013 Contra Costa          1.049280
# 06037 Los Angeles           0.795664
# 06041 Marin                 0.933626
# 06055 Napa                  0.801856

# %%
print("Housing/Jobs Balance 2000 for all counties: {:.2f}".format( 
      Balance_CO['TotalHousing00'].sum() / Balance_CO['Total_emp00'].sum()))
print("Housing/Jobs Balance 2017 for all counties: {:.2f}".format( 
      Balance_CO['TotalHousing17'].sum() / Balance_CO['Total_emp17'].sum()))
# Out:
# Housing/Jobs Balance 2000 for all counties: 0.82
# Housing/Jobs Balance 2017 for all counties: 0.86

# %%
Balance_CO['fromAve17'] = Balance_CO['housing/jobs2017'] - (Balance_CO['TotalHousing17'].sum() /
                                                            Balance_CO['Total_emp17'].sum())

Balance_CO['fromAve00'] = Balance_CO['housing/jobs2000'] - (Balance_CO['TotalHousing00'].sum() /
                                                            Balance_CO['Total_emp00'].sum())


Balance_CO.tail()
# Out:
#                    TotalHousing00  TotalHousing17  Total_emp00  Total_emp17  \
# STCO  County_name
# 54027 Hampshire             11185           14036         3735         3737
# 54037 Jefferson             17623           23181        12776        15440
# 55059 Kenosha               59989           70574        50952        66392
# 55093 Pierce                13493           16590         9283        10029
# 55109 St. Croix             24265           35823        25792        33508
#
#                    CSA                                        CSA_name  \
# STCO  County_name
# 54027 Hampshire    548  Washington-Baltimore-Arlington, DC-MD-VA-WV-PA
# 54037 Jefferson    548  Washington-Baltimore-Arlington, DC-MD-VA-WV-PA
# 55059 Kenosha      176                    Chicago-Naperville, IL-IN-WI
# 55093 Pierce       378                     Minneapolis-St. Paul, MN-WI
# 55109 St. Croix    378                     Minneapolis-St. Paul, MN-WI
#
#                    housing/jobs2017  housing/jobs2000  fromAve17  fromAve00
# STCO  County_name
# 54027 Hampshire            3.755954          2.994645   2.894442   2.171826
# 54037 Jefferson            1.501360          1.379383   0.639848   0.556564
# 55059 Kenosha              1.062990          1.177363   0.201478   0.354544
# 55093 Pierce               1.654203          1.453517   0.792691   0.630698
# 55109 St. Croix            1.069088          0.940796   0.207576   0.117977

# %%
Balance_CO['balance_ch'] = Balance_CO['housing/jobs2017'] - Balance_CO['housing/jobs2000']

Balance_CO.iloc[:,-6:].head()
# Out:
#                                               CSA_name  housing/jobs2017  \
# STCO  County_name
# 06001 Alameda       San Jose-San Francisco-Oakland, CA          0.784969
# 06013 Contra Costa  San Jose-San Francisco-Oakland, CA          1.128703
# 06037 Los Angeles           Los Angeles-Long Beach, CA          0.806177
# 06041 Marin         San Jose-San Francisco-Oakland, CA          0.980116
# 06055 Napa          San Jose-San Francisco-Oakland, CA          0.727506
#
#                     housing/jobs2000  fromAve17  fromAve00  balance_ch
# STCO  County_name
# 06001 Alameda               0.774772  -0.076543  -0.048046    0.010197
# 06013 Contra Costa          1.049280   0.267191   0.226461    0.079422
# 06037 Los Angeles           0.795664  -0.055335  -0.027154    0.010513
# 06041 Marin                 0.933626   0.118604   0.110807    0.046490
# 06055 Napa                  0.801856  -0.134006  -0.020963   -0.074350

# %% [markdown]
# ------

# %% [markdown]
# ## Reading in Geopgraphies df
# Created through notebook #0: **US_Metro_Comparison_Geographies**
#
# - **_Make sure to import GEOPANDAS_**

# %%
GEO = gpd.GeoDataFrame.from_file('exports/USmetros_rawNYC.shp')

GEO['STCO'] = GEO['STCO'].astype(str)
GEO['STCO'] = GEO['STCO'].apply(lambda x: '{0:0>5}'.format(x))

GEO['CSA_short'] = GEO['CSA_name'].str.split('-').str[0]
GEO['CSA_short'] = GEO['CSA_short'].replace(['San Jose'], ['San Francisco']) 

print(type(GEO))
print(GEO.shape)
print(GEO.geometry.name)
GEO.head()
# Out:
# <class 'geopandas.geodataframe.GeoDataFrame'>
# (274, 7)
# geometry
#      SHAPE_AREA   STCO    County_nam  CSA                            CSA_name  \
# 0  3.124167e+09  06001       Alameda  488  San Jose-San Francisco-Oakland, CA
# 1  3.158013e+09  06013  Contra Costa  488  San Jose-San Francisco-Oakland, CA
# 2  2.298070e+09  06041         Marin  488  San Jose-San Francisco-Oakland, CA
# 3  3.344885e+09  06055          Napa  488  San Jose-San Francisco-Oakland, CA
# 4  5.596080e+09  06069    San Benito  488  San Jose-San Francisco-Oakland, CA
#
#                                             geometry      CSA_short
# 0  POLYGON ((-13618345.0421 4551161.905000001, -1...  San Francisco
# 1  POLYGON ((-13628818.5334 4574539.895900004, -1...  San Francisco
# 2  (POLYGON ((-13694586.3189 4579361.395599999, -...  San Francisco
# 3  POLYGON ((-13652937.1333 4664335.483199999, -1...  San Francisco
# 4  POLYGON ((-13541348.2494 4424341.478500001, -1...  San Francisco

# %% [markdown]
# ## Merging Housing-Jobs data with .shp

# %%
Balance_geo = GEO.merge(Balance_CO, on='STCO')

Balance_geo = Balance_geo.drop(['CSA_y', 'CSA_name_y'], axis=1)
Balance_geo.rename(columns={'CSA_x':'CSA','CSA_name_x':'CSA_name'}, inplace=True)
Balance_geo = Balance_geo.set_index('CSA')

print(type(Balance_geo))
print(Balance_geo.shape)
print(Balance_geo.geometry.name)
Balance_geo.head()
# Out:
# <class 'geopandas.geodataframe.GeoDataFrame'>
# (268, 15)
# geometry
#        SHAPE_AREA   STCO    County_nam                            CSA_name  \
# CSA
# 488  3.124167e+09  06001       Alameda  San Jose-San Francisco-Oakland, CA
# 488  3.158013e+09  06013  Contra Costa  San Jose-San Francisco-Oakland, CA
# 488  2.298070e+09  06041         Marin  San Jose-San Francisco-Oakland, CA
# 488  3.344885e+09  06055          Napa  San Jose-San Francisco-Oakland, CA
# 488  5.596080e+09  06069    San Benito  San Jose-San Francisco-Oakland, CA
#
#                                               geometry      CSA_short  \
# CSA
# 488  POLYGON ((-13618345.0421 4551161.905000001, -1...  San Francisco
# 488  POLYGON ((-13628818.5334 4574539.895900004, -1...  San Francisco
# 488  (POLYGON ((-13694586.3189 4579361.395599999, -...  San Francisco
# 488  POLYGON ((-13652937.1333 4664335.483199999, -1...  San Francisco
# 488  POLYGON ((-13541348.2494 4424341.478500001, -1...  San Francisco
#
#      TotalHousing00  TotalHousing17  Total_emp00  Total_emp17  \
# CSA
# 488          540183          606052       697215       772071
# 488          354577          414007       337924       366799
# 488          104990          113126       112454       115421
# 488           48554           55847        60552        76765
# 488           16499           18876        15175        16977
#
#      housing/jobs2017  housing/jobs2000  fromAve17  fromAve00  balance_ch
# CSA
# 488          0.784969          0.774772  -0.076543  -0.048046    0.010197
# 488          1.128703          1.049280   0.267191   0.226461    0.079422
# 488          0.980116          0.933626   0.118604   0.110807    0.046490
# 488          0.727506          0.801856  -0.134006  -0.020963   -0.074350
# 488          1.111857          1.087249   0.250345   0.264430    0.024608

# %%
Balance_geo[Balance_geo['housing/jobs2000'] == 5.215504631886884]
# Out:
#        SHAPE_AREA   STCO County_nam           CSA_name  \
# CSA
# 216  9.524860e+09  08093       Park  Denver-Aurora, CO
#
#                                               geometry CSA_short  \
# CSA
# 216  POLYGON ((-11823262.3754 4736567.884499997, -1...    Denver
#
#      TotalHousing00  TotalHousing17  Total_emp00  Total_emp17  \
# CSA
# 216           10697           14562         2051         2481
#
#      housing/jobs2017  housing/jobs2000  fromAve17  fromAve00  balance_ch
# CSA
# 216          5.869407          5.215505   5.007895   4.392686    0.653903

# %%
CSAs = Balance_geo.groupby(['CSA', 'CSA_name']).count().reset_index().set_index('CSA')
CSAs = CSAs.iloc[:,:2]
CSAs.columns = ['CSA_name', 'numberCounties']

CSAs['CSA_short'] = CSAs['CSA_name'].str.split('-').str[0]
CSAs['CSA_short'] = CSAs['CSA_short'].replace(['San Jose'], ['San Francisco']) 

print(list(CSAs.index))
print(CSAs.shape)
CSAs
# Out:
# ['122', '148', '176', '206', '216', '220', '288', '348', '370', '378', '408', '428', '488', '500', '548']
# (15, 3)
#                                              CSA_name  numberCounties  \
# CSA
# 122  Atlanta--Athens-Clarke County--Sandy Springs, GA              39
# 148          Boston-Worcester-Providence, MA-RI-NH-CT              19
# 176                      Chicago-Naperville, IL-IN-WI              18
# 206                          Dallas-Fort Worth, TX-OK              20
# 216                                 Denver-Aurora, CO              11
# 220                      Detroit-Warren-Ann Arbor, MI              10
# 288                         Houston-The Woodlands, TX              14
# 348                        Los Angeles-Long Beach, CA               2
# 370          Miami-Fort Lauderdale-Port St. Lucie, FL               7
# 378                       Minneapolis-St. Paul, MN-WI              21
# 408                      New York-Newark, NY-NJ-CT-PA              30
# 428          Philadelphia-Reading-Camden, PA-NJ-DE-MD              16
# 488                San Jose-San Francisco-Oakland, CA              12
# 500                                Seattle-Tacoma, WA               9
# 548    Washington-Baltimore-Arlington, DC-MD-VA-WV-PA              40
#
#          CSA_short
# CSA
# 122        Atlanta
# 148         Boston
# 176        Chicago
# 206         Dallas
# 216         Denver
# 220        Detroit
# 288        Houston
# 348    Los Angeles
# 370          Miami
# 378    Minneapolis
# 408       New York
# 428   Philadelphia
# 488  San Francisco
# 500        Seattle
# 548     Washington

# %%
# for plotting in the order I want to

CSAs_sorted = ['500','216', '220','378','148',
               '488','176',  '122','548','408',
               '348', '206', '288', '428', '370']

# %% [markdown]
# ## General layout for plotting CSA's by counties

# %%
fig = pl.figure(figsize=(40,24))
sns.set_style("whitegrid")

for k in range(len(CSAs_sorted)):
    ax = fig.add_subplot(3,5,k+1)
    Balance_geo[Balance_geo.index == CSAs_sorted[k]].plot(ax=ax, edgecolor='k',
                                    color='lightgrey',linewidth=.6, alpha=0.6);
    ax.set_title('{} Region'.format(CSAs['CSA_short'][CSAs_sorted[k]]), fontsize=36, y=1.015)
    ax.grid(linewidth=0.25)
    ax.axis('off')
    
plt.savefig("exports/CSAsLayout.pdf", transparent=True)

# %% [markdown]
# ## Plotting Housing-Jobs Balance for all CSA's - county level
# - 2010
# - 2017
# - change 10-17

# %%
Balance_geo.max()
# Out:
# SHAPE_AREA                                             1.80434e+10
# STCO                                                         55109
# County_nam                                                  Wright
# CSA_name            Washington-Baltimore-Arlington, DC-MD-VA-WV-PA
# CSA_short                                               Washington
# TotalHousing00                                             3270909
# TotalHousing17                                             3542636
# Total_emp00                                                4110915
# Total_emp17                                                4394364
# housing/jobs2017                                           5.86941
# housing/jobs2000                                            5.2155
# fromAve17                                                   5.0079
# fromAve00                                                  4.39269
# balance_ch                                                 1.05261
# dtype: object

# %%
print(Balance_geo['housing/jobs2000'].min())
print(Balance_geo['housing/jobs2000'].max())
print(Balance_geo['housing/jobs2000'].mean())
# Out:
# 0.3254804711717297
# 5.215504631886884
# 1.157257884002568

# %%
print(Balance_CO['TotalHousing17'].sum() / Balance_CO['Total_emp17'].sum())
print(Balance_CO['TotalHousing00'].sum() / Balance_CO['Total_emp00'].sum())
# Out:
# 0.8615120017905975
# 0.8228189501229377

# %%
Balance_geo[Balance_geo['CSA_name'] == 'Dallas-Fort Worth, TX-OK']['housing/jobs2000']
# Out:
# CSA
# 206    1.359054
# 206    1.162549
# 206    1.194370
# 206    0.545636
# 206    1.408415
# 206    1.175846
# 206    1.089083
# 206    2.283327
# 206    2.025766
# 206    1.284942
# 206    1.299496
# 206    1.422567
# 206    1.219459
# 206    1.116632
# 206    1.676813
# 206    1.884864
# 206    1.138629
# 206    0.756118
# 206    0.805695
# 206    1.574245
# Name: housing/jobs2000, dtype: float64

# %% [markdown]
# ## Balance 2000

# %%
fig = pl.figure(figsize=(40,24))
sns.set_style("whitegrid")
vmin, vmax = Balance_geo['fromAve00'].min(), Balance_geo['fromAve00'].max()

cax = fig.add_axes([0.92, 0.13, 0.018, .77])
sm = plt.cm.ScalarMappable(cmap='coolwarm', norm=plt.Normalize(vmin=vmin, vmax=vmax))
sm._A = []
fig.colorbar(sm, cax=cax, orientation='vertical')


for k in range(len(CSAs_sorted)):
    ax = fig.add_subplot(3,5,k+1)
    Balance_geo[Balance_geo.index == CSAs_sorted[k]].plot(ax=ax, column='fromAve00', scheme='quantiles',
                                    cmap='coolwarm', edgecolor='k',linewidth=.6, alpha=0.8);
    ax.set_title('{} Region'.format(CSAs['CSA_short'][CSAs_sorted[k]]), fontsize=36, y=1.015)
    ax.grid(linewidth=0.25)
    ax.axis('off')
    
plt.savefig("exports/balance00.pdf", transparent=True)

# %% [markdown]
# ## Balance 2017

# %%
fig = pl.figure(figsize=(40,24))
sns.set_style("whitegrid")
vmin, vmax = Balance_geo['housing/jobs2000'].min(), Balance_geo['housing/jobs2000'].max()

cax = fig.add_axes([0.92, 0.13, 0.018, .77])
sm = plt.cm.ScalarMappable(cmap='coolwarm', norm=plt.Normalize(vmin=vmin, vmax=vmax))
sm._A = []
fig.colorbar(sm, cax=cax, orientation='vertical', values=None)


# 8 choroplets of seven major felonies + total
for k in range(len(CSAs_sorted)):
    ax = fig.add_subplot(3,5,k+1)
    Balance_geo[Balance_geo.index == CSAs_sorted[k]].plot(ax=ax, column='fromAve17',
                                          cmap='coolwarm', edgecolor='k',linewidth=.6, alpha=0.8);
    ax.set_title('{} Region'.format(CSAs['CSA_short'][CSAs_sorted[k]]), fontsize=36, y=1.015)
    ax.grid(linewidth=0.25)
    ax.axis('off')
    
plt.savefig("exports/balance17.pdf", transparent=True)

# %% [markdown]
# ## Balance change 00 vs 17

# %%
fig = pl.figure(figsize=(40,24))
sns.set_style("whitegrid")
vmin, vmax = 0, 6

cax = fig.add_axes([0.92, 0.13, 0.018, .77])
sm = plt.cm.ScalarMappable(cmap='coolwarm', norm=plt.Normalize(vmin=vmin, vmax=vmax))
sm._A = []
fig.colorbar(sm, cax=cax, orientation='vertical', values=None)


# 8 choroplets of seven major felonies + total
for k in range(len(CSAs_sorted)):
    ax = fig.add_subplot(3,5,k+1)
    Balance_geo[Balance_geo.index == CSAs_sorted[k]].plot(ax=ax, column='balance_ch',
                                          cmap='coolwarm', edgecolor='k',linewidth=.6, alpha=0.8);
    ax.set_title('{} Region'.format(CSAs['CSA_short'][CSAs_sorted[k]]), fontsize=36, y=1.015)
    ax.grid(linewidth=0.25)
    ax.axis('off')
    
plt.savefig("exports/balance_ch00-17.pdf", transparent=True)

# %% [markdown]
# ------
#
# ## CSA's

# %%
HouJobs = pd.read_excel('BPS_HousingPermits_analysis.xlsx', 
                        sheet_name='HousingJobs_Balance')[:-2].set_index('Name')

HouJobs['housing / jobs 2010'] = HouJobs['housing / jobs 2010'].round(decimals=2)
HouJobs['housing / jobs 2016'] = HouJobs['housing / jobs 2016'].round(decimals=2)
HouJobs['housing / jobs 10-16 NET'] = HouJobs['housing / jobs 10-16 NET'].round(decimals=2)

HouJobs['CSA'] = HouJobs['CSA'].astype(int)

print(HouJobs .shape)
HouJobs
# Out:
# (15, 5)
#                CSA                                          FullName  \
# Name
# New York       408                      New York-Newark, NY-NJ-CT-PA
# Los Angeles    348                        Los Angeles-Long Beach, CA
# Chicago        176                      Chicago-Naperville, IL-IN-WI
# Washington     548    Washington-Baltimore-Arlington, DC-MD-VA-WV-PA
# San Francisco  488                San Jose-San Francisco-Oakland, CA
# Boston         148          Boston-Worcester-Providence, MA-RI-NH-CT
# Dallas         206                          Dallas-Fort Worth, TX-OK
# Philadelphia   428          Philadelphia-Reading-Camden, PA-NJ-DE-MD
# Houston        288                         Houston-The Woodlands, TX
# Miami          370          Miami-Fort Lauderdale-Port St. Lucie, FL
# Atlanta        122  Atlanta--Athens-Clarke County--Sandy Springs, GA
# Detroit        220                      Detroit-Warren-Ann Arbor, MI
# Seattle        500                                Seattle-Tacoma, WA
# Minneapolis    378                       Minneapolis-St. Paul, MN-WI
# Denver         216                                 Denver-Aurora, CO
#
#                housing / jobs 2010  housing / jobs 2016  \
# Name
# New York                      0.92                 0.84
# Los Angeles                   0.68                 0.60
# Chicago                       0.42                 0.39
# Washington                    0.84                 0.80
# San Francisco                 0.92                 0.77
# Boston                        0.92                 0.84
# Dallas                        0.92                 0.81
# Philadelphia                  0.97                 0.93
# Houston                       0.94                 0.86
# Miami                         1.21                 1.05
# Atlanta                       1.02                 0.90
# Detroit                       1.15                 1.02
# Seattle                       0.97                 0.86
# Minneapolis                   0.84                 0.77
# Denver                        0.93                 0.80
#
#                housing / jobs 10-16 NET
# Name
# New York                          -0.07
# Los Angeles                       -0.08
# Chicago                           -0.03
# Washington                        -0.04
# San Francisco                     -0.14
# Boston                            -0.08
# Dallas                            -0.11
# Philadelphia                      -0.04
# Houston                           -0.08
# Miami                             -0.16
# Atlanta                           -0.13
# Detroit                           -0.13
# Seattle                           -0.11
# Minneapolis                       -0.07
# Denver                            -0.13

# %% [markdown]
# ----
# # Census tracts
# ## Downloaded + cleaned data for years 2000-2017
# _Downloaded and munged by Dara Goldberg_

# %%
AlltractsGeo = pd.read_excel("data/ALL Tract Geo Codes.xlsx")
print(AlltractsGeo.shape)
AlltractsGeo.head()
# Out:
# (28066, 5)
#          TRACT  CSA   STCO  ST  CO
# 0  10001041600  428  10001  10   1
# 1  10003001300  428  10003  10   3
# 2  10003011100  428  10003  10   3
# 3  10003011600  428  10003  10   3
# 4  10003013200  428  10003  10   3

# %% [markdown]
# # 2 - Data cleaning and munging

# %% [markdown]
# ## Total by Industry by Regions
# ## Total by Industry by Regions - City to region ratio / comparison
# ## Change by Industry by Regions
# ## Change by Industry by Regions - City to region ratio / comparison
# ## Wages + change by Region (city/region)
